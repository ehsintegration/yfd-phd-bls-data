# %%
import os

try:
    os.mkdir("../PLOTS/COMP_BOX_GENDER")
except:
    print("COMP_BOX_GENDER dir exists.")

#For testing, leave commented
swivel = 1
swivel_order = [2, 1, 7, 3, 16, 6, 12, 9, 10, 4, 5, 15, 8, 14, 20, 0, 22, 13, 19, 11, 18, 21, 17]

desired_file_prefix = "F_GENDER" 

normalize_data=True

lnconvert=False
# Out:
# COMP_BOX_GENDER dir exists.

# %%
by_year = 1

# ##################### FATAL

# per year
#
desired_file_prefix = "F_GENDER" 
male_global_y_soc1 = []
female_global_y_soc1 = []

for year in range(0,8):       
    desired_file_output = "./COMP_BOX_GENDER/F_GENDER_" + str(2011+year) + "_"    
    # %run ./box-analysis-code-gender.ipynb
    
f_male_global_y_soc1 = male_global_y_soc1
f_female_global_y_soc1 = female_global_y_soc1
    
# ##################### NON-FATAL

# per year
#
desired_file_prefix = "NF_GENDER" 
male_global_y_soc1 = []
female_global_y_soc1 = []

for year in range(0,8):       
    desired_file_output = "./COMP_BOX_GENDER/NF_GENDER_" + str(2011+year) + "_"    
    # %run ./box-analysis-code-gender.ipynb
    
nf_male_global_y_soc1 = male_global_y_soc1
nf_female_global_y_soc1 = female_global_y_soc1
# Out:
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 1, 12, 7, 16, 5, 3, 9, 6, 10, 8, 15, 4, 14, 20, 0, 22, 19, 13, 18, 11, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 3, 4, 6, 7, 1, 16, 9, 20, 12, 10, 8, 15, 14, 0, 5, 13, 22, 19, 11, 18, 21, 17]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 7, 1, 10, 6, 16, 12, 3, 9, 8, 4, 15, 14, 5, 20, 0, 22, 13, 19, 11, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 6, 22, 1, 20, 7, 3, 9, 10, 12, 16, 15, 4, 8, 0, 14, 5, 13, 19, 21, 18, 11, 17]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 7, 1, 16, 6, 3, 12, 9, 10, 5, 14, 15, 4, 8, 20, 0, 22, 13, 19, 11, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 3, 1, 7, 16, 5, 10, 12, 9, 14, 13, 15, 8, 0, 6, 4, 20, 19, 18, 21, 11, 17, 22]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 1, 7, 10, 6, 12, 16, 3, 4, 9, 8, 15, 5, 14, 20, 0, 22, 13, 11, 19, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 3, 6, 7, 9, 1, 10, 16, 12, 8, 20, 14, 0, 15, 5, 4, 13, 11, 18, 22, 19, 21, 17]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 7, 1, 16, 6, 12, 3, 4, 10, 9, 5, 15, 14, 8, 0, 20, 22, 13, 19, 11, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 3, 4, 22, 7, 1, 14, 6, 20, 16, 12, 9, 15, 0, 5, 10, 8, 13, 19, 11, 18, 21, 17]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 1, 16, 7, 10, 6, 3, 9, 12, 4, 5, 15, 14, 8, 20, 0, 22, 13, 19, 11, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 3, 6, 1, 7, 4, 16, 0, 14, 9, 5, 15, 8, 10, 12, 13, 20, 18, 21, 11, 19, 22, 17]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 1, 7, 3, 6, 16, 4, 9, 10, 12, 8, 15, 5, 0, 20, 14, 22, 19, 13, 11, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [3, 6, 2, 4, 7, 1, 9, 16, 8, 20, 12, 14, 0, 15, 10, 13, 5, 22, 19, 11, 21, 17, 18]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 7, 1, 16, 3, 6, 5, 9, 10, 4, 12, 15, 0, 14, 8, 20, 22, 19, 13, 11, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 3, 19, 16, 7, 1, 14, 9, 20, 0, 6, 15, 4, 5, 12, 8, 10, 13, 22, 21, 11, 18, 17]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# NF_GENDER_GNX_NR_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 4, 8, 7, 15, 5, 14, 9, 16, 12, 18, 17, 20, 13, 10, 21, 19, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 2, 3, 1, 6, 4, 8, 0, 16, 7, 14, 15, 5, 9, 18, 12, 17, 20, 13, 21, 10, 19, 11]
# NF_GENDER_GNX_NR
# 00 NF_GENDER_GNX_NR
# 11 NF_GENDER_GNX_NR
# 13 NF_GENDER_GNX_NR
# 15 NF_GENDER_GNX_NR
# 17 NF_GENDER_GNX_NR
# 19 NF_GENDER_GNX_NR
# 21 NF_GENDER_GNX_NR
# 23 NF_GENDER_GNX_NR
# 25 NF_GENDER_GNX_NR
# 27 NF_GENDER_GNX_NR
# 29 NF_GENDER_GNX_NR
# 31 NF_GENDER_GNX_NR
# 33 NF_GENDER_GNX_NR
# 35 NF_GENDER_GNX_NR
# 37 NF_GENDER_GNX_NR
# 39 NF_GENDER_GNX_NR
# 41 NF_GENDER_GNX_NR
# 43 NF_GENDER_GNX_NR
# 45 NF_GENDER_GNX_NR
# 47 NF_GENDER_GNX_NR
# 49 NF_GENDER_GNX_NR
# 51 NF_GENDER_GNX_NR
# 53 NF_GENDER_GNX_NR
# 55 NF_GENDER_GNX_NR
# Suggested swivel order
# [1, 2, 3, 4, 5, 6, 7, 8, 12, 15, 22, 0, 9, 14, 13, 16, 17, 20, 18, 19, 10, 11, 21]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# NF_GENDER_GNX_NR_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 4, 7, 8, 15, 5, 14, 9, 16, 12, 18, 20, 17, 13, 10, 19, 21, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 2, 3, 8, 6, 1, 4, 0, 16, 7, 15, 14, 18, 5, 9, 12, 20, 17, 13, 10, 19, 21, 11]
# NF_GENDER_GNX_NR
# 00 NF_GENDER_GNX_NR
# 11 NF_GENDER_GNX_NR
# 13 NF_GENDER_GNX_NR
# 15 NF_GENDER_GNX_NR
# 17 NF_GENDER_GNX_NR
# 19 NF_GENDER_GNX_NR
# 21 NF_GENDER_GNX_NR
# 23 NF_GENDER_GNX_NR
# 25 NF_GENDER_GNX_NR
# 27 NF_GENDER_GNX_NR
# 29 NF_GENDER_GNX_NR
# 31 NF_GENDER_GNX_NR
# 33 NF_GENDER_GNX_NR
# 35 NF_GENDER_GNX_NR
# 37 NF_GENDER_GNX_NR
# 39 NF_GENDER_GNX_NR
# 41 NF_GENDER_GNX_NR
# 43 NF_GENDER_GNX_NR
# 45 NF_GENDER_GNX_NR
# 47 NF_GENDER_GNX_NR
# 49 NF_GENDER_GNX_NR
# 51 NF_GENDER_GNX_NR
# 53 NF_GENDER_GNX_NR
# 55 NF_GENDER_GNX_NR
# Suggested swivel order
# [1, 2, 3, 4, 5, 6, 7, 8, 22, 0, 14, 15, 16, 9, 12, 10, 20, 17, 11, 13, 18, 19, 21]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# NF_GENDER_GNX_NR_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 4, 7, 15, 8, 5, 14, 9, 16, 12, 18, 13, 20, 17, 10, 19, 21, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 3, 2, 6, 8, 4, 1, 0, 16, 7, 14, 15, 18, 5, 9, 20, 12, 17, 13, 19, 21, 11, 10]
# NF_GENDER_GNX_NR
# 00 NF_GENDER_GNX_NR
# 11 NF_GENDER_GNX_NR
# 13 NF_GENDER_GNX_NR
# 15 NF_GENDER_GNX_NR
# 17 NF_GENDER_GNX_NR
# 19 NF_GENDER_GNX_NR
# 21 NF_GENDER_GNX_NR
# 23 NF_GENDER_GNX_NR
# 25 NF_GENDER_GNX_NR
# 27 NF_GENDER_GNX_NR
# 29 NF_GENDER_GNX_NR
# 31 NF_GENDER_GNX_NR
# 33 NF_GENDER_GNX_NR
# 35 NF_GENDER_GNX_NR
# 37 NF_GENDER_GNX_NR
# 39 NF_GENDER_GNX_NR
# 41 NF_GENDER_GNX_NR
# 43 NF_GENDER_GNX_NR
# 45 NF_GENDER_GNX_NR
# 47 NF_GENDER_GNX_NR
# 49 NF_GENDER_GNX_NR
# 51 NF_GENDER_GNX_NR
# 53 NF_GENDER_GNX_NR
# 55 NF_GENDER_GNX_NR
# Suggested swivel order
# [1, 2, 3, 4, 6, 8, 17, 22, 0, 12, 14, 7, 15, 16, 5, 9, 10, 20, 13, 11, 18, 19, 21]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# NF_GENDER_GNX_NR_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 7, 8, 4, 15, 14, 5, 9, 16, 12, 18, 20, 17, 13, 10, 19, 21, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 2, 3, 6, 1, 8, 0, 4, 16, 15, 7, 14, 5, 9, 18, 12, 20, 17, 13, 10, 19, 21, 11]
# NF_GENDER_GNX_NR
# 00 NF_GENDER_GNX_NR
# 11 NF_GENDER_GNX_NR
# 13 NF_GENDER_GNX_NR
# 15 NF_GENDER_GNX_NR
# 17 NF_GENDER_GNX_NR
# 19 NF_GENDER_GNX_NR
# 21 NF_GENDER_GNX_NR
# 23 NF_GENDER_GNX_NR
# 25 NF_GENDER_GNX_NR
# 27 NF_GENDER_GNX_NR
# 29 NF_GENDER_GNX_NR
# 31 NF_GENDER_GNX_NR
# 33 NF_GENDER_GNX_NR
# 35 NF_GENDER_GNX_NR
# 37 NF_GENDER_GNX_NR
# 39 NF_GENDER_GNX_NR
# 41 NF_GENDER_GNX_NR
# 43 NF_GENDER_GNX_NR
# 45 NF_GENDER_GNX_NR
# 47 NF_GENDER_GNX_NR
# 49 NF_GENDER_GNX_NR
# 51 NF_GENDER_GNX_NR
# 53 NF_GENDER_GNX_NR
# 55 NF_GENDER_GNX_NR
# Suggested swivel order
# [0, 1, 2, 3, 4, 6, 8, 22, 7, 15, 12, 14, 5, 16, 9, 20, 17, 10, 13, 11, 18, 19, 21]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# NF_GENDER_GNX_NR_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 3, 4, 0, 8, 7, 15, 5, 14, 9, 16, 12, 18, 20, 13, 17, 10, 19, 21, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 2, 6, 1, 8, 4, 3, 0, 16, 15, 7, 14, 18, 5, 9, 12, 20, 13, 17, 10, 19, 21, 11]
# NF_GENDER_GNX_NR
# 00 NF_GENDER_GNX_NR
# 11 NF_GENDER_GNX_NR
# 13 NF_GENDER_GNX_NR
# 15 NF_GENDER_GNX_NR
# 17 NF_GENDER_GNX_NR
# 19 NF_GENDER_GNX_NR
# 21 NF_GENDER_GNX_NR
# 23 NF_GENDER_GNX_NR
# 25 NF_GENDER_GNX_NR
# 27 NF_GENDER_GNX_NR
# 29 NF_GENDER_GNX_NR
# 31 NF_GENDER_GNX_NR
# 33 NF_GENDER_GNX_NR
# 35 NF_GENDER_GNX_NR
# 37 NF_GENDER_GNX_NR
# 39 NF_GENDER_GNX_NR
# 41 NF_GENDER_GNX_NR
# 43 NF_GENDER_GNX_NR
# 45 NF_GENDER_GNX_NR
# 47 NF_GENDER_GNX_NR
# 49 NF_GENDER_GNX_NR
# 51 NF_GENDER_GNX_NR
# 53 NF_GENDER_GNX_NR
# 55 NF_GENDER_GNX_NR
# Suggested swivel order
# [0, 1, 2, 3, 4, 6, 7, 8, 22, 15, 14, 9, 16, 5, 12, 10, 20, 13, 18, 11, 19, 21, 17]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# NF_GENDER_GNX_NR_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 4, 7, 15, 8, 5, 14, 9, 16, 12, 18, 20, 17, 13, 10, 19, 21, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 2, 3, 8, 1, 4, 6, 0, 16, 15, 7, 14, 5, 9, 12, 20, 18, 13, 17, 19, 10, 11, 21]
# NF_GENDER_GNX_NR
# 00 NF_GENDER_GNX_NR
# 11 NF_GENDER_GNX_NR
# 13 NF_GENDER_GNX_NR
# 15 NF_GENDER_GNX_NR
# 17 NF_GENDER_GNX_NR
# 19 NF_GENDER_GNX_NR
# 21 NF_GENDER_GNX_NR
# 23 NF_GENDER_GNX_NR
# 25 NF_GENDER_GNX_NR
# 27 NF_GENDER_GNX_NR
# 29 NF_GENDER_GNX_NR
# 31 NF_GENDER_GNX_NR
# 33 NF_GENDER_GNX_NR
# 35 NF_GENDER_GNX_NR
# 37 NF_GENDER_GNX_NR
# 39 NF_GENDER_GNX_NR
# 41 NF_GENDER_GNX_NR
# 43 NF_GENDER_GNX_NR
# 45 NF_GENDER_GNX_NR
# 47 NF_GENDER_GNX_NR
# 49 NF_GENDER_GNX_NR
# 51 NF_GENDER_GNX_NR
# 53 NF_GENDER_GNX_NR
# 55 NF_GENDER_GNX_NR
# Suggested swivel order
# [1, 2, 3, 4, 6, 8, 22, 7, 0, 5, 14, 9, 16, 15, 10, 20, 12, 11, 13, 17, 18, 19, 21]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# NF_GENDER_GNX_NR_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 4, 7, 8, 15, 5, 14, 9, 16, 12, 18, 20, 13, 17, 10, 21, 19, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 2, 3, 6, 1, 8, 4, 0, 16, 7, 15, 14, 5, 9, 18, 12, 20, 13, 17, 19, 10, 11, 21]
# NF_GENDER_GNX_NR
# 00 NF_GENDER_GNX_NR
# 11 NF_GENDER_GNX_NR
# 13 NF_GENDER_GNX_NR
# 15 NF_GENDER_GNX_NR
# 17 NF_GENDER_GNX_NR
# 19 NF_GENDER_GNX_NR
# 21 NF_GENDER_GNX_NR
# 23 NF_GENDER_GNX_NR
# 25 NF_GENDER_GNX_NR
# 27 NF_GENDER_GNX_NR
# 29 NF_GENDER_GNX_NR
# 31 NF_GENDER_GNX_NR
# 33 NF_GENDER_GNX_NR
# 35 NF_GENDER_GNX_NR
# 37 NF_GENDER_GNX_NR
# 39 NF_GENDER_GNX_NR
# 41 NF_GENDER_GNX_NR
# 43 NF_GENDER_GNX_NR
# 45 NF_GENDER_GNX_NR
# 47 NF_GENDER_GNX_NR
# 49 NF_GENDER_GNX_NR
# 51 NF_GENDER_GNX_NR
# 53 NF_GENDER_GNX_NR
# 55 NF_GENDER_GNX_NR
# Suggested swivel order
# [0, 1, 2, 3, 4, 5, 6, 7, 8, 15, 22, 12, 16, 14, 13, 10, 9, 20, 17, 18, 19, 11, 21]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# NF_GENDER_GNX_NR_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F', 'NF_GENDER_GNX_NR'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 2, 6, 1, 0, 3, 4, 7, 8, 15, 5, 14, 9, 16, 12, 18, 20, 13, 17, 10, 19, 21, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 3, 6, 2, 1, 4, 8, 0, 16, 15, 7, 14, 5, 9, 18, 12, 20, 17, 13, 10, 19, 11, 21]
# NF_GENDER_GNX_NR
# 00 NF_GENDER_GNX_NR
# 11 NF_GENDER_GNX_NR
# 13 NF_GENDER_GNX_NR
# 15 NF_GENDER_GNX_NR
# 17 NF_GENDER_GNX_NR
# 19 NF_GENDER_GNX_NR
# 21 NF_GENDER_GNX_NR
# 23 NF_GENDER_GNX_NR
# 25 NF_GENDER_GNX_NR
# 27 NF_GENDER_GNX_NR
# 29 NF_GENDER_GNX_NR
# 31 NF_GENDER_GNX_NR
# 33 NF_GENDER_GNX_NR
# 35 NF_GENDER_GNX_NR
# 37 NF_GENDER_GNX_NR
# 39 NF_GENDER_GNX_NR
# 41 NF_GENDER_GNX_NR
# 43 NF_GENDER_GNX_NR
# 45 NF_GENDER_GNX_NR
# 47 NF_GENDER_GNX_NR
# 49 NF_GENDER_GNX_NR
# 51 NF_GENDER_GNX_NR
# 53 NF_GENDER_GNX_NR
# 55 NF_GENDER_GNX_NR
# Suggested swivel order
# [2, 3, 4, 6, 22, 1, 0, 15, 14, 7, 8, 16, 9, 5, 13, 20, 10, 12, 17, 18, 19, 11, 21]

# %% [markdown]
# # Male boxblots

# %%
### Creating pandas |dataframe from numpy array
#pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
pd_df = pd.DataFrame()

global_y_soc1 = male_global_y_soc1

for index in range(0,len(global_y_soc1)):
    pd_df[global_y_soc1[index][0]] = global_y_soc1[index][1]

#print(pd_df)

title = desired_file_prefix + " MALE boxplots"
plt.figure(title,figsize=(10, 10))
plt.title(title)

#plt.ylim(0.0, 0.15)

pd_df.boxplot()
plt.xticks(rotation = 90)
plt.tight_layout()

save_title = "../PLOTS/" + desired_file_output + title + ".png"
save_title = save_title.replace(",","")
save_title = save_title.replace(" ","_")
plt.savefig(save_title, dpi=100, bbox_inches='tight')
plt.savefig(save_title, dpi=100, bbox_inches='tight')

# %% [markdown]
# # Female boxplots

# %%
# Creating pandas |dataframe from numpy array
#pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
pd_df = pd.DataFrame()

global_y_soc1 = female_global_y_soc1

for index in range(0,len(global_y_soc1)):
    pd_df[global_y_soc1[index][0]] = global_y_soc1[index][1]

#print(pd_df)

title = desired_file_prefix + " FEMALE boxplots"
plt.figure(title,figsize=(10, 10))
plt.title(title)

#plt.ylim(0.0, 0.15)

pd_df.boxplot()
plt.xticks(rotation = 90)
plt.tight_layout()

save_title = "../PLOTS/" + desired_file_output + title + ".png"
save_title = save_title.replace(",","")
save_title = save_title.replace(" ","_")
plt.savefig(save_title, dpi=100, bbox_inches='tight')
plt.savefig(save_title, dpi=100, bbox_inches='tight')

# %% [markdown]
# # SOC GENDER BOXPLOTS

# %%
flist = [
    ["F_GMX Male", f_male_global_y_soc1],
    ["F_GFX Female", f_female_global_y_soc1] ]

nflist = [
    ["NF_GMX Male", nf_male_global_y_soc1],
    ["NF_GFX Female", nf_female_global_y_soc1] ]

for index in range(0,2):

    #print(index)
    
    use_case1 = flist[index][0]
    data1     = flist[index][1]
    
    use_case2 = nflist[index][0]
    data2     = nflist[index][1]
    
    soc_box1 = []
    soc_box2 = []
    
    #print(data1[0][1])
    #print(data1[0][1][0])
    
    for soc_index in range (0,23):
        tmp1 = []
        tmp2 = []
        for y_index in range(0,8):
            #print(soc_index)
            dat1 = data1[y_index][1][soc_index]
            tmp1.append(dat1)      
            dat2 = data2[y_index][1][soc_index]
            tmp2.append(dat2)
         
        soc_box1.append(tmp1)
        soc_box2.append(tmp2)
                       
    #print(soc_box)

    # BOX PLOT per occupation
    jlist = []
    for jb in range(1,24):
       jlist.append(job_code[jb][1])
    #print(jlist)

    #print(jlist[22])

    # Creating pandas |dataframe from numpy array
    #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
    pd_df1 = pd.DataFrame(columns=jlist)
    pd_df2 = pd.DataFrame(columns=jlist)

    #global_y_soc1 = female_global_y_soc1

    for index in range(0,23):
        pd_df1[jlist[index]] = soc_box1[index]
        pd_df2[jlist[index]] = soc_box2[index]
        #pd_df1[index] = soc_box1[index]
        #pd_df2[index] = soc_box2[index]
                       
    # Creating plot with dataset_1
    fig, ax1 = plt.subplots()

    title = use_case1 + " SOC boxplots " + use_case2
    #plt.figure(title,figsize=(20, 20))
    
    plt.title(title)

    boxprops = dict(color="red",linewidth=1.5)
    medianprops = dict(color="red",linewidth=1.5)
    
    ax1.tick_params(axis='y', colors='red')
    
    pd_df1.boxplot(ax=ax1, rot=90, boxprops=boxprops,medianprops=medianprops)
    #ax1.xticks(rotation = 90)
    #ax1.tight_layout()
    
    ax2 = ax1.twinx()
    
    boxprops = dict(color="green", linewidth=1.5)
    medianprops = dict(color="green",linewidth=1.5)
     
    ax2.tick_params(axis='y', colors='green')

    pd_df2.boxplot(ax=ax2, rot=90, boxprops=boxprops,medianprops=medianprops, grid=False)
    
    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
