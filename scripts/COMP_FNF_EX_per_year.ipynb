# %%
import os

try:
    os.mkdir("../PLOTS/COMP_BOX_EX")
except:
    print("COMB_BOX_EX dir exists.")

#For testing, leave commented
swivel = 1
swivel_order = [2, 1, 7, 3, 16, 6, 12, 9, 10, 4, 5, 15, 8, 14, 20, 0, 22, 13, 19, 11, 18, 21, 17]

desired_file_prefix = "F_E" 

normalize_data=True

lnconvert = False
# Out:
# COMB_BOX_EX dir exists.

# %%
by_year = 1

"""
# All genders all years
desired_file_prefix = "F_E" 
year = 8
rsq_avg = []
desired_file_output = "./F_BOX_EX/F_EX_ALL_"
# %run ./box-analysis-code-ex.ipynb
"""

# ##################### FATAL

# per year
#
desired_file_prefix = "F_E" 
e1_global_y_soc1 = []
e2_global_y_soc1 = []
e3_global_y_soc1 = []
e4_global_y_soc1 = []
e5_global_y_soc1 = []
e6_global_y_soc1 = []

for year in range(0,8):       
    desired_file_output = "./COMP_BOX_EX/F_EX_" + str(2011+year) + "_"    
    # %run ./box-analysis-code-ex.ipynb
    
f_e1_global_y_soc1 = e1_global_y_soc1
f_e2_global_y_soc1 = e2_global_y_soc1
f_e3_global_y_soc1 = e3_global_y_soc1
f_e4_global_y_soc1 = e4_global_y_soc1
f_e5_global_y_soc1 = e5_global_y_soc1
f_e6_global_y_soc1 = e6_global_y_soc1

# ##################### NON-FATAL

# per year
#
desired_file_prefix = "NF_E" 

e1_global_y_soc1 = []
e2_global_y_soc1 = []
e3_global_y_soc1 = []
e4_global_y_soc1 = []
e5_global_y_soc1 = []
e6_global_y_soc1 = []

for year in range(0,8):       
    desired_file_output = "./COMP_BOX_EX/NF_EX_" + str(2011+year) + "_"    
    # %run ./box-analysis-code-ex.ipynb
    
nf_e1_global_y_soc1 = e1_global_y_soc1
nf_e2_global_y_soc1 = e2_global_y_soc1
nf_e3_global_y_soc1 = e3_global_y_soc1
nf_e4_global_y_soc1 = e4_global_y_soc1
nf_e5_global_y_soc1 = e5_global_y_soc1
nf_e6_global_y_soc1 = e6_global_y_soc1
# Out:
# SOC_all.csv
# global_y_soc1 not found....defining
# global_soc1_empty not found....defining
# F_E1X_Violence_person_animals_all.csv
# F_E3X_Fires_explosions_all.csv
# F_E6X_Contact_object_equipment_all.csv
# F_E5X_Substance_environment_all.csv
# F_E2X_Transportation_all.csv
# F_E4X_Falls_slips_trips_all.csv
# dict_keys(['F_E1X_Violence_person_animals', 'F_E3X_Fires_explosions', 'F_E6X_Contact_object_equipment', 'F_E5X_Substance_environment', 'F_E2X_Transportation', 'F_E4X_Falls_slips_trips'])
# dict_keys(['F_E1X_Violence_person_animals', 'F_E3X_Fires_explosions', 'F_E6X_Contact_object_equipment', 'F_E5X_Substance_environment', 'F_E2X_Transportation', 'F_E4X_Falls_slips_trips'])
# F_E1X_Violence_person_animals
# 00 F_E1X_Violence_person_animals
# 11 F_E1X_Violence_person_animals
# 13 F_E1X_Violence_person_animals
# 15 F_E1X_Violence_person_animals
# 17 F_E1X_Violence_person_animals
# 19 F_E1X_Violence_person_animals
# 21 F_E1X_Violence_person_animals
# ...

# %% [markdown]
# # Boxplots

# %%
#print(e1_global_y_soc1)

# %%
### Creating pandas |dataframe from numpy array
#pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
pd_df = pd.DataFrame()

global_y_soc1 = e1_global_y_soc1

for index in range(0,len(global_y_soc1)):
    pd_df[global_y_soc1[index][0]] = global_y_soc1[index][1]

#print(pd_df)

title = desired_file_prefix + " boxplots"
plt.figure(title,figsize=(10, 10))
plt.title(title)

#plt.ylim(0.0, 0.15)

pd_df.boxplot()
plt.xticks(rotation = 90)
plt.tight_layout()

save_title = "../PLOTS/" + desired_file_output + title + ".png"
save_title = save_title.replace(",","")
save_title = save_title.replace(" ","_")
plt.savefig(save_title, dpi=100, bbox_inches='tight')
plt.savefig(save_title, dpi=100, bbox_inches='tight')

# %%
print(job_code)
# Out:
# [['00-0000', 'All Occupations'], ['11-0000', 'Computer and Mathematical Occupations'], ['13-0000', 'Business and Financial Operations Occupations'], ['15-0000', 'Educational Instruction and Library Occupations'], ['17-0000', 'Architecture and Engineering Occupations'], ['19-0000', 'Office and Administrative Support Occupations'], ['21-0000', 'Legal Occupations'], ['23-0000', 'Food Preparation and Serving Related Occupations'], ['25-0000', 'Healthcare Practitioners and Technical Occupations'], ['27-0000', 'Healthcare Support Occupations'], ['29-0000', 'Life, Physical, and Social Science Occupations'], ['31-0000', 'Community and Social Service Occupations'], ['33-0000', 'Sales and Related Occupations'], ['35-0000', 'Arts, Design, Entertainment, Sports, and Media Occupations'], ['37-0000', 'Personal Care and Service Occupations'], ['39-0000', 'Production Occupations'], ['41-0000', 'Management Occupations'], ['43-0000', 'Military Specific Occupations'], ['45-0000', 'Building and Grounds 
# ...

# %%
print(str(e6_global_y_soc1[0][0])[5:])
# Out:
# NF_E6X_Contact

# %% [markdown]
# # SOC GENDER BOXPLOTS

# %%
flist = [
    ["F_E1X Violence person animals", f_e1_global_y_soc1],
    ["F_E2X Transportation", f_e2_global_y_soc1],
    ["F_E3X Fires and explosions", f_e3_global_y_soc1],
    ["F_E4X Falls slips trips", f_e4_global_y_soc1],
    ["F_E5X Substance enviroment", f_e5_global_y_soc1],
    ["F_E6X Contact object equipment", f_e6_global_y_soc1] ]

nflist = [
    ["NF_E1X Violence person animals", nf_e1_global_y_soc1],
    ["NF_E2X Transportation", nf_e2_global_y_soc1],
    ["NF_E3X Fires and explosions", nf_e3_global_y_soc1],
    ["NF_E4X Falls slips trips", nf_e4_global_y_soc1],
    ["NF_E5X Substance enviroment", nf_e5_global_y_soc1],
    ["NF_E6X Contact object equipment", nf_e6_global_y_soc1] ]

for index in range(0,6):

    #print(index)
    
    use_case1 = flist[index][0]
    data1     = flist[index][1]
    
    use_case2 = nflist[index][0]
    data2     = nflist[index][1]
    
    soc_box1 = []
    soc_box2 = []
    
    #print(data1[0][1])
    #print(data1[0][1][0])
    
    for soc_index in range (0,23):
        tmp1 = []
        tmp2 = []
        for y_index in range(0,8):
            #print(soc_index)
            dat1 = data1[y_index][1][soc_index]
            tmp1.append(dat1)      
            dat2 = data2[y_index][1][soc_index]
            tmp2.append(dat2)
         
        soc_box1.append(tmp1)
        soc_box2.append(tmp2)
                       
    #print(soc_box)

    # BOX PLOT per occupation
    jlist = []
    for jb in range(1,24):
       jlist.append(job_code[jb][1])
    #print(jlist)

    #print(jlist[22])

    # Creating pandas |dataframe from numpy array
    #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
    pd_df1 = pd.DataFrame(columns=jlist)
    pd_df2 = pd.DataFrame(columns=jlist)

    #global_y_soc1 = female_global_y_soc1

    for index in range(0,23):
        pd_df1[jlist[index]] = soc_box1[index]
        pd_df2[jlist[index]] = soc_box2[index]
        #pd_df1[index] = soc_box1[index]
        #pd_df2[index] = soc_box2[index]
                       
    # Creating plot with dataset_1
    fig, ax1 = plt.subplots()

    title = use_case1 + " SOC boxplots " + use_case2
    #plt.figure(title,figsize=(20, 20))
    
    plt.title(title)

    boxprops = dict(color="red",linewidth=1.5)
    medianprops = dict(color="red",linewidth=1.5)
    
    ax1.tick_params(axis='y', colors='red')
    
    pd_df1.boxplot(ax=ax1, rot=90, boxprops=boxprops,medianprops=medianprops)
    #ax1.xticks(rotation = 90)
    #ax1.tight_layout()
    
    ax2 = ax1.twinx()
    
    boxprops = dict(color="green", linewidth=1.5)
    medianprops = dict(color="green",linewidth=1.5)
     
    ax2.tick_params(axis='y', colors='green')

    pd_df2.boxplot(ax=ax2, rot=90, boxprops=boxprops,medianprops=medianprops, grid=False)
    
    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    plt.savefig(save_title, dpi=100, bbox_inches='tight')

# %% [markdown]
# # FARMING ONLY

# %%
occupation = "Farming"

flist = [
    ["F_E1X Violence person animals", f_e1_global_y_soc1],
    ["F_E2X Transportation", f_e2_global_y_soc1],
    ["F_E3X Fires and explosions", f_e3_global_y_soc1],
    ["F_E4X Falls slips trips", f_e4_global_y_soc1],
    ["F_E5X Substance enviroment", f_e5_global_y_soc1],
    ["F_E6X Contact object equipment", f_e6_global_y_soc1] ]

nflist = [
    ["NF_E1X Violence person animals", nf_e1_global_y_soc1],
    ["NF_E2X Transportation", nf_e2_global_y_soc1],
    ["NF_E3X Fires and explosions", nf_e3_global_y_soc1],
    ["NF_E4X Falls slips trips", nf_e4_global_y_soc1],
    ["NF_E5X Substance enviroment", nf_e5_global_y_soc1],
    ["NF_E6X Contact object equipment", nf_e6_global_y_soc1] ]


# Creating pandas |dataframe from numpy array
#pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
#pd_df1 = pd.DataFrame(columns=jlist)
#pd_df2 = pd.DataFrame(columns=jlist)
pd_df1 = pd.DataFrame()
pd_df2 = pd.DataFrame()

for index in range(0,6):

    #print(index)
    
    use_case1 = flist[index][0]
    data1     = flist[index][1]
    
    use_case2 = nflist[index][0]
    data2     = nflist[index][1]
    
    soc_box1 = []
    soc_box2 = []
    
    #print(data1[0][1])
    #print(data1[0][1][0])
    
    for soc_index in range (0,23):
        tmp1 = []
        tmp2 = []
        for y_index in range(0,8):
            #print(soc_index)
            dat1 = data1[y_index][1][soc_index]
            tmp1.append(dat1)      
            dat2 = data2[y_index][1][soc_index]
            tmp2.append(dat2)
         
        soc_box1.append(tmp1)
        soc_box2.append(tmp2)
                       
    #print(soc_box)

    # BOX PLOT per occupation
    jlist = []
    for jb in range(1,24):
       jlist.append(job_code[jb][1])
    #print(jlist)

    #print(jlist[22])

    #global_y_soc1 = female_global_y_soc1

    for index in range(0,23):
        if (str(jlist[index]).find(occupation) >= 0):
            print(str(jlist[index]))
            pd_df1[use_case1] = soc_box1[index]
            pd_df2[use_case2] = soc_box2[index]
            #pd_df1[jlist[index]] = soc_box1[index]
            #pd_df2[jlist[index]] = soc_box2[index]
            
                      
# Creating plot with dataset_1
fig, ax1 = plt.subplots()


title = use_case1.split(" ")[0] + " " + occupation + " boxplots " + use_case2.split(" ")[0]
#plt.figure(title,figsize=(20, 20))
    
plt.title(title)

boxprops = dict(color="red",linewidth=1.5)
medianprops = dict(color="red",linewidth=1.5)
    
ax1.tick_params(axis='y', colors='red')
    
pd_df1.boxplot(ax=ax1, rot=90, boxprops=boxprops,medianprops=medianprops)
#ax1.xticks(rotation = 90)
#ax1.tight_layout()
    
ax2 = ax1.twinx()
    
boxprops = dict(color="green", linewidth=1.5)
medianprops = dict(color="green",linewidth=1.5)
     
ax2.tick_params(axis='y', colors='green')

pd_df2.boxplot(ax=ax2, rot=90, boxprops=boxprops,medianprops=medianprops, grid=False)
    
save_title = "../PLOTS/" + desired_file_output + title + ".png"
save_title = save_title.replace(",","")
save_title = save_title.replace(" ","_")
plt.savefig(save_title, dpi=100, bbox_inches='tight')
plt.savefig(save_title, dpi=100, bbox_inches='tight')
# Out:
# Farming, Fishing, and Forestry Occupations
# Farming, Fishing, and Forestry Occupations
# Farming, Fishing, and Forestry Occupations
# Farming, Fishing, and Forestry Occupations
# Farming, Fishing, and Forestry Occupations
# Farming, Fishing, and Forestry Occupations
