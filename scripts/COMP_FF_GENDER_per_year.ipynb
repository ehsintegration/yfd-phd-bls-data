# %%
import os

try:
    os.mkdir("../PLOTS/COMP_BOX_GENDER")
except:
    print("COMP_BOX_GENDER dir exists.")

#For testing, leave commented
swivel = 1
swivel_order = [2, 1, 7, 3, 16, 6, 12, 9, 10, 4, 5, 15, 8, 14, 20, 0, 22, 13, 19, 11, 18, 21, 17]

desired_file_prefix = "F_GENDER" 

normalize_data=True

lnconvert=False
# Out:
# COMP_BOX_GENDER dir exists.

# %%
by_year = 1


# ##################### NON-FATAL

# per year
#
desired_file_prefix = "F_GENDER" 
male_global_y_soc1 = []
female_global_y_soc1 = []

for year in range(0,8):       
    desired_file_output = "./COMP_BOX_GENDER/F_GENDER_" + str(2011+year) + "_"    
    # %run ./box-analysis-code-gender.ipynb
    
f_male_global_y_soc1 = male_global_y_soc1
f_female_global_y_soc1 = female_global_y_soc1
# Out:
# SOC_all.csv
# global_y_soc1 not found....defining
# global_soc1_empty not found....defining
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 1, 12, 7, 16, 5, 3, 9, 6, 10, 8, 15, 4, 14, 20, 0, 22, 19, 13, 18, 11, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 3, 4, 6, 7, 1, 16, 9, 20, 12, 10, 8, 15, 14, 0, 5, 13, 22, 19, 11, 18, 21, 17]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 7, 1, 10, 6, 16, 12, 3, 9, 8, 4, 15, 14, 5, 20, 0, 22, 13, 19, 11, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 6, 22, 1, 20, 7, 3, 9, 10, 12, 16, 15, 4, 8, 0, 14, 5, 13, 19, 21, 18, 11, 17]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 7, 1, 16, 6, 3, 12, 9, 10, 5, 14, 15, 4, 8, 20, 0, 22, 13, 19, 11, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 3, 1, 7, 16, 5, 10, 12, 9, 14, 13, 15, 8, 0, 6, 4, 20, 19, 18, 21, 11, 17, 22]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 1, 7, 10, 6, 12, 16, 3, 4, 9, 8, 15, 5, 14, 20, 0, 22, 13, 11, 19, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 3, 6, 7, 9, 1, 10, 16, 12, 8, 20, 14, 0, 15, 5, 4, 13, 11, 18, 22, 19, 21, 17]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 7, 1, 16, 6, 12, 3, 4, 10, 9, 5, 15, 14, 8, 0, 20, 22, 13, 19, 11, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 3, 4, 22, 7, 1, 14, 6, 20, 16, 12, 9, 15, 0, 5, 10, 8, 13, 19, 11, 18, 21, 17]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 1, 16, 7, 10, 6, 3, 9, 12, 4, 5, 15, 14, 8, 20, 0, 22, 13, 19, 11, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 3, 6, 1, 7, 4, 16, 0, 14, 9, 5, 15, 8, 10, 12, 13, 20, 18, 21, 11, 19, 22, 17]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 1, 7, 3, 6, 16, 4, 9, 10, 12, 8, 15, 5, 0, 20, 14, 22, 19, 13, 11, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [3, 6, 2, 4, 7, 1, 9, 16, 8, 20, 12, 14, 0, 15, 10, 13, 5, 22, 19, 11, 21, 17, 18]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_GENDER_GMX_M_all.csv
# F_GENDER_GFX_F_all.csv
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# dict_keys(['F_GENDER_GMX_M', 'F_GENDER_GFX_F'])
# F_GENDER_GMX_M
# 00 F_GENDER_GMX_M
# 11 F_GENDER_GMX_M
# 13 F_GENDER_GMX_M
# 15 F_GENDER_GMX_M
# 17 F_GENDER_GMX_M
# 19 F_GENDER_GMX_M
# 21 F_GENDER_GMX_M
# 23 F_GENDER_GMX_M
# 25 F_GENDER_GMX_M
# 27 F_GENDER_GMX_M
# 29 F_GENDER_GMX_M
# 31 F_GENDER_GMX_M
# 33 F_GENDER_GMX_M
# 35 F_GENDER_GMX_M
# 37 F_GENDER_GMX_M
# 39 F_GENDER_GMX_M
# 41 F_GENDER_GMX_M
# 43 F_GENDER_GMX_M
# 45 F_GENDER_GMX_M
# 47 F_GENDER_GMX_M
# 49 F_GENDER_GMX_M
# 51 F_GENDER_GMX_M
# 53 F_GENDER_GMX_M
# 55 F_GENDER_GMX_M
# Suggested swivel order
# [2, 7, 1, 16, 3, 6, 5, 9, 10, 4, 12, 15, 0, 14, 8, 20, 22, 19, 13, 11, 18, 21, 17]
# F_GENDER_GFX_F
# 00 F_GENDER_GFX_F
# 11 F_GENDER_GFX_F
# 13 F_GENDER_GFX_F
# 15 F_GENDER_GFX_F
# 17 F_GENDER_GFX_F
# 19 F_GENDER_GFX_F
# 21 F_GENDER_GFX_F
# 23 F_GENDER_GFX_F
# 25 F_GENDER_GFX_F
# 27 F_GENDER_GFX_F
# 29 F_GENDER_GFX_F
# 31 F_GENDER_GFX_F
# 33 F_GENDER_GFX_F
# 35 F_GENDER_GFX_F
# 37 F_GENDER_GFX_F
# 39 F_GENDER_GFX_F
# 41 F_GENDER_GFX_F
# 43 F_GENDER_GFX_F
# 45 F_GENDER_GFX_F
# 47 F_GENDER_GFX_F
# 49 F_GENDER_GFX_F
# 51 F_GENDER_GFX_F
# 53 F_GENDER_GFX_F
# 55 F_GENDER_GFX_F
# Suggested swivel order
# [2, 3, 19, 16, 7, 1, 14, 9, 20, 0, 6, 15, 4, 5, 12, 8, 10, 13, 22, 21, 11, 18, 17]

# %% [markdown]
# # Male boxblots

# %% [markdown]
# # Female boxplots

# %% [markdown]
# # SOC GENDER BOXPLOTS

# %%
flist = [
    ["F_GMX Male", f_male_global_y_soc1] ]

nflist = [
    ["F_GFX Female", f_female_global_y_soc1] ]

for index in range(0,1):

    #print(index)
    
    use_case1 = flist[index][0]
    data1     = flist[index][1]
    
    use_case2 = nflist[index][0]
    data2     = nflist[index][1]
    
    soc_box1 = []
    soc_box2 = []
    
    #print(data1[0][1])
    #print(data1[0][1][0])
    
    for soc_index in range (0,23):
        tmp1 = []
        tmp2 = []
        for y_index in range(0,8):
            #print(soc_index)
            dat1 = data1[y_index][1][soc_index]
            tmp1.append(dat1)      
            dat2 = data2[y_index][1][soc_index]
            tmp2.append(dat2)
         
        soc_box1.append(tmp1)
        soc_box2.append(tmp2)
                       
    #print(soc_box)

    # BOX PLOT per occupation
    jlist = []
    for jb in range(1,24):
       jlist.append(job_code[jb][1])
    #print(jlist)

    #print(jlist[22])

    # Creating pandas |dataframe from numpy array
    #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
    pd_df1 = pd.DataFrame(columns=jlist)
    pd_df2 = pd.DataFrame(columns=jlist)

    #global_y_soc1 = female_global_y_soc1

    for index in range(0,23):
        pd_df1[jlist[index]] = soc_box1[index]
        pd_df2[jlist[index]] = soc_box2[index]
        #pd_df1[index] = soc_box1[index]
        #pd_df2[index] = soc_box2[index]
                       
    # Creating plot with dataset_1
    fig, ax1 = plt.subplots()

    title = use_case1 + " SOC boxplots " + use_case2
    #plt.figure(title,figsize=(20, 20))
    
    plt.title(title)

    boxprops = dict(color="red",linewidth=1.5)
    medianprops = dict(color="red",linewidth=1.5)
    
    ax1.tick_params(axis='y', colors='red')
    
    ax1.set_ylim([0, 0.0003])
    
    pd_df1.boxplot(ax=ax1, rot=90, boxprops=boxprops,medianprops=medianprops)
    #ax1.xticks(rotation = 90)
    #ax1.tight_layout()
    
    ax2 = ax1.twinx()
    
    boxprops = dict(color="green", linewidth=1.5)
    medianprops = dict(color="green",linewidth=1.5)
     
    ax2.tick_params(axis='y', colors='green')
    
    ax2.set_ylim([0, 0.0003])

    pd_df2.boxplot(ax=ax2, rot=90, boxprops=boxprops,medianprops=medianprops, grid=False)
    
    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    
    plt.show()
    plt.close()

    # ################################ PLOT MEAN
    
    # Creating plot with dataset_1
    fig, ax1 = plt.subplots()

    title = use_case1 + " SOC MEAN plot " + use_case2
    #plt.figure(title,figsize=(20, 20))
    
    plt.title(title)

    boxprops = dict(color="red",linewidth=1.5)
    medianprops = dict(color="red",linewidth=1.5)
    
    ax1.tick_params(axis='y', colors='red')
    
    ax1.set_ylim([0, 0.0003])
    
    pd_df1_mean = pd_df1.mean()
    ax1.plot(pd_df1_mean, 'r-') # , boxprops=boxprops,medianprops=medianprops)    
    #ax1.set_xticklabels(ax1.get_xticklabels(), rotation = 90)
    
    #pd_df1.boxplot(ax=ax1, rot=90, boxprops=boxprops,medianprops=medianprops)
    plt.xticks(rotation = 90)
    #ax1.tight_layout()
    
    ax2 = ax1.twinx()
    
    boxprops = dict(color="green", linewidth=1.5)
    medianprops = dict(color="green",linewidth=1.5)
     
    ax2.tick_params(axis='y', colors='green')
    
    ax2.set_ylim([0, 0.0003])

    pd_df2_mean = pd_df2.mean()
    ax2.plot(pd_df2_mean, 'g-') # , boxprops=boxprops,medianprops=medianprops) 
    #pd_df2.boxplot(ax=ax2, rot=90, boxprops=boxprops,medianprops=medianprops, grid=False)
    
    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    
    plt.show()
    plt.close()

# %%
print(pd_df2_mean.tolist())
# Out:
# [9.527439024390244e-08, 1.74546790788829e-06, 1.7052955845679918e-06, 2.4084778420038533e-07, 2.9368720829048336e-06, 1.921106557377049e-06, 4.57584392810171e-06, 3.1670205237084214e-06, 5.101233786776337e-06, 3.6764705882352942e-06, 5.541526374859708e-06, 5.106941598360656e-06, 5.40368722186904e-06, 4.619505794883009e-06, 4.832863471606927e-06, 5.116358658453114e-06, 1.7241379310344828e-05, 7.547559966914805e-06, 1.9594594594594592e-05, 2.583217753120666e-05, 3.047703180212014e-05, 2.8481894150417828e-05, 5.238970588235294e-05]

# %%
import scipy.stats as stats

# %%
data_group1 = pd_df1_mean.tolist()
data_group2 = pd_df2_mean.tolist()

stats.ttest_ind(a=data_group1, b=data_group2, equal_var=True)
# Out:
# Ttest_indResult(statistic=2.7982716449613942, pvalue=0.0075962683661143)

# %% [markdown]
# ![image.png](attachment:cad871d4-938f-4676-af62-3b938130f498.png)

# %% [markdown]
# #### Since the p-value (0.00759) is less than alpha = 0.05 so we CAN reject the null
# #### hypothesis of the test. We DO have sufficient evidence to say that the mean
# #### fatality probability across occupational groups is different.
