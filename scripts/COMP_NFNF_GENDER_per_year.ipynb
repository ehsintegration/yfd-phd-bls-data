# %%
import os

try:
    os.mkdir("../PLOTS/COMP_BOX_GENDER")
except:
    print("COMP_BOX_GENDER dir exists.")

#For testing, leave commented
swivel = 1

# F ORDER
#swivel_order = [2, 1, 7, 3, 16, 6, 12, 9, 10, 4, 5, 15, 8, 14, 20, 0, 22, 13, 19, 11, 18, 21, 17]

# NF ORDER
swivel_order = [22, 2, 6, 1, 3, 0, 4, 8, 7, 15, 5, 14, 16, 9, 12, 18, 20, 17, 13, 10, 19, 21, 11]



desired_file_prefix = "NF_GENDER" 

normalize_data=True

lnconvert=False
# Out:
# COMP_BOX_GENDER dir exists.

# %%
by_year = 1

"""
# ##################### FATAL

# per year
#
desired_file_prefix = "NF_GENDER" 
male_global_y_soc1 = []
female_global_y_soc1 = []

for year in range(0,8):       
    desired_file_output = "./COMP_BOX_GENDER/F_GENDER_" + str(2011+year) + "_"    
    # %run ./box-analysis-code-gender.ipynb
    
f_male_global_y_soc1 = male_global_y_soc1
f_female_global_y_soc1 = female_global_y_soc1

"""

# ##################### NON-FATAL

# per year
#
desired_file_prefix = "NF_GENDER" 
male_global_y_soc1 = []
female_global_y_soc1 = []

for year in range(0,8):       
    desired_file_output = "./COMP_BOX_GENDER/NF_GENDER_" + str(2011+year) + "_"    
    # %run ./box-analysis-code-gender.ipynb
    
nf_male_global_y_soc1 = male_global_y_soc1
nf_female_global_y_soc1 = female_global_y_soc1
# Out:
# SOC_all.csv
# global_y_soc1 not found....defining
# global_soc1_empty not found....defining
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 4, 8, 7, 15, 5, 14, 9, 16, 12, 18, 17, 20, 13, 10, 21, 19, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 2, 3, 1, 6, 4, 8, 0, 16, 7, 14, 15, 5, 9, 18, 12, 17, 20, 13, 21, 10, 19, 11]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 4, 7, 8, 15, 5, 14, 9, 16, 12, 18, 20, 17, 13, 10, 19, 21, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 2, 3, 8, 6, 1, 4, 0, 16, 7, 15, 14, 18, 5, 9, 12, 20, 17, 13, 10, 19, 21, 11]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 4, 7, 15, 8, 5, 14, 9, 16, 12, 18, 13, 20, 17, 10, 19, 21, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 3, 2, 6, 8, 4, 1, 0, 16, 7, 14, 15, 18, 5, 9, 20, 12, 17, 13, 19, 21, 11, 10]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 7, 8, 4, 15, 14, 5, 9, 16, 12, 18, 20, 17, 13, 10, 19, 21, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 2, 3, 6, 1, 8, 0, 4, 16, 15, 7, 14, 5, 9, 18, 12, 20, 17, 13, 10, 19, 21, 11]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 3, 4, 0, 8, 7, 15, 5, 14, 9, 16, 12, 18, 20, 13, 17, 10, 19, 21, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 2, 6, 1, 8, 4, 3, 0, 16, 15, 7, 14, 18, 5, 9, 12, 20, 13, 17, 10, 19, 21, 11]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 4, 7, 15, 8, 5, 14, 9, 16, 12, 18, 20, 17, 13, 10, 19, 21, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 2, 3, 8, 1, 4, 6, 0, 16, 15, 7, 14, 5, 9, 12, 20, 18, 13, 17, 19, 10, 11, 21]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 4, 7, 8, 15, 5, 14, 9, 16, 12, 18, 20, 13, 17, 10, 21, 19, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 2, 3, 6, 1, 8, 4, 0, 16, 7, 15, 14, 5, 9, 18, 12, 20, 13, 17, 19, 10, 11, 21]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_GENDER_GMX_M_all.csv
# NF_GENDER_GFX_F_all.csv
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# dict_keys(['NF_GENDER_GMX_M', 'NF_GENDER_GFX_F'])
# NF_GENDER_GMX_M
# 00 NF_GENDER_GMX_M
# 11 NF_GENDER_GMX_M
# 13 NF_GENDER_GMX_M
# 15 NF_GENDER_GMX_M
# 17 NF_GENDER_GMX_M
# 19 NF_GENDER_GMX_M
# 21 NF_GENDER_GMX_M
# 23 NF_GENDER_GMX_M
# 25 NF_GENDER_GMX_M
# 27 NF_GENDER_GMX_M
# 29 NF_GENDER_GMX_M
# 31 NF_GENDER_GMX_M
# 33 NF_GENDER_GMX_M
# 35 NF_GENDER_GMX_M
# 37 NF_GENDER_GMX_M
# 39 NF_GENDER_GMX_M
# 41 NF_GENDER_GMX_M
# 43 NF_GENDER_GMX_M
# 45 NF_GENDER_GMX_M
# 47 NF_GENDER_GMX_M
# 49 NF_GENDER_GMX_M
# 51 NF_GENDER_GMX_M
# 53 NF_GENDER_GMX_M
# 55 NF_GENDER_GMX_M
# Suggested swivel order
# [22, 2, 6, 1, 0, 3, 4, 7, 8, 15, 5, 14, 9, 16, 12, 18, 20, 13, 17, 10, 19, 21, 11]
# NF_GENDER_GFX_F
# 00 NF_GENDER_GFX_F
# 11 NF_GENDER_GFX_F
# 13 NF_GENDER_GFX_F
# 15 NF_GENDER_GFX_F
# 17 NF_GENDER_GFX_F
# 19 NF_GENDER_GFX_F
# 21 NF_GENDER_GFX_F
# 23 NF_GENDER_GFX_F
# 25 NF_GENDER_GFX_F
# 27 NF_GENDER_GFX_F
# 29 NF_GENDER_GFX_F
# 31 NF_GENDER_GFX_F
# 33 NF_GENDER_GFX_F
# 35 NF_GENDER_GFX_F
# 37 NF_GENDER_GFX_F
# 39 NF_GENDER_GFX_F
# 41 NF_GENDER_GFX_F
# 43 NF_GENDER_GFX_F
# 45 NF_GENDER_GFX_F
# 47 NF_GENDER_GFX_F
# 49 NF_GENDER_GFX_F
# 51 NF_GENDER_GFX_F
# 53 NF_GENDER_GFX_F
# 55 NF_GENDER_GFX_F
# Suggested swivel order
# [22, 3, 6, 2, 1, 4, 8, 0, 16, 15, 7, 14, 5, 9, 18, 12, 20, 17, 13, 10, 19, 11, 21]

# %% [markdown]
# # Male boxblots

# %% [markdown]
# # Female boxplots

# %% [markdown]
# # SOC GENDER BOXPLOTS

# %%
flist = [
    ["NF_GMX Male", nf_male_global_y_soc1] ]

nflist = [
    ["NF_GFX Female", nf_female_global_y_soc1] ]

for index in range(0,1):

    #print(index)
    
    use_case1 = flist[index][0]
    data1     = flist[index][1]
    
    use_case2 = nflist[index][0]
    data2     = nflist[index][1]
    
    soc_box1 = []
    soc_box2 = []
    
    #print(data1[0][1])
    #print(data1[0][1][0])
    
    for soc_index in range (0,23):
        tmp1 = []
        tmp2 = []
        for y_index in range(0,8):
            #print(soc_index)
            dat1 = data1[y_index][1][soc_index]
            tmp1.append(dat1)      
            dat2 = data2[y_index][1][soc_index]
            tmp2.append(dat2)
         
        soc_box1.append(tmp1)
        soc_box2.append(tmp2)
                       
    #print(soc_box)

    # BOX PLOT per occupation
    jlist = []
    for jb in range(1,24):
       jlist.append(job_code[jb][1])
    #print(jlist)

    #print(jlist[22])

    # Creating pandas |dataframe from numpy array
    #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
    pd_df1 = pd.DataFrame(columns=jlist)
    pd_df2 = pd.DataFrame(columns=jlist)

    #global_y_soc1 = female_global_y_soc1

    for index in range(0,23):
        pd_df1[jlist[index]] = soc_box1[index]
        pd_df2[jlist[index]] = soc_box2[index]
        #pd_df1[index] = soc_box1[index]
        #pd_df2[index] = soc_box2[index]
                       
    # Creating plot with dataset_1
    fig, ax1 = plt.subplots()

    title = use_case1 + " SOC boxplots " + use_case2
    #plt.figure(title,figsize=(20, 20))
    
    plt.title(title)

    boxprops = dict(color="red",linewidth=1.5)
    medianprops = dict(color="red",linewidth=1.5)
    
    ax1.tick_params(axis='y', colors='red')
    
    ax1.set_ylim([0, 0.03])
    
    pd_df1.boxplot(ax=ax1, rot=90, boxprops=boxprops,medianprops=medianprops)
    #ax1.xticks(rotation = 90)
    #ax1.tight_layout()
    
    ax2 = ax1.twinx()
    
    boxprops = dict(color="green", linewidth=1.5)
    medianprops = dict(color="green",linewidth=1.5)
     
    ax2.tick_params(axis='y', colors='green')
    
    ax2.set_ylim([0, 0.03])

    pd_df2.boxplot(ax=ax2, rot=90, boxprops=boxprops,medianprops=medianprops, grid=False)
    
    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    
    
   # ################################ PLOT MEAN
    
    # Creating plot with dataset_1
    fig, ax1 = plt.subplots()

    title = use_case1 + " SOC MEAN plot " + use_case2
    #plt.figure(title,figsize=(20, 20))
    
    plt.title(title)

    boxprops = dict(color="red",linewidth=1.5)
    medianprops = dict(color="red",linewidth=1.5)
    
    ax1.tick_params(axis='y', colors='red')
    
    ax1.set_ylim([0, 0.03])
    
    pd_df1_mean = pd_df1.mean()
    
    ax1.plot(pd_df1_mean, 'r-') # , boxprops=boxprops,medianprops=medianprops)    
    #ax1.set_xticklabels(ax1.get_xticklabels(), rotation = 90)
    
    #pd_df1.boxplot(ax=ax1, rot=90, boxprops=boxprops,medianprops=medianprops)
    plt.xticks(rotation = 90)
    #ax1.tight_layout()
    
    ax2 = ax1.twinx()
    
    boxprops = dict(color="green", linewidth=1.5)
    medianprops = dict(color="green",linewidth=1.5)
     
    ax2.tick_params(axis='y', colors='green')
    
    ax2.set_ylim([0, 0.03])
    
    pd_df2_mean = pd_df2.mean()
    ax2.plot(pd_df2_mean, 'g-') # , boxprops=boxprops,medianprops=medianprops) 
    #pd_df2.boxplot(ax=ax2, rot=90, boxprops=boxprops,medianprops=medianprops, grid=False)
    
    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    
    plt.show()
    plt.close()

# %%
print(pd_df2_mean.tolist())
# Out:
# [0.0, 0.0007288490853658537, 0.0011308913934426229, 0.001352890739833415, 0.0009296724470134874, 0.0019438740588637923, 0.0016771708683473389, 0.001485219326128417, 0.004625385066744902, 0.004582159323770492, 0.0058143939393939395, 0.005015580581675049, 0.0035625148326872873, 0.007064755838641189, 0.010277290661990355, 0.007835689045936395, 0.010768223922674184, 0.012642463235294117, 0.013866315136476428, 0.017732125909522303, 0.01772297297297297, 0.020669916434540386, 0.020849514563106797]

# %%
import scipy.stats as stats

# %%
data_group1 = pd_df1_mean.tolist()
data_group2 = pd_df2_mean.tolist()

stats.ttest_ind(a=data_group1, b=data_group2, equal_var=True)
# Out:
# Ttest_indResult(statistic=0.10584981524716569, pvalue=0.9161826212073612)

# %% [markdown]
# ![image.png](attachment:cad871d4-938f-4676-af62-3b938130f498.png)

# %% [markdown]
# #### Since the p-value (0.91618) is greater than alpha = 0.05 so we CANNOT reject
# #### the null hypothesis of the test. We do NOT have sufficient evidence to say that the
# #### mean fatality probability across occupational groups is different.
