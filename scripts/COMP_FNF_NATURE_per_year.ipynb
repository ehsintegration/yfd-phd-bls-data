# %%
import os

try:
    os.mkdir("../PLOTS/COMB_BOX_NATURE")
except:
    print("COMB_BOX_NATURE dir exists.")

#For testing, leave commented
swivel = 1
swivel_order = [2, 1, 7, 3, 16, 6, 12, 9, 10, 4, 5, 15, 8, 14, 20, 0, 22, 13, 19, 11, 18, 21, 17]

desired_file_prefix = "F_N" 

normalize_data=True

lnconvert = False
# Out:
# COMB_BOX_NATURE dir exists.

# %%
by_year = 1


# ##################### FATAL

# per year
#
desired_file_prefix = "F_N" 
n1_global_y_soc1 = []
n2_global_y_soc1 = []
n3_global_y_soc1 = []
n4_global_y_soc1 = []
n5_global_y_soc1 = []
n6_global_y_soc1 = []
n7_global_y_soc1 = []
n8_global_y_soc1 = []
n9_global_y_soc1 = []
rsq_array = []

for year in range(0,8):       
    desired_file_output = "./COMB_BOX_NATURE/F_NATURE_" + str(2011+year) + "_"    
    # %run ./box-analysis-code-nature.ipynb
    
f_n1_global_y_soc1 = n1_global_y_soc1
f_n2_global_y_soc1 = n2_global_y_soc1
f_n3_global_y_soc1 = n3_global_y_soc1
f_n4_global_y_soc1 = n4_global_y_soc1
f_n5_global_y_soc1 = n5_global_y_soc1
f_n6_global_y_soc1 = n6_global_y_soc1
f_n7_global_y_soc1 = n7_global_y_soc1
f_n8_global_y_soc1 = n8_global_y_soc1
f_n9_global_y_soc1 = n9_global_y_soc1
    
# ##################### NON-FATAL

# per year
#
desired_file_prefix = "NF_N" 
n1_global_y_soc1 = []
n2_global_y_soc1 = []
n3_global_y_soc1 = []
n4_global_y_soc1 = []
n5_global_y_soc1 = []
n6_global_y_soc1 = []
n7_global_y_soc1 = []
n8_global_y_soc1 = []
n9_global_y_soc1 = []

for year in range(0,8):       
    desired_file_output = "./COMB_BOX_NATURE/NF_NATURE_" + str(2011+year) + "_"    
    # %run ./box-analysis-code-nature.ipynb
    
print("******************************************************")
print(n1_global_y_soc1)

nf_n1_global_y_soc1 = n1_global_y_soc1
nf_n2_global_y_soc1 = n2_global_y_soc1
nf_n3_global_y_soc1 = n3_global_y_soc1
nf_n4_global_y_soc1 = n4_global_y_soc1
nf_n5_global_y_soc1 = n5_global_y_soc1
nf_n6_global_y_soc1 = n6_global_y_soc1
nf_n7_global_y_soc1 = n7_global_y_soc1
nf_n8_global_y_soc1 = n8_global_y_soc1
nf_n9_global_y_soc1 = n9_global_y_soc1
# Out:
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# F_N4X_Surface_wound
# 00 F_N4X_Surface_wound
# 11 F_N4X_Surface_wound
# 13 F_N4X_Surface_wound
# 15 F_N4X_Surface_wound
# 17 F_N4X_Surface_wound
# 19 F_N4X_Surface_wound
# ...

# %% [markdown]
# # Boxplots

# %%
print(f_n2_global_y_soc1)
# Out:
# [['2011_F_N2X_Muscles_tendons_ligaments', array([0.00000000e+00, 0.00000000e+00, 1.07376785e-07, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.06157113e-07,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 9.36621917e-07,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00])], ['2012_F_N2X_Muscles_tendons_ligaments', array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.26564713e-07, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 9.36621917e-07,
# ...

# %%
### Creating pandas |dataframe from numpy array
#pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
pd_df = pd.DataFrame()

global_y_soc1 = f_n1_global_y_soc1

for index in range(0,len(global_y_soc1)):
    pd_df[global_y_soc1[index][0]] = global_y_soc1[index][1]

#print(pd_df)

title = desired_file_prefix + " boxplots"
plt.figure(title,figsize=(10, 10))
plt.title(title)

#plt.ylim(0.0, 0.15)

pd_df.boxplot()
plt.xticks(rotation = 90)
plt.tight_layout()

save_title = "../PLOTS/" + desired_file_output + title + ".png"
save_title = save_title.replace(",","")
save_title = save_title.replace(" ","_")
plt.savefig(save_title, dpi=100, bbox_inches='tight')
plt.savefig(save_title, dpi=100, bbox_inches='tight')

# %%
### Creating pandas |dataframe from numpy array
#pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
pd_df = pd.DataFrame()

global_y_soc1 = n9_global_y_soc1

for index in range(0,len(global_y_soc1)):
    pd_df[global_y_soc1[index][0]] = global_y_soc1[index][1]

#print(pd_df)

title = desired_file_prefix + " MALE boxplots"
plt.figure(title,figsize=(10, 10))
plt.title(title)

#plt.ylim(0.0, 0.15)

pd_df.boxplot()
plt.xticks(rotation = 90)
plt.tight_layout()

save_title = "../PLOTS/" + desired_file_output + title + ".png"
save_title = save_title.replace(",","")
save_title = save_title.replace(" ","_")
plt.savefig(save_title, dpi=100, bbox_inches='tight')
plt.savefig(save_title, dpi=100, bbox_inches='tight')

# %%
print(str(nf_n9_global_y_soc1[0][0])[5:])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_880222/3863153431.py in <module>
# ----> 1 print(str(nf_n9_global_y_soc1[0][0])[5:])
#
# IndexError: list index out of range

# %%
list1 = [
    ["F_N1X Bones nerves spinal", f_n1_global_y_soc1],
    ["F_N2X Muscles tendons ligaments", f_n2_global_y_soc1],
    ["F_N3X Open Wounds", f_n3_global_y_soc1],
    ["F_N4X Surface wound", f_n4_global_y_soc1],
    ["F_N5X Burns corrosion", f_n5_global_y_soc1],
    ["F_N6X Intracranial", f_n6_global_y_soc1],
    ["F_N7X Enviromental", f_n7_global_y_soc1],
    ["F_N8X Multiple trauma", f_n8_global_y_soc1],
    ["F_N9X Other trauma", f_n9_global_y_soc1] ]

list2 = [
    ["NF_N1X Bones nerves spinal", nf_n1_global_y_soc1],
    ["NF_N2X Muscles tendons ligaments", nf_n2_global_y_soc1],
    ["NF_N3X Open Wounds", nf_n3_global_y_soc1],
    ["NF_N4X Surface wound", nf_n4_global_y_soc1],
    ["NF_N5X Burns corrosion", nf_n5_global_y_soc1],
    ["NF_N6X Intracranial", nf_n6_global_y_soc1],
    ["NF_N7X Enviromental", nf_n7_global_y_soc1],
    ["NF_N8X Multiple trauma", nf_n8_global_y_soc1],
    ["NF_N9X Other trauma", nf_n9_global_y_soc1] ]

soc_ylimit = 0.00005

for index1 in range(0,len(list1)):

    for index2 in range(0,len(list2)):
    
        use_case1 = list1[index1][0]
        data1     = list1[index1][1]
    
        use_case2 = list2[index2][0]
        data2     = list2[index2][1]
        
        print(list2)
    
        soc_box1 = []
        soc_box2 = []
    
        for soc_index in range (0,23):
            tmp1 = []
            tmp2 = []
            for y_index in range(0,8):
                #print(soc_index)
                dat1 = data1[y_index][1][soc_index]
                tmp1.append(dat1) 
                dat2 = data2[y_index][1][soc_index]
                tmp2.append(dat2)
         
            soc_box1.append(tmp1)
            soc_box2.append(tmp2)
                       
        #print(soc_box)

        # BOX PLOT per occupation
        jlist = []
        for jb in range(1,24):
           jlist.append(job_code[jb][1])
        #print(jlist)

        #print(jlist[22])

        # Creating pandas |dataframe from numpy array
        #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
        pd_df1 = pd.DataFrame(columns=jlist)
        pd_df2 = pd.DataFrame(columns=jlist)

        #global_y_soc1 = female_global_y_soc1

        for index in range(0,23):
            pd_df1[jlist[index]] = soc_box1[index]
            pd_df2[jlist[index]] = soc_box2[index]
            #pd_df1[index] = soc_box1[index]
            #pd_df2[index] = soc_box2[index]
                       
        # Creating plot with dataset_1
        fig, ax1 = plt.subplots()

        title = use_case1 + " SOC boxplots " + use_case2
        #plt.figure(title,figsize=(20, 20))
    
        plt.title(title)

        boxprops = dict(color="red",linewidth=1.5)
        medianprops = dict(color="red",linewidth=1.5)
    
        ax1.tick_params(axis='y', colors='red')
        if (soc_ylimit>0):
            ax1.set_ylim([0, soc_ylimit])
    
        pd_df1.boxplot(ax=ax1, rot=90, boxprops=boxprops,medianprops=medianprops)
        #ax1.xticks(rotation = 90)
        #ax1.tight_layout()
    
        ax2 = ax1.twinx()
    
        boxprops = dict(color="green", linewidth=1.5)
        medianprops = dict(color="green",linewidth=1.5)
     
        ax2.tick_params(axis='y', colors='green')
        if (soc_ylimit>0):
            ax2.set_ylim([0, soc_ylimit])

        pd_df2.boxplot(ax=ax2, rot=90, boxprops=boxprops,medianprops=medianprops, grid=False)
    
        save_title = "../PLOTS/" + desired_file_output + title + ".png"
        save_title = save_title.replace(",","")
        save_title = save_title.replace(" ","_")
        plt.savefig(save_title, dpi=100, bbox_inches='tight')
        
        plt.show()
        plt.close(fig)
# Out:
# 0 0
# [['NF_N1X Bones nerves spinal', []], ['NF_N2X Muscles tendons ligaments', []], ['NF_N3X Open Wounds', []], ['NF_N4X Surface wound', []], ['NF_N5X Burns corrosion', []], ['NF_N6X Intracranial', []], ['NF_N7X Enviromental', []], ['NF_N8X Multiple trauma', []], ['NF_N9X Other trauma', []]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_880222/2211674292.py in <module>
#      47                 dat1 = data1[y_index][1][soc_index]
#      48                 tmp1.append(dat1)
# ---> 49                 dat2 = data2[y_index][1][soc_index]
#      50                 tmp2.append(dat2)
#      51
#
# IndexError: list index out of range
