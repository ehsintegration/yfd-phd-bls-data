# %%
import os

try:
    os.mkdir("../PLOTS/NF_BOX_RACE")
except:
    print("NF_BOX_RACE dir exists.")

#For testing, leave commented
swivel = 1

# F ORDER
#swivel_order = [2, 1, 7, 3, 16, 6, 12, 9, 10, 4, 5, 15, 8, 14, 20, 0, 22, 13, 19, 11, 18, 21, 17]

# NF ORDER
swivel_order = [22, 2, 6, 1, 3, 0, 4, 8, 7, 15, 5, 14, 16, 9, 12, 18, 20, 17, 13, 10, 19, 21, 11]

desired_file_prefix = "NF_R" 

normalize_data=True

lnconvert=False
# Out:
# NF_BOX_RACE dir exists.

# %%
by_year = 1

"""
year = 8

desired_file_output = "./F_BOX_RACE/F_R_ALL_"

# %run ./analysis-code-race.ipynb
"""

# ##################### NON-FATAL

desired_file_prefix = "NF_R" 

rw_global_y_soc1 = []
rb_global_y_soc1 = []
ra_global_y_soc1 = []
rh_global_y_soc1 = []
rh2_global_y_soc1 = []

rsq_array = []

for year in range(0,8):       
    desired_file_output = "./NF_BOX_RACE/NF_R_" + str(2011+year) + "_"    
    # %run ./box-analysis-code-race.ipynb
# Out:
# SOC_all.csv
# global_y_soc1 not found....defining
# global_soc1_empty not found....defining
# NF_RGX_NR_all.csv
# NF_RAX_AmericanIndian_AlaskaNative_all.csv
# NF_RCX_Black_AfricanAmerican_all.csv
# Importing  ../DATA/SOC_all.csv
# NF_RIX_Hispanic_all.csv
# Importing  ../DATA/NF_RCX_Black_AfricanAmerican_all.csv
# NF_RHX_Multi_all.csv
# NF_REX_Hawaiian_all.csv
# NF_RFX_White_all.csv
# Importing  ../DATA/NF_RIX_Hispanic_all.csv
# NF_RBX_Asian_all.csv
# Importing  ../DATA/NF_RFX_White_all.csv
# NF_RDX_Hispanic_all.csv
# Importing  ../DATA/NF_RBX_Asian_all.csv
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# NF_RCX_Black_AfricanAmerican
# 00 NF_RCX_Black_AfricanAmerican
# 11 NF_RCX_Black_AfricanAmerican
# 13 NF_RCX_Black_AfricanAmerican
# 15 NF_RCX_Black_AfricanAmerican
# 17 NF_RCX_Black_AfricanAmerican
# 19 NF_RCX_Black_AfricanAmerican
# 21 NF_RCX_Black_AfricanAmerican
# 23 NF_RCX_Black_AfricanAmerican
# 25 NF_RCX_Black_AfricanAmerican
# 27 NF_RCX_Black_AfricanAmerican
# 29 NF_RCX_Black_AfricanAmerican
# 31 NF_RCX_Black_AfricanAmerican
# 33 NF_RCX_Black_AfricanAmerican
# 35 NF_RCX_Black_AfricanAmerican
# 37 NF_RCX_Black_AfricanAmerican
# 39 NF_RCX_Black_AfricanAmerican
# 41 NF_RCX_Black_AfricanAmerican
# 43 NF_RCX_Black_AfricanAmerican
# 45 NF_RCX_Black_AfricanAmerican
# 47 NF_RCX_Black_AfricanAmerican
# 49 NF_RCX_Black_AfricanAmerican
# 51 NF_RCX_Black_AfricanAmerican
# 53 NF_RCX_Black_AfricanAmerican
# 55 NF_RCX_Black_AfricanAmerican
# Suggested swivel order
# [22, 3, 6, 2, 1, 8, 0, 15, 4, 7, 16, 5, 14, 9, 18, 12, 17, 20, 19, 21, 13, 11, 10]
# NF_RIX_Hispanic
# 00 NF_RIX_Hispanic
# 11 NF_RIX_Hispanic
# 13 NF_RIX_Hispanic
# 15 NF_RIX_Hispanic
# 17 NF_RIX_Hispanic
# 19 NF_RIX_Hispanic
# 21 NF_RIX_Hispanic
# 23 NF_RIX_Hispanic
# 25 NF_RIX_Hispanic
# 27 NF_RIX_Hispanic
# 29 NF_RIX_Hispanic
# 31 NF_RIX_Hispanic
# 33 NF_RIX_Hispanic
# 35 NF_RIX_Hispanic
# 37 NF_RIX_Hispanic
# 39 NF_RIX_Hispanic
# 41 NF_RIX_Hispanic
# 43 NF_RIX_Hispanic
# 45 NF_RIX_Hispanic
# 47 NF_RIX_Hispanic
# 49 NF_RIX_Hispanic
# 51 NF_RIX_Hispanic
# 53 NF_RIX_Hispanic
# 55 NF_RIX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [1, 2, 3, 4, 5, 6, 8, 11, 14, 17, 18, 22, 15, 9, 16, 0, 12, 20, 7, 10, 21, 19, 13]
# NF_RFX_White
# 00 NF_RFX_White
# 11 NF_RFX_White
# 13 NF_RFX_White
# 15 NF_RFX_White
# 17 NF_RFX_White
# 19 NF_RFX_White
# 21 NF_RFX_White
# 23 NF_RFX_White
# 25 NF_RFX_White
# 27 NF_RFX_White
# 29 NF_RFX_White
# 31 NF_RFX_White
# 33 NF_RFX_White
# 35 NF_RFX_White
# 37 NF_RFX_White
# 39 NF_RFX_White
# 41 NF_RFX_White
# 43 NF_RFX_White
# 45 NF_RFX_White
# 47 NF_RFX_White
# 49 NF_RFX_White
# 51 NF_RFX_White
# 53 NF_RFX_White
# 55 NF_RFX_White
# Suggested swivel order
# [22, 2, 1, 6, 3, 4, 0, 8, 15, 5, 16, 7, 14, 17, 9, 12, 18, 13, 20, 21, 10, 19, 11]
# NF_RBX_Asian
# 00 NF_RBX_Asian
# 11 NF_RBX_Asian
# 13 NF_RBX_Asian
# 15 NF_RBX_Asian
# 17 NF_RBX_Asian
# 19 NF_RBX_Asian
# 21 NF_RBX_Asian
# 23 NF_RBX_Asian
# 25 NF_RBX_Asian
# 27 NF_RBX_Asian
# 29 NF_RBX_Asian
# 31 NF_RBX_Asian
# 33 NF_RBX_Asian
# 35 NF_RBX_Asian
# 37 NF_RBX_Asian
# 39 NF_RBX_Asian
# 41 NF_RBX_Asian
# 43 NF_RBX_Asian
# 45 NF_RBX_Asian
# 47 NF_RBX_Asian
# 49 NF_RBX_Asian
# 51 NF_RBX_Asian
# 53 NF_RBX_Asian
# 55 NF_RBX_Asian
# Suggested swivel order
# [6, 22, 2, 3, 8, 1, 7, 0, 4, 15, 5, 14, 16, 9, 17, 18, 12, 21, 20, 19, 10, 11, 13]
# NF_RDX_Hispanic
# 00 NF_RDX_Hispanic
# 11 NF_RDX_Hispanic
# 13 NF_RDX_Hispanic
# 15 NF_RDX_Hispanic
# 17 NF_RDX_Hispanic
# 19 NF_RDX_Hispanic
# 21 NF_RDX_Hispanic
# 23 NF_RDX_Hispanic
# 25 NF_RDX_Hispanic
# 27 NF_RDX_Hispanic
# 29 NF_RDX_Hispanic
# 31 NF_RDX_Hispanic
# 33 NF_RDX_Hispanic
# 35 NF_RDX_Hispanic
# 37 NF_RDX_Hispanic
# 39 NF_RDX_Hispanic
# 41 NF_RDX_Hispanic
# 43 NF_RDX_Hispanic
# 45 NF_RDX_Hispanic
# 47 NF_RDX_Hispanic
# 49 NF_RDX_Hispanic
# 51 NF_RDX_Hispanic
# 53 NF_RDX_Hispanic
# 55 NF_RDX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [22, 2, 4, 3, 1, 6, 0, 9, 14, 15, 7, 8, 5, 16, 12, 10, 20, 21, 19, 11, 18, 13, 17]
# ['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_RGX_NR_all.csv
# NF_RAX_AmericanIndian_AlaskaNative_all.csv
# NF_RCX_Black_AfricanAmerican_all.csv
# Importing  ../DATA/SOC_all.csv
# NF_RIX_Hispanic_all.csv
# Importing  ../DATA/NF_RCX_Black_AfricanAmerican_all.csv
# NF_RHX_Multi_all.csv
# NF_REX_Hawaiian_all.csv
# NF_RFX_White_all.csv
# Importing  ../DATA/NF_RIX_Hispanic_all.csv
# NF_RBX_Asian_all.csv
# Importing  ../DATA/NF_RFX_White_all.csv
# NF_RDX_Hispanic_all.csv
# Importing  ../DATA/NF_RBX_Asian_all.csv
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# NF_RCX_Black_AfricanAmerican
# 00 NF_RCX_Black_AfricanAmerican
# 11 NF_RCX_Black_AfricanAmerican
# 13 NF_RCX_Black_AfricanAmerican
# 15 NF_RCX_Black_AfricanAmerican
# 17 NF_RCX_Black_AfricanAmerican
# 19 NF_RCX_Black_AfricanAmerican
# 21 NF_RCX_Black_AfricanAmerican
# 23 NF_RCX_Black_AfricanAmerican
# 25 NF_RCX_Black_AfricanAmerican
# 27 NF_RCX_Black_AfricanAmerican
# 29 NF_RCX_Black_AfricanAmerican
# 31 NF_RCX_Black_AfricanAmerican
# 33 NF_RCX_Black_AfricanAmerican
# 35 NF_RCX_Black_AfricanAmerican
# 37 NF_RCX_Black_AfricanAmerican
# 39 NF_RCX_Black_AfricanAmerican
# 41 NF_RCX_Black_AfricanAmerican
# 43 NF_RCX_Black_AfricanAmerican
# 45 NF_RCX_Black_AfricanAmerican
# 47 NF_RCX_Black_AfricanAmerican
# 49 NF_RCX_Black_AfricanAmerican
# 51 NF_RCX_Black_AfricanAmerican
# 53 NF_RCX_Black_AfricanAmerican
# 55 NF_RCX_Black_AfricanAmerican
# Suggested swivel order
# [22, 2, 3, 1, 4, 6, 0, 15, 16, 7, 8, 9, 14, 5, 12, 18, 20, 11, 21, 19, 13, 10, 17]
# NF_RIX_Hispanic
# 00 NF_RIX_Hispanic
# 11 NF_RIX_Hispanic
# 13 NF_RIX_Hispanic
# 15 NF_RIX_Hispanic
# 17 NF_RIX_Hispanic
# 19 NF_RIX_Hispanic
# 21 NF_RIX_Hispanic
# 23 NF_RIX_Hispanic
# 25 NF_RIX_Hispanic
# 27 NF_RIX_Hispanic
# 29 NF_RIX_Hispanic
# 31 NF_RIX_Hispanic
# 33 NF_RIX_Hispanic
# 35 NF_RIX_Hispanic
# 37 NF_RIX_Hispanic
# 39 NF_RIX_Hispanic
# 41 NF_RIX_Hispanic
# 43 NF_RIX_Hispanic
# 45 NF_RIX_Hispanic
# 47 NF_RIX_Hispanic
# 49 NF_RIX_Hispanic
# 51 NF_RIX_Hispanic
# 53 NF_RIX_Hispanic
# 55 NF_RIX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [1, 2, 3, 4, 5, 6, 17, 22, 0, 16, 14, 9, 12, 7, 8, 19, 20, 18, 21, 13, 10, 15, 11]
# NF_RFX_White
# 00 NF_RFX_White
# 11 NF_RFX_White
# 13 NF_RFX_White
# 15 NF_RFX_White
# 17 NF_RFX_White
# 19 NF_RFX_White
# 21 NF_RFX_White
# 23 NF_RFX_White
# 25 NF_RFX_White
# 27 NF_RFX_White
# 29 NF_RFX_White
# 31 NF_RFX_White
# 33 NF_RFX_White
# 35 NF_RFX_White
# 37 NF_RFX_White
# 39 NF_RFX_White
# 41 NF_RFX_White
# 43 NF_RFX_White
# 45 NF_RFX_White
# 47 NF_RFX_White
# 49 NF_RFX_White
# 51 NF_RFX_White
# 53 NF_RFX_White
# 55 NF_RFX_White
# Suggested swivel order
# [22, 2, 6, 1, 3, 8, 4, 0, 15, 16, 7, 5, 14, 17, 9, 12, 13, 18, 20, 21, 10, 19, 11]
# NF_RBX_Asian
# 00 NF_RBX_Asian
# 11 NF_RBX_Asian
# 13 NF_RBX_Asian
# 15 NF_RBX_Asian
# 17 NF_RBX_Asian
# 19 NF_RBX_Asian
# 21 NF_RBX_Asian
# 23 NF_RBX_Asian
# 25 NF_RBX_Asian
# 27 NF_RBX_Asian
# 29 NF_RBX_Asian
# 31 NF_RBX_Asian
# 33 NF_RBX_Asian
# 35 NF_RBX_Asian
# 37 NF_RBX_Asian
# 39 NF_RBX_Asian
# 41 NF_RBX_Asian
# 43 NF_RBX_Asian
# 45 NF_RBX_Asian
# 47 NF_RBX_Asian
# 49 NF_RBX_Asian
# 51 NF_RBX_Asian
# 53 NF_RBX_Asian
# 55 NF_RBX_Asian
# Suggested swivel order
# [6, 22, 2, 1, 0, 3, 4, 8, 7, 14, 15, 16, 5, 9, 18, 21, 12, 20, 10, 19, 13, 17, 11]
# NF_RDX_Hispanic
# 00 NF_RDX_Hispanic
# 11 NF_RDX_Hispanic
# 13 NF_RDX_Hispanic
# 15 NF_RDX_Hispanic
# 17 NF_RDX_Hispanic
# 19 NF_RDX_Hispanic
# 21 NF_RDX_Hispanic
# 23 NF_RDX_Hispanic
# 25 NF_RDX_Hispanic
# 27 NF_RDX_Hispanic
# 29 NF_RDX_Hispanic
# 31 NF_RDX_Hispanic
# 33 NF_RDX_Hispanic
# 35 NF_RDX_Hispanic
# 37 NF_RDX_Hispanic
# 39 NF_RDX_Hispanic
# 41 NF_RDX_Hispanic
# 43 NF_RDX_Hispanic
# 45 NF_RDX_Hispanic
# 47 NF_RDX_Hispanic
# 49 NF_RDX_Hispanic
# 51 NF_RDX_Hispanic
# 53 NF_RDX_Hispanic
# 55 NF_RDX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [22, 2, 3, 4, 1, 6, 0, 8, 9, 7, 15, 14, 5, 16, 10, 12, 20, 21, 11, 19, 18, 13, 17]
# ['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_RGX_NR_all.csv
# NF_RAX_AmericanIndian_AlaskaNative_all.csv
# NF_RCX_Black_AfricanAmerican_all.csv
# Importing  ../DATA/SOC_all.csv
# NF_RIX_Hispanic_all.csv
# Importing  ../DATA/NF_RCX_Black_AfricanAmerican_all.csv
# NF_RHX_Multi_all.csv
# NF_REX_Hawaiian_all.csv
# NF_RFX_White_all.csv
# Importing  ../DATA/NF_RIX_Hispanic_all.csv
# NF_RBX_Asian_all.csv
# Importing  ../DATA/NF_RFX_White_all.csv
# NF_RDX_Hispanic_all.csv
# Importing  ../DATA/NF_RBX_Asian_all.csv
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# NF_RCX_Black_AfricanAmerican
# 00 NF_RCX_Black_AfricanAmerican
# 11 NF_RCX_Black_AfricanAmerican
# 13 NF_RCX_Black_AfricanAmerican
# 15 NF_RCX_Black_AfricanAmerican
# 17 NF_RCX_Black_AfricanAmerican
# 19 NF_RCX_Black_AfricanAmerican
# 21 NF_RCX_Black_AfricanAmerican
# 23 NF_RCX_Black_AfricanAmerican
# 25 NF_RCX_Black_AfricanAmerican
# 27 NF_RCX_Black_AfricanAmerican
# 29 NF_RCX_Black_AfricanAmerican
# 31 NF_RCX_Black_AfricanAmerican
# 33 NF_RCX_Black_AfricanAmerican
# 35 NF_RCX_Black_AfricanAmerican
# 37 NF_RCX_Black_AfricanAmerican
# 39 NF_RCX_Black_AfricanAmerican
# 41 NF_RCX_Black_AfricanAmerican
# 43 NF_RCX_Black_AfricanAmerican
# 45 NF_RCX_Black_AfricanAmerican
# 47 NF_RCX_Black_AfricanAmerican
# 49 NF_RCX_Black_AfricanAmerican
# 51 NF_RCX_Black_AfricanAmerican
# 53 NF_RCX_Black_AfricanAmerican
# 55 NF_RCX_Black_AfricanAmerican
# Suggested swivel order
# [22, 2, 3, 6, 1, 0, 15, 4, 16, 8, 7, 14, 18, 9, 12, 5, 20, 13, 19, 11, 21, 17, 10]
# NF_RIX_Hispanic
# 00 NF_RIX_Hispanic
# 11 NF_RIX_Hispanic
# 13 NF_RIX_Hispanic
# 15 NF_RIX_Hispanic
# 17 NF_RIX_Hispanic
# 19 NF_RIX_Hispanic
# 21 NF_RIX_Hispanic
# 23 NF_RIX_Hispanic
# 25 NF_RIX_Hispanic
# 27 NF_RIX_Hispanic
# 29 NF_RIX_Hispanic
# 31 NF_RIX_Hispanic
# 33 NF_RIX_Hispanic
# 35 NF_RIX_Hispanic
# 37 NF_RIX_Hispanic
# 39 NF_RIX_Hispanic
# 41 NF_RIX_Hispanic
# 43 NF_RIX_Hispanic
# 45 NF_RIX_Hispanic
# 47 NF_RIX_Hispanic
# 49 NF_RIX_Hispanic
# 51 NF_RIX_Hispanic
# 53 NF_RIX_Hispanic
# 55 NF_RIX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [0, 1, 2, 3, 4, 5, 6, 8, 17, 18, 22, 14, 9, 15, 7, 16, 20, 12, 13, 21, 19, 11, 10]
# NF_RFX_White
# 00 NF_RFX_White
# 11 NF_RFX_White
# 13 NF_RFX_White
# 15 NF_RFX_White
# 17 NF_RFX_White
# 19 NF_RFX_White
# 21 NF_RFX_White
# 23 NF_RFX_White
# 25 NF_RFX_White
# 27 NF_RFX_White
# 29 NF_RFX_White
# 31 NF_RFX_White
# 33 NF_RFX_White
# 35 NF_RFX_White
# 37 NF_RFX_White
# 39 NF_RFX_White
# 41 NF_RFX_White
# 43 NF_RFX_White
# 45 NF_RFX_White
# 47 NF_RFX_White
# 49 NF_RFX_White
# 51 NF_RFX_White
# 53 NF_RFX_White
# 55 NF_RFX_White
# Suggested swivel order
# [22, 2, 6, 1, 3, 0, 4, 8, 15, 16, 7, 5, 17, 14, 9, 12, 13, 18, 20, 21, 10, 19, 11]
# NF_RBX_Asian
# 00 NF_RBX_Asian
# 11 NF_RBX_Asian
# 13 NF_RBX_Asian
# 15 NF_RBX_Asian
# 17 NF_RBX_Asian
# 19 NF_RBX_Asian
# 21 NF_RBX_Asian
# 23 NF_RBX_Asian
# 25 NF_RBX_Asian
# 27 NF_RBX_Asian
# 29 NF_RBX_Asian
# 31 NF_RBX_Asian
# 33 NF_RBX_Asian
# 35 NF_RBX_Asian
# 37 NF_RBX_Asian
# 39 NF_RBX_Asian
# 41 NF_RBX_Asian
# 43 NF_RBX_Asian
# 45 NF_RBX_Asian
# 47 NF_RBX_Asian
# 49 NF_RBX_Asian
# 51 NF_RBX_Asian
# 53 NF_RBX_Asian
# 55 NF_RBX_Asian
# Suggested swivel order
# [22, 2, 3, 1, 6, 0, 14, 7, 8, 15, 4, 5, 16, 9, 17, 18, 21, 12, 19, 20, 11, 10, 13]
# NF_RDX_Hispanic
# 00 NF_RDX_Hispanic
# 11 NF_RDX_Hispanic
# 13 NF_RDX_Hispanic
# 15 NF_RDX_Hispanic
# 17 NF_RDX_Hispanic
# 19 NF_RDX_Hispanic
# 21 NF_RDX_Hispanic
# 23 NF_RDX_Hispanic
# 25 NF_RDX_Hispanic
# 27 NF_RDX_Hispanic
# 29 NF_RDX_Hispanic
# 31 NF_RDX_Hispanic
# 33 NF_RDX_Hispanic
# 35 NF_RDX_Hispanic
# 37 NF_RDX_Hispanic
# 39 NF_RDX_Hispanic
# 41 NF_RDX_Hispanic
# 43 NF_RDX_Hispanic
# 45 NF_RDX_Hispanic
# 47 NF_RDX_Hispanic
# 49 NF_RDX_Hispanic
# 51 NF_RDX_Hispanic
# 53 NF_RDX_Hispanic
# 55 NF_RDX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [22, 2, 3, 1, 4, 6, 0, 8, 9, 14, 7, 15, 16, 5, 10, 12, 20, 21, 11, 19, 13, 18, 17]
# ['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_RGX_NR_all.csv
# NF_RAX_AmericanIndian_AlaskaNative_all.csv
# NF_RCX_Black_AfricanAmerican_all.csv
# Importing  ../DATA/SOC_all.csv
# NF_RIX_Hispanic_all.csv
# Importing  ../DATA/NF_RCX_Black_AfricanAmerican_all.csv
# NF_RHX_Multi_all.csv
# NF_REX_Hawaiian_all.csv
# NF_RFX_White_all.csv
# Importing  ../DATA/NF_RIX_Hispanic_all.csv
# NF_RBX_Asian_all.csv
# Importing  ../DATA/NF_RFX_White_all.csv
# NF_RDX_Hispanic_all.csv
# Importing  ../DATA/NF_RBX_Asian_all.csv
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# NF_RCX_Black_AfricanAmerican
# 00 NF_RCX_Black_AfricanAmerican
# 11 NF_RCX_Black_AfricanAmerican
# 13 NF_RCX_Black_AfricanAmerican
# 15 NF_RCX_Black_AfricanAmerican
# 17 NF_RCX_Black_AfricanAmerican
# 19 NF_RCX_Black_AfricanAmerican
# 21 NF_RCX_Black_AfricanAmerican
# 23 NF_RCX_Black_AfricanAmerican
# 25 NF_RCX_Black_AfricanAmerican
# 27 NF_RCX_Black_AfricanAmerican
# 29 NF_RCX_Black_AfricanAmerican
# 31 NF_RCX_Black_AfricanAmerican
# 33 NF_RCX_Black_AfricanAmerican
# 35 NF_RCX_Black_AfricanAmerican
# 37 NF_RCX_Black_AfricanAmerican
# 39 NF_RCX_Black_AfricanAmerican
# 41 NF_RCX_Black_AfricanAmerican
# 43 NF_RCX_Black_AfricanAmerican
# 45 NF_RCX_Black_AfricanAmerican
# 47 NF_RCX_Black_AfricanAmerican
# 49 NF_RCX_Black_AfricanAmerican
# 51 NF_RCX_Black_AfricanAmerican
# 53 NF_RCX_Black_AfricanAmerican
# 55 NF_RCX_Black_AfricanAmerican
# Suggested swivel order
# [22, 2,
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# NF_RCX_Black_AfricanAmerican
# 00 NF_RCX_Black_AfricanAmerican
# 11 NF_RCX_Black_AfricanAmerican
# 13 NF_RCX_Black_AfricanAmerican
# 15 NF_RCX_Black_AfricanAmerican
# 17 NF_RCX_Black_AfricanAmerican
# 19 NF_RCX_Black_AfricanAmerican
# 21 NF_RCX_Black_AfricanAmerican
# 23 NF_RCX_Black_AfricanAmerican
# 25 NF_RCX_Black_AfricanAmerican
# 27 NF_RCX_Black_AfricanAmerican
# 29 NF_RCX_Black_AfricanAmerican
# 31 NF_RCX_Black_AfricanAmerican
# 33 NF_RCX_Black_AfricanAmerican
# 35 NF_RCX_Black_AfricanAmerican
# 37 NF_RCX_Black_AfricanAmerican
# 39 NF_RCX_Black_AfricanAmerican
# 41 NF_RCX_Black_AfricanAmerican
# 43 NF_RCX_Black_AfricanAmerican
# 45 NF_RCX_Black_AfricanAmerican
# 47 NF_RCX_Black_AfricanAmerican
# 49 NF_RCX_Black_AfricanAmerican
# 51 NF_RCX_Black_AfricanAmerican
# 53 NF_RCX_Black_AfricanAmerican
# 55 NF_RCX_Black_AfricanAmerican
# Suggested swivel order
# [22, 2, 6, 1, 8, 4, 0, 3, 15, 16, 7, 9, 12, 14, 5, 17, 20, 18, 13, 11, 19, 21, 10]
# NF_RIX_Hispanic
# 00 NF_RIX_Hispanic
# 11 NF_RIX_Hispanic
# 13 NF_RIX_Hispanic
# 15 NF_RIX_Hispanic
# 17 NF_RIX_Hispanic
# 19 NF_RIX_Hispanic
# 21 NF_RIX_Hispanic
# 23 NF_RIX_Hispanic
# 25 NF_RIX_Hispanic
# 27 NF_RIX_Hispanic
# 29 NF_RIX_Hispanic
# 31 NF_RIX_Hispanic
# 33 NF_RIX_Hispanic
# 35 NF_RIX_Hispanic
# 37 NF_RIX_Hispanic
# 39 NF_RIX_Hispanic
# 41 NF_RIX_Hispanic
# 43 NF_RIX_Hispanic
# 45 NF_RIX_Hispanic
# 47 NF_RIX_Hispanic
# 49 NF_RIX_Hispanic
# 51 NF_RIX_Hispanic
# 53 NF_RIX_Hispanic
# 55 NF_RIX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [1, 2, 3, 4, 5, 6, 8, 14, 17, 22, 9, 12, 7, 0, 10, 13, 16, 20, 15, 11, 19, 21, 18]
# NF_RFX_White
# 00 NF_RFX_White
# 11 NF_RFX_White
# 13 NF_RFX_White
# 15 NF_RFX_White
# 17 NF_RFX_White
# 19 NF_RFX_White
# 21 NF_RFX_White
# 23 NF_RFX_White
# 25 NF_RFX_White
# 27 NF_RFX_White
# 29 NF_RFX_White
# 31 NF_RFX_White
# 33 NF_RFX_White
# 35 NF_RFX_White
# 37 NF_RFX_White
# 39 NF_RFX_White
# 41 NF_RFX_White
# 43 NF_RFX_White
# 45 NF_RFX_White
# 47 NF_RFX_White
# 49 NF_RFX_White
# 51 NF_RFX_White
# 53 NF_RFX_White
# 55 NF_RFX_White
# Suggested swivel order
# [22, 2, 6, 1, 3, 4, 0, 8, 15, 16, 5, 7, 14, 9, 17, 12, 13, 18, 20, 10, 21, 19, 11]
# NF_RBX_Asian
# 00 NF_RBX_Asian
# 11 NF_RBX_Asian
# 13 NF_RBX_Asian
# 15 NF_RBX_Asian
# 17 NF_RBX_Asian
# 19 NF_RBX_Asian
# 21 NF_RBX_Asian
# 23 NF_RBX_Asian
# 25 NF_RBX_Asian
# 27 NF_RBX_Asian
# 29 NF_RBX_Asian
# 31 NF_RBX_Asian
# 33 NF_RBX_Asian
# 35 NF_RBX_Asian
# 37 NF_RBX_Asian
# 39 NF_RBX_Asian
# 41 NF_RBX_Asian
# 43 NF_RBX_Asian
# 45 NF_RBX_Asian
# 47 NF_RBX_Asian
# 49 NF_RBX_Asian
# 51 NF_RBX_Asian
# 53 NF_RBX_Asian
# 55 NF_RBX_Asian
# Suggested swivel order
# [6, 22, 2, 3, 1, 4, 14, 8, 5, 15, 0, 16, 7, 9, 18, 17, 12, 19, 21, 20, 10, 11, 13]
# NF_RDX_Hispanic
# 00 NF_RDX_Hispanic
# 11 NF_RDX_Hispanic
# 13 NF_RDX_Hispanic
# 15 NF_RDX_Hispanic
# 17 NF_RDX_Hispanic
# 19 NF_RDX_Hispanic
# 21 NF_RDX_Hispanic
# 23 NF_RDX_Hispanic
# 25 NF_RDX_Hispanic
# 27 NF_RDX_Hispanic
# 29 NF_RDX_Hispanic
# 31 NF_RDX_Hispanic
# 33 NF_RDX_Hispanic
# 35 NF_RDX_Hispanic
# 37 NF_RDX_Hispanic
# 39 NF_RDX_Hispanic
# 41 NF_RDX_Hispanic
# 43 NF_RDX_Hispanic
# 45 NF_RDX_Hispanic
# 47 NF_RDX_Hispanic
# 49 NF_RDX_Hispanic
# 51 NF_RDX_Hispanic
# 53 NF_RDX_Hispanic
# 55 NF_RDX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [22, 2, 6, 3, 4, 1, 8, 0, 9, 15, 14, 7, 16, 5, 10, 12, 20, 21, 11, 19, 13, 18, 17]
# ['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic']

# %% [markdown]
# # Age boxblots

# %%
#print(rh2_global_y_soc1)

# %%
for index in range(0,5): 
    # Creating pandas |dataframe from numpy array
    #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })

    pd_df = pd.DataFrame()
    sel_y = []

    if (index == 0):
        name = "White"
        sel_y = rw_global_y_soc1
    elif (index == 1):
        name = "Black"
        sel_y = rb_global_y_soc1
    elif (index == 2):
        name = "Asian"
        sel_y = ra_global_y_soc1
    elif (index == 3):
        name = "RIX_Hispanic"
        sel_y = rh_global_y_soc1
    elif (index == 4):
        name = "RDX_Hispanic"
        sel_y = rh2_global_y_soc1

    #print(sel_y)
        
    for index in range(0,len(sel_y)):
        pd_df[sel_y[index][0]] = sel_y[index][1]

    #print(pd_df)
    
    title = desired_file_prefix + " boxplots " + str(name)
    plt.figure(title,figsize=(10, 10))
    plt.title(title)

    #plt.ylim(0.0, 0.15)

    pd_df.boxplot()
    plt.xticks(rotation = 90)
    plt.tight_layout()

    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    
    plt.show()

    #plt.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2692612/2948017912.py in <module>
#      35     #plt.ylim(0.0, 0.15)
#      36
# ---> 37     pd_df.boxplot()
#      38     plt.xticks(rotation = 90)
#      39     plt.tight_layout()
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     509 ):
#     510     plot_backend = _get_plot_backend(backend)
# --> 511     return plot_backend.boxplot_frame(
#     512         self,
#     513         column=column,
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     423     import matplotlib.pyplot as plt
#     424
# --> 425     ax = boxplot(
#     426         self,
#     427         column=column,
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     394         naxes = len(data.columns)
#     395         if naxes == 0:
# --> 396             raise ValueError(
#     397                 "boxplot method requires numerical columns, nothing to plot."
#     398             )
#
# ValueError: boxplot method requires numerical columns, nothing to plot.

# %% [markdown]
# # SOC BOXPLOTS

# %%
alist = [
    ["NF_RWT White", rw_global_y_soc1],
    ["NF_RBT Black", rb_global_y_soc1],
    ["NF_RAT Asian", ra_global_y_soc1],
    #["NF_RIX Hispanic", rh_global_y_soc1],
    ["NF_RDX Hispanic", rh2_global_y_soc1] ]

for arr in alist:
    use_case= arr[0]
    data    = arr[1]
    
    soc_box = []

    for soc_index in range (0,23):
        tmp = []
        avg = np.zeros(23)
        for y_index in range(0,8):
            #avg = ( np.array(male_global_y_soc1[y_index][1][soc_index]) + np.array(female_global_y_soc1[y_index][1][soc_index]) )/2
            #avg = a35_global_y_soc1[y_index][1][soc_index]
            avg = data[y_index][1][soc_index]
            tmp.append(avg)
         
        soc_box.append(tmp)    
    #print(soc_box)

    # BOX PLOT per occupation
    jlist = []
    for jb in range(1,24):
       jlist.append(job_code[jb][1])
    #print(jlist)

    #print(jlist[22])

    # Creating pandas |dataframe from numpy array
    #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
    pd_df = pd.DataFrame(columns=jlist)

    #global_y_soc1 = female_global_y_soc1

    for index in range(0,23):
        pd_df[jlist[index]] = soc_box[index]
     
    print("STDEV for " + use_case)
    
    title =  use_case + " STDEV(RED) and MEAN(GREEN)"
    
    # Creating plot with dataset_1
    fig, ax1 = plt.subplots(figsize=(10, 10))
    plt.title(title)
    
    ax1.plot(pd_df.std(), 'r-')

    plt.xticks(rotation = 90)
    
    ax2 = ax1.twinx()
    ax2.plot(pd_df.mean(), 'g-')
    
    ax1.tick_params(axis='y', colors='red')
    ax2.tick_params(axis='y', colors='green')
    
    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    plt.show()
    plt.close()
# Out:
# STDEV for NF_RWT White
# STDEV for NF_RBT Black
# STDEV for NF_RAT Asian
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2692612/204849875.py in <module>
#      18             #avg = ( np.array(male_global_y_soc1[y_index][1][soc_index]) + np.array(female_global_y_soc1[y_index][1][soc_index]) )/2
#      19             #avg = a35_global_y_soc1[y_index][1][soc_index]
# ---> 20             avg = data[y_index][1][soc_index]
#      21             tmp.append(avg)
#      22
#
# IndexError: list index out of range
