# %%
from statsmodels.formula.api import ols
from statsmodels.graphics.api import interaction_plot, abline_plot
from statsmodels.stats.anova import anova_lm

import statsmodels.api as sm

import dataframe_image as dfi

import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
import os

try:
    os.mkdir("../PLOTS/F_SUBAVG_NATURE")
except:
    print("F_SUBAVG_NATURE dir exists.")

    7
swivel = 0

#F ORDER
#swivel_order = [2, 1, 7, 3, 16, 6, 12, 9, 10, 4, 5, 15, 8, 14, 20, 0, 22, 13, 19, 11, 18, 21, 17]
swivel_order = [2, 1, 7, 3, 16, 6, 12, 9, 10, 4, 5, 15, 8, 14, 20, 0, 13, 19, 11, 18, 21, 17]

# NF ORDER
#swivel_order = [22, 2, 6, 1, 3, 0, 4, 8, 7, 15, 5, 14, 16, 9, 12, 18, 20, 17, 13, 10, 19, 21, 11]
#swivel_order = [2, 6, 1, 3, 0, 4, 8, 7, 15, 5, 14, 16, 9, 12, 18, 20, 17, 13, 10, 19, 21, 11]

desired_dir_name = "F_SUBAVG_NATURE"
desired_file_prefix = "F_N" 

normalize_data=True

by_year = 1
lnconvert=False

# %% [markdown]
# # FUNCTIONS

# %%
def func(x, m, c):
    return (m * x) + c

# %%
def color_corr_green(val):
  color = 'green' if val > 0.8 else 'black'
  return 'color: %s' % color

# %%
def gen_boxplot():

 case_list = []

 # Create list of data cases
 #
 for index in range(0,len(global_y_soc1)):
    name = global_y_soc1[index][0]
    if (name[5:] not in case_list):
        case_list.append(name[5:])

 print(case_list)

 # Handle one case at a time
 #
 for case in case_list:
        
    #print("case = ",case)
    
    pd_df = pd.DataFrame()
    sel_y = []
    
    for index in range(0,len(global_y_soc1)):
        
        name  = global_y_soc1[index][0]
        sel_y = global_y_soc1[index][1]
        
        # Cycle through years
        #
        if (case in name):    
            #print(case,name)
            name = name[0:5] + name[8:]
            #print("8 ",name)
            
            df = pd.DataFrame()
            df[name] = sel_y
            
            #Q1 = df[name].quantile(0.25)
            #Q3 = df[name].quantile(0.75)
            #IQR = Q3 - Q1    #IQR is interquartile range. 

            #filter = (df[name] >= Q1 - 1.5 * IQR) & (df[name] <= Q3 + 1.5 *IQR)
            #print(filter)
            #df = df.loc[filter]
            
            q = df[name].quantile(0.80)
            df = df[df[name] < q]
            
            pd_df = pd.concat([pd_df,df],axis=1)
        
            #print(pd_df)

    # Get occupation
    for code in soc_new_code:
        #print(code[0][0:2])
        if (code[0][0:2].find(case[0:2]) >= 0):
            #print(code[0],code[1])
            ocup = str(code[0]) + " " + str(code[1])
            
    #print(ocup)

    title = desired_file_prefix + " " + ocup + " boxplot " + str(case[3:])
    plt.figure(title,figsize=(10, 10))
    plt.title(title)

    #plt.ylim(0.0, 3e-6)

    pd_df.boxplot()
    plt.xticks(rotation = 90)
    plt.tight_layout()  

    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    
    plt.show()
    
    #print("HERE")
    #print(df[df['YEAR'].str.contains(name)])
    
    ## ########################## correlations ######################
    
    title = title + "_pearson_corr"

    df_corr = pd_df.corr(method='pearson').style.applymap(color_corr_green)

    df = pd_df.corr(method='pearson')
 
    df_styled = df.style.background_gradient(axis=None, vmin=0.45, vmax=1.0)
  
    save_file = "../PLOTS/" + desired_file_output + title + ".png"
    dfi.export(df_styled, save_file, max_cols=-1, max_rows=-1)

    save_file = "../PLOTS/" + desired_file_output + title + ".xlsx"
    df_corr.to_excel(save_file)

    display(df_styled)

# %% [markdown]
# # ALL CORRELATIONS

# %%
# Generate all correlations
#
def gen_corr():

  pd_df = pd.DataFrame()
  sel_y = []
    
  case_list = []

  # Create list of data cases
  #
  for index in range(0,len(global_y_soc1)):
    name = global_y_soc1[index][0]
    if (name[5:] not in case_list):
        case_list.append(name[5:])

  print(case_list)

  # Handle one case at a time
  #
  for case in case_list:
    
    for index in range(0,len(global_y_soc1)):
        
        name  = global_y_soc1[index][0]
        sel_y = global_y_soc1[index][1]
        
        # Cycle through years
        #
        if (case in name):    
            #print(case,name)
            
            temp_pd_df = pd.DataFrame()
            temp_pd_df[name] = sel_y
            pd_df = pd.concat([pd_df,temp_pd_df],axis=1)
        
            #print(pd_df)

            # Get occupation
            for code in soc_new_code:
                #print(code[0][0:2])
                if (code[0][0:2].find(case[0:2]) >= 0):
                    #print(code[0],code[1])
                    ocup = str(code[0]) + " " + str(code[1])
            
  #print(ocup)

  title = desired_file_prefix + ocup +" ALL boxplot " + str(case[3:])
  plt.figure(title,figsize=(10, 10))
  plt.title(title)

  #plt.ylim(0.0, 3e-6)

  pd_df.boxplot()
  plt.xticks(rotation = 90)
  plt.tight_layout()  

  save_title = "../PLOTS/" + desired_file_output + title + ".png"
  save_title = save_title.replace(",","")
  save_title = save_title.replace(" ","_")
  plt.savefig(save_title, dpi=100, bbox_inches='tight')
    
  plt.show()
    
  #print("HERE")
  #print(df[df['YEAR'].str.contains(name)])
    
  ## ########################## correlations ######################
    
  title = title + "_pearson_corr"

  df_corr = pd_df.corr(method='pearson').style.applymap(color_corr_green)

  df = pd_df.corr(method='pearson')
 
  df_styled = df.style.background_gradient(axis=None, vmin=0.45, vmax=1.0)
  
  save_file = "../PLOTS/" + desired_file_output + title + ".png"
  dfi.export(df_styled, save_file, max_cols=-1, max_rows=-1)

  save_file = "../PLOTS/" + desired_file_output + title + ".xlsx"
  df_corr.to_excel(save_file)

  display(df_styled)

# %% [markdown]
# # COLLATE THE DATA

# %%
lastfound = ""
pcov      = []


no_genericDB_data_dict = {}


ocovper   = []
ocov      = []
lines     = []

global_y_soc1 = []

for ocup_sel in range(1,24):
    
    print("########################################## NEW OCCUPATION ###############################################")
    print("")
    
    for year in range(0,8): 

        print("########################################## NEW YEAR ###############################################")
        
        desired_file_output = "./" + desired_dir_name + "/" + desired_file_prefix + "_" + str(2011+year) + "_"     
        
        # %run ./analysis-code-subcat3-avg.ipynb

        #print(global_y_soc1)
# Out:
# ########################################## NEW OCCUPATION ###############################################
#
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty not found....defining
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 11-0000:Management Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N8X_Multiple_trauma_112021
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113011
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113121
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119013
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119111
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N3X_Open_wounds_112021
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113011
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113121
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119013
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119111
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N5X_Burns_corrosion_113011
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_113121
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_119013
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N6X_Intracranial_112022
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113011
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113131
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119013
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119121
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N1X_Bones_nerves_spinal_112022
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_113031
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119013
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119141
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N9X_Other_trauma_112011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113121
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119013
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119111
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 11-0000:Management Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N8X_Multiple_trauma_112021
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113011
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113121
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119013
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119111
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N3X_Open_wounds_112021
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113011
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113121
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119013
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119111
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N5X_Burns_corrosion_113011
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_113121
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_119013
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N6X_Intracranial_112022
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113011
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113131
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119013
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119121
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N1X_Bones_nerves_spinal_112022
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_113031
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119013
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119141
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N9X_Other_trauma_112011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113121
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119013
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119111
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 11-0000:Management Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N8X_Multiple_trauma_112021
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113011
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113121
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119013
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119111
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N3X_Open_wounds_112021
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113011
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113121
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119013
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119111
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N5X_Burns_corrosion_113011
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_113121
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_119013
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N6X_Intracranial_112022
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113011
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113131
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119013
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119121
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N1X_Bones_nerves_spinal_112022
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_113031
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119013
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119141
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N9X_Other_trauma_112011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113121
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119013
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119111
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 11-0000:Management Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N8X_Multiple_trauma_112021
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113011
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113121
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119013
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119111
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N3X_Open_wounds_112021
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113011
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113121
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119013
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119111
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N5X_Burns_corrosion_113011
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_113121
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_119013
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N6X_Intracranial_112022
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113011
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113131
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119013
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119121
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N1X_Bones_nerves_spinal_112022
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_113031
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119013
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119141
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N9X_Other_trauma_112011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113121
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119013
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119111
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 11-0000:Management Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N8X_Multiple_trauma_112021
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113011
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113121
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119013
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119111
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N3X_Open_wounds_112021
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113011
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113121
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119013
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119111
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N5X_Burns_corrosion_113011
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_113121
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_119013
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N6X_Intracranial_112022
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113011
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113131
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119013
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119121
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N1X_Bones_nerves_spinal_112022
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_113031
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119013
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119141
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N9X_Other_trauma_112011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113121
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119013
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119111
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 11-0000:Management Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N8X_Multiple_trauma_112021
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113011
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113121
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119013
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119111
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N3X_Open_wounds_112021
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113011
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113121
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119013
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119111
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N5X_Burns_corrosion_113011
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_113121
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_119013
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N6X_Intracranial_112022
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113011
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113131
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119013
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119121
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N1X_Bones_nerves_spinal_112022
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_113031
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119013
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119141
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N9X_Other_trauma_112011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113121
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119013
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119111
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 11-0000:Management Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N8X_Multiple_trauma_112021
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113011
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113121
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119013
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119111
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N3X_Open_wounds_112021
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113011
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113121
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119013
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119111
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N5X_Burns_corrosion_113011
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_113121
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_119013
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N6X_Intracranial_112022
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113011
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113131
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119013
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119121
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N1X_Bones_nerves_spinal_112022
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_113031
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119013
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119141
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N9X_Other_trauma_112011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113121
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119013
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119111
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 11-0000:Management Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N8X_Multiple_trauma_112021
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113011
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_113121
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119013
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N8X_Multiple_trauma_119111
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N3X_Open_wounds_112021
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113011
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_113121
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119013
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N3X_Open_wounds_119111
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N5X_Burns_corrosion_113011
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_113121
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N5X_Burns_corrosion_119013
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N6X_Intracranial_112022
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113011
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_113131
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119013
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N6X_Intracranial_119121
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N1X_Bones_nerves_spinal_112022
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_113031
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119013
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N1X_Bones_nerves_spinal_119141
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 11-0000:Management Occupations
# *gt(adding): F_N9X_Other_trauma_112011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113011
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_113121
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119013
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# *gt(adding): F_N9X_Other_trauma_119111
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ...
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 55-0000:Military Specific Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 55-0000:Military Specific Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 55-0000:Military Specific Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 55-0000:Military Specific Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 55-0000:Military Specific Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 55-0000:Military Specific Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# ########################################## NEW YEAR ###############################################
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_N4X_Surface_wound_all.csv
# F_N8X_Multiple_trauma_all.csv
# F_N3X_Open_wounds_all.csv
# F_N7X_Enviromental_all.csv
# F_N5X_Burns_corrosion_all.csv
# F_N6X_Intracranial_all.csv
# F_N1X_Bones_nerves_spinal_all.csv
# F_N2X_Muscles_tendons_ligaments_all.csv
# F_N9X_Other_trauma_all.csv
# dict_keys(['F_N4X_Surface_wound', 'F_N8X_Multiple_trauma', 'F_N3X_Open_wounds', 'F_N7X_Enviromental', 'F_N5X_Burns_corrosion', 'F_N6X_Intracranial', 'F_N1X_Bones_nerves_spinal', 'F_N2X_Muscles_tendons_ligaments', 'F_N9X_Other_trauma'])
# code_found: 55-0000:Military Specific Occupations
# F_N4X_Surface_wound
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N8X_Multiple_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N3X_Open_wounds
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N7X_Enviromental
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N5X_Burns_corrosion
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N6X_Intracranial
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N1X_Bones_nerves_spinal
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N2X_Muscles_tendons_ligaments
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################
# code_found: 55-0000:Military Specific Occupations
# F_N9X_Other_trauma
# ########## NEED TO EVAL ##################
# ########## NEED TO EVAL ##################

# %%
#for i in range(0,200):      #len(global_y_soc1)):
#    print(global_y_soc1[i])

# %% [markdown]
# # SAMPLE STRUCTURE

# %%
for i in range(0,10):      #len(global_y_soc1)):
    print(global_y_soc1[i])
# Out:
# ['2011_NO DATA FOUND-Management Occupations', [0, 0, 0, 0]]
# ['2011_F_N8X_Multiple_trauma_111011-Management Occupations', [2.1902206647319717e-07]]
# ['2011_F_N8X_Multiple_trauma_112021-Management Occupations', [5.475551661829929e-08]]
# ['2011_F_N8X_Multiple_trauma_113011-Management Occupations', [2.1902206647319717e-07]]
# ['2011_F_N8X_Multiple_trauma_113121-Management Occupations', [0, 0, 0, 0]]
# ['2011_F_N8X_Multiple_trauma_119013-Management Occupations', [5.311285111975032e-06, 5.475551661829929e-07, 1.0951103323659858e-07, 2.1902206647319717e-07, 1.0951103323659858e-07]]
# ['2011_F_N8X_Multiple_trauma_119111-Management Occupations', [1.0951103323659858e-07]]
# ['2011_F_N3X_Open_wounds_111011-Management Occupations', [2.7377758309149647e-07, 1.0951103323659858e-07]]
# ['2011_F_N3X_Open_wounds_112021-Management Occupations', [0, 0, 0, 0]]
# ['2011_F_N3X_Open_wounds_113011-Management Occupations', [2.1902206647319717e-07, 1.0951103323659858e-07, 1.0951103323659858e-07]]

# %%
print(global_y_soc1[-1])
# Out:
# ['2018_NO DATA FOUND-Military Specific Occupations', [0, 0, 0, 0]]

# %%
code_list = []

for i in range(0,len(global_y_soc1)):
    ucase = str(global_y_soc1[i][0]).split('-')[0]
    #print(ucase)
    ocup    = "_" + ucase[-6:-4]
    #print(ocup)
    if (ucase.find("NO DATA FOUND") < 0):
        if ocup not in code_list:
            code_list.append(ocup)
        
print(code_list)
# Out:
# ['_11', '_13', '_15', '_17', '_19', '_21', '_23', '_25', '_27', '_29', '_31', '_33', '_35', '_37', '_39', '_41', '_43', '_45', '_47', '_49', '_51', '_53']

# %%
print( str(global_y_soc1[0][0]).split("_")[1:3]  )

ca = global_y_soc1[0][0].split("_")[1:3]
print(ca[0] + "_" + ca[1])
# Out:
# ['NO DATA FOUND-Management Occupations']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_377182/1441931516.py in <module>
#       2
#       3 ca = global_y_soc1[0][0].split("_")[1:3]
# ----> 4 print(ca[0] + "_" + ca[1])
#
# IndexError: list index out of range

# %%
code_list = []
lines     = []

for i in range(0,len(global_y_soc1)):
    ucase = str(global_y_soc1[i][0]).split('-')[0]
    #print(ucase)
    ocup    = "_" + ucase[-6:-4]
    #print(ocup)
    if ocup not in code_list:
        if (str(ocup[1:]).isnumeric()):
            code_list.append(ocup)
        
print(code_list)

#code_list =  ['_11', '_13' ]

#ca = global_y_soc1[0][0].split("_")[1:3]
#use_case = ca[0] + "_" + ca[1]


for i in range(0,len(code_list)):
    
    ocup    = str(code_list[i])
    
    x = []
    y = []

    for yr in range(2011,2019):
        
        tmp_lst = []
        
        for j in range(0,len(global_y_soc1)):
        
            year = str(yr)
            case = global_y_soc1[j][0]
            
            #print(year,ocup, case)
        
            if (case.find(year) >= 0) and (case.find(ocup) >=0):
                tmp =  global_y_soc1[j][0].split('-')
                use_ocup = tmp[0][-6:-4] + "0000 " + tmp[1]
                tmp = tmp[0].split('_')
                use_var  = str(tmp[1]) + "_" + str(tmp[2])
                #use_case = use_var + " " + use_ocup
                use_case = use_ocup
                #print(use_case)
                
                data = global_y_soc1[j][1]
                #print(year,ocup,case,data)
                
                # add up all the years for the same occupation level from code_list)
                tmp_lst = tmp_lst +  data
      
    
        occupation = str(ocup[1:]) + "0000"
        
        if (len(tmp_lst) == 0):
            omean = 0.0
        else:
            omean = np.array(tmp_lst).mean()

        #print(year,occupation,omean)
        #print(" ")
 
        x.append(yr)
        y.append(omean)
        
    #print(x,y)
        
    # Curve fit
    r = []
    try:
        popt, pcov = curve_fit(func, x, y)
    except:
        popt = [0,0]
        
 
    lines.append([use_case, popt])        
        
    #display(popt, pcov)
    
    for ri in range(0+2011,len(x)+2011):
        r.append(func(ri, *popt))
        #print(ri,r)
        
    plt.figure(figsize=(10, 10))
    
    plt.plot(x,y)
    plt.plot(x,r, 'r--')
    
    title = " time plots "
    
    plt.title(use_case + title + str(popt))    
    
    save_title = "../PLOTS/" + desired_file_output + use_case + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    print(save_title)
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    
    plt.show()
    #plt.close()

# %%
for i in range(0,len(lines)):
    print(" y = {0: 1.8f} x + {1: 1.8f}  : {2} ".format(lines[i][1][0], lines[i][1][1], lines[i][0]))

# %% [markdown]
# # CALC COV

# %%
cov_array = []

code_list = []
lines     = []

for i in range(0,len(global_y_soc1)):
    ucase = str(global_y_soc1[i][0]).split('-')[0]
    #print(ucase)
    ocup    = "_" + ucase[-6:-4]
    #print(ocup)
    if ocup not in code_list:
        if (str(ocup[1:]).isnumeric()):
            code_list.append(ocup)

print(code_list)

# %%
# ['_11', '_13' .... ]

#ca = global_y_soc1[0][0].split("_")[1:3]
#use_case = ca[0] + "_" + ca[1]

for i in range(0,len(code_list)):
       
    ocup    = str(code_list[i])
    
    x = []
    y = []

    for yr in range(2011,2019):
        
        tmp_lst = []
        
        for j in range(0,len(global_y_soc1)):
            
            year  = str(yr)
            case1 = global_y_soc1[j][0].split("-")[0][0:4]
            case2 = global_y_soc1[j][0].split("-")[0][-7:]
            
            #print(case1, case2,ocup)
        
            if (case1.find(year) >= 0) and (case2.find(ocup) >=0):
                
                tmp =  global_y_soc1[j][0].split('-')
                use_ocup = tmp[0][-6:-4] + "0000 " + tmp[1]
                tmp = tmp[0].split('_')
                use_var  = str(tmp[1]) + "_" + str(tmp[2])
                #use_case = use_var + " " + use_ocup
                use_case = use_ocup
                #print(use_case)
                
                data = global_y_soc1[j][1]
                #print(year,ocup,case,data)
                
                # add up all the years for the same occupation level from code_list)
                tmp_lst = tmp_lst +  data
      
    
        occupation = str(ocup[1:]) + "0000"
        omean = np.array(tmp_lst).mean()
        
        if (math.isnan(omean)):
            omean = 0.0

        #print(year,occupation,omean)
        #print(" ")
        
        x.append(yr)
        y.append(omean)
        

    #print(x,y)
        
    # Curve fit
    r = []
    try:
        popt, pcov = curve_fit(func, x, y)
    except:
        popt = [0,0]
        
    #ca = global_y_soc1[0][0].split("_")[1:3]
    #use_case = ca[0] + "_" + ca[1] + ocup + "0000"
                   
    omean = np.array(y).mean()
    
    if (math.isnan(omean)):
        ocov = 0.0
    else:
        ostd  = np.array(y).std()
        ocov  = ostd/omean
        
    #ocov.append(str(use_case),ocov)
    print("***",use_case,ocov)
    
    if (ocov >= 0):
        cov_array.append([str(use_case),ocov])
    else:
        print("########ERROR#######")

# %%
print(cov_array)

# %%
test_list = cov_array.copy()
    
# sort list of list
# sort by second index
test_list.sort(key = lambda test_list: test_list[1])
 
# printing result
for i in range(0,len(test_list)):
    print("{0:1.7f} \t {1:} ".format(test_list[i][1], str(test_list[i][0])))

# %% [markdown]
# # MEAN

# %%
mean_array = []

code_list = []
lines     = []

for i in range(0,len(global_y_soc1)):
    ucase = str(global_y_soc1[i][0]).split('-')[0]
    #print(ucase)
    ocup    = "_" + ucase[-6:-4]
    #print(ocup)
    if ocup not in code_list:
        if (str(ocup[1:]).isnumeric()):
            code_list.append(ocup)
        
print(code_list)

# ['_11', '_13' .... ]

#ca = global_y_soc1[0][0].split("_")[1:3]
#use_case = ca[0] + "_" + ca[1]


for i in range(0,len(code_list)):
    
    
    ocup    = str(code_list[i])
    
    x = []
    y = []

    for yr in range(2011,2019):
        
        tmp_lst = []
        
        for j in range(0,len(global_y_soc1)):
            
            year  = str(yr)
            case1 = global_y_soc1[j][0].split("-")[0][0:4]
            case2 = global_y_soc1[j][0].split("-")[0][-7:]
            
            #print(case1, case2,ocup)
        
            if (case1.find(year) >= 0) and (case2.find(ocup) >=0):
                
                tmp =  global_y_soc1[j][0].split('-')
                use_ocup = tmp[0][-6:-4] + "0000 " + tmp[1]
                tmp = tmp[0].split('_')
                use_var  = str(tmp[1]) + "_" + str(tmp[2])
                #use_case = use_var + " " + use_ocup
                use_case = use_ocup
                #print(use_case)
                
                data = global_y_soc1[j][1]
                #print(year,ocup,case,data)
                
                # add up all the years for the same occupation level from code_list)
                tmp_lst = tmp_lst +  data
      
    
        occupation = str(ocup[1:]) + "0000"
        omean = np.array(tmp_lst).mean()
        
        if (math.isnan(omean)):
            omean = 0.0
        
        #print(year,occupation,omean)
        #print(" ")
        
        x.append(yr)
        y.append(omean)
        
    #print(x,y)
        
    # Curve fit
    r = []
    try:
        popt, pcov = curve_fit(func, x, y)
    except:
        popt = [0,0]
        
    #ca = global_y_soc1[0][0].split("_")[1:3]
    #use_case = ca[0] + "_" + ca[1] + ocup + "0000"
                   
    omean = np.array(y).mean()
    #ostd  = np.array(y).std()
    #ocov  = ostd/omean 
    #ocov.append(str(use_case),ocov)
    print(use_case,omean)
    
    if (omean >= 0):
        mean_array.append([str(use_case),omean])

# %%
test_list = mean_array.copy()
    
# sort list of list
# sort by second index
test_list.sort(key = lambda test_list: test_list[1])
 
# printing result
for i in range(0,len(test_list)):
    print("{0:1.7f} \t {1:} ".format(test_list[i][1], str(test_list[i][0])))    
    
    
# create sorted order index list
sorted_order = []
for i in range(0,len(test_list)):
    idx = str(test_list[i][0]).split(" ")[0][0:2]
    nidx = int( (int(idx) - 11) / 2 )
    sorted_order.append(nidx)
    
print(sorted_order)

# %% [markdown]
# # COV LEVEL 3

# %%
code_list = []
soc_level = 3

for i in range(0,len(global_y_soc1)):
    ucase = str(global_y_soc1[i][0]).split('-')[0]
    #print(ucase)
    ocup    = "_" + ucase[-6:-5 + soc_level]
    #print(ocup)
    if ocup not in code_list:
        if (str(ocup[1:]).isnumeric()):
            code_list.append(ocup)
        
print(code_list)

# %%
cov_array = []

lines     = []

# ['_11', '_13' .... ]

#ca = global_y_soc1[0][0].split("_")[1:3]
#use_case = ca[0] + "_" + ca[1]

soc_level = 3

for i in range(0,len(code_list)):
    
    ocup    = str(code_list[i])
    
    x = []
    y = []

    for yr in range(2011,2019):
        
        tmp_lst = []
        
        for j in range(0,len(global_y_soc1)):
            
            year  = str(yr)
            case1 = global_y_soc1[j][0].split("-")[0][0:4]
            case2 = global_y_soc1[j][0].split("-")[0][-7:]
            
            #print(case1, case2,ocup)
        
            if (case1.find(year) >= 0) and (case2.find(ocup) >=0):
                
                tmp =  global_y_soc1[j][0].split('-')
                use_ocup = tmp[0][-6:-4] + "0000 " + tmp[1]
                tmp = tmp[0].split('_')
                use_var  = str(tmp[1]) + "_" + str(tmp[2])
                #use_case = use_var + " " + use_ocup
                use_case = use_ocup
                #print(use_case)
                
                data = global_y_soc1[j][1]
                #print(year,ocup,case,data)
                
                # add up all the years for the same occupation level from code_list)
                tmp_lst = tmp_lst +  data
      
    
        occupation = str(ocup[1:]) + "0000"
        omean = np.array(tmp_lst).mean()
        
        if (math.isnan(omean)):
            omean = 0.0
        
        #print(year,occupation,omean)
        #print(" ")
        
        x.append(yr)
        y.append(omean)
        
    #print(x,y)
                   
    omean = np.array(y).mean()
    ostd  = np.array(y).std()
    ocov  = ostd/omean 
    #ocov.append(str(use_case),ocov)
    print(use_case, ocov)
    
    if (ocov >= 0):
        cov_array.append([str(use_case),ocov])

# %%
test_list = cov_array.copy()
    
# sort list of list
# sort by second index
test_list.sort(key = lambda test_list: test_list[1])
 
# printing result
for i in range(0,len(test_list)):
    print("{0:1.7f} \t {1:} ".format(test_list[i][1], str(test_list[i][0])))

# %% [markdown]
# # VARIANCE ACROSS AGE

# %%
def get_case_list(soc_level, desired_case):
    code_list = []

    #soc_level = 1
    #desired_case = "16to19"

    global global_y_soc1
    
    for i in range(0,len(global_y_soc1)):
        ucase = str(global_y_soc1[i][0]).split('-')[0]
        #print(ucase)
        
        if (ucase.find("NO DATA FOUND") < 0):
            ocup    = "_" + desired_case + "_" + ucase[-6:-5 + soc_level]
            #print(ocup)
            if ocup not in code_list:
                code_list.append(ocup)
                #if (str(ocup[1:]).isnumeric()):
                #    code_list.append(ocup)
        
    print(code_list)
    
    return(code_list)

# %%
#soc_level = 1
#desired_case = "16to19"
#
#get_case_list(soc_level, desired_case)

# %%
print(sorted_order)

# %%
desired_case = "E6X_Contact"
get_case_list(1, desired_case)

# %%
cases = [ "Bones_nerves_spinal", "Muscles_tendons_ligaments", "Open_wounds", "Surface_wound", "Burns_corrosion", "Intracranial", "Enviromental", "Multiple_trauma", "Other_trauma" ]

mult_array = []

for desired_case in cases:

    soc_level = 1
    #desired_case = "16to19"

    code_list = get_case_list(soc_level, desired_case)
    
    #print(code_list)

    cov_array = []

    #for i in range(0,len(code_list)):
    #for i in swivel_order:
    for i in sorted_order:
        
        ocup    = str(code_list[i])
    
        x = []
        y = []

        for yr in range(2011,2019):
        
            tmp_lst = []
        
            for j in range(0,len(global_y_soc1)):
            
                year  = str(yr)
                case1 = global_y_soc1[j][0].split("-")[0][0:4]
                case2 = global_y_soc1[j][0].split("-")[0][-7:]
                case3 = global_y_soc1[j][0].split("-")[0][4:-7]
                
                #print(ocup,case1,case2,case3)
        
                if  (case1.find(year) >= 0) and (case2.find(ocup[-3:]) >=0) and (case3.find(ocup[0:-3]) >= 0):
                
                    #print(case1, case2, case3, ocup)
                
                    tmp =  global_y_soc1[j][0].split('-')
                    
                    #print(tmp)
                    #stop()
                    
                    use_ocup = tmp[0][-6:-4] + "0000 " + tmp[1]
                    tmp = tmp[0].split('_')
                    use_var  = str(tmp[1]) + "_" + str(tmp[2])
                    #use_case = use_var + " " + use_ocup
                    use_case = use_ocup
                    #print(use_case)
                
                    data = global_y_soc1[j][1]
                    #print(year,ocup,case,data)
                
                    # add up all the years for the same occupation level from code_list)
                    tmp_lst = tmp_lst +  data
                    
                    #print(tmp_lst)
      
      
            occupation = str(ocup[1:]) + "0000"
        
            #print(tmp_lst)
            if (len(tmp_lst) == 0):
                mean = 0.0
            else:
                omean = np.array(tmp_lst).mean()
            
            #print(year,occupation,omean)
            #print(" ")
        
            x.append(yr)
            y.append(omean)
        
        #print(x,y)
                   
        omean = np.array(y).mean()
        ostd  = np.array(y).std()
        ocov  = ostd/omean 
    
        if math.isnan(ocov):
            ocov = 0.0
        
        ocov_case = desired_case + " " + use_case
    
        #ocov.append(str(use_case),ocov)
        #print(ocov_case, ocov)

        cov_array.append([str(ocov_case),ocov])
        
    mult_array.append([str(desired_case),cov_array])
    
    # SORT LIST
    
    #test_list = cov_array.copy()
    
    # sort list of list
    # sort by second index
    #test_list.sort(key = lambda test_list: test_list[1])
 
    # printing result
    #for i in range(0,len(test_list)):
        #print("{0:1.7f} \t {1:} ".format(test_list[i][1], str(test_list[i][0]))) 
        
    for i in range(0,len(cov_array)):
        print("{0:1.7f} \t {1:} ".format(cov_array[i][1], str(cov_array[i][0]))) 

    print(" ")

# %%
print(mult_array[2][1])

# %%
labels = []

for a in range(0,len(mult_array)):

    for i in range(0,len(mult_array[a][1])):
        line = mult_array[a][1][i]
        larr = str(line[0]).split(" ")
        lbl  = ""
        #print(larr)
        for j in range(0,len(larr[1:])):
            new_lbl = str(larr[1+j])
            lbl = lbl + " " + new_lbl
        #print(lbl)

        if lbl not in labels:
            labels.append(lbl)
        
#print(labels)

groups = len(mult_array)
grpd = []
grpl = []
for i in range(0,len(mult_array)):
    subgrp = []
    # Get value point by point
    for j in range(0,len(mult_array[i][1])):
        val = mult_array[i][1][j][1]
        val = round(val,2)
        subgrp.append(val)

    #print(subgrp)
    grpl.append(mult_array[i][0])
    grpd.append(subgrp)

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

rects = []

fig, ax = plt.subplots(figsize=(40, 10))

for i in range(0,len(grpd)):
    tmp_rect = ax.bar(x+i*(width/2), grpd[i], width/2, label=grpl[i])
    rects.append(tmp_rect)
    
    
# Add bar for relative population size
#total_ocup = np.array(total_male) + np.array(total_female)
#pop_scaled = np.array(grpd).max() / total_ocup[0:-1].max() * total_ocup
#i=i+1
#tmp_rect = ax.bar(x+i*(width/2), pop_scaled[0:-1], width/2, label='Population')
#rects.append(tmp_rect)


title = "Coef by AGE"
    
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Coef of Variance')
ax.set_title(title)
ax.set_xticks(x, labels, rotation=90)
ax.legend()

#ax.set_ylim(0, 0.25)

for i in range(0,len(grpd)):
    ax.bar_label(rects[i], padding=10)

#fig.tight_layout() 
    
save_title = "../PLOTS/" + desired_file_output + title + ".png"
save_title = save_title.replace(",","")
save_title = save_title.replace(" ","_")
print(save_title)
plt.savefig(save_title, dpi=100, bbox_inches='tight')
    
plt.show()
#plt.close()

# %% [markdown]
# # MEAN

# %%
cases = [ "Bones_nerves_spinal", "Muscles_tendons_ligaments", "Open_wounds", "Surface_wound", "Burns_corrosion", "Intracranial", "Enviromental", "Multiple_trauma", "Other_trauma" ]

mult_array = []

for desired_case in cases:

    soc_level = 1
    #desired_case = "16to19"

    code_list = get_case_list(soc_level, desired_case)

    mean_array = []

    #for i in range(0,len(code_list)):
    #for i in swivel_order:
    for i in sorted_order:
    
        ocup    = str(code_list[i])
    
        x = []
        y = []

        for yr in range(2011,2019):
        
            tmp_lst = []
        
            for j in range(0,len(global_y_soc1)):
            
                year  = str(yr)
                case1 = global_y_soc1[j][0].split("-")[0][0:4]
                case2 = global_y_soc1[j][0].split("-")[0][-7:]
                case3 = global_y_soc1[j][0].split("-")[0][4:-7]
        
                if  (case1.find(year) >= 0) and (case2.find(ocup[-3:]) >=0) and (case3.find(ocup[0:-3]) >= 0):
                
                    #print(case1, case2, case3, ocup)
                
                    tmp =  global_y_soc1[j][0].split('-')
                    
                    #print(tmp)
                    #stop()
                    
                    use_ocup = tmp[0][-6:-4] + "0000 " + tmp[1]
                    tmp = tmp[0].split('_')
                    use_var  = str(tmp[1]) + "_" + str(tmp[2])
                    #use_case = use_var + " " + use_ocup
                    use_case = use_ocup
                    #print(use_case)
                
                    data = global_y_soc1[j][1]
                    #print(year,ocup,case,data)
                
                    # add up all the years for the same occupation level from code_list)
                    tmp_lst = tmp_lst +  data
      
    
            occupation = str(ocup[1:]) + "0000"
        
            #print(tmp_lst)
            if (len(tmp_lst) == 0):
                mean = 0.0
            else:
                omean = np.array(tmp_lst).mean()
            
            #print(year,occupation,omean)
            #print(" ")
        
            x.append(yr)
            y.append(omean)
        
        #print(x,y)
                   
        omean = np.array(y).mean()
        #ostd  = np.array(y).std()
        #ocov  = ostd/omean 
    
        if math.isnan(omean):
            ocov = 0.0
        
        omean_case = desired_case + " " + use_case
    
        #ocov.append(str(use_case),ocov)
        #print(ocov_case, ocov)

        mean_array.append([str(omean_case),omean])
        
    mult_array.append([str(desired_case),mean_array])
    
    # SORT LIST
    
    #test_list = cov_array.copy()
    
    # sort list of list
    # sort by second index
    #test_list.sort(key = lambda test_list: test_list[1])
 
    # printing result
    #for i in range(0,len(test_list)):
        #print("{0:1.7f} \t {1:} ".format(test_list[i][1], str(test_list[i][0]))) 
        
    for i in range(0,len(mean_array)):
        print("{0:1.7f} \t {1:} ".format(mean_array[i][1], str(mean_array[i][0]))) 

    print(" ")

# %%
labels = []

for a in range(0,len(mult_array)):

    for i in range(0,len(mult_array[a][1])):
        line = mult_array[a][1][i]
        larr = str(line[0]).split(" ")
        lbl  = ""
        #print(larr)
        for j in range(0,len(larr[1:])):
            new_lbl = str(larr[1+j])
            lbl = lbl + " " + new_lbl
        #print(lbl)

        if lbl not in labels:
            labels.append(lbl)
              
for i in range(0,len(labels)):
    print(labels[i])

# %%
           
groups = len(mult_array)
grpd = []
grpl = []
for i in range(0,len(mult_array)):
    subgrp = []
    # Get value point by point
    for j in range(0,len(mult_array[i][1])):
        val = mult_array[i][1][j][1]
        
        val = round(10000*val,2)
        
        subgrp.append(val)

    #print(subgrp)
    grpl.append(mult_array[i][0])
    grpd.append(subgrp)
    
x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

rects = []

fig, ax = plt.subplots(figsize=(40, 10))

print(len(grpd))
print(len(grpd[0]))

for i in range(0,len(grpd)):
    tmp_rect = ax.bar(x+i*(width/2), grpd[i], width/2, label=grpl[i])
    rects.append(tmp_rect)
    
    
# Add bar for relative population size
#total_ocup = np.array(total_male) + np.array(total_female)
#pop_scaled = np.array(grpd).max() / total_ocup[0:-1].max() * total_ocup
#i=i+1
#tmp_rect = ax.bar(x+i*(width/2), pop_scaled[0:-1], width/2, label='Population')
#rects.append(tmp_rect)

    
title = "Mean Injury per 10,000 by AGE"
    
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mean Injury Rate')
ax.set_title(title)
ax.set_xticks(x, labels, rotation=90)
ax.legend()

#ax.set_ylim(0, 100)

for i in range(0,len(grpd)):
    ax.bar_label(rects[i], padding=10)

#fig.tight_layout() 
    
save_title = "../PLOTS/" + desired_file_output + title + ".png"
save_title = save_title.replace(",","")
save_title = save_title.replace(" ","_")
print(save_title)
plt.savefig(save_title, dpi=100, bbox_inches='tight')
    
plt.show()
#plt.close()
