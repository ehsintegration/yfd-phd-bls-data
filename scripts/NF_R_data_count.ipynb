# %%
# Used to get zoom-able & resize-able notebook. This is the best for quick tests where you need to work interactively.
# %matplotlib notebook    

# this only draws the images, not interactive / zoom-able but it works well. I recommend to change figure size to be bigger than the default in most cases
#%matplotlib inline

# %%
# Used for high quality plot
# %config InlineBackend.figure_format = 'svg'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import matplotlib.dates as mdates
import datetime
import math
from scipy import optimize

# %% [markdown]
# ## GITHUB ACCESS
# The following is how you import an object:
#
# This object lets you access files from the GITHUB repository of files
# its where all of the COVID-19 data is kept.
#
# What is GITHUB : https://en.wikipedia.org/wiki/GitHub
#
# Documentation : https://pygithub.readthedocs.io/en/latest/

# %%
from github import Github

# %% [markdown]
# When you import the github library, an object called g needs to be
# created. This object will represent the github object that we will use
# to pull data from the github repository. You will be able to pull data
# from your own personal repository, or any repository that exits in
# github.
#
# This object will be used to access any file or directory within the
# github "filesystem".
#
# For this access to occur you need to insert your personal github
# username and password. If you dont have one, you would need to creat a
# github account. Please note that the fields below are exactly what
# you would enter when prompted when logging into the github site.

# %%
# Replace with your login
#
#g = Github("username", "password")

# %% [markdown]
# In the following command we create another object called
# repo (short for repository of files), and assign it to a specific
# repository. Specifically the PHD repository located at:
# https://github.com/ehsintegration/yfd-phd-bls-data

# %%
repo = g.get_repo("ehsintegration/yfd-phd-bls-data")

# %%
contents = repo.get_contents("")
print(contents)
for index in contents:
    print(index)
# Out:
# [ContentFile(path="DATA"), ContentFile(path="README.md"), ContentFile(path="scripts")]
# ContentFile(path="DATA")
# ContentFile(path="README.md")
# ContentFile(path="scripts")

# %% [markdown]
# ## Get the list of files
# Get the list of files from the directory that we are interested in, the DATA folder

# %%
contents = repo.get_contents("DATA")
count = 1
for index in contents:
    url = index.download_url
    print(url)
    count = count + 1
print(count)
# Out:
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/FATAL_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_AGE_14to15_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_AGE_16to19_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_AGE_20to24_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_AGE_25to34_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_AGE_35to44_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_AGE_45to54_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_AGE_55to64_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_AGE_65plus_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_AGE_NR_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_E1X_In_UnIn_Animal_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_E2X_Transportion_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_E3X_Fire_Explosion_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_E4X_Falls_Slip_Trip_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_E5X_Exposure_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_E6X_Contact_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_E7X_Overex_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_EXX_All_other_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_GENDER_F_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_GENDER_M_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_GENDER_NR_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_LOS_1to5yr_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_LOS_3to11mos_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_LOS_5plus_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_LOS_NR_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_LOS_ltg3mos_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RAX_AmericanIndian_AlaskaNative_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RBX_Asian_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RCX_Black_AfricanAmerican_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RDX_Hispanic_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_REX_Hawaiian_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RFX_White_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RGX_NR_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RHX_Multi_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RIX_Hispanic_all.csv
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/SOC_all.csv
# 37

# %% [markdown]
# ## Use HTTP Access to grab the files
# Here we are pulling in another object called BS4, which stands for
# Beautiful Soup 4. We will use the Beautiful Soup Object to fetch web data.
# Beautiful soup is normally used to parse HTML, but we are just using
# it to download the file and convert it to a string.

# %%
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Create SOC dictionary

# %%
# pull in the list of SOC industry codes
soc = []

desired_file = "SOC_all.csv"

# Iterate through all of the URLs
for index in contents:
    url = index.download_url
    
    # Is content_file a file with the .csv extension
    if (desired_file in url):
        print(url)
        
        # Grab the source contents of the file
        source = urllib.request.urlopen(url).read()
        
        #print(source)
        decoded_data = source.decode("utf-8")
        soc.append(decoded_data)   

#print(soc)
# Out:
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/SOC_all.csv

# %%
# Create a dictionary of soc_codes
#
soc_dict = {}

line = soc[0].replace("\"","")
soc_array= line.split("\n")

# Create Dictionary of SOC codes
#
for line in soc_array:
    key  = line[0:7].replace("-","")
    data = line[9:]
    soc_dict.setdefault(key, []).append(data)
    
#index = 0
#for key in soc_dict:
#    print(index, key, soc_dict[key])
#    index = index + 1

# %% [markdown]
# ## Select Generic Database to work with

# %%
genericDB_files_dict = {}

desired_file_prefix = "NF_R"  # "NF_AGE_14to15_all.csv"

# %% [markdown]
# ## Create NF_LOS dictionary

# %%
# pull in the data

# Iterate through all of the URLs
for index in contents:
    url = index.download_url
    
    # Is content_file a file with the .csv extension
    if (desired_file_prefix in url):
        print(url)
        
        name = url.split("/")[-1].split("_all")[0]
        print(name)
        
        # Grab the source contents of the file
        source = urllib.request.urlopen(url).read()
        
        #print(source)
        decoded_data = source.decode("utf-8")
        genericDB_files_dict.setdefault(name, []).append(decoded_data)
        #genericDB.append(decoded_data)   

#print(genericDB_files_dict)
# Out:
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RAX_AmericanIndian_AlaskaNative_all.csv
# NF_RAX_AmericanIndian_AlaskaNative
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RBX_Asian_all.csv
# NF_RBX_Asian
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RCX_Black_AfricanAmerican_all.csv
# NF_RCX_Black_AfricanAmerican
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RDX_Hispanic_all.csv
# NF_RDX_Hispanic
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_REX_Hawaiian_all.csv
# NF_REX_Hawaiian
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RFX_White_all.csv
# NF_RFX_White
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RGX_NR_all.csv
# NF_RGX_NR
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RHX_Multi_all.csv
# NF_RHX_Multi
# https://raw.githubusercontent.com/ehsintegration/yfd-phd-bls-data/master/DATA/NF_RIX_Hispanic_all.csv
# NF_RIX_Hispanic

# %%
# Create a dictionary of soc_codes
#
genericDB_dict = {}


# Create Dictionary of SOC codes
#
for db in genericDB_files_dict.keys():
    
    genericDB = genericDB_files_dict[db]
    
    #print(genericDB[0])    
    line = genericDB[0].replace("\"","")
    genericDB_array= line.split("\n")
    #print(genericDB_array[12:])
    
    # Line 12 is where the header stops and the data starts
    #
    for line in genericDB_array[12:]:
        line_array = line.split(",")
        #key  = line_array[0].    [0:7].replace("-","")
        key  = line_array[0][6:12]
        data = line_array[1:]
        #print(line_array)
        #print(key,data)

        # Replace empty values with zero
        if (len(key) > 1):
            #print(key,data[0:8])
            for index in range(0,8):
                if (len(data[index]) == 0):
                    data[index] = '0'
            #print(key,data[0:8])
        
        # Convert to Integers
        if (len(key) > 1):
            #print(key,data[0:8])
            for index in range(0,8):
                data[index] = int(data[index])
            #print(key,data[0:8])   
            
        # Create dictionary entry
        if (len(key) > 1):
            genericDB_dict.setdefault(db+"_"+key, []).append(data[0:8])
    
index = 0
for key in genericDB_dict:
    print(index, key, genericDB_dict[key])
    index = index + 1
# Out:
# 0 NF_RAX_AmericanIndian_AlaskaNative_110000 [[260, 100, 160, 80, 100, 140, 140, 140]]
# 1 NF_RAX_AmericanIndian_AlaskaNative_111000 [[0, 0, 80, 20, 0, 0, 0, 0]]
# 2 NF_RAX_AmericanIndian_AlaskaNative_111020 [[0, 0, 80, 20, 0, 0, 0, 0]]
# 3 NF_RAX_AmericanIndian_AlaskaNative_111021 [[0, 0, 80, 20, 0, 0, 0, 0]]
# 4 NF_RAX_AmericanIndian_AlaskaNative_112000 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 5 NF_RAX_AmericanIndian_AlaskaNative_112020 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 6 NF_RAX_AmericanIndian_AlaskaNative_112021 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 7 NF_RAX_AmericanIndian_AlaskaNative_113000 [[20, 20, 30, 0, 0, 0, 80, 0]]
# 8 NF_RAX_AmericanIndian_AlaskaNative_119000 [[230, 70, 60, 40, 60, 120, 60, 120]]
# 9 NF_RAX_AmericanIndian_AlaskaNative_119030 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 10 NF_RAX_AmericanIndian_AlaskaNative_119033 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 11 NF_RAX_AmericanIndian_AlaskaNative_119050 [[80, 30, 0, 0, 30, 30, 0, 100]]
# 12 NF_RAX_AmericanIndian_AlaskaNative_119051 [[80, 30, 0, 0, 30, 30, 0, 100]]
# 13 NF_RAX_AmericanIndian_AlaskaNative_119110 [[0, 0, 0, 0, 0, 80, 20, 0]]
# 14 NF_RAX_AmericanIndian_AlaskaNative_119111 [[0, 0, 0, 0, 0, 80, 20, 0]]
# 15 NF_RAX_AmericanIndian_AlaskaNative_119190 [[100, 0, 30, 0, 0, 0, 30, 0]]
# 16 NF_RAX_AmericanIndian_AlaskaNative_119199 [[100, 0, 30, 0, 0, 0, 30, 0]]
# 17 NF_RAX_AmericanIndian_AlaskaNative_130000 [[20, 40, 0, 30, 30, 30, 30, 40]]
# 18 NF_RAX_AmericanIndian_AlaskaNative_131000 [[20, 30, 0, 20, 20, 30, 20, 40]]
# 19 NF_RAX_AmericanIndian_AlaskaNative_131070 [[20, 0, 0, 0, 0, 20, 0, 0]]
# 20 NF_RAX_AmericanIndian_AlaskaNative_131071 [[0, 0, 0, 0, 0, 20, 0, 0]]
# 21 NF_RAX_AmericanIndian_AlaskaNative_170000 [[20, 100, 0, 0, 0, 0, 0, 0]]
# 22 NF_RAX_AmericanIndian_AlaskaNative_173000 [[0, 100, 0, 0, 0, 0, 0, 0]]
# 23 NF_RAX_AmericanIndian_AlaskaNative_173020 [[0, 100, 0, 0, 0, 0, 0, 0]]
# 24 NF_RAX_AmericanIndian_AlaskaNative_173023 [[0, 80, 0, 0, 0, 0, 0, 0]]
# 25 NF_RAX_AmericanIndian_AlaskaNative_210000 [[50, 70, 170, 110, 100, 70, 120, 130]]
# 26 NF_RAX_AmericanIndian_AlaskaNative_211000 [[50, 70, 170, 110, 100, 70, 120, 130]]
# 27 NF_RAX_AmericanIndian_AlaskaNative_211010 [[30, 0, 100, 20, 30, 50, 20, 0]]
# 28 NF_RAX_AmericanIndian_AlaskaNative_211012 [[0, 0, 30, 0, 0, 0, 20, 0]]
# 29 NF_RAX_AmericanIndian_AlaskaNative_211014 [[0, 0, 0, 0, 20, 30, 0, 0]]
# 30 NF_RAX_AmericanIndian_AlaskaNative_211019 [[0, 0, 60, 0, 0, 0, 0, 0]]
# 31 NF_RAX_AmericanIndian_AlaskaNative_211020 [[0, 40, 20, 80, 20, 0, 50, 0]]
# 32 NF_RAX_AmericanIndian_AlaskaNative_211021 [[0, 0, 0, 40, 0, 0, 0, 0]]
# 33 NF_RAX_AmericanIndian_AlaskaNative_211029 [[0, 40, 20, 30, 20, 0, 40, 0]]
# 34 NF_RAX_AmericanIndian_AlaskaNative_211090 [[20, 20, 50, 20, 50, 0, 40, 120]]
# 35 NF_RAX_AmericanIndian_AlaskaNative_211092 [[0, 0, 40, 0, 40, 0, 40, 0]]
# 36 NF_RAX_AmericanIndian_AlaskaNative_230000 [[0, 20, 0, 0, 0, 0, 0, 0]]
# 37 NF_RAX_AmericanIndian_AlaskaNative_250000 [[100, 130, 160, 280, 130, 480, 310, 120]]
# 38 NF_RAX_AmericanIndian_AlaskaNative_251000 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 39 NF_RAX_AmericanIndian_AlaskaNative_251190 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 40 NF_RAX_AmericanIndian_AlaskaNative_251199 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 41 NF_RAX_AmericanIndian_AlaskaNative_252000 [[70, 20, 70, 150, 50, 40, 240, 60]]
# 42 NF_RAX_AmericanIndian_AlaskaNative_252010 [[30, 0, 0, 60, 0, 0, 0, 0]]
# 43 NF_RAX_AmericanIndian_AlaskaNative_252011 [[30, 0, 0, 60, 0, 0, 0, 0]]
# 44 NF_RAX_AmericanIndian_AlaskaNative_252020 [[30, 0, 70, 50, 40, 20, 220, 50]]
# 45 NF_RAX_AmericanIndian_AlaskaNative_252021 [[20, 0, 70, 50, 40, 0, 220, 50]]
# 46 NF_RAX_AmericanIndian_AlaskaNative_252030 [[0, 0, 0, 40, 0, 0, 20, 0]]
# 47 NF_RAX_AmericanIndian_AlaskaNative_252031 [[0, 0, 0, 40, 0, 0, 20, 0]]
# 48 NF_RAX_AmericanIndian_AlaskaNative_253000 [[0, 0, 0, 0, 50, 0, 0, 0]]
# 49 NF_RAX_AmericanIndian_AlaskaNative_253090 [[0, 0, 0, 0, 50, 0, 0, 0]]
# 50 NF_RAX_AmericanIndian_AlaskaNative_253099 [[0, 0, 0, 0, 50, 0, 0, 0]]
# 51 NF_RAX_AmericanIndian_AlaskaNative_259000 [[20, 100, 50, 120, 30, 440, 50, 60]]
# 52 NF_RAX_AmericanIndian_AlaskaNative_259040 [[20, 100, 50, 110, 30, 440, 50, 50]]
# 53 NF_RAX_AmericanIndian_AlaskaNative_259041 [[20, 100, 50, 110, 30, 440, 50, 50]]
# 54 NF_RAX_AmericanIndian_AlaskaNative_270000 [[0, 0, 0, 20, 0, 0, 0, 20]]
# 55 NF_RAX_AmericanIndian_AlaskaNative_272000 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 56 NF_RAX_AmericanIndian_AlaskaNative_290000 [[320, 160, 160, 270, 200, 160, 120, 100]]
# 57 NF_RAX_AmericanIndian_AlaskaNative_291000 [[170, 50, 50, 220, 70, 50, 30, 30]]
# 58 NF_RAX_AmericanIndian_AlaskaNative_291111 [[160, 0, 0, 0, 0, 0, 0, 0]]
# 59 NF_RAX_AmericanIndian_AlaskaNative_291140 [[160, 50, 50, 210, 70, 50, 30, 30]]
# 60 NF_RAX_AmericanIndian_AlaskaNative_291141 [[160, 50, 50, 210, 70, 50, 30, 30]]
# 61 NF_RAX_AmericanIndian_AlaskaNative_292000 [[140, 100, 100, 60, 130, 110, 80, 70]]
# 62 NF_RAX_AmericanIndian_AlaskaNative_292040 [[0, 30, 20, 0, 70, 20, 20, 0]]
# 63 NF_RAX_AmericanIndian_AlaskaNative_292041 [[0, 30, 20, 0, 70, 20, 20, 0]]
# 64 NF_RAX_AmericanIndian_AlaskaNative_292050 [[50, 30, 40, 30, 20, 60, 30, 30]]
# 65 NF_RAX_AmericanIndian_AlaskaNative_292051 [[0, 0, 20, 20, 0, 0, 20, 0]]
# 66 NF_RAX_AmericanIndian_AlaskaNative_292053 [[0, 20, 0, 0, 0, 40, 0, 20]]
# 67 NF_RAX_AmericanIndian_AlaskaNative_292060 [[50, 20, 0, 0, 30, 20, 20, 30]]
# 68 NF_RAX_AmericanIndian_AlaskaNative_292061 [[50, 20, 0, 0, 30, 20, 20, 30]]
# 69 NF_RAX_AmericanIndian_AlaskaNative_292070 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 70 NF_RAX_AmericanIndian_AlaskaNative_292071 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 71 NF_RAX_AmericanIndian_AlaskaNative_310000 [[360, 210, 240, 320, 330, 270, 310, 240]]
# 72 NF_RAX_AmericanIndian_AlaskaNative_311000 [[330, 180, 210, 310, 300, 240, 280, 200]]
# 73 NF_RAX_AmericanIndian_AlaskaNative_311010 [[330, 180, 210, 310, 300, 240, 280, 200]]
# 74 NF_RAX_AmericanIndian_AlaskaNative_311011 [[50, 20, 20, 0, 0, 0, 0, 0]]
# 75 NF_RAX_AmericanIndian_AlaskaNative_311012 [[280, 0, 0, 0, 0, 0, 0, 0]]
# 76 NF_RAX_AmericanIndian_AlaskaNative_311013 [[0, 0, 0, 40, 0, 0, 70, 40]]
# 77 NF_RAX_AmericanIndian_AlaskaNative_311014 [[280, 160, 180, 270, 280, 230, 200, 150]]
# 78 NF_RAX_AmericanIndian_AlaskaNative_319000 [[30, 20, 30, 0, 30, 30, 30, 40]]
# 79 NF_RAX_AmericanIndian_AlaskaNative_319090 [[30, 20, 20, 0, 20, 20, 30, 40]]
# 80 NF_RAX_AmericanIndian_AlaskaNative_319092 [[0, 0, 0, 0, 0, 0, 0, 30]]
# 81 NF_RAX_AmericanIndian_AlaskaNative_330000 [[250, 260, 220, 330, 340, 260, 360, 360]]
# 82 NF_RAX_AmericanIndian_AlaskaNative_331000 [[0, 0, 50, 0, 0, 0, 70, 0]]
# 83 NF_RAX_AmericanIndian_AlaskaNative_331010 [[0, 0, 40, 0, 0, 0, 70, 0]]
# 84 NF_RAX_AmericanIndian_AlaskaNative_332000 [[0, 20, 30, 20, 0, 0, 40, 0]]
# 85 NF_RAX_AmericanIndian_AlaskaNative_332010 [[0, 20, 30, 20, 0, 0, 40, 0]]
# 86 NF_RAX_AmericanIndian_AlaskaNative_332011 [[0, 20, 30, 20, 0, 0, 40, 0]]
# 87 NF_RAX_AmericanIndian_AlaskaNative_333000 [[190, 150, 70, 220, 220, 100, 200, 320]]
# 88 NF_RAX_AmericanIndian_AlaskaNative_333010 [[110, 50, 0, 20, 120, 40, 50, 100]]
# 89 NF_RAX_AmericanIndian_AlaskaNative_333012 [[110, 50, 0, 20, 120, 40, 50, 100]]
# 90 NF_RAX_AmericanIndian_AlaskaNative_333050 [[80, 100, 60, 200, 100, 70, 140, 210]]
# 91 NF_RAX_AmericanIndian_AlaskaNative_333051 [[80, 100, 60, 200, 100, 70, 140, 210]]
# 92 NF_RAX_AmericanIndian_AlaskaNative_339000 [[40, 80, 70, 80, 110, 130, 40, 40]]
# 93 NF_RAX_AmericanIndian_AlaskaNative_339030 [[20, 40, 40, 60, 80, 80, 30, 20]]
# 94 NF_RAX_AmericanIndian_AlaskaNative_339032 [[20, 40, 40, 60, 80, 80, 30, 20]]
# 95 NF_RAX_AmericanIndian_AlaskaNative_339090 [[0, 30, 30, 30, 20, 50, 20, 0]]
# 96 NF_RAX_AmericanIndian_AlaskaNative_339091 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 97 NF_RAX_AmericanIndian_AlaskaNative_339092 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 98 NF_RAX_AmericanIndian_AlaskaNative_339099 [[0, 20, 0, 0, 0, 20, 0, 0]]
# 99 NF_RAX_AmericanIndian_AlaskaNative_350000 [[340, 410, 580, 430, 690, 300, 400, 630]]
# 100 NF_RAX_AmericanIndian_AlaskaNative_351000 [[70, 20, 0, 0, 0, 60, 170, 0]]
# 101 NF_RAX_AmericanIndian_AlaskaNative_351010 [[70, 20, 0, 0, 0, 60, 170, 0]]
# 102 NF_RAX_AmericanIndian_AlaskaNative_351012 [[60, 0, 0, 0, 0, 60, 170, 0]]
# 103 NF_RAX_AmericanIndian_AlaskaNative_352000 [[100, 190, 150, 110, 500, 120, 60, 210]]
# 104 NF_RAX_AmericanIndian_AlaskaNative_352010 [[60, 130, 120, 80, 460, 100, 30, 120]]
# 105 NF_RAX_AmericanIndian_AlaskaNative_352012 [[30, 80, 40, 70, 30, 20, 0, 30]]
# 106 NF_RAX_AmericanIndian_AlaskaNative_352014 [[20, 40, 70, 0, 420, 40, 20, 90]]
# 107 NF_RAX_AmericanIndian_AlaskaNative_352020 [[40, 60, 30, 30, 40, 20, 20, 90]]
# 108 NF_RAX_AmericanIndian_AlaskaNative_352021 [[40, 60, 30, 30, 40, 20, 20, 90]]
# 109 NF_RAX_AmericanIndian_AlaskaNative_353000 [[120, 150, 310, 130, 110, 60, 110, 180]]
# 110 NF_RAX_AmericanIndian_AlaskaNative_353010 [[20, 0, 0, 0, 0, 20, 60, 40]]
# 111 NF_RAX_AmericanIndian_AlaskaNative_353011 [[20, 0, 0, 0, 0, 20, 60, 40]]
# 112 NF_RAX_AmericanIndian_AlaskaNative_353020 [[80, 70, 260, 80, 30, 0, 30, 130]]
# 113 NF_RAX_AmericanIndian_AlaskaNative_353021 [[30, 60, 190, 80, 20, 0, 30, 120]]
# 114 NF_RAX_AmericanIndian_AlaskaNative_353022 [[0, 0, 70, 0, 0, 0, 0, 0]]
# 115 NF_RAX_AmericanIndian_AlaskaNative_353030 [[0, 50, 40, 30, 0, 40, 20, 0]]
# 116 NF_RAX_AmericanIndian_AlaskaNative_353031 [[0, 50, 40, 30, 0, 40, 20, 0]]
# 117 NF_RAX_AmericanIndian_AlaskaNative_353040 [[0, 20, 0, 20, 0, 0, 0, 0]]
# 118 NF_RAX_AmericanIndian_AlaskaNative_353041 [[0, 20, 0, 20, 0, 0, 0, 0]]
# 119 NF_RAX_AmericanIndian_AlaskaNative_359000 [[50, 50, 100, 170, 70, 60, 70, 230]]
# 120 NF_RAX_AmericanIndian_AlaskaNative_359010 [[0, 20, 50, 140, 20, 20, 30, 20]]
# 121 NF_RAX_AmericanIndian_AlaskaNative_359011 [[0, 20, 50, 140, 20, 20, 30, 20]]
# 122 NF_RAX_AmericanIndian_AlaskaNative_359020 [[30, 0, 40, 20, 50, 0, 20, 70]]
# 123 NF_RAX_AmericanIndian_AlaskaNative_359021 [[30, 0, 40, 20, 50, 0, 20, 70]]
# 124 NF_RAX_AmericanIndian_AlaskaNative_359090 [[0, 0, 0, 0, 0, 20, 0, 130]]
# 125 NF_RAX_AmericanIndian_AlaskaNative_359099 [[0, 0, 0, 0, 0, 20, 0, 130]]
# 126 NF_RAX_AmericanIndian_AlaskaNative_370000 [[800, 550, 510, 570, 430, 210, 380, 500]]
# 127 NF_RAX_AmericanIndian_AlaskaNative_371000 [[30, 0, 0, 0, 60, 0, 0, 0]]
# 128 NF_RAX_AmericanIndian_AlaskaNative_371010 [[30, 0, 0, 0, 60, 0, 0, 0]]
# 129 NF_RAX_AmericanIndian_AlaskaNative_371012 [[20, 0, 0, 0, 50, 0, 0, 0]]
# 130 NF_RAX_AmericanIndian_AlaskaNative_372000 [[690, 260, 440, 300, 260, 190, 320, 460]]
# 131 NF_RAX_AmericanIndian_AlaskaNative_372010 [[690, 260, 420, 280, 250, 190, 320, 460]]
# 132 NF_RAX_AmericanIndian_AlaskaNative_372011 [[580, 140, 300, 180, 150, 130, 250, 310]]
# 133 NF_RAX_AmericanIndian_AlaskaNative_372012 [[110, 110, 120, 80, 100, 50, 80, 150]]
# 134 NF_RAX_AmericanIndian_AlaskaNative_373000 [[80, 290, 70, 260, 120, 0, 40, 30]]
# 135 NF_RAX_AmericanIndian_AlaskaNative_373010 [[80, 290, 70, 260, 120, 0, 40, 30]]
# 136 NF_RAX_AmericanIndian_AlaskaNative_373011 [[80, 280, 70, 20, 120, 0, 40, 20]]
# 137 NF_RAX_AmericanIndian_AlaskaNative_373013 [[0, 0, 0, 240, 0, 0, 0, 0]]
# 138 NF_RAX_AmericanIndian_AlaskaNative_390000 [[150, 100, 150, 200, 90, 90, 140, 100]]
# 139 NF_RAX_AmericanIndian_AlaskaNative_391000 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 140 NF_RAX_AmericanIndian_AlaskaNative_393000 [[0, 20, 20, 0, 0, 0, 0, 0]]
# 141 NF_RAX_AmericanIndian_AlaskaNative_396000 [[20, 0, 0, 0, 0, 30, 0, 0]]
# 142 NF_RAX_AmericanIndian_AlaskaNative_396010 [[20, 0, 0, 0, 0, 30, 0, 0]]
# 143 NF_RAX_AmericanIndian_AlaskaNative_396011 [[20, 0, 0, 0, 0, 30, 0, 0]]
# 144 NF_RAX_AmericanIndian_AlaskaNative_397000 [[0, 0, 40, 0, 0, 0, 0, 0]]
# 145 NF_RAX_AmericanIndian_AlaskaNative_397010 [[0, 0, 40, 0, 0, 0, 0, 0]]
# 146 NF_RAX_AmericanIndian_AlaskaNative_397011 [[0, 0, 40, 0, 0, 0, 0, 0]]
# 147 NF_RAX_AmericanIndian_AlaskaNative_399000 [[90, 80, 80, 100, 60, 60, 80, 90]]
# 148 NF_RAX_AmericanIndian_AlaskaNative_399010 [[20, 0, 0, 40, 0, 0, 0, 30]]
# 149 NF_RAX_AmericanIndian_AlaskaNative_399011 [[20, 0, 0, 40, 0, 0, 0, 30]]
# 150 NF_RAX_AmericanIndian_AlaskaNative_399020 [[20, 60, 60, 60, 50, 40, 30, 50]]
# 151 NF_RAX_AmericanIndian_AlaskaNative_399021 [[20, 60, 60, 60, 50, 40, 30, 50]]
# 152 NF_RAX_AmericanIndian_AlaskaNative_399030 [[30, 0, 0, 0, 0, 0, 30, 0]]
# 153 NF_RAX_AmericanIndian_AlaskaNative_399032 [[0, 0, 0, 0, 0, 0, 30, 0]]
# 154 NF_RAX_AmericanIndian_AlaskaNative_399090 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 155 NF_RAX_AmericanIndian_AlaskaNative_399099 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 156 NF_RAX_AmericanIndian_AlaskaNative_410000 [[400, 170, 150, 110, 580, 180, 190, 110]]
# 157 NF_RAX_AmericanIndian_AlaskaNative_411000 [[210, 20, 30, 40, 30, 30, 70, 20]]
# 158 NF_RAX_AmericanIndian_AlaskaNative_411010 [[210, 20, 30, 40, 30, 30, 70, 20]]
# 159 NF_RAX_AmericanIndian_AlaskaNative_411011 [[210, 20, 0, 0, 30, 30, 60, 20]]
# 160 NF_RAX_AmericanIndian_AlaskaNative_411012 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 161 NF_RAX_AmericanIndian_AlaskaNative_412000 [[150, 160, 100, 60, 550, 120, 110, 50]]
# 162 NF_RAX_AmericanIndian_AlaskaNative_412010 [[50, 60, 70, 20, 470, 50, 50, 20]]
# 163 NF_RAX_AmericanIndian_AlaskaNative_412011 [[40, 50, 70, 20, 470, 50, 40, 20]]
# 164 NF_RAX_AmericanIndian_AlaskaNative_412020 [[0, 0, 0, 0, 0, 20, 0, 0]]
# 165 NF_RAX_AmericanIndian_AlaskaNative_412030 [[110, 90, 30, 40, 70, 40, 70, 20]]
# 166 NF_RAX_AmericanIndian_AlaskaNative_412031 [[110, 90, 30, 40, 70, 40, 70, 20]]
# 167 NF_RAX_AmericanIndian_AlaskaNative_414000 [[0, 0, 0, 20, 0, 0, 0, 40]]
# 168 NF_RAX_AmericanIndian_AlaskaNative_414010 [[0, 0, 0, 20, 0, 0, 0, 40]]
# 169 NF_RAX_AmericanIndian_AlaskaNative_414011 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 170 NF_RAX_AmericanIndian_AlaskaNative_414012 [[0, 0, 0, 0, 0, 0, 0, 40]]
# 171 NF_RAX_AmericanIndian_AlaskaNative_419000 [[30, 0, 0, 0, 0, 20, 0, 0]]
# 172 NF_RAX_AmericanIndian_AlaskaNative_419090 [[30, 0, 0, 0, 0, 20, 0, 0]]
# 173 NF_RAX_AmericanIndian_AlaskaNative_419099 [[30, 0, 0, 0, 0, 20, 0, 0]]
# 174 NF_RAX_AmericanIndian_AlaskaNative_430000 [[230, 190, 450, 290, 290, 200, 530, 310]]
# 175 NF_RAX_AmericanIndian_AlaskaNative_433000 [[20, 20, 90, 0, 20, 20, 0, 0]]
# 176 NF_RAX_AmericanIndian_AlaskaNative_433030 [[0, 0, 80, 0, 0, 0, 0, 0]]
# 177 NF_RAX_AmericanIndian_AlaskaNative_433031 [[0, 0, 80, 0, 0, 0, 0, 0]]
# 178 NF_RAX_AmericanIndian_AlaskaNative_434000 [[30, 70, 30, 30, 20, 40, 310, 0]]
# 179 NF_RAX_AmericanIndian_AlaskaNative_434050 [[20, 30, 20, 0, 20, 0, 290, 0]]
# 180 NF_RAX_AmericanIndian_AlaskaNative_434051 [[20, 30, 20, 0, 20, 0, 290, 0]]
# 181 NF_RAX_AmericanIndian_AlaskaNative_434170 [[0, 0, 0, 0, 0, 20, 0, 0]]
# 182 NF_RAX_AmericanIndian_AlaskaNative_434171 [[0, 0, 0, 0, 0, 20, 0, 0]]
# 183 NF_RAX_AmericanIndian_AlaskaNative_435000 [[100, 70, 130, 150, 80, 110, 130, 260]]
# 184 NF_RAX_AmericanIndian_AlaskaNative_435070 [[20, 0, 0, 0, 0, 0, 30, 0]]
# 185 NF_RAX_AmericanIndian_AlaskaNative_435071 [[20, 0, 0, 0, 0, 0, 30, 0]]
# 186 NF_RAX_AmericanIndian_AlaskaNative_435080 [[80, 30, 90, 120, 70, 80, 80, 240]]
# 187 NF_RAX_AmericanIndian_AlaskaNative_435081 [[80, 30, 90, 120, 70, 80, 80, 240]]
# 188 NF_RAX_AmericanIndian_AlaskaNative_436000 [[20, 0, 100, 30, 110, 0, 60, 0]]
# 189 NF_RAX_AmericanIndian_AlaskaNative_436010 [[20, 0, 100, 30, 110, 0, 60, 0]]
# 190 NF_RAX_AmericanIndian_AlaskaNative_436011 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 191 NF_RAX_AmericanIndian_AlaskaNative_436014 [[20, 0, 70, 30, 100, 0, 40, 0]]
# 192 NF_RAX_AmericanIndian_AlaskaNative_439000 [[60, 20, 90, 70, 40, 0, 20, 20]]
# 193 NF_RAX_AmericanIndian_AlaskaNative_439060 [[30, 0, 0, 50, 20, 0, 0, 0]]
# 194 NF_RAX_AmericanIndian_AlaskaNative_439061 [[30, 0, 0, 50, 20, 0, 0, 0]]
# 195 NF_RAX_AmericanIndian_AlaskaNative_439190 [[0, 0, 80, 0, 0, 0, 0, 0]]
# 196 NF_RAX_AmericanIndian_AlaskaNative_439199 [[0, 0, 80, 0, 0, 0, 0, 0]]
# 197 NF_RAX_AmericanIndian_AlaskaNative_450000 [[40, 80, 50, 80, 80, 80, 80, 40]]
# 198 NF_RAX_AmericanIndian_AlaskaNative_451000 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 199 NF_RAX_AmericanIndian_AlaskaNative_451010 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 200 NF_RAX_AmericanIndian_AlaskaNative_451011 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 201 NF_RAX_AmericanIndian_AlaskaNative_452000 [[20, 30, 50, 70, 80, 70, 70, 0]]
# 202 NF_RAX_AmericanIndian_AlaskaNative_452090 [[20, 30, 50, 70, 80, 70, 70, 0]]
# 203 NF_RAX_AmericanIndian_AlaskaNative_452092 [[0, 0, 20, 0, 50, 70, 40, 0]]
# 204 NF_RAX_AmericanIndian_AlaskaNative_452093 [[0, 0, 30, 0, 0, 0, 30, 0]]
# 205 NF_RAX_AmericanIndian_AlaskaNative_454000 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 206 NF_RAX_AmericanIndian_AlaskaNative_454020 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 207 NF_RAX_AmericanIndian_AlaskaNative_454029 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 208 NF_RAX_AmericanIndian_AlaskaNative_470000 [[460, 820, 890, 730, 290, 680, 420, 490]]
# 209 NF_RAX_AmericanIndian_AlaskaNative_471000 [[40, 0, 270, 0, 30, 0, 20, 0]]
# 210 NF_RAX_AmericanIndian_AlaskaNative_471010 [[40, 0, 270, 0, 30, 0, 20, 0]]
# 211 NF_RAX_AmericanIndian_AlaskaNative_471011 [[40, 0, 270, 0, 30, 0, 20, 0]]
# 212 NF_RAX_AmericanIndian_AlaskaNative_472000 [[320, 770, 500, 570, 220, 570, 390, 440]]
# 213 NF_RAX_AmericanIndian_AlaskaNative_472030 [[80, 210, 30, 180, 40, 100, 80, 20]]
# 214 NF_RAX_AmericanIndian_AlaskaNative_472031 [[80, 210, 30, 180, 40, 100, 80, 20]]
# 215 NF_RAX_AmericanIndian_AlaskaNative_472050 [[0, 0, 20, 0, 0, 0, 20, 0]]
# 216 NF_RAX_AmericanIndian_AlaskaNative_472051 [[0, 0, 20, 0, 0, 0, 20, 0]]
# 217 NF_RAX_AmericanIndian_AlaskaNative_472060 [[110, 160, 290, 280, 110, 50, 100, 260]]
# 218 NF_RAX_AmericanIndian_AlaskaNative_472061 [[110, 160, 290, 280, 110, 50, 100, 260]]
# 219 NF_RAX_AmericanIndian_AlaskaNative_472070 [[20, 40, 0, 20, 0, 80, 110, 20]]
# 220 NF_RAX_AmericanIndian_AlaskaNative_472073 [[20, 40, 0, 20, 0, 80, 110, 20]]
# 221 NF_RAX_AmericanIndian_AlaskaNative_472110 [[20, 180, 50, 20, 30, 30, 0, 80]]
# 222 NF_RAX_AmericanIndian_AlaskaNative_472111 [[20, 180, 50, 20, 30, 30, 0, 80]]
# 223 NF_RAX_AmericanIndian_AlaskaNative_472150 [[50, 20, 20, 0, 0, 50, 20, 0]]
# 224 NF_RAX_AmericanIndian_AlaskaNative_472152 [[50, 20, 20, 0, 0, 50, 20, 0]]
# 225 NF_RAX_AmericanIndian_AlaskaNative_472180 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 226 NF_RAX_AmericanIndian_AlaskaNative_472181 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 227 NF_RAX_AmericanIndian_AlaskaNative_472210 [[0, 30, 40, 0, 0, 0, 0, 0]]
# 228 NF_RAX_AmericanIndian_AlaskaNative_472211 [[0, 30, 40, 0, 0, 0, 0, 0]]
# 229 NF_RAX_AmericanIndian_AlaskaNative_472220 [[0, 60, 0, 0, 0, 160, 0, 0]]
# 230 NF_RAX_AmericanIndian_AlaskaNative_472221 [[0, 60, 0, 0, 0, 160, 0, 0]]
# 231 NF_RAX_AmericanIndian_AlaskaNative_473000 [[70, 0, 0, 0, 0, 0, 0, 0]]
# 232 NF_RAX_AmericanIndian_AlaskaNative_473010 [[70, 0, 0, 0, 0, 0, 0, 0]]
# 233 NF_RAX_AmericanIndian_AlaskaNative_474000 [[0, 0, 110, 120, 40, 70, 0, 0]]
# 234 NF_RAX_AmericanIndian_AlaskaNative_474030 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 235 NF_RAX_AmericanIndian_AlaskaNative_474031 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 236 NF_RAX_AmericanIndian_AlaskaNative_474050 [[0, 0, 30, 110, 20, 30, 0, 0]]
# 237 NF_RAX_AmericanIndian_AlaskaNative_474051 [[0, 0, 30, 110, 20, 30, 0, 0]]
# 238 NF_RAX_AmericanIndian_AlaskaNative_474070 [[0, 0, 0, 0, 0, 40, 0, 0]]
# 239 NF_RAX_AmericanIndian_AlaskaNative_474071 [[0, 0, 0, 0, 0, 40, 0, 0]]
# 240 NF_RAX_AmericanIndian_AlaskaNative_475000 [[20, 30, 0, 30, 0, 0, 0, 0]]
# 241 NF_RAX_AmericanIndian_AlaskaNative_475070 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 242 NF_RAX_AmericanIndian_AlaskaNative_475071 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 243 NF_RAX_AmericanIndian_AlaskaNative_475090 [[0, 30, 0, 0, 0, 0, 0, 0]]
# 244 NF_RAX_AmericanIndian_AlaskaNative_475099 [[0, 30, 0, 0, 0, 0, 0, 0]]
# 245 NF_RAX_AmericanIndian_AlaskaNative_490000 [[430, 410, 410, 470, 350, 700, 350, 270]]
# 246 NF_RAX_AmericanIndian_AlaskaNative_491000 [[20, 0, 50, 0, 0, 0, 0, 0]]
# 247 NF_RAX_AmericanIndian_AlaskaNative_491010 [[20, 0, 50, 0, 0, 0, 0, 0]]
# 248 NF_RAX_AmericanIndian_AlaskaNative_491011 [[20, 0, 50, 0, 0, 0, 0, 0]]
# 249 NF_RAX_AmericanIndian_AlaskaNative_492000 [[0, 0, 0, 0, 30, 20, 0, 0]]
# 250 NF_RAX_AmericanIndian_AlaskaNative_493000 [[170, 80, 200, 100, 60, 390, 60, 20]]
# 251 NF_RAX_AmericanIndian_AlaskaNative_493020 [[20, 40, 110, 80, 20, 40, 30, 0]]
# 252 NF_RAX_AmericanIndian_AlaskaNative_493023 [[20, 40, 80, 80, 20, 40, 30, 0]]
# 253 NF_RAX_AmericanIndian_AlaskaNative_493030 [[70, 0, 70, 0, 20, 290, 0, 0]]
# 254 NF_RAX_AmericanIndian_AlaskaNative_493031 [[70, 0, 70, 0, 20, 290, 0, 0]]
# 255 NF_RAX_AmericanIndian_AlaskaNative_493040 [[0, 30, 20, 0, 0, 0, 20, 0]]
# 256 NF_RAX_AmericanIndian_AlaskaNative_493042 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 257 NF_RAX_AmericanIndian_AlaskaNative_493043 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 258 NF_RAX_AmericanIndian_AlaskaNative_493090 [[80, 0, 0, 0, 0, 50, 0, 0]]
# 259 NF_RAX_AmericanIndian_AlaskaNative_493093 [[80, 0, 0, 0, 0, 40, 0, 0]]
# 260 NF_RAX_AmericanIndian_AlaskaNative_499000 [[240, 310, 160, 360, 270, 300, 280, 240]]
# 261 NF_RAX_AmericanIndian_AlaskaNative_499020 [[0, 60, 0, 0, 30, 0, 0, 20]]
# 262 NF_RAX_AmericanIndian_AlaskaNative_499021 [[0, 60, 0, 0, 30, 0, 0, 20]]
# 263 NF_RAX_AmericanIndian_AlaskaNative_499040 [[20, 20, 0, 0, 0, 0, 20, 0]]
# 264 NF_RAX_AmericanIndian_AlaskaNative_499041 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 265 NF_RAX_AmericanIndian_AlaskaNative_499050 [[50, 0, 20, 90, 30, 30, 90, 0]]
# 266 NF_RAX_AmericanIndian_AlaskaNative_499051 [[50, 0, 20, 40, 30, 30, 70, 0]]
# 267 NF_RAX_AmericanIndian_AlaskaNative_499052 [[0, 0, 0, 50, 0, 0, 0, 0]]
# 268 NF_RAX_AmericanIndian_AlaskaNative_499070 [[140, 170, 110, 220, 150, 250, 160, 170]]
# 269 NF_RAX_AmericanIndian_AlaskaNative_499071 [[140, 170, 110, 220, 150, 250, 160, 170]]
# 270 NF_RAX_AmericanIndian_AlaskaNative_499090 [[20, 50, 20, 30, 50, 0, 0, 0]]
# 271 NF_RAX_AmericanIndian_AlaskaNative_499098 [[0, 0, 0, 0, 40, 0, 0, 0]]
# 272 NF_RAX_AmericanIndian_AlaskaNative_499099 [[20, 40, 0, 0, 0, 0, 0, 0]]
# 273 NF_RAX_AmericanIndian_AlaskaNative_510000 [[400, 500, 470, 530, 280, 380, 560, 470]]
# 274 NF_RAX_AmericanIndian_AlaskaNative_511000 [[0, 0, 0, 30, 0, 20, 20, 0]]
# 275 NF_RAX_AmericanIndian_AlaskaNative_511010 [[0, 0, 0, 30, 0, 20, 20, 0]]
# 276 NF_RAX_AmericanIndian_AlaskaNative_511011 [[0, 0, 0, 30, 0, 20, 20, 0]]
# 277 NF_RAX_AmericanIndian_AlaskaNative_512000 [[50, 70, 70, 110, 60, 20, 70, 0]]
# 278 NF_RAX_AmericanIndian_AlaskaNative_512020 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 279 NF_RAX_AmericanIndian_AlaskaNative_512022 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 280 NF_RAX_AmericanIndian_AlaskaNative_512090 [[50, 70, 50, 110, 50, 20, 70, 0]]
# 281 NF_RAX_AmericanIndian_AlaskaNative_512091 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 282 NF_RAX_AmericanIndian_AlaskaNative_512099 [[50, 70, 40, 100, 50, 20, 70, 0]]
# 283 NF_RAX_AmericanIndian_AlaskaNative_513000 [[20, 70, 30, 30, 50, 0, 40, 20]]
# 284 NF_RAX_AmericanIndian_AlaskaNative_513020 [[20, 70, 20, 20, 40, 0, 30, 20]]
# 285 NF_RAX_AmericanIndian_AlaskaNative_513021 [[20, 0, 0, 0, 30, 0, 0, 0]]
# 286 NF_RAX_AmericanIndian_AlaskaNative_513022 [[0, 70, 20, 20, 0, 0, 0, 0]]
# 287 NF_RAX_AmericanIndian_AlaskaNative_514000 [[130, 110, 110, 70, 100, 100, 100, 160]]
# 288 NF_RAX_AmericanIndian_AlaskaNative_514030 [[0, 0, 30, 20, 0, 0, 20, 20]]
# 289 NF_RAX_AmericanIndian_AlaskaNative_514031 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 290 NF_RAX_AmericanIndian_AlaskaNative_514040 [[30, 0, 0, 0, 20, 0, 0, 0]]
# 291 NF_RAX_AmericanIndian_AlaskaNative_514041 [[30, 0, 0, 0, 20, 0, 0, 0]]
# 292 NF_RAX_AmericanIndian_AlaskaNative_514070 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 293 NF_RAX_AmericanIndian_AlaskaNative_514072 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 294 NF_RAX_AmericanIndian_AlaskaNative_514120 [[50, 60, 30, 20, 50, 40, 70, 100]]
# 295 NF_RAX_AmericanIndian_AlaskaNative_514121 [[0, 0, 30, 20, 30, 0, 70, 0]]
# 296 NF_RAX_AmericanIndian_AlaskaNative_514122 [[50, 50, 0, 0, 20, 30, 0, 90]]
# 297 NF_RAX_AmericanIndian_AlaskaNative_514190 [[30, 20, 0, 20, 0, 30, 0, 20]]
# 298 NF_RAX_AmericanIndian_AlaskaNative_514199 [[30, 20, 0, 20, 0, 30, 0, 20]]
# 299 NF_RAX_AmericanIndian_AlaskaNative_515100 [[20, 0, 0, 0, 0, 0, 0, 20]]
# 300 NF_RAX_AmericanIndian_AlaskaNative_515110 [[20, 0, 0, 0, 0, 0, 0, 20]]
# 301 NF_RAX_AmericanIndian_AlaskaNative_515112 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 302 NF_RAX_AmericanIndian_AlaskaNative_516000 [[30, 0, 20, 0, 0, 20, 100, 20]]
# 303 NF_RAX_AmericanIndian_AlaskaNative_516010 [[20, 0, 20, 0, 0, 20, 0, 0]]
# 304 NF_RAX_AmericanIndian_AlaskaNative_516011 [[20, 0, 20, 0, 0, 20, 0, 0]]
# 305 NF_RAX_AmericanIndian_AlaskaNative_517000 [[0, 0, 20, 60, 0, 0, 70, 120]]
# 306 NF_RAX_AmericanIndian_AlaskaNative_517010 [[0, 0, 0, 40, 0, 0, 0, 90]]
# 307 NF_RAX_AmericanIndian_AlaskaNative_517011 [[0, 0, 0, 40, 0, 0, 0, 90]]
# 308 NF_RAX_AmericanIndian_AlaskaNative_517040 [[0, 0, 0, 20, 0, 0, 70, 30]]
# 309 NF_RAX_AmericanIndian_AlaskaNative_517041 [[0, 0, 0, 20, 0, 0, 70, 30]]
# 310 NF_RAX_AmericanIndian_AlaskaNative_518000 [[0, 0, 30, 60, 0, 20, 0, 0]]
# 311 NF_RAX_AmericanIndian_AlaskaNative_518030 [[0, 0, 20, 60, 0, 0, 0, 0]]
# 312 NF_RAX_AmericanIndian_AlaskaNative_518031 [[0, 0, 20, 60, 0, 0, 0, 0]]
# 313 NF_RAX_AmericanIndian_AlaskaNative_518090 [[0, 0, 0, 0, 0, 20, 0, 0]]
# 314 NF_RAX_AmericanIndian_AlaskaNative_518093 [[0, 0, 0, 0, 0, 20, 0, 0]]
# 315 NF_RAX_AmericanIndian_AlaskaNative_519000 [[120, 230, 170, 150, 60, 170, 150, 110]]
# 316 NF_RAX_AmericanIndian_AlaskaNative_519060 [[0, 0, 0, 0, 0, 30, 0, 0]]
# 317 NF_RAX_AmericanIndian_AlaskaNative_519061 [[0, 0, 0, 0, 0, 30, 0, 0]]
# 318 NF_RAX_AmericanIndian_AlaskaNative_519110 [[0, 30, 0, 20, 0, 0, 0, 0]]
# 319 NF_RAX_AmericanIndian_AlaskaNative_519111 [[0, 30, 0, 20, 0, 0, 0, 0]]
# 320 NF_RAX_AmericanIndian_AlaskaNative_519120 [[0, 30, 40, 0, 0, 0, 0, 0]]
# 321 NF_RAX_AmericanIndian_AlaskaNative_519122 [[0, 20, 0, 0, 0, 0, 0, 0]]
# 322 NF_RAX_AmericanIndian_AlaskaNative_519190 [[100, 160, 110, 110, 50, 110, 140, 90]]
# 323 NF_RAX_AmericanIndian_AlaskaNative_519198 [[0, 0, 0, 0, 0, 40, 0, 50]]
# 324 NF_RAX_AmericanIndian_AlaskaNative_519199 [[90, 140, 100, 100, 40, 60, 130, 40]]
# 325 NF_RAX_AmericanIndian_AlaskaNative_530000 [[520, 800, 1130, 550, 480, 700, 380, 330]]
# 326 NF_RAX_AmericanIndian_AlaskaNative_531000 [[0, 0, 40, 20, 0, 0, 0, 0]]
# 327 NF_RAX_AmericanIndian_AlaskaNative_531020 [[0, 0, 40, 20, 0, 0, 0, 0]]
# 328 NF_RAX_AmericanIndian_AlaskaNative_531021 [[0, 0, 40, 20, 0, 0, 0, 0]]
# 329 NF_RAX_AmericanIndian_AlaskaNative_533000 [[240, 490, 280, 330, 320, 290, 130, 160]]
# 330 NF_RAX_AmericanIndian_AlaskaNative_533020 [[0, 80, 80, 50, 70, 20, 30, 0]]
# 331 NF_RAX_AmericanIndian_AlaskaNative_533022 [[0, 70, 70, 40, 60, 20, 20, 0]]
# 332 NF_RAX_AmericanIndian_AlaskaNative_533030 [[200, 390, 190, 280, 240, 250, 100, 140]]
# 333 NF_RAX_AmericanIndian_AlaskaNative_533031 [[70, 0, 30, 70, 0, 20, 0, 0]]
# 334 NF_RAX_AmericanIndian_AlaskaNative_533032 [[80, 150, 140, 110, 180, 130, 70, 120]]
# 335 NF_RAX_AmericanIndian_AlaskaNative_533033 [[60, 230, 20, 90, 60, 110, 30, 0]]
# 336 NF_RAX_AmericanIndian_AlaskaNative_533040 [[20, 0, 0, 0, 0, 20, 0, 0]]
# 337 NF_RAX_AmericanIndian_AlaskaNative_533041 [[20, 0, 0, 0, 0, 20, 0, 0]]
# 338 NF_RAX_AmericanIndian_AlaskaNative_533090 [[0, 30, 0, 0, 0, 0, 0, 0]]
# 339 NF_RAX_AmericanIndian_AlaskaNative_533099 [[0, 30, 0, 0, 0, 0, 0, 0]]
# 340 NF_RAX_AmericanIndian_AlaskaNative_536000 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 341 NF_RAX_AmericanIndian_AlaskaNative_537000 [[260, 310, 790, 190, 140, 400, 240, 150]]
# 342 NF_RAX_AmericanIndian_AlaskaNative_537020 [[0, 50, 0, 0, 0, 0, 0, 0]]
# 343 NF_RAX_AmericanIndian_AlaskaNative_537021 [[0, 50, 0, 0, 0, 0, 0, 0]]
# 344 NF_RAX_AmericanIndian_AlaskaNative_537050 [[40, 20, 0, 20, 20, 0, 0, 0]]
# 345 NF_RAX_AmericanIndian_AlaskaNative_537051 [[40, 20, 0, 20, 20, 0, 0, 0]]
# 346 NF_RAX_AmericanIndian_AlaskaNative_537060 [[200, 190, 770, 160, 110, 380, 210, 120]]
# 347 NF_RAX_AmericanIndian_AlaskaNative_537061 [[0, 30, 400, 0, 0, 0, 0, 0]]
# 348 NF_RAX_AmericanIndian_AlaskaNative_537062 [[190, 160, 370, 140, 90, 350, 180, 90]]
# 349 NF_RAX_AmericanIndian_AlaskaNative_537064 [[0, 0, 0, 0, 0, 20, 20, 0]]
# 350 NF_RAX_AmericanIndian_AlaskaNative_537080 [[0, 30, 0, 0, 0, 0, 0, 20]]
# 351 NF_RAX_AmericanIndian_AlaskaNative_537081 [[0, 30, 0, 0, 0, 0, 0, 20]]
# 352 NF_RAX_AmericanIndian_AlaskaNative_O10XXX [[280, 130, 180, 100, 130, 170, 170, 190]]
# 353 NF_RAX_AmericanIndian_AlaskaNative_O23XXX [[40, 110, 30, 0, 30, 0, 0, 0]]
# 354 NF_RAX_AmericanIndian_AlaskaNative_O25XXX [[180, 230, 340, 430, 240, 560, 450, 270]]
# 355 NF_RAX_AmericanIndian_AlaskaNative_O27XXX [[320, 160, 160, 270, 200, 160, 120, 100]]
# 356 NF_RAX_AmericanIndian_AlaskaNative_O30XXX [[1910, 1520, 1690, 1850, 1880, 1130, 1590, 1830]]
# 357 NF_RAX_AmericanIndian_AlaskaNative_O41XXX [[400, 170, 150, 110, 580, 180, 190, 110]]
# 358 NF_RAX_AmericanIndian_AlaskaNative_O43XXX [[230, 190, 450, 290, 290, 200, 530, 310]]
# 359 NF_RAX_AmericanIndian_AlaskaNative_O45XXX [[40, 80, 50, 80, 80, 80, 80, 40]]
# 360 NF_RAX_AmericanIndian_AlaskaNative_O47XXX [[460, 820, 890, 730, 290, 680, 420, 490]]
# 361 NF_RAX_AmericanIndian_AlaskaNative_O49XXX [[430, 410, 410, 470, 350, 700, 350, 270]]
# 362 NF_RAX_AmericanIndian_AlaskaNative_O51XXX [[400, 500, 470, 530, 280, 380, 560, 470]]
# 363 NF_RAX_AmericanIndian_AlaskaNative_O53XXX [[520, 800, 1130, 550, 480, 700, 380, 330]]
# 364 NF_RAX_AmericanIndian_AlaskaNative_OT1XXX [[820, 630, 700, 810, 590, 900, 750, 570]]
# 365 NF_RAX_AmericanIndian_AlaskaNative_OT2XXX [[630, 360, 590, 410, 870, 380, 720, 430]]
# 366 NF_RAX_AmericanIndian_AlaskaNative_OT3XXX [[930, 1300, 1360, 1280, 720, 1460, 850, 800]]
# 367 NF_RAX_AmericanIndian_AlaskaNative_OT4XXX [[920, 1300, 1600, 1070, 760, 1070, 940, 790]]
# 368 NF_RBX_Asian_0XXXXX [[20, 50, 250, 30, 0, 0, 0, 0]]
# 369 NF_RBX_Asian_110000 [[360, 290, 530, 760, 970, 240, 240, 1100]]
# 370 NF_RBX_Asian_111000 [[30, 30, 70, 30, 120, 40, 70, 0]]
# 371 NF_RBX_Asian_111010 [[0, 0, 0, 0, 110, 0, 0, 0]]
# 372 NF_RBX_Asian_111011 [[0, 0, 0, 0, 110, 0, 0, 0]]
# 373 NF_RBX_Asian_111020 [[30, 20, 70, 20, 0, 40, 60, 0]]
# 374 NF_RBX_Asian_111021 [[30, 20, 70, 20, 0, 40, 60, 0]]
# 375 NF_RBX_Asian_112000 [[0, 50, 0, 40, 0, 0, 20, 0]]
# 376 NF_RBX_Asian_112020 [[0, 0, 0, 40, 0, 0, 20, 0]]
# 377 NF_RBX_Asian_112021 [[0, 0, 0, 30, 0, 0, 20, 0]]
# 378 NF_RBX_Asian_113000 [[20, 60, 40, 90, 110, 30, 80, 210]]
# 379 NF_RBX_Asian_113010 [[0, 0, 0, 0, 0, 0, 20, 110]]
# 380 NF_RBX_Asian_113011 [[0, 0, 0, 0, 0, 0, 20, 110]]
# 381 NF_RBX_Asian_113020 [[0, 0, 20, 0, 60, 0, 0, 0]]
# 382 NF_RBX_Asian_113021 [[0, 0, 20, 0, 60, 0, 0, 0]]
# 383 NF_RBX_Asian_113030 [[0, 20, 0, 50, 30, 0, 50, 60]]
# 384 NF_RBX_Asian_113031 [[0, 20, 0, 50, 30, 0, 50, 60]]
# 385 NF_RBX_Asian_113070 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 386 NF_RBX_Asian_113071 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 387 NF_RBX_Asian_119000 [[300, 160, 410, 600, 720, 170, 60, 860]]
# 388 NF_RBX_Asian_119010 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 389 NF_RBX_Asian_119013 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 390 NF_RBX_Asian_119020 [[0, 0, 0, 0, 530, 0, 0, 0]]
# 391 NF_RBX_Asian_119021 [[0, 0, 0, 0, 530, 0, 0, 0]]
# 392 NF_RBX_Asian_119030 [[20, 20, 0, 40, 0, 0, 0, 70]]
# 393 NF_RBX_Asian_119032 [[0, 0, 0, 40, 0, 0, 0, 70]]
# 394 NF_RBX_Asian_119040 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 395 NF_RBX_Asian_119041 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 396 NF_RBX_Asian_119050 [[20, 0, 20, 60, 80, 0, 0, 0]]
# 397 NF_RBX_Asian_119051 [[20, 0, 20, 60, 80, 0, 0, 0]]
# 398 NF_RBX_Asian_119110 [[50, 60, 90, 110, 50, 30, 0, 50]]
# 399 NF_RBX_Asian_119111 [[50, 60, 90, 110, 50, 30, 0, 50]]
# 400 NF_RBX_Asian_119140 [[140, 0, 0, 0, 0, 0, 0, 0]]
# 401 NF_RBX_Asian_119141 [[140, 0, 0, 0, 0, 0, 0, 0]]
# 402 NF_RBX_Asian_119150 [[0, 30, 0, 0, 0, 0, 0, 0]]
# 403 NF_RBX_Asian_119151 [[0, 30, 0, 0, 0, 0, 0, 0]]
# 404 NF_RBX_Asian_119190 [[40, 30, 290, 390, 30, 120, 30, 410]]
# 405 NF_RBX_Asian_119199 [[40, 30, 290, 390, 30, 120, 30, 410]]
# 406 NF_RBX_Asian_130000 [[190, 160, 140, 120, 90, 160, 180, 130]]
# 407 NF_RBX_Asian_131000 [[110, 100, 100, 50, 30, 80, 60, 80]]
# 408 NF_RBX_Asian_131030 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 409 NF_RBX_Asian_131031 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 410 NF_RBX_Asian_131070 [[0, 40, 0, 0, 0, 0, 0, 0]]
# 411 NF_RBX_Asian_131071 [[0, 40, 0, 0, 0, 0, 0, 0]]
# 412 NF_RBX_Asian_131110 [[0, 20, 0, 0, 0, 0, 40, 20]]
# 413 NF_RBX_Asian_131111 [[0, 20, 0, 0, 0, 0, 40, 20]]
# 414 NF_RBX_Asian_131120 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 415 NF_RBX_Asian_131121 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 416 NF_RBX_Asian_131150 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 417 NF_RBX_Asian_131151 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 418 NF_RBX_Asian_131190 [[80, 20, 0, 0, 0, 0, 0, 0]]
# 419 NF_RBX_Asian_131199 [[80, 20, 0, 0, 0, 0, 0, 0]]
# 420 NF_RBX_Asian_132000 [[80, 60, 30, 80, 50, 70, 120, 60]]
# 421 NF_RBX_Asian_132010 [[70, 40, 20, 60, 40, 20, 90, 0]]
# 422 NF_RBX_Asian_132011 [[70, 40, 20, 60, 40, 20, 90, 0]]
# 423 NF_RBX_Asian_132050 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 424 NF_RBX_Asian_132051 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 425 NF_RBX_Asian_132070 [[0, 0, 0, 0, 0, 20, 0, 0]]
# 426 NF_RBX_Asian_132072 [[0, 0, 0, 0, 0, 20, 0, 0]]
# 427 NF_RBX_Asian_132090 [[0, 0, 0, 0, 0, 30, 0, 40]]
# 428 NF_RBX_Asian_132099 [[0, 0, 0, 0, 0, 30, 0, 40]]
# 429 NF_RBX_Asian_150000 [[20, 100, 100, 60, 60, 40, 140, 40]]
# 430 NF_RBX_Asian_151100 [[20, 90, 90, 60, 50, 40, 140, 40]]
# 431 NF_RBX_Asian_151130 [[0, 60, 0, 0, 0, 0, 0, 20]]
# 432 NF_RBX_Asian_151133 [[0, 50, 0, 0, 0, 0, 0, 20]]
# 433 NF_RBX_Asian_151140 [[0, 20, 60, 0, 0, 0, 0, 0]]
# 434 NF_RBX_Asian_151142 [[0, 0, 60, 0, 0, 0, 0, 0]]
# 435 NF_RBX_Asian_151150 [[0, 0, 20, 20, 20, 0, 0, 0]]
# 436 NF_RBX_Asian_151151 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 437 NF_RBX_Asian_151152 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 438 NF_RBX_Asian_151190 [[0, 0, 0, 0, 0, 20, 110, 0]]
# 439 NF_RBX_Asian_151199 [[0, 0, 0, 0, 0, 20, 110, 0]]
# 440 NF_RBX_Asian_170000 [[70, 110, 40, 50, 220, 100, 30, 30]]
# 441 NF_RBX_Asian_172000 [[60, 40, 20, 20, 200, 0, 20, 20]]
# 442 NF_RBX_Asian_172110 [[20, 0, 0, 0, 0, 0, 20, 0]]
# 443 NF_RBX_Asian_172112 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 444 NF_RBX_Asian_172190 [[30, 0, 0, 0, 30, 0, 0, 20]]
# 445 NF_RBX_Asian_172199 [[30, 0, 0, 0, 30, 0, 0, 20]]
# 446 NF_RBX_Asian_173000 [[0, 70, 20, 20, 0, 90, 0, 0]]
# 447 NF_RBX_Asian_173020 [[0, 70, 20, 20, 0, 90, 0, 0]]
# 448 NF_RBX_Asian_173023 [[0, 70, 0, 0, 0, 70, 0, 0]]
# 449 NF_RBX_Asian_190000 [[70, 70, 160, 140, 70, 70, 60, 50]]
# 450 NF_RBX_Asian_191000 [[0, 20, 20, 60, 40, 0, 20, 0]]
# 451 NF_RBX_Asian_191020 [[0, 0, 20, 20, 30, 0, 0, 0]]
# 452 NF_RBX_Asian_191029 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 453 NF_RBX_Asian_191040 [[0, 20, 0, 40, 0, 0, 0, 0]]
# 454 NF_RBX_Asian_191042 [[0, 0, 0, 40, 0, 0, 0, 0]]
# 455 NF_RBX_Asian_192000 [[20, 0, 40, 0, 0, 30, 20, 0]]
# 456 NF_RBX_Asian_192030 [[0, 0, 30, 0, 0, 20, 0, 0]]
# 457 NF_RBX_Asian_192031 [[0, 0, 30, 0, 0, 20, 0, 0]]
# 458 NF_RBX_Asian_194000 [[40, 30, 100, 70, 30, 20, 0, 30]]
# 459 NF_RBX_Asian_194010 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 460 NF_RBX_Asian_194011 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 461 NF_RBX_Asian_194060 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 462 NF_RBX_Asian_194061 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 463 NF_RBX_Asian_194090 [[20, 0, 70, 60, 0, 20, 0, 20]]
# 464 NF_RBX_Asian_194091 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 465 NF_RBX_Asian_194099 [[0, 0, 60, 60, 0, 20, 0, 0]]
# 466 NF_RBX_Asian_210000 [[90, 170, 120, 130, 60, 140, 90, 100]]
# 467 NF_RBX_Asian_211000 [[90, 160, 110, 130, 60, 140, 80, 100]]
# 468 NF_RBX_Asian_211010 [[20, 0, 70, 30, 30, 70, 50, 30]]
# 469 NF_RBX_Asian_211012 [[0, 0, 30, 0, 0, 0, 30, 0]]
# 470 NF_RBX_Asian_211014 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 471 NF_RBX_Asian_211015 [[0, 0, 0, 0, 0, 40, 0, 0]]
# 472 NF_RBX_Asian_211020 [[30, 100, 30, 30, 20, 30, 0, 20]]
# 473 NF_RBX_Asian_211022 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 474 NF_RBX_Asian_211023 [[0, 80, 0, 0, 0, 0, 0, 0]]
# 475 NF_RBX_Asian_211029 [[0, 20, 0, 0, 20, 20, 0, 0]]
# 476 NF_RBX_Asian_211090 [[40, 50, 20, 70, 0, 40, 30, 40]]
# 477 NF_RBX_Asian_211093 [[40, 30, 0, 70, 0, 20, 20, 30]]
# 478 NF_RBX_Asian_230000 [[0, 0, 30, 0, 0, 20, 260, 0]]
# 479 NF_RBX_Asian_231000 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 480 NF_RBX_Asian_232000 [[0, 0, 0, 0, 0, 0, 250, 0]]
# 481 NF_RBX_Asian_232010 [[0, 0, 0, 0, 0, 0, 240, 0]]
# 482 NF_RBX_Asian_232011 [[0, 0, 0, 0, 0, 0, 240, 0]]
# 483 NF_RBX_Asian_250000 [[160, 270, 260, 470, 310, 720, 260, 740]]
# 484 NF_RBX_Asian_251000 [[0, 20, 30, 20, 0, 0, 0, 20]]
# 485 NF_RBX_Asian_251190 [[0, 20, 30, 20, 0, 0, 0, 20]]
# 486 NF_RBX_Asian_251194 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 487 NF_RBX_Asian_251199 [[0, 20, 0, 0, 0, 0, 0, 20]]
# 488 NF_RBX_Asian_252000 [[60, 130, 50, 100, 140, 90, 110, 520]]
# 489 NF_RBX_Asian_252010 [[20, 90, 30, 70, 50, 20, 50, 20]]
# 490 NF_RBX_Asian_252011 [[20, 90, 30, 70, 50, 20, 50, 20]]
# 491 NF_RBX_Asian_252020 [[30, 20, 0, 20, 70, 70, 60, 480]]
# 492 NF_RBX_Asian_252021 [[30, 20, 0, 20, 70, 30, 60, 480]]
# 493 NF_RBX_Asian_252022 [[0, 0, 0, 0, 0, 40, 0, 0]]
# 494 NF_RBX_Asian_252050 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 495 NF_RBX_Asian_252052 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 496 NF_RBX_Asian_253000 [[30, 30, 0, 130, 50, 50, 30, 30]]
# 497 NF_RBX_Asian_253090 [[30, 30, 0, 130, 40, 50, 20, 30]]
# 498 NF_RBX_Asian_253099 [[30, 30, 0, 130, 40, 50, 20, 30]]
# 499 NF_RBX_Asian_259000 [[60, 100, 160, 200, 110, 560, 110, 150]]
# 500 NF_RBX_Asian_259040 [[60, 20, 150, 200, 80, 560, 90, 140]]
# 501 NF_RBX_Asian_259041 [[60, 20, 150, 200, 80, 560, 90, 140]]
# 502 NF_RBX_Asian_259090 [[0, 80, 0, 0, 20, 0, 20, 0]]
# 503 NF_RBX_Asian_259099 [[0, 80, 0, 0, 20, 0, 20, 0]]
# 504 NF_RBX_Asian_270000 [[50, 80, 120, 120, 100, 70, 50, 110]]
# 505 NF_RBX_Asian_271000 [[0, 0, 20, 20, 0, 20, 0, 80]]
# 506 NF_RBX_Asian_271020 [[0, 0, 20, 20, 0, 0, 0, 80]]
# 507 NF_RBX_Asian_272000 [[30, 40, 60, 80, 70, 40, 30, 20]]
# 508 NF_RBX_Asian_272020 [[0, 0, 0, 0, 40, 20, 0, 0]]
# 509 NF_RBX_Asian_272021 [[0, 0, 0, 0, 0, 20, 0, 0]]
# 510 NF_RBX_Asian_272022 [[0, 0, 0, 0, 40, 0, 0, 0]]
# 511 NF_RBX_Asian_272030 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 512 NF_RBX_Asian_272031 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 513 NF_RBX_Asian_272090 [[20, 0, 40, 60, 20, 20, 20, 0]]
# 514 NF_RBX_Asian_272099 [[20, 0, 40, 60, 20, 20, 20, 0]]
# 515 NF_RBX_Asian_273000 [[0, 30, 0, 0, 20, 0, 0, 0]]
# 516 NF_RBX_Asian_274000 [[20, 0, 40, 0, 0, 0, 0, 0]]
# 517 NF_RBX_Asian_290000 [[1620, 1900, 1630, 1620, 1430, 1690, 1380, 1510]]
# 518 NF_RBX_Asian_291000 [[1050, 1230, 1110, 1250, 1090, 1250, 970, 1080]]
# 519 NF_RBX_Asian_291020 [[0, 0, 0, 0, 0, 40, 0, 0]]
# 520 NF_RBX_Asian_291021 [[0, 0, 0, 0, 0, 40, 0, 0]]
# 521 NF_RBX_Asian_291050 [[0, 0, 20, 30, 0, 0, 0, 0]]
# 522 NF_RBX_Asian_291051 [[0, 0, 20, 30, 0, 0, 0, 0]]
# 523 NF_RBX_Asian_291060 [[0, 30, 50, 20, 60, 40, 50, 30]]
# 524 NF_RBX_Asian_291069 [[0, 20, 30, 0, 30, 30, 30, 20]]
# 525 NF_RBX_Asian_291111 [[940, 0, 0, 0, 0, 0, 0, 0]]
# 526 NF_RBX_Asian_291120 [[90, 80, 80, 70, 70, 140, 30, 90]]
# 527 NF_RBX_Asian_291122 [[0, 0, 30, 0, 0, 30, 0, 0]]
# 528 NF_RBX_Asian_291123 [[30, 40, 30, 20, 40, 70, 0, 50]]
# 529 NF_RBX_Asian_291126 [[40, 40, 20, 30, 0, 40, 0, 20]]
# 530 NF_RBX_Asian_291140 [[920, 1110, 930, 1090, 970, 1010, 860, 910]]
# 531 NF_RBX_Asian_291141 [[920, 1110, 930, 1090, 970, 1010, 860, 910]]
# 532 NF_RBX_Asian_291170 [[20, 0, 0, 30, 0, 0, 0, 20]]
# 533 NF_RBX_Asian_291171 [[20, 0, 0, 30, 0, 0, 0, 20]]
# 534 NF_RBX_Asian_292000 [[560, 660, 510, 370, 340, 440, 390, 420]]
# 535 NF_RBX_Asian_292010 [[20, 60, 90, 20, 40, 40, 110, 50]]
# 536 NF_RBX_Asian_292011 [[0, 40, 0, 0, 20, 30, 20, 0]]
# 537 NF_RBX_Asian_292012 [[20, 20, 90, 0, 20, 0, 90, 40]]
# 538 NF_RBX_Asian_292030 [[60, 60, 90, 40, 40, 40, 50, 30]]
# 539 NF_RBX_Asian_292031 [[0, 40, 0, 0, 0, 0, 0, 0]]
# 540 NF_RBX_Asian_292032 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 541 NF_RBX_Asian_292034 [[30, 20, 60, 30, 20, 0, 30, 0]]
# 542 NF_RBX_Asian_292040 [[50, 0, 20, 20, 0, 20, 0, 40]]
# 543 NF_RBX_Asian_292041 [[50, 0, 20, 20, 0, 20, 0, 40]]
# 544 NF_RBX_Asian_292050 [[270, 390, 120, 160, 80, 150, 120, 180]]
# 545 NF_RBX_Asian_292051 [[70, 60, 50, 40, 30, 30, 40, 50]]
# 546 NF_RBX_Asian_292052 [[70, 0, 20, 30, 0, 0, 0, 40]]
# 547 NF_RBX_Asian_292053 [[50, 0, 0, 70, 0, 90, 50, 0]]
# 548 NF_RBX_Asian_292055 [[80, 40, 20, 20, 40, 0, 20, 20]]
# 549 NF_RBX_Asian_292056 [[0, 0, 0, 0, 0, 0, 0, 60]]
# 550 NF_RBX_Asian_292060 [[110, 80, 160, 100, 130, 150, 80, 110]]
# 551 NF_RBX_Asian_292061 [[110, 80, 160, 100, 130, 150, 80, 110]]
# 552 NF_RBX_Asian_292070 [[0, 0, 20, 0, 20, 0, 0, 0]]
# 553 NF_RBX_Asian_292071 [[0, 0, 20, 0, 20, 0, 0, 0]]
# 554 NF_RBX_Asian_292090 [[40, 50, 0, 0, 20, 30, 20, 0]]
# 555 NF_RBX_Asian_292099 [[40, 50, 0, 0, 20, 20, 20, 0]]
# 556 NF_RBX_Asian_299000 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 557 NF_RBX_Asian_299090 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 558 NF_RBX_Asian_299099 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 559 NF_RBX_Asian_310000 [[1120, 980, 1250, 1090, 1120, 1020, 1110, 1030]]
# 560 NF_RBX_Asian_311000 [[950, 920, 1150, 1020, 1020, 870, 980, 860]]
# 561 NF_RBX_Asian_311010 [[950, 920, 1150, 1020, 1020, 870, 980, 860]]
# 562 NF_RBX_Asian_311011 [[250, 160, 140, 180, 160, 160, 130, 130]]
# 563 NF_RBX_Asian_311012 [[680, 0, 0, 0, 0, 0, 0, 0]]
# 564 NF_RBX_Asian_311013 [[20, 0, 30, 50, 30, 40, 30, 30]]
# 565 NF_RBX_Asian_311014 [[640, 750, 940, 770, 810, 660, 810, 690]]
# 566 NF_RBX_Asian_311015 [[40, 0, 30, 0, 20, 0, 0, 0]]
# 567 NF_RBX_Asian_312000 [[0, 0, 40, 0, 0, 20, 0, 0]]
# 568 NF_RBX_Asian_312010 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 569 NF_RBX_Asian_312012 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 570 NF_RBX_Asian_319000 [[160, 50, 70, 70, 90, 130, 120, 170]]
# 571 NF_RBX_Asian_319090 [[160, 50, 50, 60, 80, 120, 120, 160]]
# 572 NF_RBX_Asian_319091 [[70, 0, 0, 0, 0, 0, 60, 0]]
# 573 NF_RBX_Asian_319092 [[0, 20, 30, 0, 20, 30, 20, 20]]
# 574 NF_RBX_Asian_319093 [[0, 0, 0, 0, 0, 20, 0, 40]]
# 575 NF_RBX_Asian_319096 [[0, 0, 0, 0, 0, 0, 0, 30]]
# 576 NF_RBX_Asian_319097 [[30, 0, 0, 20, 30, 30, 0, 30]]
# 577 NF_RBX_Asian_319099 [[40, 0, 0, 20, 0, 0, 0, 40]]
# 578 NF_RBX_Asian_330000 [[490, 850, 400, 790, 250, 380, 250, 500]]
# 579 NF_RBX_Asian_331000 [[20, 270, 0, 40, 0, 30, 50, 0]]
# 580 NF_RBX_Asian_331010 [[0, 260, 0, 40, 0, 0, 0, 0]]
# 581 NF_RBX_Asian_331012 [[0, 260, 0, 30, 0, 0, 0, 0]]
# 582 NF_RBX_Asian_331090 [[0, 0, 0, 0, 0, 20, 0, 0]]
# 583 NF_RBX_Asian_331099 [[0, 0, 0, 0, 0, 20, 0, 0]]
# 584 NF_RBX_Asian_332000 [[30, 30, 30, 60, 0, 20, 30, 0]]
# 585 NF_RBX_Asian_332010 [[30, 30, 30, 60, 0, 20, 20, 0]]
# 586 NF_RBX_Asian_332011 [[30, 30, 30, 60, 0, 20, 20, 0]]
# 587 NF_RBX_Asian_333000 [[320, 460, 230, 520, 120, 130, 70, 360]]
# 588 NF_RBX_Asian_333010 [[40, 80, 20, 110, 50, 30, 20, 0]]
# 589 NF_RBX_Asian_333012 [[40, 80, 20, 110, 50, 30, 20, 0]]
# 590 NF_RBX_Asian_333030 [[30, 0, 0, 0, 0, 0, 0, 0]]
# 591 NF_RBX_Asian_333031 [[30, 0, 0, 0, 0, 0, 0, 0]]
# 592 NF_RBX_Asian_333050 [[250, 370, 190, 410, 70, 90, 40, 340]]
# 593 NF_RBX_Asian_333051 [[250, 370, 190, 410, 70, 90, 40, 340]]
# 594 NF_RBX_Asian_339000 [[120, 100, 120, 170, 120, 200, 110, 120]]
# 595 NF_RBX_Asian_339030 [[100, 100, 110, 160, 100, 190, 100, 80]]
# 596 NF_RBX_Asian_339032 [[100, 100, 110, 160, 100, 190, 100, 80]]
# 597 NF_RBX_Asian_339090 [[20, 0, 0, 0, 0, 0, 0, 40]]
# 598 NF_RBX_Asian_339092 [[0, 0, 0, 0, 0, 0, 0, 40]]
# 599 NF_RBX_Asian_350000 [[1580, 1890, 1500, 1840, 2210, 1780, 1770, 1760]]
# 600 NF_RBX_Asian_351000 [[450, 330, 200, 410, 110, 170, 520, 170]]
# 601 NF_RBX_Asian_351010 [[450, 330, 200, 410, 110, 170, 520, 170]]
# 602 NF_RBX_Asian_351011 [[110, 260, 150, 330, 100, 120, 320, 120]]
# 603 NF_RBX_Asian_351012 [[340, 80, 50, 90, 0, 40, 200, 50]]
# 604 NF_RBX_Asian_352000 [[470, 630, 590, 540, 650, 880, 610, 920]]
# 605 NF_RBX_Asian_352010 [[290, 470, 280, 360, 490, 490, 400, 540]]
# 606 NF_RBX_Asian_352011 [[30, 0, 0, 0, 0, 0, 0, 0]]
# 607 NF_RBX_Asian_352012 [[70, 100, 70, 110, 90, 100, 40, 80]]
# 608 NF_RBX_Asian_352014 [[160, 330, 160, 200, 310, 380, 340, 440]]
# 609 NF_RBX_Asian_352015 [[0, 0, 20, 20, 0, 0, 0, 0]]
# 610 NF_RBX_Asian_352019 [[30, 20, 30, 30, 50, 0, 0, 20]]
# 611 NF_RBX_Asian_352020 [[170, 160, 310, 180, 160, 390, 210, 380]]
# 612 NF_RBX_Asian_352021 [[170, 160, 310, 180, 160, 390, 210, 380]]
# 613 NF_RBX_Asian_353000 [[360, 360, 390, 690, 480, 430, 360, 440]]
# 614 NF_RBX_Asian_353010 [[0, 0, 20, 0, 40, 40, 40, 0]]
# 615 NF_RBX_Asian_353011 [[0, 0, 20, 0, 40, 40, 40, 0]]
# 616 NF_RBX_Asian_353020 [[170, 80, 210, 100, 200, 80, 140, 100]]
# 617 NF_RBX_Asian_353021 [[140, 70, 200, 90, 190, 30, 130, 80]]
# 618 NF_RBX_Asian_353022 [[30, 0, 0, 0, 0, 50, 0, 20]]
# 619 NF_RBX_Asian_353030 [[140, 210, 120, 490, 150, 250, 120, 260]]
# 620 NF_RBX_Asian_353031 [[140, 210, 120, 490, 150, 250, 120, 260]]
# 621 NF_RBX_Asian_353040 [[40, 70, 50, 90, 80, 70, 60, 70]]
# 622 NF_RBX_Asian_353041 [[40, 70, 50, 90, 80, 70, 60, 70]]
# 623 NF_RBX_Asian_359000 [[300, 560, 320, 200, 960, 300, 290, 240]]
# 624 NF_RBX_Asian_359010 [[70, 110, 120, 90, 100, 130, 90, 90]]
# 625 NF_RBX_Asian_359011 [[70, 110, 120, 90, 100, 130, 90, 90]]
# 626 NF_RBX_Asian_359020 [[30, 340, 100, 50, 80, 60, 70, 110]]
# 627 NF_RBX_Asian_359021 [[30, 340, 100, 50, 80, 60, 70, 110]]
# 628 NF_RBX_Asian_359030 [[30, 20, 20, 0, 0, 30, 20, 0]]
# 629 NF_RBX_Asian_359031 [[30, 20, 20, 0, 0, 30, 20, 0]]
# 630 NF_RBX_Asian_359090 [[170, 100, 80, 40, 780, 80, 100, 40]]
# 631 NF_RBX_Asian_359099 [[170, 100, 80, 40, 780, 80, 100, 40]]
# 632 NF_RBX_Asian_370000 [[1360, 1110, 1320, 1420, 1370, 1430, 1200, 1590]]
# 633 NF_RBX_Asian_371000 [[0, 20, 40, 40, 40, 60, 130, 60]]
# 634 NF_RBX_Asian_371010 [[0, 20, 40, 40, 40, 60, 130, 60]]
# 635 NF_RBX_Asian_371011 [[0, 20, 40, 40, 0, 50, 130, 50]]
# 636 NF_RBX_Asian_371012 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 637 NF_RBX_Asian_372000 [[1280, 1000, 1200, 1230, 1260, 1260, 1010, 1420]]
# 638 NF_RBX_Asian_372010 [[1280, 990, 1150, 1230, 1260, 1260, 1010, 1420]]
# 639 NF_RBX_Asian_372011 [[740, 380, 420, 450, 430, 550, 440, 830]]
# 640 NF_RBX_Asian_372012 [[530, 610, 720, 770, 830, 700, 570, 590]]
# 641 NF_RBX_Asian_373000 [[70, 90, 90, 150, 70, 120, 70, 110]]
# 642 NF_RBX_Asian_373010 [[70, 90, 90, 150, 70, 120, 70, 110]]
# 643 NF_RBX_Asian_373011 [[60, 70, 70, 150, 60, 80, 60, 110]]
# 644 NF_RBX_Asian_373013 [[0, 20, 0, 0, 0, 0, 0, 0]]
# 645 NF_RBX_Asian_390000 [[540, 440, 310, 530, 400, 400, 380, 310]]
# 646 NF_RBX_Asian_392000 [[0, 0, 0, 70, 0, 0, 0, 0]]
# 647 NF_RBX_Asian_392020 [[0, 0, 0, 60, 0, 0, 0, 0]]
# 648 NF_RBX_Asian_392021 [[0, 0, 0, 60, 0, 0, 0, 0]]
# 649 NF_RBX_Asian_393000 [[70, 150, 120, 130, 70, 120, 100, 70]]
# 650 NF_RBX_Asian_393010 [[70, 110, 90, 120, 60, 80, 70, 60]]
# 651 NF_RBX_Asian_393011 [[60, 100, 70, 110, 60, 80, 70, 60]]
# 652 NF_RBX_Asian_393019 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 653 NF_RBX_Asian_393030 [[0, 30, 0, 0, 0, 0, 0, 0]]
# 654 NF_RBX_Asian_393031 [[0, 30, 0, 0, 0, 0, 0, 0]]
# 655 NF_RBX_Asian_393090 [[0, 0, 20, 0, 0, 30, 20, 0]]
# 656 NF_RBX_Asian_393093 [[0, 0, 0, 0, 0, 20, 20, 0]]
# 657 NF_RBX_Asian_395000 [[350, 0, 20, 0, 0, 0, 0, 0]]
# 658 NF_RBX_Asian_395010 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 659 NF_RBX_Asian_395012 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 660 NF_RBX_Asian_395090 [[350, 0, 0, 0, 0, 0, 0, 0]]
# 661 NF_RBX_Asian_395092 [[350, 0, 0, 0, 0, 0, 0, 0]]
# 662 NF_RBX_Asian_396000 [[20, 30, 0, 30, 40, 30, 0, 20]]
# 663 NF_RBX_Asian_396010 [[20, 30, 0, 30, 40, 30, 0, 20]]
# 664 NF_RBX_Asian_396011 [[20, 30, 0, 30, 20, 30, 0, 20]]
# 665 NF_RBX_Asian_396012 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 666 NF_RBX_Asian_397000 [[0, 0, 0, 0, 0, 0, 0, 40]]
# 667 NF_RBX_Asian_397010 [[0, 0, 0, 0, 0, 0, 0, 40]]
# 668 NF_RBX_Asian_397011 [[0, 0, 0, 0, 0, 0, 0, 40]]
# 669 NF_RBX_Asian_399000 [[100, 230, 150, 260, 260, 230, 260, 170]]
# 670 NF_RBX_Asian_399010 [[20, 0, 30, 20, 30, 60, 40, 20]]
# 671 NF_RBX_Asian_399011 [[20, 0, 30, 20, 30, 60, 40, 20]]
# 672 NF_RBX_Asian_399020 [[40, 190, 90, 200, 210, 140, 170, 80]]
# 673 NF_RBX_Asian_399021 [[40, 190, 90, 200, 210, 140, 170, 80]]
# 674 NF_RBX_Asian_399030 [[0, 20, 20, 20, 20, 20, 20, 50]]
# 675 NF_RBX_Asian_399032 [[0, 0, 20, 20, 20, 20, 20, 50]]
# 676 NF_RBX_Asian_399090 [[20, 0, 0, 20, 0, 0, 20, 0]]
# 677 NF_RBX_Asian_399099 [[20, 0, 0, 20, 0, 0, 20, 0]]
# 678 NF_RBX_Asian_410000 [[400, 910, 550, 810, 890, 810, 1120, 830]]
# 679 NF_RBX_Asian_411000 [[110, 310, 130, 110, 50, 70, 220, 220]]
# 680 NF_RBX_Asian_411010 [[110, 310, 130, 110, 50, 70, 220, 220]]
# 681 NF_RBX_Asian_411011 [[90, 310, 80, 90, 50, 50, 180, 220]]
# 682 NF_RBX_Asian_411012 [[20, 0, 50, 0, 0, 20, 40, 0]]
# 683 NF_RBX_Asian_412000 [[240, 400, 330, 300, 740, 620, 800, 450]]
# 684 NF_RBX_Asian_412010 [[80, 190, 140, 100, 240, 150, 100, 190]]
# 685 NF_RBX_Asian_412011 [[80, 180, 130, 100, 240, 150, 90, 190]]
# 686 NF_RBX_Asian_412020 [[20, 0, 0, 0, 30, 0, 270, 0]]
# 687 NF_RBX_Asian_412021 [[0, 0, 0, 0, 0, 0, 270, 0]]
# 688 NF_RBX_Asian_412022 [[0, 0, 0, 0, 30, 0, 0, 0]]
# 689 NF_RBX_Asian_412030 [[140, 210, 180, 200, 480, 460, 430, 260]]
# 690 NF_RBX_Asian_412031 [[140, 210, 180, 200, 480, 460, 430, 260]]
# 691 NF_RBX_Asian_413000 [[20, 20, 30, 370, 20, 40, 70, 0]]
# 692 NF_RBX_Asian_413020 [[0, 0, 0, 320, 0, 0, 0, 0]]
# 693 NF_RBX_Asian_413021 [[0, 0, 0, 320, 0, 0, 0, 0]]
# 694 NF_RBX_Asian_413090 [[0, 0, 0, 0, 0, 0, 60, 0]]
# 695 NF_RBX_Asian_413099 [[0, 0, 0, 0, 0, 0, 60, 0]]
# 696 NF_RBX_Asian_414000 [[20, 140, 0, 0, 0, 70, 20, 100]]
# 697 NF_RBX_Asian_414010 [[20, 140, 0, 0, 0, 70, 20, 100]]
# 698 NF_RBX_Asian_414011 [[0, 0, 0, 0, 0, 20, 0, 100]]
# 699 NF_RBX_Asian_414012 [[20, 140, 0, 0, 0, 50, 0, 0]]
# ...
# 5659 NF_RHX_Multi_292051 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 5660 NF_RHX_Multi_292060 [[0, 20, 0, 0, 0, 0, 0, 0]]
# 5661 NF_RHX_Multi_292061 [[0, 20, 0, 0, 0, 0, 0, 0]]
# 5662 NF_RHX_Multi_310000 [[70, 100, 70, 50, 80, 40, 80, 30]]
# 5663 NF_RHX_Multi_311000 [[70, 90, 70, 50, 80, 40, 70, 30]]
# 5664 NF_RHX_Multi_311010 [[70, 90, 70, 50, 80, 40, 70, 30]]
# 5665 NF_RHX_Multi_311011 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 5666 NF_RHX_Multi_311012 [[60, 0, 0, 0, 0, 0, 0, 0]]
# 5667 NF_RHX_Multi_311013 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 5668 NF_RHX_Multi_311014 [[60, 30, 50, 30, 60, 40, 60, 30]]
# 5669 NF_RHX_Multi_330000 [[40, 40, 100, 40, 130, 30, 40, 50]]
# 5670 NF_RHX_Multi_333000 [[30, 30, 70, 20, 0, 0, 20, 30]]
# 5671 NF_RHX_Multi_333010 [[30, 0, 50, 0, 0, 0, 0, 20]]
# 5672 NF_RHX_Multi_333012 [[30, 0, 40, 0, 0, 0, 0, 20]]
# 5673 NF_RHX_Multi_333050 [[0, 20, 0, 0, 0, 0, 0, 0]]
# 5674 NF_RHX_Multi_333051 [[0, 20, 0, 0, 0, 0, 0, 0]]
# 5675 NF_RHX_Multi_339000 [[0, 0, 30, 20, 120, 0, 0, 0]]
# 5676 NF_RHX_Multi_339030 [[0, 0, 0, 0, 120, 0, 0, 0]]
# 5677 NF_RHX_Multi_339032 [[0, 0, 0, 0, 120, 0, 0, 0]]
# 5678 NF_RHX_Multi_339090 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 5679 NF_RHX_Multi_339099 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 5680 NF_RHX_Multi_350000 [[70, 60, 60, 50, 110, 110, 90, 210]]
# 5681 NF_RHX_Multi_351000 [[0, 0, 0, 0, 0, 0, 0, 50]]
# 5682 NF_RHX_Multi_351010 [[0, 0, 0, 0, 0, 0, 0, 50]]
# 5683 NF_RHX_Multi_351011 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 5684 NF_RHX_Multi_352000 [[20, 40, 0, 0, 70, 80, 40, 60]]
# 5685 NF_RHX_Multi_352010 [[20, 40, 0, 0, 60, 0, 30, 50]]
# 5686 NF_RHX_Multi_352014 [[0, 30, 0, 0, 50, 0, 0, 0]]
# 5687 NF_RHX_Multi_352020 [[0, 0, 0, 0, 0, 80, 0, 0]]
# 5688 NF_RHX_Multi_352021 [[0, 0, 0, 0, 0, 80, 0, 0]]
# 5689 NF_RHX_Multi_353000 [[20, 0, 20, 30, 40, 0, 40, 0]]
# 5690 NF_RHX_Multi_353030 [[0, 0, 0, 20, 30, 0, 0, 0]]
# 5691 NF_RHX_Multi_353031 [[0, 0, 0, 20, 30, 0, 0, 0]]
# 5692 NF_RHX_Multi_359000 [[20, 0, 20, 0, 0, 0, 0, 80]]
# 5693 NF_RHX_Multi_359020 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 5694 NF_RHX_Multi_359021 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 5695 NF_RHX_Multi_359030 [[0, 0, 0, 0, 0, 0, 0, 50]]
# 5696 NF_RHX_Multi_359031 [[0, 0, 0, 0, 0, 0, 0, 50]]
# 5697 NF_RHX_Multi_370000 [[20, 520, 50, 70, 30, 90, 70, 120]]
# 5698 NF_RHX_Multi_371000 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 5699 NF_RHX_Multi_371010 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 5700 NF_RHX_Multi_371011 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 5701 NF_RHX_Multi_372000 [[20, 340, 50, 30, 30, 30, 0, 40]]
# 5702 NF_RHX_Multi_372010 [[20, 340, 40, 30, 30, 30, 0, 40]]
# 5703 NF_RHX_Multi_372011 [[0, 310, 20, 20, 0, 20, 0, 30]]
# 5704 NF_RHX_Multi_372012 [[0, 30, 20, 0, 0, 0, 0, 0]]
# 5705 NF_RHX_Multi_373000 [[0, 180, 0, 30, 0, 50, 40, 30]]
# 5706 NF_RHX_Multi_373010 [[0, 180, 0, 30, 0, 50, 40, 30]]
# 5707 NF_RHX_Multi_373011 [[0, 180, 0, 30, 0, 0, 40, 30]]
# 5708 NF_RHX_Multi_390000 [[70, 20, 20, 130, 40, 130, 30, 40]]
# 5709 NF_RHX_Multi_392000 [[0, 0, 0, 0, 0, 40, 0, 0]]
# 5710 NF_RHX_Multi_399000 [[30, 20, 20, 120, 20, 70, 30, 20]]
# 5711 NF_RHX_Multi_399020 [[20, 0, 0, 120, 0, 70, 30, 20]]
# 5712 NF_RHX_Multi_399021 [[20, 0, 0, 120, 0, 70, 30, 20]]
# 5713 NF_RHX_Multi_410000 [[60, 30, 350, 30, 0, 40, 30, 0]]
# 5714 NF_RHX_Multi_411000 [[0, 0, 20, 0, 0, 20, 0, 0]]
# 5715 NF_RHX_Multi_411010 [[0, 0, 20, 0, 0, 20, 0, 0]]
# 5716 NF_RHX_Multi_411011 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 5717 NF_RHX_Multi_412000 [[20, 20, 320, 20, 0, 0, 0, 0]]
# 5718 NF_RHX_Multi_412030 [[20, 0, 310, 0, 0, 0, 0, 0]]
# 5719 NF_RHX_Multi_412031 [[20, 0, 310, 0, 0, 0, 0, 0]]
# 5720 NF_RHX_Multi_430000 [[70, 70, 70, 70, 40, 40, 50, 40]]
# 5721 NF_RHX_Multi_434000 [[0, 20, 40, 0, 0, 0, 0, 20]]
# 5722 NF_RHX_Multi_434050 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 5723 NF_RHX_Multi_434051 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 5724 NF_RHX_Multi_435000 [[40, 40, 20, 20, 20, 20, 20, 0]]
# 5725 NF_RHX_Multi_435080 [[20, 40, 0, 20, 20, 20, 20, 0]]
# 5726 NF_RHX_Multi_435081 [[20, 40, 0, 20, 20, 20, 20, 0]]
# 5727 NF_RHX_Multi_439000 [[0, 0, 0, 30, 0, 0, 0, 0]]
# 5728 NF_RHX_Multi_450000 [[0, 0, 0, 30, 0, 0, 0, 0]]
# 5729 NF_RHX_Multi_452000 [[0, 0, 0, 30, 0, 0, 0, 0]]
# 5730 NF_RHX_Multi_452090 [[0, 0, 0, 30, 0, 0, 0, 0]]
# 5731 NF_RHX_Multi_452093 [[0, 0, 0, 30, 0, 0, 0, 0]]
# 5732 NF_RHX_Multi_470000 [[20, 30, 80, 60, 20, 90, 30, 20]]
# 5733 NF_RHX_Multi_472000 [[20, 0, 80, 50, 20, 90, 20, 0]]
# 5734 NF_RHX_Multi_472030 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 5735 NF_RHX_Multi_472031 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 5736 NF_RHX_Multi_472060 [[0, 0, 0, 0, 0, 60, 0, 0]]
# 5737 NF_RHX_Multi_472061 [[0, 0, 0, 0, 0, 60, 0, 0]]
# 5738 NF_RHX_Multi_472110 [[0, 0, 0, 0, 0, 30, 0, 0]]
# 5739 NF_RHX_Multi_472111 [[0, 0, 0, 0, 0, 30, 0, 0]]
# 5740 NF_RHX_Multi_472220 [[0, 0, 50, 0, 0, 0, 0, 0]]
# 5741 NF_RHX_Multi_472221 [[0, 0, 50, 0, 0, 0, 0, 0]]
# 5742 NF_RHX_Multi_490000 [[40, 30, 70, 180, 80, 220, 90, 40]]
# 5743 NF_RHX_Multi_493000 [[0, 0, 0, 0, 40, 0, 80, 20]]
# 5744 NF_RHX_Multi_499000 [[30, 20, 60, 50, 40, 210, 0, 0]]
# 5745 NF_RHX_Multi_499020 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 5746 NF_RHX_Multi_499021 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 5747 NF_RHX_Multi_499070 [[30, 0, 0, 20, 30, 40, 0, 0]]
# 5748 NF_RHX_Multi_499071 [[30, 0, 0, 20, 30, 40, 0, 0]]
# 5749 NF_RHX_Multi_499090 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 5750 NF_RHX_Multi_499099 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 5751 NF_RHX_Multi_510000 [[80, 120, 50, 120, 80, 60, 80, 50]]
# 5752 NF_RHX_Multi_512000 [[0, 40, 0, 0, 20, 0, 0, 20]]
# 5753 NF_RHX_Multi_512090 [[0, 40, 0, 0, 20, 0, 0, 20]]
# 5754 NF_RHX_Multi_512099 [[0, 0, 0, 0, 20, 0, 0, 20]]
# 5755 NF_RHX_Multi_514000 [[40, 50, 0, 20, 20, 20, 30, 0]]
# 5756 NF_RHX_Multi_514040 [[30, 0, 0, 0, 0, 0, 0, 0]]
# 5757 NF_RHX_Multi_514041 [[30, 0, 0, 0, 0, 0, 0, 0]]
# 5758 NF_RHX_Multi_514120 [[0, 30, 0, 0, 0, 20, 0, 0]]
# 5759 NF_RHX_Multi_514190 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 5760 NF_RHX_Multi_518000 [[0, 0, 0, 30, 0, 0, 0, 0]]
# 5761 NF_RHX_Multi_518030 [[0, 0, 0, 30, 0, 0, 0, 0]]
# 5762 NF_RHX_Multi_518031 [[0, 0, 0, 30, 0, 0, 0, 0]]
# 5763 NF_RHX_Multi_519000 [[20, 30, 20, 60, 30, 20, 20, 0]]
# 5764 NF_RHX_Multi_519190 [[0, 30, 20, 20, 30, 20, 20, 0]]
# 5765 NF_RHX_Multi_519199 [[0, 30, 20, 20, 30, 20, 0, 0]]
# 5766 NF_RHX_Multi_530000 [[130, 110, 280, 150, 470, 320, 120, 120]]
# 5767 NF_RHX_Multi_531000 [[0, 0, 20, 0, 0, 0, 0, 20]]
# 5768 NF_RHX_Multi_531020 [[0, 0, 20, 0, 0, 0, 0, 20]]
# 5769 NF_RHX_Multi_531021 [[0, 0, 20, 0, 0, 0, 0, 20]]
# 5770 NF_RHX_Multi_533000 [[70, 40, 180, 80, 60, 190, 60, 30]]
# 5771 NF_RHX_Multi_533020 [[0, 0, 20, 0, 0, 100, 0, 0]]
# 5772 NF_RHX_Multi_533021 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 5773 NF_RHX_Multi_533022 [[0, 0, 0, 0, 0, 100, 0, 0]]
# 5774 NF_RHX_Multi_533030 [[60, 20, 160, 70, 40, 100, 50, 30]]
# 5775 NF_RHX_Multi_533031 [[0, 0, 60, 0, 0, 0, 0, 0]]
# 5776 NF_RHX_Multi_533032 [[50, 0, 100, 50, 20, 90, 0, 30]]
# 5777 NF_RHX_Multi_533033 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 5778 NF_RHX_Multi_537000 [[60, 70, 80, 50, 410, 90, 60, 70]]
# 5779 NF_RHX_Multi_537050 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 5780 NF_RHX_Multi_537051 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 5781 NF_RHX_Multi_537060 [[50, 60, 80, 50, 400, 60, 40, 60]]
# 5782 NF_RHX_Multi_537062 [[40, 50, 50, 50, 400, 60, 30, 50]]
# 5783 NF_RHX_Multi_O10XXX [[0, 50, 90, 0, 20, 40, 20, 40]]
# 5784 NF_RHX_Multi_O23XXX [[0, 0, 20, 0, 0, 0, 0, 50]]
# 5785 NF_RHX_Multi_O25XXX [[30, 0, 20, 140, 20, 90, 20, 20]]
# 5786 NF_RHX_Multi_O27XXX [[60, 50, 80, 40, 100, 30, 60, 50]]
# 5787 NF_RHX_Multi_O30XXX [[270, 750, 310, 330, 390, 400, 300, 440]]
# 5788 NF_RHX_Multi_O41XXX [[60, 30, 350, 30, 0, 40, 30, 0]]
# 5789 NF_RHX_Multi_O43XXX [[70, 70, 70, 70, 40, 40, 50, 40]]
# 5790 NF_RHX_Multi_O45XXX [[0, 0, 0, 30, 0, 0, 0, 0]]
# 5791 NF_RHX_Multi_O47XXX [[20, 30, 80, 60, 20, 90, 30, 20]]
# 5792 NF_RHX_Multi_O49XXX [[40, 30, 70, 180, 80, 220, 90, 40]]
# 5793 NF_RHX_Multi_O51XXX [[80, 120, 50, 120, 80, 60, 80, 50]]
# 5794 NF_RHX_Multi_O53XXX [[130, 110, 280, 150, 470, 320, 120, 120]]
# 5795 NF_RHX_Multi_OT1XXX [[90, 110, 220, 200, 140, 170, 100, 160]]
# 5796 NF_RHX_Multi_OT2XXX [[130, 100, 420, 90, 60, 70, 70, 50]]
# 5797 NF_RHX_Multi_OT3XXX [[70, 60, 150, 270, 100, 310, 160, 50]]
# 5798 NF_RHX_Multi_OT4XXX [[220, 230, 330, 270, 560, 380, 190, 170]]
# 5799 NF_RIX_Hispanic_110000 [[40, 20, 0, 0, 0, 0, 0, 80]]
# 5800 NF_RIX_Hispanic_119000 [[0, 0, 0, 0, 0, 0, 0, 30]]
# 5801 NF_RIX_Hispanic_210000 [[0, 0, 0, 0, 0, 30, 0, 0]]
# 5802 NF_RIX_Hispanic_211000 [[0, 0, 0, 0, 0, 30, 0, 0]]
# 5803 NF_RIX_Hispanic_211010 [[0, 0, 0, 0, 0, 30, 0, 0]]
# 5804 NF_RIX_Hispanic_250000 [[50, 20, 40, 0, 50, 0, 60, 20]]
# 5805 NF_RIX_Hispanic_252000 [[0, 0, 40, 0, 0, 0, 0, 0]]
# 5806 NF_RIX_Hispanic_252030 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 5807 NF_RIX_Hispanic_252031 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 5808 NF_RIX_Hispanic_259000 [[40, 20, 0, 0, 40, 0, 40, 0]]
# 5809 NF_RIX_Hispanic_259040 [[40, 20, 0, 0, 40, 0, 40, 0]]
# 5810 NF_RIX_Hispanic_259041 [[40, 20, 0, 0, 40, 0, 40, 0]]
# 5811 NF_RIX_Hispanic_270000 [[0, 20, 0, 0, 0, 0, 0, 0]]
# 5812 NF_RIX_Hispanic_290000 [[30, 30, 30, 20, 70, 60, 0, 20]]
# 5813 NF_RIX_Hispanic_292000 [[30, 20, 0, 20, 70, 30, 0, 0]]
# 5814 NF_RIX_Hispanic_310000 [[40, 80, 280, 100, 40, 50, 30, 20]]
# 5815 NF_RIX_Hispanic_311000 [[40, 70, 50, 80, 30, 40, 30, 0]]
# 5816 NF_RIX_Hispanic_311010 [[40, 70, 50, 80, 30, 40, 30, 0]]
# 5817 NF_RIX_Hispanic_311011 [[0, 0, 20, 60, 0, 0, 0, 0]]
# 5818 NF_RIX_Hispanic_311012 [[30, 0, 0, 0, 0, 0, 0, 0]]
# 5819 NF_RIX_Hispanic_311014 [[30, 60, 30, 20, 30, 40, 30, 0]]
# 5820 NF_RIX_Hispanic_319000 [[0, 0, 230, 20, 0, 0, 0, 0]]
# 5821 NF_RIX_Hispanic_319090 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 5822 NF_RIX_Hispanic_330000 [[0, 190, 60, 60, 30, 50, 0, 30]]
# 5823 NF_RIX_Hispanic_331000 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 5824 NF_RIX_Hispanic_331020 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 5825 NF_RIX_Hispanic_331021 [[0, 0, 30, 0, 0, 0, 0, 0]]
# 5826 NF_RIX_Hispanic_333000 [[0, 160, 0, 20, 30, 40, 0, 0]]
# 5827 NF_RIX_Hispanic_333050 [[0, 150, 0, 0, 20, 30, 0, 0]]
# 5828 NF_RIX_Hispanic_333051 [[0, 150, 0, 0, 20, 30, 0, 0]]
# 5829 NF_RIX_Hispanic_339000 [[0, 30, 0, 0, 0, 0, 0, 0]]
# 5830 NF_RIX_Hispanic_350000 [[30, 20, 70, 60, 0, 120, 90, 20]]
# 5831 NF_RIX_Hispanic_351000 [[0, 0, 0, 0, 0, 20, 0, 0]]
# 5832 NF_RIX_Hispanic_351010 [[0, 0, 0, 0, 0, 20, 0, 0]]
# 5833 NF_RIX_Hispanic_352000 [[0, 0, 40, 20, 0, 0, 80, 0]]
# 5834 NF_RIX_Hispanic_352010 [[0, 0, 40, 0, 0, 0, 70, 0]]
# 5835 NF_RIX_Hispanic_352015 [[0, 0, 20, 0, 0, 0, 0, 0]]
# 5836 NF_RIX_Hispanic_353000 [[0, 0, 20, 0, 0, 80, 0, 0]]
# 5837 NF_RIX_Hispanic_353020 [[0, 0, 0, 0, 0, 80, 0, 0]]
# 5838 NF_RIX_Hispanic_353021 [[0, 0, 0, 0, 0, 80, 0, 0]]
# 5839 NF_RIX_Hispanic_359000 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 5840 NF_RIX_Hispanic_370000 [[90, 60, 40, 280, 90, 140, 120, 20]]
# 5841 NF_RIX_Hispanic_371000 [[0, 0, 0, 0, 0, 40, 0, 0]]
# 5842 NF_RIX_Hispanic_371010 [[0, 0, 0, 0, 0, 40, 0, 0]]
# 5843 NF_RIX_Hispanic_371011 [[0, 0, 0, 0, 0, 40, 0, 0]]
# 5844 NF_RIX_Hispanic_372000 [[90, 60, 40, 70, 90, 80, 90, 0]]
# 5845 NF_RIX_Hispanic_372010 [[90, 60, 40, 70, 90, 80, 90, 0]]
# 5846 NF_RIX_Hispanic_372011 [[50, 50, 20, 50, 50, 70, 80, 0]]
# 5847 NF_RIX_Hispanic_372012 [[40, 0, 20, 20, 40, 0, 0, 0]]
# 5848 NF_RIX_Hispanic_373000 [[0, 0, 0, 210, 0, 20, 0, 0]]
# 5849 NF_RIX_Hispanic_373010 [[0, 0, 0, 210, 0, 20, 0, 0]]
# 5850 NF_RIX_Hispanic_373011 [[0, 0, 0, 210, 0, 20, 0, 0]]
# 5851 NF_RIX_Hispanic_390000 [[0, 20, 20, 0, 0, 20, 100, 0]]
# 5852 NF_RIX_Hispanic_399000 [[0, 0, 0, 0, 0, 20, 20, 0]]
# 5853 NF_RIX_Hispanic_410000 [[20, 340, 50, 30, 0, 60, 70, 250]]
# 5854 NF_RIX_Hispanic_412000 [[20, 340, 0, 0, 0, 50, 60, 20]]
# 5855 NF_RIX_Hispanic_412010 [[0, 330, 0, 0, 0, 0, 60, 0]]
# 5856 NF_RIX_Hispanic_412011 [[0, 330, 0, 0, 0, 0, 60, 0]]
# 5857 NF_RIX_Hispanic_412030 [[20, 0, 0, 0, 0, 0, 0, 20]]
# 5858 NF_RIX_Hispanic_412031 [[20, 0, 0, 0, 0, 0, 0, 20]]
# 5859 NF_RIX_Hispanic_419000 [[0, 0, 40, 0, 0, 0, 0, 0]]
# 5860 NF_RIX_Hispanic_419090 [[0, 0, 40, 0, 0, 0, 0, 0]]
# 5861 NF_RIX_Hispanic_419099 [[0, 0, 40, 0, 0, 0, 0, 0]]
# 5862 NF_RIX_Hispanic_430000 [[30, 20, 90, 40, 60, 30, 50, 90]]
# 5863 NF_RIX_Hispanic_434000 [[0, 0, 30, 0, 0, 0, 30, 0]]
# 5864 NF_RIX_Hispanic_434050 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 5865 NF_RIX_Hispanic_434051 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 5866 NF_RIX_Hispanic_435000 [[20, 0, 30, 20, 0, 20, 0, 0]]
# 5867 NF_RIX_Hispanic_435070 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 5868 NF_RIX_Hispanic_435071 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 5869 NF_RIX_Hispanic_435080 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 5870 NF_RIX_Hispanic_435081 [[20, 0, 0, 0, 0, 0, 0, 0]]
# 5871 NF_RIX_Hispanic_439000 [[0, 0, 0, 0, 0, 0, 0, 50]]
# 5872 NF_RIX_Hispanic_450000 [[0, 0, 0, 0, 0, 0, 50, 0]]
# 5873 NF_RIX_Hispanic_452000 [[0, 0, 0, 0, 0, 0, 50, 0]]
# 5874 NF_RIX_Hispanic_452090 [[0, 0, 0, 0, 0, 0, 50, 0]]
# 5875 NF_RIX_Hispanic_452092 [[0, 0, 0, 0, 0, 0, 50, 0]]
# 5876 NF_RIX_Hispanic_470000 [[0, 20, 0, 90, 70, 160, 100, 130]]
# 5877 NF_RIX_Hispanic_471000 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 5878 NF_RIX_Hispanic_471010 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 5879 NF_RIX_Hispanic_471011 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 5880 NF_RIX_Hispanic_472000 [[0, 20, 0, 50, 30, 150, 70, 120]]
# 5881 NF_RIX_Hispanic_472060 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 5882 NF_RIX_Hispanic_472061 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 5883 NF_RIX_Hispanic_490000 [[80, 20, 120, 60, 20, 320, 230, 90]]
# 5884 NF_RIX_Hispanic_492000 [[0, 0, 0, 0, 0, 0, 210, 0]]
# 5885 NF_RIX_Hispanic_492020 [[0, 0, 0, 0, 0, 0, 210, 0]]
# 5886 NF_RIX_Hispanic_492022 [[0, 0, 0, 0, 0, 0, 210, 0]]
# 5887 NF_RIX_Hispanic_493000 [[60, 0, 100, 30, 0, 0, 20, 60]]
# 5888 NF_RIX_Hispanic_493020 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 5889 NF_RIX_Hispanic_493023 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 5890 NF_RIX_Hispanic_493030 [[0, 0, 0, 0, 0, 0, 0, 50]]
# 5891 NF_RIX_Hispanic_493031 [[0, 0, 0, 0, 0, 0, 0, 50]]
# 5892 NF_RIX_Hispanic_493090 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 5893 NF_RIX_Hispanic_493093 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 5894 NF_RIX_Hispanic_499000 [[0, 20, 20, 20, 0, 0, 0, 30]]
# 5895 NF_RIX_Hispanic_499070 [[0, 20, 20, 20, 0, 0, 0, 20]]
# 5896 NF_RIX_Hispanic_499071 [[0, 20, 20, 20, 0, 0, 0, 20]]
# 5897 NF_RIX_Hispanic_510000 [[40, 70, 60, 90, 50, 40, 80, 70]]
# 5898 NF_RIX_Hispanic_512000 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 5899 NF_RIX_Hispanic_512090 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 5900 NF_RIX_Hispanic_512099 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 5901 NF_RIX_Hispanic_513000 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 5902 NF_RIX_Hispanic_513020 [[0, 0, 0, 0, 0, 0, 0, 20]]
# 5903 NF_RIX_Hispanic_514000 [[0, 0, 0, 20, 0, 0, 0, 0]]
# 5904 NF_RIX_Hispanic_519000 [[20, 40, 50, 60, 30, 20, 30, 20]]
# 5905 NF_RIX_Hispanic_519190 [[0, 30, 30, 60, 20, 0, 20, 0]]
# 5906 NF_RIX_Hispanic_519199 [[0, 20, 30, 0, 20, 0, 0, 0]]
# 5907 NF_RIX_Hispanic_530000 [[100, 130, 100, 220, 110, 160, 430, 310]]
# 5908 NF_RIX_Hispanic_533000 [[0, 100, 70, 140, 30, 120, 60, 260]]
# 5909 NF_RIX_Hispanic_533030 [[0, 90, 60, 120, 30, 120, 50, 260]]
# 5910 NF_RIX_Hispanic_533032 [[0, 90, 0, 120, 0, 0, 40, 0]]
# 5911 NF_RIX_Hispanic_533033 [[0, 0, 60, 0, 20, 110, 0, 0]]
# 5912 NF_RIX_Hispanic_533040 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 5913 NF_RIX_Hispanic_533041 [[0, 0, 0, 0, 0, 0, 20, 0]]
# 5914 NF_RIX_Hispanic_536000 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 5915 NF_RIX_Hispanic_536020 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 5916 NF_RIX_Hispanic_536021 [[0, 0, 0, 0, 20, 0, 0, 0]]
# 5917 NF_RIX_Hispanic_537000 [[90, 20, 30, 80, 50, 40, 360, 40]]
# 5918 NF_RIX_Hispanic_537060 [[90, 0, 20, 40, 50, 40, 350, 40]]
# 5919 NF_RIX_Hispanic_537062 [[0, 0, 20, 30, 40, 30, 320, 40]]
# 5920 NF_RIX_Hispanic_537064 [[70, 0, 0, 0, 0, 0, 0, 0]]
# 5921 NF_RIX_Hispanic_O10XXX [[50, 20, 30, 0, 20, 0, 0, 90]]
# 5922 NF_RIX_Hispanic_O25XXX [[50, 50, 60, 20, 60, 50, 70, 50]]
# 5923 NF_RIX_Hispanic_O27XXX [[30, 30, 30, 20, 70, 60, 0, 20]]
# 5924 NF_RIX_Hispanic_O30XXX [[180, 370, 470, 500, 160, 380, 340, 90]]
# 5925 NF_RIX_Hispanic_O41XXX [[20, 340, 50, 30, 0, 60, 70, 250]]
# 5926 NF_RIX_Hispanic_O43XXX [[30, 20, 90, 40, 60, 30, 50, 90]]
# 5927 NF_RIX_Hispanic_O45XXX [[0, 0, 0, 0, 0, 0, 50, 0]]
# 5928 NF_RIX_Hispanic_O47XXX [[0, 20, 0, 90, 70, 160, 100, 130]]
# 5929 NF_RIX_Hispanic_O49XXX [[80, 20, 120, 60, 20, 320, 230, 90]]
# 5930 NF_RIX_Hispanic_O51XXX [[40, 70, 60, 90, 50, 40, 80, 70]]
# 5931 NF_RIX_Hispanic_O53XXX [[100, 130, 100, 220, 110, 160, 430, 310]]
# 5932 NF_RIX_Hispanic_OT1XXX [[140, 90, 110, 50, 150, 110, 90, 150]]
# 5933 NF_RIX_Hispanic_OT2XXX [[50, 360, 140, 60, 60, 90, 120, 340]]
# 5934 NF_RIX_Hispanic_OT3XXX [[100, 40, 140, 150, 90, 490, 380, 230]]
# 5935 NF_RIX_Hispanic_OT4XXX [[140, 200, 160, 310, 160, 210, 510, 380]]

# %%
print(genericDB_dict['NF_RAX_AmericanIndian_AlaskaNative_419090'][0])
# Out:
# [30, 0, 0, 0, 0, 20, 0, 0]

# %% [markdown]
# ## Create SOC Level Groups
# Create SOC Level Groups for SOC work groups as a dictionary of keys
#
# Level 1 "11XXXX", "12XXXX"....<br>
# Level 2 "110XXX", "111XXX", "120XXX"...<br>
# Level 3 "1101XX", "1102XX", "1201XX"......<br>

# %%
level1_sockeys = {}
level2_sockeys = {}
level3_sockeys = {}

for key in soc_dict.keys():
    lev1 = key[0:2]
    lev2 = key[0:3]
    lev3 = key[0:4]
    #print(lev1)
    level1_sockeys.setdefault(lev1, []).append(key)
    level2_sockeys.setdefault(lev2, []).append(key)
    level3_sockeys.setdefault(lev3, []).append(key)
    
#print(level1_sockeys)

# %% [markdown]
# ## Create a count of DATABASE data for the diferent level soc groups

# %%
no_genericDB_data_dict = {}

for index in level1_sockeys.keys():
    # running totals for 2011 to 2018   
    for db in genericDB_files_dict.keys(): 
        if (len(index) > 0):
            totals = np.array([0,0,0,0,0,0,0,0])
            for key in level1_sockeys[index]:
                new_key = db+"_"+key
                if new_key in genericDB_dict.keys():
                    #print(genericDB_dict[key][0])
                    totals = totals + np.array(genericDB_dict[new_key][0])
                    #print(key,genericDB_dict[key])
                else:
                    no_genericDB_data_dict.setdefault(key, []).append(0)
                    #print("No GenericDB data for ", key)
            print(db+"\t"+index,totals)
        
print("") 

for index in level2_sockeys.keys():
    # running totals for 2011 to 2018   
    for db in genericDB_files_dict.keys(): 
        if (len(index) > 0):
            totals = np.array([0,0,0,0,0,0,0,0])
            for key in level2_sockeys[index]:
                new_key = db+"_"+key
                if new_key in genericDB_dict.keys():
                    #print(genericDB_dict[key][0])
                    totals = totals + np.array(genericDB_dict[new_key][0])
                    #print(key,genericDB_dict[key])
                else:
                    no_genericDB_data_dict.setdefault(key, []).append(0)
                    #print("No GenericDB data for ", key)
            print(db+"\t"+index,totals)
        
print("") 

for index in level3_sockeys.keys():
    # running totals for 2011 to 2018   
    for db in genericDB_files_dict.keys(): 
        if (len(index) > 0):
            totals = np.array([0,0,0,0,0,0,0,0])
            for key in level3_sockeys[index]:
                new_key = db+"_"+key
                if new_key in genericDB_dict.keys():
                    #print(genericDB_dict[key][0])
                    totals = totals + np.array(genericDB_dict[new_key][0])
                    #print(key,genericDB_dict[key])
                else:
                    no_genericDB_data_dict.setdefault(key, []).append(0)
                    #print("No GenericDB data for ", key)
            print(db+"\t"+index,totals)
        
print("")
# Out:
# NF_RAX_AmericanIndian_AlaskaNative	11 [870 250 590 180 280 480 380 460]
# NF_RBX_Asian	11 [1330  930 2030 2970 3700  860  810 3500]
# NF_RCX_Black_AfricanAmerican	11 [7430 6840 6470 7360 6680 6650 7650 5750]
# NF_RDX_Hispanic	11 [7260 6490 6680 6040 8520 6760 5040 8480]
# NF_REX_Hawaiian	11 [200  80 130  80 170 290  60 150]
# NF_RFX_White	11 [56700 53830 53080 46970 54230 47440 49340 45700]
# NF_RGX_NR	11 [28680 31900 35340 31870 33670 30270 29450 38700]
# NF_RHX_Multi	11 [  0  30 260   0  20 100  20  20]
# NF_RIX_Hispanic	11 [ 40  20   0   0   0   0   0 110]
# NF_RAX_AmericanIndian_AlaskaNative	13 [ 60  70   0  50  50 100  50  80]
# NF_RBX_Asian	13 [680 560 450 370 250 450 660 390]
# NF_RCX_Black_AfricanAmerican	13 [1680 1920 2810 2330 1920 1890 3300 1860]
# NF_RDX_Hispanic	13 [3820 1650 1530 2250 1900 1530 1960 3780]
# NF_REX_Hawaiian	13 [90 40  0  0  0  0 20 60]
# NF_RFX_White	13 [11950 13120 18160 11990 11120 11290 10900  8710]
# NF_RGX_NR	13 [13170 13530 13010 16680 12830 12450 13630 13820]
# NF_RHX_Multi	13 [ 0 40  0  0  0  0  0  0]
# NF_RIX_Hispanic	13 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	15 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	15 [ 20 100 100  60  60  40 140  40]
# NF_RCX_Black_AfricanAmerican	15 [220 200 110 170 130 110 130 110]
# NF_RDX_Hispanic	15 [ 90 100  40 110 330  70 100 130]
# NF_REX_Hawaiian	15 [0 0 0 0 0 0 0 0]
# NF_RFX_White	15 [1530 1240 1540 1240 1510  950  850 1050]
# NF_RGX_NR	15 [1640 3430 1730 1440  920 1440 1090 1610]
# NF_RHX_Multi	15 [ 0  0 20  0  0  0  0  0]
# NF_RIX_Hispanic	15 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	17 [ 20 380   0   0   0   0   0   0]
# NF_RBX_Asian	17 [230 360 100 110 480 350  70  90]
# NF_RCX_Black_AfricanAmerican	17 [260 450 320 280 330 210 260 500]
# NF_RDX_Hispanic	17 [910 580 200 570 370 990 510 490]
# NF_REX_Hawaiian	17 [0 0 0 0 0 0 0 0]
# NF_RFX_White	17 [7620 6390 7940 8930 8900 5310 6120 5810]
# NF_RGX_NR	17 [4680 6270 5060 5380 4040 4150 6180 5690]
# NF_RHX_Multi	17 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	17 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	19 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	19 [190 140 550 510 170 200 100 100]
# NF_RCX_Black_AfricanAmerican	19 [990 350 590 190 200  90 360 270]
# NF_RDX_Hispanic	19 [ 330  350  420 1070  260  190  640  530]
# NF_REX_Hawaiian	19 [  0   0   0 120   0   0   0   0]
# NF_RFX_White	19 [3450 3320 3800 5990 2910 4630 2910 2720]
# NF_RGX_NR	19 [5650 5350 2600 3860 4350 3080 4400 3770]
# NF_RHX_Multi	19 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	19 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	21 [150 240 660 410 380 220 450 380]
# NF_RBX_Asian	21 [310 610 380 500 190 500 300 320]
# NF_RCX_Black_AfricanAmerican	21 [ 8440 10200 11600  9300  9590 10910  8930 10570]
# NF_RDX_Hispanic	21 [3080 3210 4040 2840 3990 2690 2810 3420]
# NF_REX_Hawaiian	21 [  0 160   0   0  60  40  40  80]
# NF_RFX_White	21 [16540 18360 18580 18720 16920 17060 14820 14930]
# NF_RGX_NR	21 [24040 24840 22310 25320 22280 30730 24940 23760]
# NF_RHX_Multi	21 [ 0  0  0  0  0 40  0  0]
# NF_RIX_Hispanic	21 [ 0  0  0  0  0 90  0  0]
# NF_RAX_AmericanIndian_AlaskaNative	23 [ 0 20  0  0  0  0  0  0]
# NF_RBX_Asian	23 [  0   0  50   0   0  20 990   0]
# NF_RCX_Black_AfricanAmerican	23 [210 540 430 200 390 130 230 200]
# NF_RDX_Hispanic	23 [530 290 320 310 260 560 320 160]
# NF_REX_Hawaiian	23 [0 0 0 0 0 0 0 0]
# NF_RFX_White	23 [3580 2670 2530 3250 2700 3660 1790 1460]
# NF_RGX_NR	23 [1200 2010 1380 1640  830 1200 1020 2610]
# NF_RHX_Multi	23 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	23 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	25 [ 320  350  560  960  470 1420 1130  390]
# NF_RBX_Asian	25 [ 530 1050  760 1580 1050 2260  900 2720]
# NF_RCX_Black_AfricanAmerican	25 [ 8740  9230  8750  8680  9350  8430  5980 10880]
# NF_RDX_Hispanic	25 [ 7070  6430  7140  7670  8350  7690  7750 10590]
# NF_REX_Hawaiian	25 [240 210 230 300  70  20 160  20]
# NF_RFX_White	25 [63970 56570 59460 61400 54560 63650 53380 59680]
# NF_RGX_NR	25 [52130 51340 49090 50610 62300 56680 54450 60270]
# NF_RHX_Multi	25 [ 20   0   0 140   0 170  60   0]
# NF_RIX_Hispanic	25 [130  60 140   0 130   0 140  20]
# NF_RAX_AmericanIndian_AlaskaNative	27 [ 0  0  0 40  0  0  0 20]
# NF_RBX_Asian	27 [140 150 340 360 310 210 160 290]
# NF_RCX_Black_AfricanAmerican	27 [1140 2710 1550 3250 2150 1980 1100  720]
# NF_RDX_Hispanic	27 [2690 1520 1330 1070  770 1640 1680 1190]
# NF_REX_Hawaiian	27 [ 30 580  20 450   0 140 100   0]
# NF_RFX_White	27 [12250  7840  9460 11780  9960 10620  8540 10350]
# NF_RGX_NR	27 [10900  6830 17620  7630  8530 14920 14850 12770]
# NF_RHX_Multi	27 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	27 [ 0 20  0  0  0  0  0  0]
# NF_RAX_AmericanIndian_AlaskaNative	29 [1120  530  490 1020  690  580  400  370]
# NF_RBX_Asian	29 [6290 7160 6230 6290 5520 6510 5280 5760]
# NF_RCX_Black_AfricanAmerican	29 [20960 18410 19800 20510 20910 18660 18210 18480]
# NF_RDX_Hispanic	29 [ 8960 10370  9980  8480 10850  8310 10030  8980]
# NF_REX_Hawaiian	29 [ 800  800  440  690 1260  570  630  560]
# NF_RFX_White	29 [110480 106670 104220 102250  95520  95590  87580  86440]
# NF_RGX_NR	29 [ 97800 106250 104770 107540 101170  96750 113830 120830]
# NF_RHX_Multi	29 [150 130 260 120 310  90 170 170]
# NF_RIX_Hispanic	29 [ 60  50  30  40 140  90   0  20]
# NF_RAX_AmericanIndian_AlaskaNative	31 [420 250 290 320 380 320 370 350]
# NF_RBX_Asian	31 [1580 1100 1500 1260 1340 1370 1430 1520]
# NF_RCX_Black_AfricanAmerican	31 [19380 15700 16100 14560 14930 13950 12320 12540]
# NF_RDX_Hispanic	31 [9310 7320 6360 8700 8070 6380 5960 5680]
# NF_REX_Hawaiian	31 [270 240 250 260 250 190 170 200]
# NF_RFX_White	31 [40950 36320 37240 34040 34990 28170 30690 27590]
# NF_RGX_NR	31 [42270 38340 34790 32870 34420 32040 38750 37880]
# NF_RHX_Multi	31 [ 70 100  70  50  80  40  80  30]
# NF_RIX_Hispanic	31 [ 40  80 510 140  40  50  30  20]
# NF_RAX_AmericanIndian_AlaskaNative	33 [ 900  980  770 1280 1310  940 1340 1380]
# NF_RBX_Asian	33 [1900 3390 1480 3130  930 1460  870 1900]
# NF_RCX_Black_AfricanAmerican	33 [32190 20100 22320 21070 18970 23970 23120 21680]
# NF_RDX_Hispanic	33 [18450 17600 16450 15500 14910 24430 23920 16780]
# NF_REX_Hawaiian	33 [ 690  920  640  610  350  350 1590  460]
# NF_RFX_White	33 [157630 130640 120030 115110 119260 106480 117530 107860]
# NF_RGX_NR	33 [161980 163810 167920 158340 174560 166780 160720 180460]
# NF_RHX_Multi	33 [130 110 330  80 490  30  60 120]
# NF_RIX_Hispanic	33 [  0 680 150  80 100 150   0  30]
# NF_RAX_AmericanIndian_AlaskaNative	35 [1180 1460 1950 1550 2530 1120 1530 2320]
# NF_RBX_Asian	35 [6110 7460 5810 7210 8540 7040 6930 6950]
# NF_RCX_Black_AfricanAmerican	35 [25130 23490 23650 21840 22060 20600 20530 19970]
# NF_RDX_Hispanic	35 [47430 49820 52640 47910 56340 49800 53880 44350]
# NF_REX_Hawaiian	35 [ 570 1690  810 1060 1370  750  890  570]
# NF_RFX_White	35 [100920 102960 109320  95580  95970  93610  91000  96750]
# NF_RGX_NR	35 [112150 118450 125060 118350 135390 128810 129960 142460]
# NF_RHX_Multi	35 [190 170 100 120 390 350 200 620]
# NF_RIX_Hispanic	35 [ 50  20 190  80   0 320 240  20]
# NF_RAX_AmericanIndian_AlaskaNative	37 [3190 2180 2000 2190 1720  770 1470 1960]
# NF_RBX_Asian	37 [5390 4420 5180 5670 5450 5690 4820 6350]
# NF_RCX_Black_AfricanAmerican	37 [32410 30370 26690 24770 26040 28900 29020 27340]
# NF_RDX_Hispanic	37 [81140 90910 75980 80870 78940 79970 76390 77580]
# NF_REX_Hawaiian	37 [ 760 1080 1030 1110 1470  860 1320  750]
# NF_RFX_White	37 [122640 100890 104210 105530  88900  99320  86430  79860]
# NF_RGX_NR	37 [118310 104230 106280 114690 124410 107310 110430 116570]
# NF_RHX_Multi	37 [  60 2080  180  240   90  270  250  320]
# NF_RIX_Hispanic	37 [ 360  230  160 1120  360  550  380   20]
# NF_RAX_AmericanIndian_AlaskaNative	39 [430 200 370 380 150 240 280 250]
# NF_RBX_Asian	39 [2030 1200  940 1550 1070 1210 1080  990]
# NF_RCX_Black_AfricanAmerican	39 [11920 10980 10340 10820 10350 11190 11130 11270]
# NF_RDX_Hispanic	39 [6540 9250 8310 7630 5410 6830 4970 8030]
# NF_REX_Hawaiian	39 [360 200 150 340 290 170 100 120]
# NF_RFX_White	39 [36280 35610 35680 36200 37390 32580 31310 36430]
# NF_RGX_NR	39 [29450 33840 30870 34150 35910 40500 33270 37390]
# NF_RHX_Multi	39 [100  40  40 250  60 240  60  60]
# NF_RIX_Hispanic	39 [  0  20  20   0   0  40 120   0]
# NF_RAX_AmericanIndian_AlaskaNative	41 [1580  680  530  430 2300  650  730  420]
# NF_RBX_Asian	41 [1570 3590 2080 3120 3490 3170 4340 3230]
# NF_RCX_Black_AfricanAmerican	41 [ 9900 12240 11530  9130 12800 10660  9240 10240]
# NF_RDX_Hispanic	41 [13760 13180 15690  9770 16560 11790 11260 12340]
# NF_REX_Hawaiian	41 [220 290 530  40 310 350 300 250]
# NF_RFX_White	41 [76400 78330 80780 71950 73020 68350 59770 68300]
# NF_RGX_NR	41 [131430 127830 140120 127130 128880 129740 136630 143820]
# NF_RHX_Multi	41 [ 120   50 1350   50    0   80   30    0]
# NF_RIX_Hispanic	41 [  80 1340  170   30    0  110  250  310]
# NF_RAX_AmericanIndian_AlaskaNative	43 [ 640  430 1450  730  850  410 1790  590]
# NF_RBX_Asian	43 [3080 3830 3500 2950 2510 3340 3050 3320]
# NF_RCX_Black_AfricanAmerican	43 [22700 17240 17880 20820 18380 17240 15590 16770]
# NF_RDX_Hispanic	43 [27950 21770 22280 21710 21050 18860 22160 19670]
# NF_REX_Hawaiian	43 [1120  970  940  710  430  870  850  850]
# NF_RFX_White	43 [106180  90700  93200  83150  81920  76570  79080  68020]
# NF_RGX_NR	43 [139860 127600 125180 144380 127280 124030 115890 137410]
# NF_RHX_Multi	43 [110 130 190 120  60  60  70  60]
# NF_RIX_Hispanic	43 [ 50  20 150 100  60  50 120 140]
# NF_RAX_AmericanIndian_AlaskaNative	45 [140 140 200 220 290 290 290 100]
# NF_RBX_Asian	45 [180 740 170 230 230 140 120 170]
# NF_RCX_Black_AfricanAmerican	45 [ 970 1980 2210  860 1030  700  990 1090]
# NF_RDX_Hispanic	45 [31940 33990 36260 33430 33410 35320 32140 29510]
# NF_REX_Hawaiian	45 [  0   0 190 160 110  60 150  90]
# NF_RFX_White	45 [11700 13080 10870 11680 11150 11380 10420 13130]
# NF_RGX_NR	45 [12670 10220 13780 13590 17980 10830 16190 18530]
# NF_RHX_Multi	45 [  0   0   0 120   0   0   0   0]
# NF_RIX_Hispanic	45 [  0   0   0   0   0   0 200   0]
# NF_RAX_AmericanIndian_AlaskaNative	47 [1660 3080 3310 2670 1040 2400 1530 1730]
# NF_RBX_Asian	47 [1330 1200  960 1350 1720 1240 1270  810]
# NF_RCX_Black_AfricanAmerican	47 [11460 13360  9520 13860 12600 19330 13850 16530]
# NF_RDX_Hispanic	47 [55270 48320 63750 66050 62010 78640 91780 71690]
# NF_REX_Hawaiian	47 [ 790  300  700 1710  620  560 1000  570]
# NF_RFX_White	47 [178040 174410 176190 170140 170240 170300 144550 145760]
# NF_RGX_NR	47 [ 98750  94910 106050  97240  89660  92850 106930 105890]
# NF_RHX_Multi	47 [ 40  30 260 150  40 360  50  20]
# NF_RIX_Hispanic	47 [  0  40   0 140 160 310 170 290]
# NF_RAX_AmericanIndian_AlaskaNative	49 [1700 1480 1570 1740 1300 2720 1290  910]
# NF_RBX_Asian	49 [3080 3000 2400 3010 2660 3120 2820 2130]
# NF_RCX_Black_AfricanAmerican	49 [14120 16140 16110 13430 14330 14060 17090 16280]
# NF_RDX_Hispanic	49 [35910 39050 37810 38920 34870 38290 38300 46890]
# NF_REX_Hawaiian	49 [1690  410  880  720  580  880  460  850]
# NF_RFX_White	49 [214050 193580 178970 177010 194320 166440 163430 160310]
# NF_RGX_NR	49 [137160 140360 140880 140770 146820 136820 155870 147190]
# NF_RHX_Multi	49 [130  50 230 270 220 510 170  60]
# NF_RIX_Hispanic	49 [140  80 280 190  20 320 920 320]
# NF_RAX_AmericanIndian_AlaskaNative	51 [1380 1800 1540 1940  950 1290 1890 1690]
# NF_RBX_Asian	51 [7740 9030 8040 8580 9230 8240 7470 7250]
# NF_RCX_Black_AfricanAmerican	51 [32800 32550 30520 30810 34060 31960 34080 31980]
# NF_RDX_Hispanic	51 [76710 76860 76300 78250 83250 73580 64450 72030]
# NF_REX_Hawaiian	51 [830 620 970 830 830 930 930 860]
# NF_RFX_White	51 [214730 209420 196440 186630 186050 161430 160320 155220]
# NF_RGX_NR	51 [120970 120360 121150 119970 126110 124870 130360 130060]
# NF_RHX_Multi	51 [200 370 110 330 250 160 170 110]
# NF_RIX_Hispanic	51 [ 60 160 170 230 120  60 130 190]
# NF_RAX_AmericanIndian_AlaskaNative	53 [1900 3010 4160 1980 1680 2650 1360 1150]
# NF_RBX_Asian	53 [5240 4530 4410 5290 6950 6700 6330 6090]
# NF_RCX_Black_AfricanAmerican	53 [61090 57200 60280 64550 72720 72290 63280 67990]
# NF_RDX_Hispanic	53 [77690 86010 78340 82640 86880 90370 78510 80070]
# NF_REX_Hawaiian	53 [2140 2350 1660 2870 1800 2310 2070 2000]
# NF_RFX_White	53 [292900 279110 271440 298730 271120 249010 241750 225220]
# NF_RGX_NR	53 [291570 327460 306330 309030 311760 328560 347210 388540]
# NF_RHX_Multi	53 [ 460  350 1010  500 1820  910  400  410]
# NF_RIX_Hispanic	53 [ 350  430  360  750  390  620 1610  950]
# NF_RAX_AmericanIndian_AlaskaNative	55 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	55 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	55 [0 0 0 0 0 0 0 0]
# NF_RDX_Hispanic	55 [0 0 0 0 0 0 0 0]
# NF_REX_Hawaiian	55 [0 0 0 0 0 0 0 0]
# NF_RFX_White	55 [0 0 0 0 0 0 0 0]
# NF_RGX_NR	55 [0 0 0 0 0 0 0 0]
# NF_RHX_Multi	55 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	55 [0 0 0 0 0 0 0 0]
#
# NF_RAX_AmericanIndian_AlaskaNative	110 [260 100 160  80 100 140 140 140]
# NF_RBX_Asian	110 [ 360  290  530  760  970  240  240 1100]
# NF_RCX_Black_AfricanAmerican	110 [1980 1760 1650 1880 1730 1700 1960 1470]
# NF_RDX_Hispanic	110 [1880 1690 1700 1540 2160 1740 1280 2180]
# NF_REX_Hawaiian	110 [ 60  50  40  40  50 160  30  50]
# NF_RFX_White	110 [14450 13770 13540 12030 13740 12020 12510 11670]
# NF_RGX_NR	110 [7260 8100 9030 8050 8470 7660 7500 9790]
# NF_RHX_Multi	110 [ 0 30 80  0 20 40 20 20]
# NF_RIX_Hispanic	110 [40 20  0  0  0  0  0 80]
# NF_RAX_AmericanIndian_AlaskaNative	111 [  0   0 240  60   0   0   0   0]
# NF_RBX_Asian	111 [ 90  70 210  70 340 120 190   0]
# NF_RCX_Black_AfricanAmerican	111 [ 400 1180  550  460  240  220  790  260]
# NF_RDX_Hispanic	111 [ 480  370  860  320 1080  510  330  480]
# NF_REX_Hawaiian	111 [ 0  0  0 20  0  0  0  0]
# NF_RFX_White	111 [7590 8340 8400 5370 5850 7500 6820 6090]
# NF_RGX_NR	111 [3490 5940 4780 3930 3480 3440 3510 3870]
# NF_RHX_Multi	111 [ 0  0  0  0  0 60  0  0]
# NF_RIX_Hispanic	111 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	112 [ 0  0  0  0 60  0  0  0]
# NF_RBX_Asian	112 [  0  50   0 110   0   0  60   0]
# NF_RCX_Black_AfricanAmerican	112 [280  40  70 210 180 110   0  60]
# NF_RDX_Hispanic	112 [220 140 140 200  40  70 100 120]
# NF_REX_Hawaiian	112 [0 0 0 0 0 0 0 0]
# NF_RFX_White	112 [1720 2630 3180 1750 1210 2740 1340 1640]
# NF_RGX_NR	112 [1390 1550 1790 1290 2170  850  760 1900]
# NF_RHX_Multi	112 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	112 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	113 [20 20 30  0  0  0 80  0]
# NF_RBX_Asian	113 [ 20 100  80 230 290  30 200 440]
# NF_RCX_Black_AfricanAmerican	113 [1210  660  560  970  390  240  350 1100]
# NF_RDX_Hispanic	113 [ 470  320 1550  610  830  810 1090  750]
# NF_REX_Hawaiian	113 [ 0  0  0  0  0 30  0  0]
# NF_RFX_White	113 [8270 6370 7190 6440 6480 5770 8390 6390]
# NF_RGX_NR	113 [2380 3090 4060 3000 4330 3600 2510 4530]
# NF_RHX_Multi	113 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	113 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	119 [590 130 160  40 120 340 160 320]
# NF_RBX_Asian	119 [ 860  420 1210 1800 2100  470  120 1960]
# NF_RCX_Black_AfricanAmerican	119 [3560 3200 3640 3840 4140 4380 4550 2860]
# NF_RDX_Hispanic	119 [4210 3970 2430 3370 4410 3630 2240 4950]
# NF_REX_Hawaiian	119 [140  30  90  20 120 100  30 100]
# NF_RFX_White	119 [24670 22720 20770 21380 26950 19410 20280 19910]
# NF_RGX_NR	119 [14160 13220 15680 15600 15220 14720 15170 18610]
# NF_RHX_Multi	119 [  0   0 180   0   0   0   0   0]
# NF_RIX_Hispanic	119 [ 0  0  0  0  0  0  0 30]
# NF_RAX_AmericanIndian_AlaskaNative	130 [20 40  0 30 30 30 30 40]
# NF_RBX_Asian	130 [190 160 140 120  90 160 180 130]
# NF_RCX_Black_AfricanAmerican	130 [450 520 740 620 530 510 850 490]
# NF_RDX_Hispanic	130 [980 440 430 750 500 410 520 970]
# NF_REX_Hawaiian	130 [30 20  0  0  0  0 20 30]
# NF_RFX_White	130 [3010 3290 4560 3040 2810 2850 2770 2220]
# NF_RGX_NR	130 [3310 3410 3280 4190 3220 3140 3470 3470]
# NF_RHX_Multi	130 [ 0 20  0  0  0  0  0  0]
# NF_RIX_Hispanic	130 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	131 [40 30  0 20 20 70 20 40]
# NF_RBX_Asian	131 [270 260 240  50  30  80 140 120]
# NF_RCX_Black_AfricanAmerican	131 [ 950 1080 1730 1420  950 1110 2120 1160]
# NF_RDX_Hispanic	131 [2420  490  990  820 1090  810 1310 2640]
# NF_REX_Hawaiian	131 [60 20  0  0  0  0  0 30]
# NF_RFX_White	131 [ 6190  7520 10410  7510  6500  7140  5240  4640]
# NF_RGX_NR	131 [7530 7410 7140 7670 7280 7650 7600 7510]
# NF_RHX_Multi	131 [ 0 20  0  0  0  0  0  0]
# NF_RIX_Hispanic	131 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	132 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	132 [220 140  70 200 130 210 340 140]
# NF_RCX_Black_AfricanAmerican	132 [280 320 340 290 440 270 330 210]
# NF_RDX_Hispanic	132 [420 720 110 680 310 310 130 170]
# NF_REX_Hawaiian	132 [0 0 0 0 0 0 0 0]
# NF_RFX_White	132 [2750 2310 3190 1440 1810 1300 2890 1850]
# NF_RGX_NR	132 [2330 2710 2590 4820 2330 1660 2560 2840]
# NF_RHX_Multi	132 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	132 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	150 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	150 [ 20 100 100  60  60  40 140  40]
# NF_RCX_Black_AfricanAmerican	150 [220 200 110 150 130 110  70 110]
# NF_RDX_Hispanic	150 [ 90 100  40 110 330  70 100  70]
# NF_REX_Hawaiian	150 [0 0 0 0 0 0 0 0]
# NF_RFX_White	150 [1250  990  880 1170 1210  800  630  690]
# NF_RGX_NR	150 [1340 2040 1300 1250  820 1230  860 1250]
# NF_RHX_Multi	150 [ 0  0 20  0  0  0  0  0]
# NF_RIX_Hispanic	150 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	151 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	151 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	151 [0 0 0 0 0 0 0 0]
# NF_RDX_Hispanic	151 [0 0 0 0 0 0 0 0]
# NF_REX_Hawaiian	151 [0 0 0 0 0 0 0 0]
# NF_RFX_White	151 [0 0 0 0 0 0 0 0]
# NF_RGX_NR	151 [0 0 0 0 0 0 0 0]
# NF_RHX_Multi	151 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	151 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	152 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	152 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	152 [ 0  0  0 20  0  0 60  0]
# NF_RDX_Hispanic	152 [ 0  0  0  0  0  0  0 60]
# NF_REX_Hawaiian	152 [0 0 0 0 0 0 0 0]
# NF_RFX_White	152 [280 250 660  70 300 150 220 360]
# NF_RGX_NR	152 [ 300 1390  430  190  100  210  230  360]
# NF_RHX_Multi	152 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	152 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	170 [ 20 100   0   0   0   0   0   0]
# NF_RBX_Asian	170 [ 70 110  40  50 220 100  30  30]
# NF_RCX_Black_AfricanAmerican	170 [ 90 140  90  80 100  80  90 240]
# NF_RDX_Hispanic	170 [270 160  70 160 130 280 150 220]
# NF_REX_Hawaiian	170 [0 0 0 0 0 0 0 0]
# NF_RFX_White	170 [1950 1640 2010 2270 2330 1380 1640 1490]
# NF_RGX_NR	170 [1210 1600 1290 1390 1050 1050 1560 1440]
# NF_RHX_Multi	170 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	170 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	171 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	171 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	171 [0 0 0 0 0 0 0 0]
# NF_RDX_Hispanic	171 [210 120   0   0   0  30 210   0]
# NF_REX_Hawaiian	171 [0 0 0 0 0 0 0 0]
# NF_RFX_White	171 [1430  750  150 2380 1380  490  490  890]
# NF_RGX_NR	171 [280 410 180 270 190 840 240 210]
# NF_RHX_Multi	171 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	171 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	172 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	172 [160  40  20  20 260   0  40  60]
# NF_RCX_Black_AfricanAmerican	172 [40  0 20 20 20 80  0  0]
# NF_RDX_Hispanic	172 [210  20   0  90  30   0  20  70]
# NF_REX_Hawaiian	172 [0 0 0 0 0 0 0 0]
# NF_RFX_White	172 [1390 1190 2640 2080 3030 1320 2200 1490]
# NF_RGX_NR	172 [1670 2420 2060 1330 1580 1130 1830 1700]
# NF_RHX_Multi	172 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	172 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	173 [  0 280   0   0   0   0   0   0]
# NF_RBX_Asian	173 [  0 210  40  40   0 250   0   0]
# NF_RCX_Black_AfricanAmerican	173 [130 310 210 180 210  50 170 260]
# NF_RDX_Hispanic	173 [220 280 130 320 210 680 130 200]
# NF_REX_Hawaiian	173 [0 0 0 0 0 0 0 0]
# NF_RFX_White	173 [2850 2810 3140 2200 2160 2120 1790 1940]
# NF_RGX_NR	173 [1520 1840 1530 2390 1220 1130 2550 2340]
# NF_RHX_Multi	173 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	173 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	190 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	190 [ 70  70 160 140  70  70  60  50]
# NF_RCX_Black_AfricanAmerican	190 [270 110 210  80  90  50 110 100]
# NF_RDX_Hispanic	190 [120 110 180 350 100  70 190 200]
# NF_REX_Hawaiian	190 [ 0  0  0 60  0  0  0  0]
# NF_RFX_White	190 [ 950  910 1060 1610  780 1220  810  760]
# NF_RGX_NR	190 [1490 1470  750 1050 1170  870 1220 1000]
# NF_RHX_Multi	190 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	190 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	191 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	191 [  0  40  40 180  70   0  20   0]
# NF_RCX_Black_AfricanAmerican	191 [ 0  0  0  0 20  0  0  0]
# NF_RDX_Hispanic	191 [ 0  0 80  0 20 20 70  0]
# NF_REX_Hawaiian	191 [0 0 0 0 0 0 0 0]
# NF_RFX_White	191 [630 340 720 810 340 730 460 530]
# NF_RGX_NR	191 [1470 1540  470  810  860  410  510  610]
# NF_RHX_Multi	191 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	191 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	192 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	192 [ 20   0 100   0   0  70  20   0]
# NF_RCX_Black_AfricanAmerican	192 [  0   0 150  20   0   0   0   0]
# NF_RDX_Hispanic	192 [  0   0   0   0   0   0 240   0]
# NF_REX_Hawaiian	192 [0 0 0 0 0 0 0 0]
# NF_RFX_White	192 [ 520  290  240  350  180 1900  190  230]
# NF_RGX_NR	192 [580 440  90 240 640 310 550 480]
# NF_RHX_Multi	192 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	192 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	193 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	193 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	193 [660  70   0   0   0   0   0   0]
# NF_RDX_Hispanic	193 [ 90   0   0   0 100   0   0   0]
# NF_REX_Hawaiian	193 [0 0 0 0 0 0 0 0]
# NF_RFX_White	193 [220 370 200 400 290 200 190 220]
# NF_RGX_NR	193 [230 370 240 380 390 390 270 340]
# NF_RHX_Multi	193 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	193 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	194 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	194 [100  30 250 190  30  60   0  50]
# NF_RCX_Black_AfricanAmerican	194 [ 60 170 230  90  90  40 250 170]
# NF_RDX_Hispanic	194 [120 240 160 720  40 100 140 330]
# NF_REX_Hawaiian	194 [ 0  0  0 60  0  0  0  0]
# NF_RFX_White	194 [1130 1410 1580 2820 1320  580 1260  980]
# NF_RGX_NR	194 [1880 1530 1050 1380 1290 1100 1850 1340]
# NF_RHX_Multi	194 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	194 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	195 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	195 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	195 [0 0 0 0 0 0 0 0]
# NF_RDX_Hispanic	195 [0 0 0 0 0 0 0 0]
# NF_REX_Hawaiian	195 [0 0 0 0 0 0 0 0]
# NF_RFX_White	195 [0 0 0 0 0 0 0 0]
# NF_RGX_NR	195 [0 0 0 0 0 0 0 0]
# NF_RHX_Multi	195 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	195 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	210 [ 50  70 170 110 100  70 120 130]
# NF_RBX_Asian	210 [ 90 170 120 130  60 140  90 100]
# NF_RCX_Black_AfricanAmerican	210 [2110 2560 2900 2330 2400 2740 2230 2650]
# NF_RDX_Hispanic	210 [ 780  810 1020  730 1010  680  710  870]
# NF_REX_Hawaiian	210 [ 0 50  0  0 30 20 20 30]
# NF_RFX_White	210 [4140 4590 4650 4680 4230 4270 3710 3730]
# NF_RGX_NR	210 [6020 6210 5580 6340 5570 7680 6250 5940]
# NF_RHX_Multi	210 [ 0  0  0  0  0 20  0  0]
# NF_RIX_Hispanic	210 [ 0  0  0  0  0 30  0  0]
# NF_RAX_AmericanIndian_AlaskaNative	211 [100 170 490 300 280 150 330 250]
# NF_RBX_Asian	211 [220 440 260 370 130 360 210 220]
# NF_RCX_Black_AfricanAmerican	211 [6330 7640 8610 6970 7130 8110 6700 7920]
# NF_RDX_Hispanic	211 [2300 2400 3020 2110 2980 2010 2100 2550]
# NF_REX_Hawaiian	211 [  0 110   0   0  30  20  20  50]
# NF_RFX_White	211 [12170 13570 13710 13140 12300 12660 10710 10600]
# NF_RGX_NR	211 [17890 18610 16660 18910 16540 22870 18660 17700]
# NF_RHX_Multi	211 [ 0  0  0  0  0 20  0  0]
# NF_RIX_Hispanic	211 [ 0  0  0  0  0 60  0  0]
# NF_RAX_AmericanIndian_AlaskaNative	212 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	212 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	212 [ 0  0 90  0 60 60  0  0]
# NF_RDX_Hispanic	212 [0 0 0 0 0 0 0 0]
# NF_REX_Hawaiian	212 [0 0 0 0 0 0 0 0]
# NF_RFX_White	212 [230 200 220 900 390 130 400 600]
# NF_RGX_NR	212 [130  20  70  70 170 180  30 120]
# NF_RHX_Multi	212 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	212 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	230 [ 0 20  0  0  0  0  0  0]
# NF_RBX_Asian	230 [  0   0  30   0   0  20 260   0]
# NF_RCX_Black_AfricanAmerican	230 [ 60 150 120  60 100  50  60  60]
# NF_RDX_Hispanic	230 [140  80  90  80  70 150  80  50]
# NF_REX_Hawaiian	230 [0 0 0 0 0 0 0 0]
# NF_RFX_White	230 [960 680 640 820 690 920 470 390]
# NF_RGX_NR	230 [310 510 350 420 220 310 260 650]
# NF_RHX_Multi	230 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	230 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	231 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	231 [ 0  0 20  0  0  0  0  0]
# NF_RCX_Black_AfricanAmerican	231 [ 0 60 80 40 80 60 40  0]
# NF_RDX_Hispanic	231 [  0   0 160   0  60   0   0   0]
# NF_REX_Hawaiian	231 [0 0 0 0 0 0 0 0]
# NF_RFX_White	231 [ 410  650  560 1990  490  530  380  390]
# NF_RGX_NR	231 [ 440  950  410  280  250  320  310 1380]
# NF_RHX_Multi	231 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	231 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	232 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	232 [  0   0   0   0   0   0 730   0]
# NF_RCX_Black_AfricanAmerican	232 [150 330 230 100 210  20 130 140]
# NF_RDX_Hispanic	232 [390 210  70 230 130 410 240 110]
# NF_REX_Hawaiian	232 [0 0 0 0 0 0 0 0]
# NF_RFX_White	232 [2210 1340 1330  440 1520 2210  940  680]
# NF_RGX_NR	232 [450 550 620 940 360 570 450 580]
# NF_RHX_Multi	232 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	232 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	250 [100 130 160 280 130 480 310 120]
# NF_RBX_Asian	250 [160 270 260 470 310 720 260 740]
# NF_RCX_Black_AfricanAmerican	250 [2480 2570 2410 2460 2650 2360 1710 3080]
# NF_RDX_Hispanic	250 [2040 1770 2050 2120 2440 2150 2230 2950]
# NF_REX_Hawaiian	250 [ 90  60  70 120  30  20  80  20]
# NF_RFX_White	250 [17350 15580 16180 16880 15270 17530 14590 16660]
# NF_RGX_NR	250 [14450 14070 13650 14130 17460 15790 15190 16970]
# NF_RHX_Multi	250 [20  0  0 70  0 70 20  0]
# NF_RIX_Hispanic	250 [50 20 40  0 50  0 60 20]
# NF_RAX_AmericanIndian_AlaskaNative	251 [ 0  0 90  0  0  0  0  0]
# NF_RBX_Asian	251 [ 0 60 80 40  0  0  0 60]
# NF_RCX_Black_AfricanAmerican	251 [ 60 210 160 110 210  90 110 190]
# NF_RDX_Hispanic	251 [ 80  60 290 120   0 170   0 120]
# NF_REX_Hawaiian	251 [0 0 0 0 0 0 0 0]
# NF_RFX_White	251 [1200 1060 1520 1120  680 1720 1010 1140]
# NF_RGX_NR	251 [1080 1260 1320 1330 1030 1080  990 1370]
# NF_RHX_Multi	251 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	251 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	252 [180  20 210 450 130  60 720 160]
# NF_RBX_Asian	252 [ 160  350  110  280  380  270  330 1540]
# NF_RCX_Black_AfricanAmerican	252 [3400 3470 2990 3260 3430 3230 1950 4350]
# NF_RDX_Hispanic	252 [2180 2450 1490 3280 2290 1550 2550 3680]
# NF_REX_Hawaiian	252 [ 30  20 120   0   0   0  40   0]
# NF_RFX_White	252 [24600 23640 23970 24700 20870 26510 23710 25620]
# NF_RGX_NR	252 [21390 19490 17020 18890 23430 21460 19270 21450]
# NF_RHX_Multi	252 [ 0  0  0 70  0  0  0  0]
# NF_RIX_Hispanic	252 [  0   0 100   0   0   0   0   0]
# NF_RAX_AmericanIndian_AlaskaNative	253 [  0   0   0   0 150   0   0   0]
# NF_RBX_Asian	253 [ 90  90   0 390 130 150  70  90]
# NF_RCX_Black_AfricanAmerican	253 [ 360  570 1360  630  590  810  440  660]
# NF_RDX_Hispanic	253 [ 740  820 1140  570  970 1870  790 1270]
# NF_REX_Hawaiian	253 [0 0 0 0 0 0 0 0]
# NF_RFX_White	253 [9640 4140 5650 6470 4260 5650 3360 2910]
# NF_RGX_NR	253 [4080 5310 5400 4520 4200 5400 5140 4980]
# NF_RHX_Multi	253 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	253 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	254 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	254 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	254 [  0   0 180 100   0  20   0  50]
# NF_RDX_Hispanic	254 [ 60   0   0 210   0   0  80  70]
# NF_REX_Hawaiian	254 [0 0 0 0 0 0 0 0]
# NF_RFX_White	254 [ 730 1150  980  590 1060  570  550  950]
# NF_RGX_NR	254 [490 180 630 600 400 450 420 390]
# NF_RHX_Multi	254 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	254 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	259 [ 40 200 100 230  60 880 100 110]
# NF_RBX_Asian	259 [ 120  280  310  400  230 1120  240  290]
# NF_RCX_Black_AfricanAmerican	259 [2440 2410 1650 2120 2470 1920 1770 2550]
# NF_RDX_Hispanic	259 [1970 1330 2170 1370 2650 1950 2100 2500]
# NF_REX_Hawaiian	259 [120 130  40 180  40   0  40   0]
# NF_RFX_White	259 [10450 11000 11160 11640 12420 11670 10160 12400]
# NF_RGX_NR	259 [10640 11030 11070 11140 15780 12500 13440 15110]
# NF_RHX_Multi	259 [  0   0   0   0   0 100  40   0]
# NF_RIX_Hispanic	259 [80 40  0  0 80  0 80  0]
# NF_RAX_AmericanIndian_AlaskaNative	270 [ 0  0  0 20  0  0  0 20]
# NF_RBX_Asian	270 [ 50  80 120 120 100  70  50 110]
# NF_RCX_Black_AfricanAmerican	270 [310 710 520 850 590 520 320 210]
# NF_RDX_Hispanic	270 [790 400 400 310 230 450 460 360]
# NF_REX_Hawaiian	270 [ 30 150  20 120   0  40  30   0]
# NF_RFX_White	270 [3100 2000 2500 3010 2530 2690 2170 2650]
# NF_RGX_NR	270 [2740 1730 5170 1930 2160 3780 3760 3210]
# NF_RHX_Multi	270 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	270 [ 0 20  0  0  0  0  0  0]
# NF_RAX_AmericanIndian_AlaskaNative	271 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	271 [  0   0  40  40   0  20   0 160]
# NF_RCX_Black_AfricanAmerican	271 [ 40 130  90   0  80   0   0 120]
# NF_RDX_Hispanic	271 [740 450 170  80  40 370  80 160]
# NF_REX_Hawaiian	271 [0 0 0 0 0 0 0 0]
# NF_RFX_White	271 [2170  870  970 1120  970  800 1010 2020]
# NF_RGX_NR	271 [1320  940 3480 1300 1640 1330 2220 2570]
# NF_RHX_Multi	271 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	271 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	272 [ 0  0  0 20  0  0  0  0]
# NF_RBX_Asian	272 [ 70  40 140 200 190 120 110  20]
# NF_RCX_Black_AfricanAmerican	272 [ 710 1810  870 2350 1320 1440  660  350]
# NF_RDX_Hispanic	272 [820 480 430 530 240 480 840 460]
# NF_REX_Hawaiian	272 [  0 430   0 330   0 100  70   0]
# NF_RFX_White	272 [5030 3400 3510 5360 4370 4680 4180 3470]
# NF_RGX_NR	272 [5400 2380 7860 3200 3160 8280 7330 4380]
# NF_RHX_Multi	272 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	272 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	273 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	273 [ 0 30  0  0 20  0  0  0]
# NF_RCX_Black_AfricanAmerican	273 [20 60 50 50 20 20 40 20]
# NF_RDX_Hispanic	273 [190 150 310 110  20 110 100 140]
# NF_REX_Hawaiian	273 [0 0 0 0 0 0 0 0]
# NF_RFX_White	273 [ 550  780  570 1200  370  470  600  570]
# NF_RGX_NR	273 [630 710 340 410 610 510 480 700]
# NF_RHX_Multi	273 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	273 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	274 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	274 [20  0 40  0  0  0  0  0]
# NF_RCX_Black_AfricanAmerican	274 [ 60   0  20   0 140   0  80  20]
# NF_RDX_Hispanic	274 [150  40  20  40 240 230 200  70]
# NF_REX_Hawaiian	274 [0 0 0 0 0 0 0 0]
# NF_RFX_White	274 [1400  790 1910 1090 1720 1980  580 1640]
# NF_RGX_NR	274 [ 810 1070  770  790  960 1020 1060 1910]
# NF_RHX_Multi	274 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	274 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	290 [320 160 160 270 200 160 120 100]
# NF_RBX_Asian	290 [1620 1900 1630 1620 1430 1690 1380 1510]
# NF_RCX_Black_AfricanAmerican	290 [5380 4720 5060 5360 5330 4750 4680 4740]
# NF_RDX_Hispanic	290 [2300 2700 2670 2200 2800 2140 2650 2520]
# NF_REX_Hawaiian	290 [220 230 130 210 330 160 180 150]
# NF_RFX_White	290 [28890 28140 27440 26990 25250 25350 22990 22880]
# NF_RGX_NR	290 [25550 27500 27170 27790 26230 25020 29620 31260]
# NF_RHX_Multi	290 [ 60  50  80  40 100  30  60  50]
# NF_RIX_Hispanic	290 [30 30 30 20 70 60  0 20]
# NF_RAX_AmericanIndian_AlaskaNative	291 [490 150 150 640 210 150  90  90]
# NF_RBX_Asian	291 [3090 3610 3170 3670 3140 3630 2720 3100]
# NF_RCX_Black_AfricanAmerican	291 [5520 4780 5620 6000 5120 5040 4910 5020]
# NF_RDX_Hispanic	291 [2340 2330 2830 2420 2620 2060 2240 2000]
# NF_REX_Hawaiian	291 [440 310 250 310 400 360 220 220]
# NF_RFX_White	291 [44390 39350 41510 40620 38390 35600 33230 32480]
# NF_RGX_NR	291 [40830 40730 43140 43370 39630 40610 45490 45850]
# NF_RHX_Multi	291 [  0   0 120  60  60  60  90  70]
# NF_RIX_Hispanic	291 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	292 [310 220 180 110 280 270 190 180]
# NF_RBX_Asian	292 [1580 1650 1430 1000  950 1190 1120 1150]
# NF_RCX_Black_AfricanAmerican	292 [ 9910  8420  8710  8660 10240  8610  8320  8150]
# NF_RDX_Hispanic	292 [4200 5070 4420 3710 5410 4080 5080 3720]
# NF_REX_Hawaiian	292 [140 260  60 170 530  50 230 190]
# NF_RFX_White	292 [36420 38110 34520 34140 31430 34070 30930 29340]
# NF_RGX_NR	292 [30390 37000 33790 35710 34500 30690 37820 42500]
# NF_RHX_Multi	292 [ 90  80  60  20 150   0  20  50]
# NF_RIX_Hispanic	292 [30 20  0 20 70 30  0  0]
# NF_RAX_AmericanIndian_AlaskaNative	299 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	299 [ 0  0  0  0  0  0 60  0]
# NF_RCX_Black_AfricanAmerican	299 [150 490 410 490 220 260 300 570]
# NF_RDX_Hispanic	299 [120 270  60 150  20  30  60 740]
# NF_REX_Hawaiian	299 [0 0 0 0 0 0 0 0]
# NF_RFX_White	299 [ 780 1070  750  500  450  570  430 1740]
# NF_RGX_NR	299 [1030 1020  670  670  810  430  900 1220]
# NF_RHX_Multi	299 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	299 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	310 [360 210 240 320 330 270 310 240]
# NF_RBX_Asian	310 [1120  980 1250 1090 1120 1020 1110 1030]
# NF_RCX_Black_AfricanAmerican	310 [14090 12570 13330 11740 12100 11310 10220 10140]
# NF_RDX_Hispanic	310 [5810 4770 4670 5270 4930 4200 3820 4010]
# NF_REX_Hawaiian	310 [230 180 250 220 160 190 170 160]
# NF_RFX_White	310 [26460 25380 24930 23250 21860 18860 18330 16520]
# NF_RGX_NR	310 [25960 24960 24620 22190 21970 22150 24440 23920]
# NF_RHX_Multi	310 [ 70 100  70  50  80  40  80  30]
# NF_RIX_Hispanic	310 [ 40  80 280 100  40  50  30  20]
# NF_RAX_AmericanIndian_AlaskaNative	311 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	311 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	311 [0 0 0 0 0 0 0 0]
# NF_RDX_Hispanic	311 [0 0 0 0 0 0 0 0]
# NF_REX_Hawaiian	311 [0 0 0 0 0 0 0 0]
# NF_RFX_White	311 [0 0 0 0 0 0 0 0]
# NF_RGX_NR	311 [0 0 0 0 0 0 0 0]
# NF_RHX_Multi	311 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	311 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	312 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	312 [  0   0 100   0   0  20   0   0]
# NF_RCX_Black_AfricanAmerican	312 [730 290 210 300 160 200 120 210]
# NF_RDX_Hispanic	312 [170 190 120  50 140  90  20  20]
# NF_REX_Hawaiian	312 [0 0 0 0 0 0 0 0]
# NF_RFX_White	312 [2790 1500 1640 1140  930 1210 1260  780]
# NF_RGX_NR	312 [2160 1290 1110 1130 1200 1380 1450  980]
# NF_RHX_Multi	312 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	312 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	319 [ 60  40  50   0  50  50  60 110]
# NF_RBX_Asian	319 [460 120 150 170 220 330 320 490]
# NF_RCX_Black_AfricanAmerican	319 [4560 2840 2560 2520 2670 2440 1980 2190]
# NF_RDX_Hispanic	319 [3330 2360 1570 3380 3000 2090 2120 1650]
# NF_REX_Hawaiian	319 [40 60  0 40 90  0  0 40]
# NF_RFX_White	319 [11700  9440 10670  9650 12200  8100 11100 10290]
# NF_RGX_NR	319 [14150 12090  9060  9550 11250  8510 12860 12980]
# NF_RHX_Multi	319 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	319 [  0   0 230  40   0   0   0   0]
# NF_RAX_AmericanIndian_AlaskaNative	330 [250 260 220 330 340 260 360 360]
# NF_RBX_Asian	330 [490 850 400 790 250 380 250 500]
# NF_RCX_Black_AfricanAmerican	330 [8060 5030 5590 5270 4740 5990 5790 5440]
# NF_RDX_Hispanic	330 [4620 4410 4120 3900 3730 6110 6000 4200]
# NF_REX_Hawaiian	330 [190 260 160 170 100 100 430 150]
# NF_RFX_White	330 [39420 32670 30010 28780 29970 26620 29400 26970]
# NF_RGX_NR	330 [40500 40960 41990 39580 43640 41700 40180 45130]
# NF_RHX_Multi	330 [ 40  40 100  40 130  30  40  50]
# NF_RIX_Hispanic	330 [  0 190  60  60  30  50   0  30]
# NF_RAX_AmericanIndian_AlaskaNative	331 [  0   0  90   0   0   0 140   0]
# NF_RBX_Asian	331 [ 20 790   0 110   0  70  50   0]
# NF_RCX_Black_AfricanAmerican	331 [1320  630 1650 1330 1400 1090 1020 1140]
# NF_RDX_Hispanic	331 [1170  770  380  620  640 1680  480 1200]
# NF_REX_Hawaiian	331 [0 0 0 0 0 0 0 0]
# NF_RFX_White	331 [10290 10510  8850  9580 10950 11120 13370  8850]
# NF_RGX_NR	331 [11880 11370 10230  9410 12360 14570 13310 15410]
# NF_RHX_Multi	331 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	331 [ 0  0 90  0  0  0  0  0]
# NF_RAX_AmericanIndian_AlaskaNative	332 [  0  60  90  60   0   0 120   0]
# NF_RBX_Asian	332 [ 90  90  90 180   0  60  70   0]
# NF_RCX_Black_AfricanAmerican	332 [1380  930 1110 1170  660  570  930  640]
# NF_RDX_Hispanic	332 [1200 1050  810 1200  840 1230  600  720]
# NF_REX_Hawaiian	332 [ 90 120  90   0   0   0 180  90]
# NF_RFX_White	332 [18990 15210 15120 15330 15110 14280 14890 15090]
# NF_RGX_NR	332 [24720 22720 26980 25640 24660 20700 30150 31240]
# NF_RHX_Multi	332 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	332 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	333 [570 450 190 660 660 320 580 940]
# NF_RBX_Asian	333 [ 960 1360  650 1560  360  370  190 1040]
# NF_RCX_Black_AfricanAmerican	333 [16160  8800  8420  7730  7020  8900 10450  8310]
# NF_RDX_Hispanic	333 [ 9060  8660  7300  6960  6920 12070 13740  8440]
# NF_REX_Hawaiian	333 [260 290 270 240 100 130 790 200]
# NF_RFX_White	333 [75570 61670 54110 50660 51920 43840 48120 44100]
# NF_RGX_NR	333 [70610 72320 69420 68430 77420 74960 59720 69790]
# NF_RHX_Multi	333 [ 90  70 160  20   0   0  20  70]
# NF_RIX_Hispanic	333 [  0 460   0  20  70 100   0   0]
# NF_RAX_AmericanIndian_AlaskaNative	339 [ 80 210 180 230 310 360 140  80]
# NF_RBX_Asian	339 [340 300 340 490 320 580 310 360]
# NF_RCX_Black_AfricanAmerican	339 [5270 4710 5550 5570 5150 7420 4930 6150]
# NF_RDX_Hispanic	339 [2400 2710 3840 2820 2780 3340 3100 2220]
# NF_REX_Hawaiian	339 [150 250 120 200 150 120 190  20]
# NF_RFX_White	339 [13360 10580 11940 10760 11310 10620 11750 12850]
# NF_RGX_NR	339 [14270 16440 19300 15280 16480 14850 17360 18890]
# NF_RHX_Multi	339 [  0   0  70  20 360   0   0   0]
# NF_RIX_Hispanic	339 [ 0 30  0  0  0  0  0  0]
# NF_RAX_AmericanIndian_AlaskaNative	350 [340 410 580 430 690 300 400 630]
# NF_RBX_Asian	350 [1580 1890 1500 1840 2210 1780 1770 1760]
# NF_RCX_Black_AfricanAmerican	350 [6520 6120 6240 5700 5760 5350 5330 5170]
# NF_RDX_Hispanic	350 [12160 12860 13630 12380 14660 12780 13820 11460]
# NF_REX_Hawaiian	350 [180 490 220 290 350 200 260 180]
# NF_RFX_White	350 [26000 26380 28390 24710 24970 24290 23530 25170]
# NF_RGX_NR	350 [29150 31120 32840 30990 35790 33980 34150 37680]
# NF_RHX_Multi	350 [ 70  60  60  50 110 110  90 210]
# NF_RIX_Hispanic	350 [ 30  20  70  60   0 120  90  20]
# NF_RAX_AmericanIndian_AlaskaNative	351 [200  40   0   0   0 180 510   0]
# NF_RBX_Asian	351 [1350 1000  600 1240  320  500 1560  510]
# NF_RCX_Black_AfricanAmerican	351 [2190  900 1680 1290 2310 1170 1230 1720]
# NF_RDX_Hispanic	351 [1720 2190 4770 2850 4020 3720 3450 2250]
# NF_REX_Hawaiian	351 [  0  60  60  80 170  60  60 160]
# NF_RFX_White	351 [ 8700 10430  9240  8580  9060  8050  9750 13410]
# NF_RGX_NR	351 [ 6360  6840 10740  8820 10080 10200  9270 12120]
# NF_RHX_Multi	351 [  0   0   0   0   0   0   0 120]
# NF_RIX_Hispanic	351 [ 0  0  0  0  0 40  0  0]
# NF_RAX_AmericanIndian_AlaskaNative	352 [ 290  560  440  320 1490  320  150  630]
# NF_RBX_Asian	352 [1390 1870 1770 1620 1910 2630 1810 2760]
# NF_RCX_Black_AfricanAmerican	352 [8180 7890 8140 7950 7430 7690 7460 7200]
# NF_RDX_Hispanic	352 [18890 17150 16800 19190 19640 19240 19910 17040]
# NF_REX_Hawaiian	352 [230 520 280 330 340 270 370 100]
# NF_RFX_White	352 [33190 34250 38130 32240 29750 32040 27200 28590]
# NF_RGX_NR	352 [36980 38140 40660 41050 41840 39980 43900 46050]
# NF_RHX_Multi	352 [ 40 110   0   0 180 240  70 110]
# NF_RIX_Hispanic	352 [  0   0 100  20   0   0 150   0]
# NF_RAX_AmericanIndian_AlaskaNative	353 [240 360 650 310 140 180 300 390]
# NF_RBX_Asian	353 [ 890 1000  980 1950 1220 1230  940 1200]
# NF_RCX_Black_AfricanAmerican	353 [3560 4290 4680 3960 3940 3750 3450 3300]
# NF_RDX_Hispanic	353 [5540 6820 7060 6440 7720 6410 6710 6310]
# NF_REX_Hawaiian	353 [ 80 490  90 240 180  60 110  60]
# NF_RFX_White	353 [19180 20710 23240 21930 23850 20720 21870 19920]
# NF_RGX_NR	353 [22790 26180 24710 24580 30460 29170 26290 30670]
# NF_RHX_Multi	353 [ 20   0  20  70 100   0  40   0]
# NF_RIX_Hispanic	353 [  0   0  20   0   0 160   0   0]
# NF_RAX_AmericanIndian_AlaskaNative	359 [110  90 280 490 210 140 170 670]
# NF_RBX_Asian	359 [ 900 1700  960  560 2880  900  850  720]
# NF_RCX_Black_AfricanAmerican	359 [4680 4290 2910 2940 2620 2640 3060 2580]
# NF_RDX_Hispanic	359 [ 9120 10800 10380  7050 10300  7650  9990  7290]
# NF_REX_Hawaiian	359 [ 80 130 160 120 330 160  90  70]
# NF_RFX_White	359 [13850 11190 10320  8120  8340  8510  8650  9660]
# NF_RGX_NR	359 [16870 16170 16110 12910 17220 15480 16350 15940]
# NF_RHX_Multi	359 [ 60   0  20   0   0   0   0 180]
# NF_RIX_Hispanic	359 [20  0  0  0  0  0  0  0]
# NF_RAX_AmericanIndian_AlaskaNative	370 [800 550 510 570 430 210 380 500]
# NF_RBX_Asian	370 [1360 1110 1320 1420 1370 1430 1200 1590]
# NF_RCX_Black_AfricanAmerican	370 [8110 7600 6680 6200 6510 7230 7260 6840]
# NF_RDX_Hispanic	370 [20280 22730 18990 20220 19740 20000 19100 19400]
# NF_REX_Hawaiian	370 [190 270 260 280 370 230 340 200]
# NF_RFX_White	370 [30660 25220 26050 26380 22220 24830 21610 19960]
# NF_RGX_NR	370 [29580 26060 26570 28670 31110 26830 27610 29150]
# NF_RHX_Multi	370 [ 20 520  50  70  30  90  70 120]
# NF_RIX_Hispanic	370 [ 90  60  40 280  90 140 120  20]
# NF_RAX_AmericanIndian_AlaskaNative	371 [ 80   0   0   0 170   0   0   0]
# NF_RBX_Asian	371 [  0  60 120 120 100 170 390 170]
# NF_RCX_Black_AfricanAmerican	371 [1080 1370  720  700 1110  600 1080 1110]
# NF_RDX_Hispanic	371 [2580 3100 3160 3120 2450 1650 2400 4950]
# NF_REX_Hawaiian	371 [  0   0  60   0   0   0 380   0]
# NF_RFX_White	371 [6960 4740 6000 4890 5540 5640 2760 4410]
# NF_RGX_NR	371 [3900 3180 4880 3170 4410 3000 3300 4260]
# NF_RHX_Multi	371 [ 0  0  0  0  0  0 60  0]
# NF_RIX_Hispanic	371 [  0   0   0   0   0 120   0   0]
# NF_RAX_AmericanIndian_AlaskaNative	372 [2070  770 1280  840  760  560  970 1380]
# NF_RBX_Asian	372 [3830 2980 3490 3680 3780 3770 3030 4260]
# NF_RCX_Black_AfricanAmerican	372 [20780 19230 16860 15930 16480 16720 17260 17250]
# NF_RDX_Hispanic	372 [46520 45040 41650 43790 44810 41460 38520 40220]
# NF_REX_Hawaiian	372 [ 420  540  560  680 1020  630  300  430]
# NF_RFX_White	372 [64170 56430 55290 53400 43800 46840 45010 37260]
# NF_RGX_NR	372 [65510 57980 60250 59940 74020 61100 62250 64420]
# NF_RHX_Multi	372 [  40 1020  130   80   60   80    0  110]
# NF_RIX_Hispanic	372 [270 170 120 210 270 230 260   0]
# NF_RAX_AmericanIndian_AlaskaNative	373 [240 860 210 780 360   0 120  80]
# NF_RBX_Asian	373 [200 270 250 450 200 320 200 330]
# NF_RCX_Black_AfricanAmerican	373 [2440 2170 2430 1940 1940 4350 3420 2140]
# NF_RDX_Hispanic	373 [11760 20040 12180 13740 11940 16860 16370 13010]
# NF_REX_Hawaiian	373 [150 270 150 150  80   0 300 120]
# NF_RFX_White	373 [20850 14500 16870 20860 17340 22010 17050 18230]
# NF_RGX_NR	373 [19320 17010 14580 22910 14870 16380 17270 18740]
# NF_RHX_Multi	373 [  0 540   0  90   0 100 120  90]
# NF_RIX_Hispanic	373 [  0   0   0 630   0  60   0   0]
# NF_RAX_AmericanIndian_AlaskaNative	390 [150 100 150 200  90  90 140 100]
# NF_RBX_Asian	390 [540 440 310 530 400 400 380 310]
# NF_RCX_Black_AfricanAmerican	390 [4000 3970 3720 4150 3890 4390 4420 4390]
# NF_RDX_Hispanic	390 [1980 2880 2570 2480 1920 2290 1760 2590]
# NF_REX_Hawaiian	390 [130  90  80 130 110  70  60  60]
# NF_RFX_White	390 [11240 11230 11610 11350 12160 11000  9870 11630]
# NF_RGX_NR	390 [ 9400 10800 10090 11390 11700 12760 11010 12620]
# NF_RHX_Multi	390 [ 70  20  20 130  40 130  30  40]
# NF_RIX_Hispanic	390 [  0  20  20   0   0  20 100   0]
# NF_RAX_AmericanIndian_AlaskaNative	391 [20  0  0  0  0  0  0  0]
# NF_RBX_Asian	391 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	391 [140  60 130 120 100 100 210  70]
# NF_RDX_Hispanic	391 [130 120  40  50 230  20   0   0]
# NF_REX_Hawaiian	391 [0 0 0 0 0 0 0 0]
# NF_RFX_White	391 [980 500 680 480 430 340 410 960]
# NF_RGX_NR	391 [730 520 980 290 670 760 260 320]
# NF_RHX_Multi	391 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	391 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	392 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	392 [  0   0   0 190   0   0   0   0]
# NF_RCX_Black_AfricanAmerican	392 [420  90 120 550 210 180 300 340]
# NF_RDX_Hispanic	392 [1330 2010  450  900  120 1110  150 1050]
# NF_REX_Hawaiian	392 [0 0 0 0 0 0 0 0]
# NF_RFX_White	392 [3510 5490 3370 4930 6570 3570 4200 6030]
# NF_RGX_NR	392 [2370 4050 2880 3120 4170 3150 2850 4410]
# NF_RHX_Multi	392 [ 0  0  0  0  0 40  0  0]
# NF_RIX_Hispanic	392 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	393 [ 0 20 20  0  0  0  0  0]
# NF_RBX_Asian	393 [200 420 320 360 190 330 280 190]
# NF_RCX_Black_AfricanAmerican	393 [600 610 480 490 360 250 340 210]
# NF_RDX_Hispanic	393 [710 910 790 900 460 640 570 480]
# NF_REX_Hawaiian	393 [ 0  0  0 20  0  0  0  0]
# NF_RFX_White	393 [2860 2180 2960 1960 2300 2830 2510 2070]
# NF_RGX_NR	393 [3000 2700 4470 3500 2690 3510 3630 3720]
# NF_RHX_Multi	393 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	393 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	394 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	394 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	394 [  0   0   0   0 180   0   0   0]
# NF_RDX_Hispanic	394 [0 0 0 0 0 0 0 0]
# NF_REX_Hawaiian	394 [0 0 0 0 0 0 0 0]
# NF_RFX_White	394 [ 190  630  100  190   70  250 1170  130]
# NF_RGX_NR	394 [270  20 870   0   0 250  50   0]
# NF_RHX_Multi	394 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	394 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	395 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	395 [1050    0   60    0    0    0    0    0]
# NF_RCX_Black_AfricanAmerican	395 [160   0  60 120   0   0  20   0]
# NF_RDX_Hispanic	395 [ 200  320 1410   20  190    0    0 1060]
# NF_REX_Hawaiian	395 [0 0 0 0 0 0 0 0]
# NF_RFX_White	395 [2320  870 1610 1690  760  880  470 2200]
# NF_RGX_NR	395 [ 930 1840  990 2550  980 5810 2220 1860]
# NF_RHX_Multi	395 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	395 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	396 [60  0  0  0  0 90  0  0]
# NF_RBX_Asian	396 [ 60  90   0  90 120  90   0  60]
# NF_RCX_Black_AfricanAmerican	396 [150 200 360 180 240 150 140 170]
# NF_RDX_Hispanic	396 [240 260 240 140 170 200 300 210]
# NF_REX_Hawaiian	396 [ 0 60  0  0  0 60  0  0]
# NF_RFX_White	396 [930 570 570 360 720 330 270 540]
# NF_RGX_NR	396 [1320  960  790  570  750  610  660  870]
# NF_RHX_Multi	396 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	396 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	397 [  0   0 120   0   0   0   0   0]
# NF_RBX_Asian	397 [  0   0   0   0   0   0   0 120]
# NF_RCX_Black_AfricanAmerican	397 [ 60   0   0   0 120   0   0  90]
# NF_RDX_Hispanic	397 [0 0 0 0 0 0 0 0]
# NF_REX_Hawaiian	397 [0 0 0 0 0 0 0 0]
# NF_RFX_White	397 [ 300  120  430  240  230  480  360 1110]
# NF_RGX_NR	397 [240 120 190 450 540  60 240 630]
# NF_RHX_Multi	397 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	397 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	399 [200  80  80 180  60  60 140 150]
# NF_RBX_Asian	399 [180 250 250 380 360 390 420 310]
# NF_RCX_Black_AfricanAmerican	399 [6390 6050 5470 5210 5250 6120 5700 6000]
# NF_RDX_Hispanic	399 [1950 2750 2810 3140 2320 2570 2190 2640]
# NF_REX_Hawaiian	399 [230  50  70 190 180  40  40  60]
# NF_RFX_White	399 [13950 14020 14350 15000 14150 12900 12050 11760]
# NF_RGX_NR	399 [11190 12830  9610 12280 14410 13590 12350 12960]
# NF_RHX_Multi	399 [ 30  20  20 120  20  70  30  20]
# NF_RIX_Hispanic	399 [ 0  0  0  0  0 20 20  0]
# NF_RAX_AmericanIndian_AlaskaNative	410 [400 170 150 110 580 180 190 110]
# NF_RBX_Asian	410 [ 400  910  550  810  890  810 1120  830]
# NF_RCX_Black_AfricanAmerican	410 [2560 3090 2910 2320 3230 2700 2350 2600]
# NF_RDX_Hispanic	410 [3480 3310 3950 2490 4160 2970 2880 3100]
# NF_REX_Hawaiian	410 [ 80 100 140  20  90 100  90  80]
# NF_RFX_White	410 [19270 19750 20340 18150 18350 17190 15040 17140]
# NF_RGX_NR	410 [32970 32030 35170 31940 32330 32530 34360 36100]
# NF_RHX_Multi	410 [ 60  30 350  30   0  40  30   0]
# NF_RIX_Hispanic	410 [ 20 340  50  30   0  60  70 250]
# NF_RAX_AmericanIndian_AlaskaNative	411 [630  60  80  80  90  90 200  60]
# NF_RBX_Asian	411 [330 930 390 310 150 210 660 660]
# NF_RCX_Black_AfricanAmerican	411 [ 990 1110 1590 1530 2850 2040 1360 1730]
# NF_RDX_Hispanic	411 [3270 3030 3200 1470 2820 3730 2070 2820]
# NF_REX_Hawaiian	411 [ 0  0 60  0 60  0  0 90]
# NF_RFX_White	411 [13560 15020 17770 15410 13770 12450 12180 15270]
# NF_RGX_NR	411 [24990 24200 23070 25430 27810 29040 27400 31140]
# NF_RHX_Multi	411 [ 0  0 60  0  0 40  0  0]
# NF_RIX_Hispanic	411 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	412 [ 460  450  300  180 1630  320  340  130]
# NF_RBX_Asian	412 [ 700 1190  960  900 2240 1840 2390 1350]
# NF_RCX_Black_AfricanAmerican	412 [4810 6520 4980 4650 6070 5370 4880 5240]
# NF_RDX_Hispanic	412 [5830 5580 6890 5090 8720 4660 5320 5580]
# NF_REX_Hawaiian	412 [140 190 330  20 160 250 210  80]
# NF_RFX_White	412 [31950 36240 32920 29730 33640 29970 26550 30220]
# NF_RGX_NR	412 [63750 64830 71330 61570 62760 60700 67760 69010]
# NF_RHX_Multi	412 [ 60  20 940  20   0   0   0   0]
# NF_RIX_Hispanic	412 [  60 1000    0    0    0   50  180   60]
# NF_RAX_AmericanIndian_AlaskaNative	413 [0 0 0 0 0 0 0 0]
# ...
# NF_RDX_Hispanic	4740 [1240 2000 1780 4000 3000 2750 3420  900]
# NF_REX_Hawaiian	4740 [ 0  0 20  0  0 30  0  0]
# NF_RFX_White	4740 [10870 10380  8920  9090  9120 10910 10580  7790]
# NF_RGX_NR	4740 [10410  9820 11560 10780 12140  7810 12520 10230]
# NF_RHX_Multi	4740 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	4740 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	4750 [60 90  0 30  0  0  0  0]
# NF_RBX_Asian	4750 [40  0  0  0 20  0  0  0]
# NF_RCX_Black_AfricanAmerican	4750 [  20  180   90 1140   80    0    0   30]
# NF_RDX_Hispanic	4750 [2320 1420  630 1540  650  730  890  610]
# NF_REX_Hawaiian	4750 [ 0  0  0 20  0  0  0  0]
# NF_RFX_White	4750 [1920 3440 1960 3840 1430  630 1280  990]
# NF_RGX_NR	4750 [6410 5080 5640 5730 4030 3360 4870 3990]
# NF_RHX_Multi	4750 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	4750 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	4900 [430 410 410 470 350 700 350 270]
# NF_RBX_Asian	4900 [800 800 650 800 680 800 730 570]
# NF_RCX_Black_AfricanAmerican	4900 [3540 4060 4040 3470 3600 3580 4350 4090]
# NF_RDX_Hispanic	4900 [ 8990  9780  9510  9760  8750  9580  9610 11760]
# NF_REX_Hawaiian	4900 [450 140 250 230 180 250 140 250]
# NF_RFX_White	4900 [53510 48410 44770 44270 48590 41630 40860 40140]
# NF_RGX_NR	4900 [34310 35140 35240 35210 36720 34210 39050 36810]
# NF_RHX_Multi	4900 [ 40  30  70 180  80 220  90  40]
# NF_RIX_Hispanic	4900 [ 80  20 120  60  20 320 230  90]
# NF_RAX_AmericanIndian_AlaskaNative	4910 [ 60   0 150   0   0   0   0   0]
# NF_RBX_Asian	4910 [  0   0  90   0 180  60 330  90]
# NF_RCX_Black_AfricanAmerican	4910 [450 540 120 240 270 360 750 480]
# NF_RDX_Hispanic	4910 [1290  870  510  630  930 1920 1560 1950]
# NF_REX_Hawaiian	4910 [ 0  0  0  0 60  0  0  0]
# NF_RFX_White	4910 [9540 9510 6900 4980 8310 7590 5670 7470]
# NF_RGX_NR	4910 [3270 3930 2670 2880 4500 2460 4950 3600]
# NF_RHX_Multi	4910 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	4910 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	4920 [ 0  0  0  0 30 20  0  0]
# NF_RBX_Asian	4920 [140   0  20  80  20 130   0   0]
# NF_RCX_Black_AfricanAmerican	4920 [ 760 1270 1360  880 2290  870  250 1950]
# NF_RDX_Hispanic	4920 [ 880 1310  760 1340 1110  790 1120 7160]
# NF_REX_Hawaiian	4920 [ 0  0  0  0  0  0 20 20]
# NF_RFX_White	4920 [7240 5310 6790 6750 7450 6900 3730 5370]
# NF_RGX_NR	4920 [12480 15350 14450 18700 13170 14290 18890 16310]
# NF_RHX_Multi	4920 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	4920 [  0   0   0   0   0   0 630   0]
# NF_RAX_AmericanIndian_AlaskaNative	4930 [ 510  190  570  260  140 1140  160   20]
# NF_RBX_Asian	4930 [ 650 1230  760  430  630  880  980  630]
# NF_RCX_Black_AfricanAmerican	4930 [2850 2030 3730 2130 2150 2060 1750 3110]
# NF_RDX_Hispanic	4930 [6800 9030 8610 7890 7050 7950 7830 9370]
# NF_REX_Hawaiian	4930 [950  30  70 150  30  30 120 100]
# NF_RFX_White	4930 [48950 43380 41510 42630 41830 41710 40000 41330]
# NF_RGX_NR	4930 [30230 29040 25740 27300 27670 29500 29630 32110]
# NF_RHX_Multi	4930 [ 0  0  0  0 40  0 80 20]
# NF_RIX_Hispanic	4930 [ 60   0 100  70   0   0  60 160]
# NF_RAX_AmericanIndian_AlaskaNative	4990 [ 700  880  440 1010  780  860  780  620]
# NF_RBX_Asian	4990 [1490  970  880 1700 1150 1250  780  840]
# NF_RCX_Black_AfricanAmerican	4990 [6520 8240 6860 6710 6020 7190 9990 6650]
# NF_RDX_Hispanic	4990 [17950 18060 18420 19300 17030 18050 18180 16650]
# NF_REX_Hawaiian	4990 [290 240 560 340 310 600 180 480]
# NF_RFX_White	4990 [94810 86970 79000 78380 88140 68610 73170 66000]
# NF_RGX_NR	4990 [56870 56900 62780 56680 64760 56360 63350 58360]
# NF_RHX_Multi	4990 [ 90  20 160  90 100 290   0   0]
# NF_RIX_Hispanic	4990 [ 0 60 60 60  0  0  0 70]
# NF_RAX_AmericanIndian_AlaskaNative	5100 [400 500 470 530 280 380 560 470]
# NF_RBX_Asian	5100 [2010 2360 2110 2220 2400 2150 1950 1910]
# NF_RCX_Black_AfricanAmerican	5100 [8290 8250 7760 7830 8650 8080 8650 8100]
# NF_RDX_Hispanic	5100 [19270 19400 19220 19720 20980 18530 16250 18180]
# NF_REX_Hawaiian	5100 [250 210 330 280 270 280 310 250]
# NF_RFX_White	5100 [54000 52640 49420 47140 46830 40660 40430 39170]
# NF_RGX_NR	5100 [30410 30310 30440 30190 31690 31410 32810 32800]
# NF_RHX_Multi	5100 [ 80 120  50 120  80  60  80  50]
# NF_RIX_Hispanic	5100 [40 70 60 90 50 40 80 70]
# NF_RAX_AmericanIndian_AlaskaNative	5110 [ 0  0  0 90  0 60 60  0]
# NF_RBX_Asian	5110 [210  60  90 120 120  90 120  90]
# NF_RCX_Black_AfricanAmerican	5110 [690 840 420 390 510 510 360 780]
# NF_RDX_Hispanic	5110 [1410 1680 1050 1080 1230 1470 1320 1290]
# NF_REX_Hawaiian	5110 [0 0 0 0 0 0 0 0]
# NF_RFX_White	5110 [7020 4350 3810 4320 4950 5460 5550 3600]
# NF_RGX_NR	5110 [2790 2100 3030 2580 1980 2130 2040 1860]
# NF_RHX_Multi	5110 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5110 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5120 [150 210 200 320 160  60 210   0]
# NF_RBX_Asian	5120 [ 860  990  760  930  890 1100  700  800]
# NF_RCX_Black_AfricanAmerican	5120 [2390 2940 2540 2510 3120 3480 3070 3290]
# NF_RDX_Hispanic	5120 [7030 5220 5700 6160 7460 6950 5760 6640]
# NF_REX_Hawaiian	5120 [ 60  60 120 150  60   0 130  90]
# NF_RFX_White	5120 [23480 20170 20310 20330 19160 17130 16730 15020]
# NF_RGX_NR	5120 [12650 13610 16400 15560 15860 16030 16920 16340]
# NF_RHX_Multi	5120 [ 0 80  0  0 60  0  0 60]
# NF_RIX_Hispanic	5120 [ 0  0  0  0  0  0  0 60]
# NF_RAX_AmericanIndian_AlaskaNative	5130 [ 60 210  70  70 120   0  70  40]
# NF_RBX_Asian	5130 [ 870  710  830  760  740  590  590 1040]
# NF_RCX_Black_AfricanAmerican	5130 [3540 2000 1950 2770 2690 2200 2210 2810]
# NF_RDX_Hispanic	5130 [6900 5590 5670 7630 7540 5610 5160 7040]
# NF_REX_Hawaiian	5130 [ 20  60  70 130  20 120 100 100]
# NF_RFX_White	5130 [8510 8840 6670 7420 6810 6120 6810 5310]
# NF_RGX_NR	5130 [10380 10780 11790 10970 10860 11790 12080 11460]
# NF_RHX_Multi	5130 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5130 [ 0  0  0  0  0  0  0 40]
# NF_RAX_AmericanIndian_AlaskaNative	5140 [190 110 170  90 140 100 120 220]
# NF_RBX_Asian	5140 [ 560  970  770 1030  470  980  560  530]
# NF_RCX_Black_AfricanAmerican	5140 [3040 2890 2910 3210 3170 2590 2810 2800]
# NF_RDX_Hispanic	5140 [6960 6720 7190 7210 6840 6520 5250 5720]
# NF_REX_Hawaiian	5140 [ 30  70  20  30  30  20  30 120]
# NF_RFX_White	5140 [29120 31970 26270 28580 27110 20380 21570 20500]
# NF_RGX_NR	5140 [11920 10320 10970 10000 11070 10840 11290 12290]
# NF_RHX_Multi	5140 [100  50   0  20  20  20  30   0]
# NF_RIX_Hispanic	5140 [ 0  0  0 20  0  0  0  0]
# NF_RAX_AmericanIndian_AlaskaNative	5141 [160 150  60  80 100 130 140 230]
# NF_RBX_Asian	5141 [340 460 470 390 220 270 240 370]
# NF_RCX_Black_AfricanAmerican	5141 [1630 2130 1850 1330 1770 1570 2020 1840]
# NF_RDX_Hispanic	5141 [3960 4160 4910 3930 4580 5630 3890 3600]
# NF_REX_Hawaiian	5141 [40  0  0  0  0  0  0 80]
# NF_RFX_White	5141 [16870 16530 14580 15490 15240 11690 11560 13740]
# NF_RGX_NR	5141 [6350 7830 7660 6120 7560 6430 6660 8400]
# NF_RHX_Multi	5141 [ 0 30  0  0  0 20 20  0]
# NF_RIX_Hispanic	5141 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5151 [40  0  0  0  0  0  0 60]
# NF_RBX_Asian	5151 [ 60 160  80 200 120 200 130 260]
# NF_RCX_Black_AfricanAmerican	5151 [320 380 330 290 540 180 500 360]
# NF_RDX_Hispanic	5151 [1260 1040  750 1000  930 1170 1080 1010]
# NF_REX_Hawaiian	5151 [0 0 0 0 0 0 0 0]
# NF_RFX_White	5151 [3510 3810 2960 3510 3120 2610 2190 3210]
# NF_RGX_NR	5151 [1380 1170 1040 1330 1110 1440 1670 1550]
# NF_RHX_Multi	5151 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5151 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5160 [ 70   0  60   0   0  60 100  20]
# NF_RBX_Asian	5160 [390 630 560 250 580 350 700 430]
# NF_RCX_Black_AfricanAmerican	5160 [1480 1150 1340 1820 1210 1170 1160 1820]
# NF_RDX_Hispanic	5160 [3730 3930 4190 3880 4390 3320 3420 3190]
# NF_REX_Hawaiian	5160 [ 60   0  90   0   0 100  50  30]
# NF_RFX_White	5160 [5650 5900 6090 5480 3810 3850 3400 4000]
# NF_RGX_NR	5160 [4230 3890 3400 3700 5330 4610 3560 3150]
# NF_RHX_Multi	5160 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5160 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5170 [  0   0  20 180   0   0 210 360]
# NF_RBX_Asian	5170 [  0  20   0  80 150  80   0   0]
# NF_RCX_Black_AfricanAmerican	5170 [720 520 290 700 310 600 490 360]
# NF_RDX_Hispanic	5170 [1330 1720 2120 2250 1550 1800 1420 1790]
# NF_REX_Hawaiian	5170 [0 0 0 0 0 0 0 0]
# NF_RFX_White	5170 [4100 4730 5200 4890 6090 3440 3800 5290]
# NF_RGX_NR	5170 [2120 1800 1210 1840 1420 2530 1600 2360]
# NF_RHX_Multi	5170 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5170 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5180 [  0   0  70 180   0  60   0   0]
# NF_RBX_Asian	5180 [ 50  20 130   0  40  20  20   0]
# NF_RCX_Black_AfricanAmerican	5180 [230 330 290 490 470 290 800 510]
# NF_RDX_Hispanic	5180 [ 330  810 2250  610 2350  210  470  690]
# NF_REX_Hawaiian	5180 [60  0  0  0  0  0  0  0]
# NF_RFX_White	5180 [5240 5210 9380 3700 4550 4240 4980 5460]
# NF_RGX_NR	5180 [3490 3630 4270 6180 4170 2900 3680 2990]
# NF_RHX_Multi	5180 [ 0  0  0 90  0  0  0  0]
# NF_RIX_Hispanic	5180 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5190 [120 230 170 150  60 230 150 110]
# NF_RBX_Asian	5190 [1180 1220 1070 1110 2030 1040 1100  860]
# NF_RCX_Black_AfricanAmerican	5190 [4670 5240 4870 4610 5200 5250 5290 4160]
# NF_RDX_Hispanic	5190 [11060 11960 10850 11270 12180  9730  8760  9870]
# NF_REX_Hawaiian	5190 [150  90 140 100 170 190 110  70]
# NF_RFX_White	5190 [26740 24850 23800 22240 22690 20550 19680 18890]
# NF_RGX_NR	5190 [16120 15990 14910 15380 18090 15750 18060 17170]
# NF_RHX_Multi	5190 [20 30 20 60 30 20 20  0]
# NF_RIX_Hispanic	5190 [20 40 50 60 30 20 30 20]
# NF_RAX_AmericanIndian_AlaskaNative	5191 [190 390 250 250  90 210 270 180]
# NF_RBX_Asian	5191 [1210 1430 1170 1490 1470 1370 1360  960]
# NF_RCX_Black_AfricanAmerican	5191 [5800 5880 5970 4860 6420 6040 6720 5150]
# NF_RDX_Hispanic	5191 [13470 14630 12400 13510 13220 12640 11670 13010]
# NF_REX_Hawaiian	5191 [160 130 200 140 280 220 200 120]
# NF_RFX_White	5191 [30490 30420 27950 23530 25690 25300 23620 21030]
# NF_RGX_NR	5191 [19130 18930 16030 16120 16970 19010 19990 19690]
# NF_RHX_Multi	5191 [ 0 60 40 40 60 40 20  0]
# NF_RIX_Hispanic	5191 [ 0 50 60 60 40  0 20  0]
# NF_RAX_AmericanIndian_AlaskaNative	5300 [ 520  800 1130  550  480  700  380  330]
# NF_RBX_Asian	5300 [1470 1210 1250 1470 1910 1780 1750 1650]
# NF_RCX_Black_AfricanAmerican	5300 [17610 16250 16870 18180 20220 20150 17100 18480]
# NF_RDX_Hispanic	5300 [20320 22240 20420 21460 22770 23570 20380 20520]
# NF_REX_Hawaiian	5300 [620 710 470 850 520 710 570 590]
# NF_RFX_White	5300 [76880 73220 70940 78210 71140 65550 62890 59030]
# NF_RGX_NR	5300 [ 77490  87280  81260  82100  83630  86810  92190 102170]
# NF_RHX_Multi	5300 [130 110 280 150 470 320 120 120]
# NF_RIX_Hispanic	5300 [100 130 100 220 110 160 430 310]
# NF_RAX_AmericanIndian_AlaskaNative	5310 [ 0  0 40 20  0  0  0  0]
# NF_RBX_Asian	5310 [ 20   0 110  30  70  20 100  50]
# NF_RCX_Black_AfricanAmerican	5310 [170 410 220 230 420 170 210 240]
# NF_RDX_Hispanic	5310 [390 270 470 430 670 480 440 150]
# NF_REX_Hawaiian	5310 [  0   0   0 110   0   0  20   0]
# NF_RFX_White	5310 [1720 1710 1520 1650 1520  970  850 1170]
# NF_RGX_NR	5310 [1340 1500 1670 1460 2160 1460 1620 1430]
# NF_RHX_Multi	5310 [ 0  0 20  0  0  0  0 20]
# NF_RIX_Hispanic	5310 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5320 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	5320 [  0 120   0   0   0  90   0 210]
# NF_RCX_Black_AfricanAmerican	5320 [150   0   0  90  60 180  60 250]
# NF_RDX_Hispanic	5320 [160   0 270 930 100  70   0   0]
# NF_REX_Hawaiian	5320 [  0  60 150   0   0 120   0  90]
# NF_RFX_White	5320 [1560 1080 2240  970  390  780  520  840]
# NF_RGX_NR	5320 [12230 14480 12440 15700 13720 13790 16020 15300]
# NF_RHX_Multi	5320 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5320 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5330 [ 650 1320  660  880  800  800  330  420]
# NF_RBX_Asian	5330 [ 910  640 1180 1530 1770 1940 1700 1470]
# NF_RCX_Black_AfricanAmerican	5330 [20630 18340 21720 23160 26610 25430 23330 25030]
# NF_RDX_Hispanic	5330 [18480 20720 19900 24470 23910 23430 23690 22260]
# NF_REX_Hawaiian	5330 [480 520 510 700 610 660 630 580]
# NF_RFX_White	5330 [116460 107220 112280 128890 115670 101140 101870  91590]
# NF_RGX_NR	5330 [104670 108590 108460 108190 102770 109110 108420 118680]
# NF_RHX_Multi	5330 [180  60 500 200 140 380 110  90]
# NF_RIX_Hispanic	5330 [  0 280 190 380  80 350 150 520]
# NF_RAX_AmericanIndian_AlaskaNative	5340 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	5340 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	5340 [330   0 100   0 710  20   0  20]
# NF_RDX_Hispanic	5340 [ 0 70  0  0  0  0  0  0]
# NF_REX_Hawaiian	5340 [0 0 0 0 0 0 0 0]
# NF_RFX_White	5340 [170 160  50 420  70   0   0 130]
# NF_RGX_NR	5340 [4510 5410 6120 7430 5510 4570 6110 7540]
# NF_RHX_Multi	5340 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5340 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5350 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	5350 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	5350 [180  20  60   0 110  60   0 100]
# NF_RDX_Hispanic	5350 [  0   0   0  60  20   0   0 180]
# NF_REX_Hawaiian	5350 [20  0  0  0  0  0  0  0]
# NF_RFX_White	5350 [1940 1430 1010 1320 1340 1070 1410 1600]
# NF_RGX_NR	5350 [1200 1210 1080 1200  810 1660 1080 1470]
# NF_RHX_Multi	5350 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5350 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5360 [ 0  0  0  0 20  0  0  0]
# NF_RBX_Asian	5360 [100   0  70 100  70 180  20  70]
# NF_RCX_Black_AfricanAmerican	5360 [650 960 390 850 660 440 440 630]
# NF_RDX_Hispanic	5360 [580 960 380 670 730 940 700 810]
# NF_REX_Hawaiian	5360 [ 0 20 30 30 30  0 20  0]
# NF_RFX_White	5360 [3210 3120 3290 3330 2270 2250 2390 1330]
# NF_RGX_NR	5360 [6990 7650 4150 4910 4590 3340 3540 4450]
# NF_RHX_Multi	5360 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5360 [ 0  0  0  0 60  0  0  0]
# NF_RAX_AmericanIndian_AlaskaNative	5370 [ 730  890 2330  530  380 1150  650  400]
# NF_RBX_Asian	5370 [2740 2500 1800 2160 3130 2690 2760 2640]
# NF_RCX_Black_AfricanAmerican	5370 [21070 20900 20460 21900 23830 25680 22140 23120]
# NF_RDX_Hispanic	5370 [37280 41050 36380 34100 38120 41320 33160 36010]
# NF_REX_Hawaiian	5370 [1020 1040  500 1180  640  820  830  740]
# NF_RFX_White	5370 [90380 89810 78710 83080 78360 76730 71320 68870]
# NF_RGX_NR	5370 [ 82620 100320  90190  87100  97970 107080 117570 136980]
# NF_RHX_Multi	5370 [ 150  180  210  150 1210  210  170  180]
# NF_RIX_Hispanic	5370 [ 250   20   70  150  140  110 1030  120]
# NF_RAX_AmericanIndian_AlaskaNative	5371 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	5371 [ 0 60  0  0  0  0  0  0]
# NF_RCX_Black_AfricanAmerican	5371 [300 320 460 140 100 160   0 120]
# NF_RDX_Hispanic	5371 [480 700 520 520 560 560 140 140]
# NF_REX_Hawaiian	5371 [0 0 0 0 0 0 0 0]
# NF_RFX_White	5371 [ 580 1360 1400  860  360  520  500  660]
# NF_RGX_NR	5371 [ 520 1020  960  940  600  740  660  520]
# NF_RHX_Multi	5371 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5371 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5500 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	5500 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	5500 [0 0 0 0 0 0 0 0]
# NF_RDX_Hispanic	5500 [0 0 0 0 0 0 0 0]
# NF_REX_Hawaiian	5500 [0 0 0 0 0 0 0 0]
# NF_RFX_White	5500 [0 0 0 0 0 0 0 0]
# NF_RGX_NR	5500 [0 0 0 0 0 0 0 0]
# NF_RHX_Multi	5500 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5500 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5510 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	5510 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	5510 [0 0 0 0 0 0 0 0]
# NF_RDX_Hispanic	5510 [0 0 0 0 0 0 0 0]
# NF_REX_Hawaiian	5510 [0 0 0 0 0 0 0 0]
# NF_RFX_White	5510 [0 0 0 0 0 0 0 0]
# NF_RGX_NR	5510 [0 0 0 0 0 0 0 0]
# NF_RHX_Multi	5510 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5510 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5520 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	5520 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	5520 [0 0 0 0 0 0 0 0]
# NF_RDX_Hispanic	5520 [0 0 0 0 0 0 0 0]
# NF_REX_Hawaiian	5520 [0 0 0 0 0 0 0 0]
# NF_RFX_White	5520 [0 0 0 0 0 0 0 0]
# NF_RGX_NR	5520 [0 0 0 0 0 0 0 0]
# NF_RHX_Multi	5520 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5520 [0 0 0 0 0 0 0 0]
# NF_RAX_AmericanIndian_AlaskaNative	5530 [0 0 0 0 0 0 0 0]
# NF_RBX_Asian	5530 [0 0 0 0 0 0 0 0]
# NF_RCX_Black_AfricanAmerican	5530 [0 0 0 0 0 0 0 0]
# NF_RDX_Hispanic	5530 [0 0 0 0 0 0 0 0]
# NF_REX_Hawaiian	5530 [0 0 0 0 0 0 0 0]
# NF_RFX_White	5530 [0 0 0 0 0 0 0 0]
# NF_RGX_NR	5530 [0 0 0 0 0 0 0 0]
# NF_RHX_Multi	5530 [0 0 0 0 0 0 0 0]
# NF_RIX_Hispanic	5530 [0 0 0 0 0 0 0 0]

# %% [markdown]
# ## SOC code that were not found in the data set

# %%
print(no_genericDB_data_dict.keys())
# Out:
# dict_keys(['111010', '111011', '111030', '111031', '112010', '112011', '112022', '112030', '112032', '112033', '113010', '113012', '113013', '113020', '113021', '113030', '113031', '113050', '113051', '113060', '113061', '113070', '113071', '113110', '113111', '113120', '113121', '113130', '113131', '119010', '119013', '119020', '119021', '119031', '119032', '119039', '119040', '119041', '119070', '119071', '119072', '119080', '119081', '119120', '119121', '119130', '119131', '119140', '119141', '119150', '119151', '119160', '119161', '119170', '119171', '119179', '119033', '112021', '111020', '111021', '112000', '112020', '119030', '119190', '119199', '113000', '119110', '119111', '111000', '119050', '119051', '131010', '131011', '131020', '131021', '131022', '131023', '131030', '131031', '131032', '131040', '131041', '131050', '131051', '131074', '131075', '131080', '131081', '131082', '131110', '131111', '131120', '131121', '131130', '131131', '131140', '131141', '131150', '131151', '131160', '131161', '131190', '131199', '132000', '132010', '132011', '132020', '132022', '132023', '132030', '132031', '132040', '132041', '132050', '132051', '132052', '132053', '132054', '132060', '132061', '132070', '132071', '132072', '132080', '132081', '132082', '132090', '132099', '131070', '131071', '130000', '131000', '150000', '151200', '151210', '151211', '151212', '151220', '151221', '151230', '151231', '151232', '151240', '151241', '151242', '151243', '151244', '151250', '151251', '151252', '151253', '151254', '151255', '151290', '151299', '152000', '152010', '152011', '152020', '152021', '152030', '152031', '152040', '152041', '152050', '152051', '152090', '152099', '171000', '171010', '171011', '171012', '171020', '171021', '171022', '172000', '172010', '172011', '172020', '172021', '172030', '172031', '172040', '172041', '172050', '172051', '172060', '172061', '172070', '172071', '172072', '172080', '172081', '172110', '172111', '172112', '172120', '172121', '172130', '172131', '172140', '172141', '172150', '172151', '172160', '172161', '172170', '172171', '172190', '172199', '173010', '173011', '173012', '173013', '173019', '173021', '173022', '173024', '173025', '173026', '173027', '173028', '173029', '173030', '173031', '170000', '173000', '173020', '173023', '190000', '191000', '191010', '191011', '191012', '191013', '191020', '191021', '191022', '191023', '191029', '191030', '191031', '191032', '191040', '191041', '191042', '191090', '191099', '192000', '192010', '192011', '192012', '192020', '192021', '192030', '192031', '192032', '192040', '192041', '192042', '192043', '192090', '192099', '193000', '193010', '193011', '193020', '193022', '193030', '193032', '193033', '193034', '193039', '193040', '193041', '193050', '193051', '193090', '193091', '193092', '193093', '193094', '193099', '194000', '194010', '194012', '194013', '194020', '194021', '194030', '194031', '194040', '194042', '194043', '194044', '194050', '194051', '194060', '194061', '194070', '194071', '194090', '194092', '194099', '195000', '195010', '195011', '195012', '211011', '211013', '211015', '211022', '211023', '211091', '211093', '211094', '211099', '212000', '212010', '212011', '212020', '212021', '212090', '212099', '211019', '211021', '211092', '211010', '211012', '211014', '211029', '211020', '211090', '231000', '231010', '231011', '231012', '231020', '231021', '231022', '231023', '232000', '232010', '232011', '232090', '232093', '232099', '230000', '251010', '251011', '251020', '251021', '251022', '251030', '251031', '251032', '251040', '251041', '251042', '251043', '251050', '251051', '251052', '251053', '251054', '251060', '251061', '251062', '251063', '251064', '251065', '251066', '251067', '251069', '251070', '251071', '251072', '251080', '251081', '251082', '251110', '251111', '251112', '251113', '251120', '251121', '251122', '251123', '251124', '251125', '251126', '251192', '251193', '251194', '252012', '252022', '252023', '252032', '252050', ...
