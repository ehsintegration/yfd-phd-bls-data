# %%
import os

try:
    os.mkdir("../PLOTS/NF_BOX_LOS")
except:
    print("NF_BOX_LOS dir exists.")

#For testing, leave commented
swivel = 1

# F ORDER
#wivel_order = [2, 1, 7, 3, 16, 6, 12, 9, 10, 4, 5, 15, 8, 14, 20, 0, 22, 13, 19, 11, 18, 21, 17]

# NF ORDER
swivel_order = [22, 2, 6, 1, 3, 0, 4, 8, 7, 15, 5, 14, 16, 9, 12, 18, 20, 17, 13, 10, 19, 21, 11]

desired_file_prefix = "NF_LOS" 

normalize_data=True

lnconvert=False
# Out:
# NF_BOX_LOS dir exists.

# %%
by_year = 1

"""
# All age ranges all years
year = 8
desired_file_prefix = "NF_LOS" 
desired_file_output = "./NF_BOX_LOS/NF_LOS_ALL_"
# %run ./analysis-code-age.ipynb
"""

#
desired_file_prefix = "NF_LOS" 

ltg3m_global_y_soc1 = []
l3mto11m_global_y_soc1 = []
l1yto5y_global_y_soc1 = []
l5yplus_global_y_soc1 = []

for year in range(0,8):       
    desired_file_output = "./NF_BOX_LOS/NF_LOS_" + str(2011+year) + "_"    
    # %run ./box-analysis-code-los.ipynb
# Out:
# SOC_all.csv
# global_y_soc1 not found....defining
# global_soc1_empty not found....defining
# NF_LOS_3to11mos_all.csv
# NF_LOS_5plus_all.csv
# NF_LOS_ltg3mos_all.csv
# NF_LOS_1to5yr_all.csv
# NF_LOS_NR_all.csv
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# NF_LOS_3to11mos
# 00 NF_LOS_3to11mos
# 11 NF_LOS_3to11mos
# 13 NF_LOS_3to11mos
# 15 NF_LOS_3to11mos
# 17 NF_LOS_3to11mos
# 19 NF_LOS_3to11mos
# 21 NF_LOS_3to11mos
# 23 NF_LOS_3to11mos
# 25 NF_LOS_3to11mos
# 27 NF_LOS_3to11mos
# 29 NF_LOS_3to11mos
# 31 NF_LOS_3to11mos
# 33 NF_LOS_3to11mos
# 35 NF_LOS_3to11mos
# 37 NF_LOS_3to11mos
# 39 NF_LOS_3to11mos
# 41 NF_LOS_3to11mos
# 43 NF_LOS_3to11mos
# 45 NF_LOS_3to11mos
# 47 NF_LOS_3to11mos
# 49 NF_LOS_3to11mos
# 51 NF_LOS_3to11mos
# 53 NF_LOS_3to11mos
# 55 NF_LOS_3to11mos
# Suggested swivel order
# [22, 6, 2, 3, 1, 0, 8, 4, 7, 5, 15, 16, 9, 14, 11, 18, 12, 17, 13, 20, 19, 21, 10]
# NF_LOS_5plus
# 00 NF_LOS_5plus
# 11 NF_LOS_5plus
# 13 NF_LOS_5plus
# 15 NF_LOS_5plus
# 17 NF_LOS_5plus
# 19 NF_LOS_5plus
# 21 NF_LOS_5plus
# 23 NF_LOS_5plus
# 25 NF_LOS_5plus
# 27 NF_LOS_5plus
# 29 NF_LOS_5plus
# 31 NF_LOS_5plus
# 33 NF_LOS_5plus
# 35 NF_LOS_5plus
# 37 NF_LOS_5plus
# 39 NF_LOS_5plus
# 41 NF_LOS_5plus
# 43 NF_LOS_5plus
# 45 NF_LOS_5plus
# 47 NF_LOS_5plus
# 49 NF_LOS_5plus
# 51 NF_LOS_5plus
# 53 NF_LOS_5plus
# 55 NF_LOS_5plus
# Suggested swivel order
# [22, 2, 1, 3, 6, 0, 4, 8, 15, 14, 7, 16, 5, 12, 17, 9, 18, 20, 10, 13, 21, 19, 11]
# NF_LOS_ltg3mos
# 00 NF_LOS_ltg3mos
# 11 NF_LOS_ltg3mos
# 13 NF_LOS_ltg3mos
# 15 NF_LOS_ltg3mos
# 17 NF_LOS_ltg3mos
# 19 NF_LOS_ltg3mos
# 21 NF_LOS_ltg3mos
# 23 NF_LOS_ltg3mos
# 25 NF_LOS_ltg3mos
# 27 NF_LOS_ltg3mos
# 29 NF_LOS_ltg3mos
# 31 NF_LOS_ltg3mos
# 33 NF_LOS_ltg3mos
# 35 NF_LOS_ltg3mos
# 37 NF_LOS_ltg3mos
# 39 NF_LOS_ltg3mos
# 41 NF_LOS_ltg3mos
# 43 NF_LOS_ltg3mos
# 45 NF_LOS_ltg3mos
# 47 NF_LOS_ltg3mos
# 49 NF_LOS_ltg3mos
# 51 NF_LOS_ltg3mos
# 53 NF_LOS_ltg3mos
# 55 NF_LOS_ltg3mos
# Suggested swivel order
# [22, 6, 2, 0, 3, 1, 4, 7, 5, 9, 16, 8, 15, 14, 11, 12, 13, 19, 20, 18, 10, 21, 17]
# NF_LOS_1to5yr
# 00 NF_LOS_1to5yr
# 11 NF_LOS_1to5yr
# 13 NF_LOS_1to5yr
# 15 NF_LOS_1to5yr
# 17 NF_LOS_1to5yr
# 19 NF_LOS_1to5yr
# 21 NF_LOS_1to5yr
# 23 NF_LOS_1to5yr
# 25 NF_LOS_1to5yr
# 27 NF_LOS_1to5yr
# 29 NF_LOS_1to5yr
# 31 NF_LOS_1to5yr
# 33 NF_LOS_1to5yr
# 35 NF_LOS_1to5yr
# 37 NF_LOS_1to5yr
# 39 NF_LOS_1to5yr
# 41 NF_LOS_1to5yr
# 43 NF_LOS_1to5yr
# 45 NF_LOS_1to5yr
# 47 NF_LOS_1to5yr
# 49 NF_LOS_1to5yr
# 51 NF_LOS_1to5yr
# 53 NF_LOS_1to5yr
# 55 NF_LOS_1to5yr
# Suggested swivel order
# [22, 6, 2, 1, 3, 0, 8, 4, 7, 15, 16, 5, 14, 9, 18, 12, 20, 17, 13, 21, 19, 11, 10]
# NF_LOS_NR
# 00 NF_LOS_NR
# 11 NF_LOS_NR
# 13 NF_LOS_NR
# 15 NF_LOS_NR
# 17 NF_LOS_NR
# 19 NF_LOS_NR
# 21 NF_LOS_NR
# 23 NF_LOS_NR
# 25 NF_LOS_NR
# 27 NF_LOS_NR
# 29 NF_LOS_NR
# 31 NF_LOS_NR
# 33 NF_LOS_NR
# 35 NF_LOS_NR
# 37 NF_LOS_NR
# 39 NF_LOS_NR
# 41 NF_LOS_NR
# 43 NF_LOS_NR
# 45 NF_LOS_NR
# 47 NF_LOS_NR
# 49 NF_LOS_NR
# 51 NF_LOS_NR
# 53 NF_LOS_NR
# 55 NF_LOS_NR
# Suggested swivel order
# [6, 22, 2, 8, 4, 0, 1, 3, 15, 14, 7, 9, 16, 5, 20, 18, 12, 13, 19, 10, 17, 21, 11]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_LOS_3to11mos_all.csv
# NF_LOS_5plus_all.csv
# NF_LOS_ltg3mos_all.csv
# NF_LOS_1to5yr_all.csv
# NF_LOS_NR_all.csv
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# NF_LOS_3to11mos
# 00 NF_LOS_3to11mos
# 11 NF_LOS_3to11mos
# 13 NF_LOS_3to11mos
# 15 NF_LOS_3to11mos
# 17 NF_LOS_3to11mos
# 19 NF_LOS_3to11mos
# 21 NF_LOS_3to11mos
# 23 NF_LOS_3to11mos
# 25 NF_LOS_3to11mos
# 27 NF_LOS_3to11mos
# 29 NF_LOS_3to11mos
# 31 NF_LOS_3to11mos
# 33 NF_LOS_3to11mos
# 35 NF_LOS_3to11mos
# 37 NF_LOS_3to11mos
# 39 NF_LOS_3to11mos
# 41 NF_LOS_3to11mos
# 43 NF_LOS_3to11mos
# 45 NF_LOS_3to11mos
# 47 NF_LOS_3to11mos
# 49 NF_LOS_3to11mos
# 51 NF_LOS_3to11mos
# 53 NF_LOS_3to11mos
# 55 NF_LOS_3to11mos
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 4, 8, 7, 16, 5, 15, 9, 14, 11, 18, 12, 13, 20, 19, 17, 21, 10]
# NF_LOS_5plus
# 00 NF_LOS_5plus
# 11 NF_LOS_5plus
# 13 NF_LOS_5plus
# 15 NF_LOS_5plus
# 17 NF_LOS_5plus
# 19 NF_LOS_5plus
# 21 NF_LOS_5plus
# 23 NF_LOS_5plus
# 25 NF_LOS_5plus
# 27 NF_LOS_5plus
# 29 NF_LOS_5plus
# 31 NF_LOS_5plus
# 33 NF_LOS_5plus
# 35 NF_LOS_5plus
# 37 NF_LOS_5plus
# 39 NF_LOS_5plus
# 41 NF_LOS_5plus
# 43 NF_LOS_5plus
# 45 NF_LOS_5plus
# 47 NF_LOS_5plus
# 49 NF_LOS_5plus
# 51 NF_LOS_5plus
# 53 NF_LOS_5plus
# 55 NF_LOS_5plus
# Suggested swivel order
# [22, 6, 2, 8, 1, 3, 0, 4, 15, 14, 16, 7, 5, 12, 17, 9, 18, 20, 13, 10, 21, 19, 11]
# NF_LOS_ltg3mos
# 00 NF_LOS_ltg3mos
# 11 NF_LOS_ltg3mos
# 13 NF_LOS_ltg3mos
# 15 NF_LOS_ltg3mos
# 17 NF_LOS_ltg3mos
# 19 NF_LOS_ltg3mos
# 21 NF_LOS_ltg3mos
# 23 NF_LOS_ltg3mos
# 25 NF_LOS_ltg3mos
# 27 NF_LOS_ltg3mos
# 29 NF_LOS_ltg3mos
# 31 NF_LOS_ltg3mos
# 33 NF_LOS_ltg3mos
# 35 NF_LOS_ltg3mos
# 37 NF_LOS_ltg3mos
# 39 NF_LOS_ltg3mos
# 41 NF_LOS_ltg3mos
# 43 NF_LOS_ltg3mos
# 45 NF_LOS_ltg3mos
# 47 NF_LOS_ltg3mos
# 49 NF_LOS_ltg3mos
# 51 NF_LOS_ltg3mos
# 53 NF_LOS_ltg3mos
# 55 NF_LOS_ltg3mos
# Suggested swivel order
# [22, 2, 0, 1, 6, 3, 4, 7, 9, 8, 16, 5, 15, 14, 11, 12, 19, 18, 13, 10, 20, 21, 17]
# NF_LOS_1to5yr
# 00 NF_LOS_1to5yr
# 11 NF_LOS_1to5yr
# 13 NF_LOS_1to5yr
# 15 NF_LOS_1to5yr
# 17 NF_LOS_1to5yr
# 19 NF_LOS_1to5yr
# 21 NF_LOS_1to5yr
# 23 NF_LOS_1to5yr
# 25 NF_LOS_1to5yr
# 27 NF_LOS_1to5yr
# 29 NF_LOS_1to5yr
# 31 NF_LOS_1to5yr
# 33 NF_LOS_1to5yr
# 35 NF_LOS_1to5yr
# 37 NF_LOS_1to5yr
# 39 NF_LOS_1to5yr
# 41 NF_LOS_1to5yr
# 43 NF_LOS_1to5yr
# 45 NF_LOS_1to5yr
# 47 NF_LOS_1to5yr
# 49 NF_LOS_1to5yr
# 51 NF_LOS_1to5yr
# 53 NF_LOS_1to5yr
# 55 NF_LOS_1to5yr
# Suggested swivel order
# [22, 2, 6, 1, 3, 0, 4, 8, 7, 15, 16, 14, 5, 9, 18, 12, 20, 17, 13, 21, 11, 19, 10]
# NF_LOS_NR
# 00 NF_LOS_NR
# 11 NF_LOS_NR
# 13 NF_LOS_NR
# 15 NF_LOS_NR
# 17 NF_LOS_NR
# 19 NF_LOS_NR
# 21 NF_LOS_NR
# 23 NF_LOS_NR
# 25 NF_LOS_NR
# 27 NF_LOS_NR
# 29 NF_LOS_NR
# 31 NF_LOS_NR
# 33 NF_LOS_NR
# 35 NF_LOS_NR
# 37 NF_LOS_NR
# 39 NF_LOS_NR
# 41 NF_LOS_NR
# 43 NF_LOS_NR
# 45 NF_LOS_NR
# 47 NF_LOS_NR
# 49 NF_LOS_NR
# 51 NF_LOS_NR
# 53 NF_LOS_NR
# 55 NF_LOS_NR
# Suggested swivel order
# [6, 22, 2, 3, 0, 8, 4, 1, 7, 14, 15, 5, 16, 20, 9, 18, 12, 13, 19, 17, 10, 21, 11]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_LOS_3to11mos_all.csv
# NF_LOS_5plus_all.csv
# NF_LOS_ltg3mos_all.csv
# NF_LOS_1to5yr_all.csv
# NF_LOS_NR_all.csv
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# NF_LOS_3to11mos
# 00 NF_LOS_3to11mos
# 11 NF_LOS_3to11mos
# 13 NF_LOS_3to11mos
# 15 NF_LOS_3to11mos
# 17 NF_LOS_3to11mos
# 19 NF_LOS_3to11mos
# 21 NF_LOS_3to11mos
# 23 NF_LOS_3to11mos
# 25 NF_LOS_3to11mos
# 27 NF_LOS_3to11mos
# 29 NF_LOS_3to11mos
# 31 NF_LOS_3to11mos
# 33 NF_LOS_3to11mos
# 35 NF_LOS_3to11mos
# 37 NF_LOS_3to11mos
# 39 NF_LOS_3to11mos
# 41 NF_LOS_3to11mos
# 43 NF_LOS_3to11mos
# 45 NF_LOS_3to11mos
# 47 NF_LOS_3to11mos
# 49 NF_LOS_3to11mos
# 51 NF_LOS_3to11mos
# 53 NF_LOS_3to11mos
# 55 NF_LOS_3to11mos
# Suggested swivel order
# [22, 2, 3, 6, 1, 4, 0, 7, 16, 15, 8, 5, 9, 14, 11, 18, 13, 12, 20, 19, 17, 21, 10]
# NF_LOS_5plus
# 00 NF_LOS_5plus
# 11 NF_LOS_5plus
# 13 NF_LOS_5plus
# 15 NF_LOS_5plus
# 17 NF_LOS_5plus
# 19 NF_LOS_5plus
# 21 NF_LOS_5plus
# 23 NF_LOS_5plus
# 25 NF_LOS_5plus
# 27 NF_LOS_5plus
# 29 NF_LOS_5plus
# 31 NF_LOS_5plus
# 33 NF_LOS_5plus
# 35 NF_LOS_5plus
# 37 NF_LOS_5plus
# 39 NF_LOS_5plus
# 41 NF_LOS_5plus
# 43 NF_LOS_5plus
# 45 NF_LOS_5plus
# 47 NF_LOS_5plus
# 49 NF_LOS_5plus
# 51 NF_LOS_5plus
# 53 NF_LOS_5plus
# 55 NF_LOS_5plus
# Suggested swivel order
# [22, 2, 6, 1, 8, 3, 4, 0, 14, 15, 16, 7, 5, 12, 17, 9, 18, 20, 13, 10, 21, 19, 11]
# NF_LOS_ltg3mos
# 00 NF_LOS_ltg3mos
# 11 NF_LOS_ltg3mos
# 13 NF_LOS_ltg3mos
# 15 NF_LOS_ltg3mos
# 17 NF_LOS_ltg3mos
# 19 NF_LOS_ltg3mos
# 21 NF_LOS_ltg3mos
# 23 NF_LOS_ltg3mos
# 25 NF_LOS_ltg3mos
# 27 NF_LOS_ltg3mos
# 29 NF_LOS_ltg3mos
# 31 NF_LOS_ltg3mos
# 33 NF_LOS_ltg3mos
# 35 NF_LOS_ltg3mos
# 37 NF_LOS_ltg3mos
# 39 NF_LOS_ltg3mos
# 41 NF_LOS_ltg3mos
# 43 NF_LOS_ltg3mos
# 45 NF_LOS_ltg3mos
# 47 NF_LOS_ltg3mos
# 49 NF_LOS_ltg3mos
# 51 NF_LOS_ltg3mos
# 53 NF_LOS_ltg3mos
# 55 NF_LOS_ltg3mos
# Suggested swivel order
# [22, 2, 6, 0, 3, 4, 1, 7, 8, 9, 16, 5, 15, 14, 11, 19, 13, 20, 12, 10, 18, 21, 17]
# NF_LOS_1to5yr
# 00 NF_LOS_1to5yr
# 11 NF_LOS_1to5yr
# 13 NF_LOS_1to5yr
# 15 NF_LOS_1to5yr
# 17 NF_LOS_1to5yr
# 19 NF_LOS_1to5yr
# 21 NF_LOS_1to5yr
# 23 NF_LOS_1to5yr
# 25 NF_LOS_1to5yr
# 27 NF_LOS_1to5yr
# 29 NF_LOS_1to5yr
# 31 NF_LOS_1to5yr
# 33 NF_LOS_1to5yr
# 35 NF_LOS_1to5yr
# 37 NF_LOS_1to5yr
# 39 NF_LOS_1to5yr
# 41 NF_LOS_1to5yr
# 43 NF_LOS_1to5yr
# 45 NF_LOS_1to5yr
# 47 NF_LOS_1to5yr
# 49 NF_LOS_1to5yr
# 51 NF_LOS_1to5yr
# 53 NF_LOS_1to5yr
# 55 NF_LOS_1to5yr
# Suggested swivel order
# [22, 6, 2, 3, 1, 0, 4, 7, 8, 16, 15, 5, 14, 9, 18, 12, 20, 17, 13, 11, 21, 19, 10]
# NF_LOS_NR
# 00 NF_LOS_NR
# 11 NF_LOS_NR
# 13 NF_LOS_NR
# 15 NF_LOS_NR
# 17 NF_LOS_NR
# 19 NF_LOS_NR
# 21 NF_LOS_NR
# 23 NF_LOS_NR
# 25 NF_LOS_NR
# 27 NF_LOS_NR
# 29 NF_LOS_NR
# 31 NF_LOS_NR
# 33 NF_LOS_NR
# 35 NF_LOS_NR
# 37 NF_LOS_NR
# 39 NF_LOS_NR
# 41 NF_LOS_NR
# 43 NF_LOS_NR
# 45 NF_LOS_NR
# 47 NF_LOS_NR
# 49 NF_LOS_NR
# 51 NF_LOS_NR
# 53 NF_LOS_NR
# 55 NF_LOS_NR
# Suggested swivel order
# [6, 22, 2, 3, 4, 1, 8, 0, 15, 16, 14, 7, 5, 9, 20, 12, 10, 18, 13, 11, 19, 21, 17]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_LOS_3to11mos_all.csv
# NF_LOS_5plus_all.csv
# NF_LOS_ltg3mos_all.csv
# NF_LOS_1to5yr_all.csv
# NF_LOS_NR_all.csv
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# NF_LOS_3to11mos
# 00 NF_LOS_3to11mos
# 11 NF_LOS_3to11mos
# 13 NF_LOS_3to11mos
# 15 NF_LOS_3to11mos
# 17 NF_LOS_3to11mos
# 19 NF_LOS_3to11mos
# 21 NF_LOS_3to11mos
# 23 NF_LOS_3to11mos
# 25 NF_LOS_3to11mos
# 27 NF_LOS_3to11mos
# 29 NF_LOS_3to11mos
# 31 NF_LOS_3to11mos
# 33 NF_LOS_3to11mos
# 35 NF_LOS_3to11mos
# 37 NF_LOS_3to11mos
# 39 NF_LOS_3to11mos
# 41 NF_LOS_3to11mos
# 43 NF_LOS_3to11mos
# 45 NF_LOS_3to11mos
# 47 NF_LOS_3to11mos
# 49 NF_LOS_3to11mos
# 51 NF_LOS_3to11mos
# 53 NF_LOS_3to11mos
# 55 NF_LOS_3to11mos
# Suggested swivel order
# [22, 6, 2, 0, 3, 1, 8, 7, 4, 16, 15, 5, 9, 14, 11, 18, 12, 20, 13, 17, 19, 10, 21]
# NF_LOS_5plus
# 00 NF_LOS_5plus
# 11 NF_LOS_5plus
# 13 NF_LOS_5plus
# 15 NF_LOS_5plus
# 17 NF_LOS_5plus
# 19 NF_LOS_5plus
# 21 NF_LOS_5plus
# 23 NF_LOS_5plus
# 25 NF_LOS_5plus
# 27 NF_LOS_5plus
# 29 NF_LOS_5plus
# 31 NF_LOS_5plus
# 33 NF_LOS_5plus
# 35 NF_LOS_5plus
# 37 NF_LOS_5plus
# 39 NF_LOS_5plus
# 41 NF_LOS_5plus
# 43 NF_LOS_5plus
# 45 NF_LOS_5plus
# 47 NF_LOS_5plus
# 49 NF_LOS_5plus
# 51 NF_LOS_5plus
# 53 NF_LOS_5plus
# 55 NF_LOS_5plus
# Suggested swivel order
# [22, 2, 3, 6, 8, 1, 0, 4, 15, 14, 16, 7, 12, 5, 17, 9, 18, 20, 13, 10, 21, 19, 11]
# NF_LOS_ltg3mos
# 00 NF_LOS_ltg3mos
# 11 NF_LOS_ltg3mos
# 13 NF_LOS_ltg3mos
# 15 NF_LOS_ltg3mos
# 17 NF_LOS_ltg3mos
# 19 NF_LOS_ltg3mos
# 21 NF_LOS_ltg3mos
# 23 NF_LOS_ltg3mos
# 25 NF_LOS_ltg3mos
# 27 NF_LOS_ltg3mos
# 29 NF_LOS_ltg3mos
# 31 NF_LOS_ltg3mos
# 33 NF_LOS_ltg3mos
# 35 NF_LOS_ltg3mos
# 37 NF_LOS_ltg3mos
# 39 NF_LOS_ltg3mos
# 41 NF_LOS_ltg3mos
# 43 NF_LOS_ltg3mos
# 45 NF_LOS_ltg3mos
# 47 NF_LOS_ltg3mos
# 49 NF_LOS_ltg3mos
# 51 NF_LOS_ltg3mos
# 53 NF_LOS_ltg3mos
# 55 NF_LOS_ltg3mos
# Suggested swivel order
# [6, 22, 2, 1, 0, 3, 4, 7, 5, 9, 8, 15, 16, 14, 11, 19, 12, 13, 20, 18, 10, 21, 17]
# NF_LOS_1to5yr
# 00 NF_LOS_1to5yr
# 11 NF_LOS_1to5yr
# 13 NF_LOS_1to5yr
# 15 NF_LOS_1to5yr
# 17 NF_LOS_1to5yr
# 19 NF_LOS_1to5yr
# 21 NF_LOS_1to5yr
# 23 NF_LOS_1to5yr
# 25 NF_LOS_1to5yr
# 27 NF_LOS_1to5yr
# 29 NF_LOS_1to5yr
# 31 NF_LOS_1to5yr
# 33 NF_LOS_1to5yr
# 35 NF_LOS_1to5yr
# 37 NF_LOS_1to5yr
# 39 NF_LOS_1to5yr
# 41 NF_LOS_1to5yr
# 43 NF_LOS_1to5yr
# 45 NF_LOS_1to5yr
# 47 NF_LOS_1to5yr
# 49 NF_LOS_1to5yr
# 51 NF_LOS_1to5yr
# 53 NF_LOS_1to5yr
# 55 NF_LOS_1to5yr
# Suggested swivel order
# [22, 6, 2, 1, 3, 0, 4, 8, 7, 15, 16, 5, 14, 9, 12, 18, 17, 20, 13, 11, 19, 21, 10]
# NF_LOS_NR
# 00 NF_LOS_NR
# 11 NF_LOS_NR
# 13 NF_LOS_NR
# 15 NF_LOS_NR
# 17 NF_LOS_NR
# 19 NF_LOS_NR
# 21 NF_LOS_NR
# 23 NF_LOS_NR
# 25 NF_LOS_NR
# 27 NF_LOS_NR
# 29 NF_LOS_NR
# 31 NF_LOS_NR
# 33 NF_LOS_NR
# 35 NF_LOS_NR
# 37 NF_LOS_NR
# 39 NF_LOS_NR
# 41 NF_LOS_NR
# 43 NF_LOS_NR
# 45 NF_LOS_NR
# 47 NF_LOS_NR
# 49 NF_LOS_NR
# 51 NF_LOS_NR
# 53 NF_LOS_NR
# 55 NF_LOS_NR
# Suggested swivel order
# [6, 22, 2, 0, 8, 4, 1, 15, 3, 16, 7, 5, 9, 14, 20, 12, 10, 13, 18, 19, 17, 11, 21]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_LOS_3to11mos_all.csv
# NF_LOS_5plus_all.csv
# NF_LOS_ltg3mos_all.csv
# NF_LOS_1to5yr_all.csv
# NF_LOS_NR_all.csv
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# NF_LOS_3to11mos
# 00 NF_LOS_3to11mos
# 11 NF_LOS_3to11mos
# 13 NF_LOS_3to11mos
# 15 NF_LOS_3to11mos
# 17 NF_LOS_3to11mos
# 19 NF_LOS_3to11mos
# 21 NF_LOS_3to11mos
# 23 NF_LOS_3to11mos
# 25 NF_LOS_3to11mos
# 27 NF_LOS_3to11mos
# 29 NF_LOS_3to11mos
# 31 NF_LOS_3to11mos
# 33 NF_LOS_3to11mos
# 35 NF_LOS_3to11mos
# 37 NF_LOS_3to11mos
# 39 NF_LOS_3to11mos
# 41 NF_LOS_3to11mos
# 43 NF_LOS_3to11mos
# 45 NF_LOS_3to11mos
# 47 NF_LOS_3to11mos
# 49 NF_LOS_3to11mos
# 51 NF_LOS_3to11mos
# 53 NF_LOS_3to11mos
# 55 NF_LOS_3to11mos
# Suggested swivel order
# [22, 3, 2, 1, 6, 4, 0, 8, 7, 5, 15, 16, 9, 14, 11, 13, 18, 12, 20, 19, 17, 10, 21]
# NF_LOS_5plus
# 00 NF_LOS_5plus
# 11 NF_LOS_5plus
# 13 NF_LOS_5plus
# 15 NF_LOS_5plus
# 17 NF_LOS_5plus
# 19 NF_LOS_5plus
# 21 NF_LOS_5plus
# 23 NF_LOS_5plus
# 25 NF_LOS_5plus
# 27 NF_LOS_5plus
# 29 NF_LOS_5plus
# 31 NF_LOS_5plus
# 33 NF_LOS_5plus
# 35 NF_LOS_5plus
# 37 NF_LOS_5plus
# 39 NF_LOS_5plus
# 41 NF_LOS_5plus
# 43 NF_LOS_5plus
# 45 NF_LOS_5plus
# 47 NF_LOS_5plus
# 49 NF_LOS_5plus
# 51 NF_LOS_5plus
# 53 NF_LOS_5plus
# 55 NF_LOS_5plus
# Suggested swivel order
# [22, 6, 2, 1, 8, 3, 4, 0, 14, 15, 16, 5, 7, 12, 9, 18, 17, 20, 13, 10, 21, 19, 11]
# NF_LOS_ltg3mos
# 00 NF_LOS_ltg3mos
# 11 NF_LOS_ltg3mos
# 13 NF_LOS_ltg3mos
# 15 NF_LOS_ltg3mos
# 17 NF_LOS_ltg3mos
# 19 NF_LOS_ltg3mos
# 21 NF_LOS_ltg3mos
# 23 NF_LOS_ltg3mos
# 25 NF_LOS_ltg3mos
# 27 NF_LOS_ltg3mos
# 29 NF_LOS_ltg3mos
# 31 NF_LOS_ltg3mos
# 33 NF_LOS_ltg3mos
# 35 NF_LOS_ltg3mos
# 37 NF_LOS_ltg3mos
# 39 NF_LOS_ltg3mos
# 41 NF_LOS_ltg3mos
# 43 NF_LOS_ltg3mos
# 45 NF_LOS_ltg3mos
# 47 NF_LOS_ltg3mos
# 49 NF_LOS_ltg3mos
# 51 NF_LOS_ltg3mos
# 53 NF_LOS_ltg3mos
# 55 NF_LOS_ltg3mos
# Suggested swivel order
# [6, 22, 2, 1, 0, 4, 3, 7, 8, 5, 9, 16, 15, 14, 11, 19, 13, 18, 10, 20, 12, 21, 17]
# NF_LOS_1to5yr
# 00 NF_LOS_1to5yr
# 11 NF_LOS_1to5yr
# 13 NF_LOS_1to5yr
# 15 NF_LOS_1to5yr
# 17 NF_LOS_1to5yr
# 19 NF_LOS_1to5yr
# 21 NF_LOS_1to5yr
# 23 NF_LOS_1to5yr
# 25 NF_LOS_1to5yr
# 27 NF_LOS_1to5yr
# 29 NF_LOS_1to5yr
# 31 NF_LOS_1to5yr
# 33 NF_LOS_1to5yr
# 35 NF_LOS_1to5yr
# 37 NF_LOS_1to5yr
# 39 NF_LOS_1to5yr
# 41 NF_LOS_1to5yr
# 43 NF_LOS_1to5yr
# 45 NF_LOS_1to5yr
# 47 NF_LOS_1to5yr
# 49 NF_LOS_1to5yr
# 51 NF_LOS_1to5yr
# 53 NF_LOS_1to5yr
# 55 NF_LOS_1to5yr
# Suggested swivel order
# [22, 2, 6, 1, 3, 0, 4, 8, 7, 15, 16, 5, 14, 9, 18, 12, 20, 17, 13, 10, 11, 21, 19]
# NF_LOS_NR
# 00 NF_LOS_NR
# 11 NF_LOS_NR
# 13 NF_LOS_NR
# 15 NF_LOS_NR
# 17 NF_LOS_NR
# 19 NF_LOS_NR
# 21 NF_LOS_NR
# 23 NF_LOS_NR
# 25 NF_LOS_NR
# 27 NF_LOS_NR
# 29 NF_LOS_NR
# 31 NF_LOS_NR
# 33 NF_LOS_NR
# 35 NF_LOS_NR
# 37 NF_LOS_NR
# 39 NF_LOS_NR
# 41 NF_LOS_NR
# 43 NF_LOS_NR
# 45 NF_LOS_NR
# 47 NF_LOS_NR
# 49 NF_LOS_NR
# 51 NF_LOS_NR
# 53 NF_LOS_NR
# 55 NF_LOS_NR
# Suggested swivel order
# [6, 22, 3, 8, 1, 2, 0, 4, 16, 14, 15, 9, 7, 20, 12, 5, 10, 18, 13, 19, 21, 17, 11]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_LOS_3to11mos_all.csv
# NF_LOS_5plus_all.csv
# NF_LOS_ltg3mos_all.csv
# NF_LOS_1to5yr_all.csv
# NF_LOS_NR_all.csv
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# NF_LOS_3to11mos
# 00 NF_LOS_3to11mos
# 11 NF_LOS_3to11mos
# 13 NF_LOS_3to11mos
# 15 NF_LOS_3to11mos
# 17 NF_LOS_3to11mos
# 19 NF_LOS_3to11mos
# 21 NF_LOS_3to11mos
# 23 NF_LOS_3to11mos
# 25 NF_LOS_3to11mos
# 27 NF_LOS_3to11mos
# 29 NF_LOS_3to11mos
# 31 NF_LOS_3to11mos
# 33 NF_LOS_3to11mos
# 35 NF_LOS_3to11mos
# 37 NF_LOS_3to11mos
# 39 NF_LOS_3to11mos
# 41 NF_LOS_3to11mos
# 43 NF_LOS_3to11mos
# 45 NF_LOS_3to11mos
# 47 NF_LOS_3to11mos
# 49 NF_LOS_3to11mos
# 51 NF_LOS_3to11mos
# 53 NF_LOS_3to11mos
# 55 NF_LOS_3to11mos
# Suggested swivel order
# [22, 2, 0, 3, 1, 6, 4, 8, 7, 15, 16, 9, 5, 14, 11, 18, 20, 12, 13, 17, 19, 10, 21]
# NF_LOS_5plus
# 00 NF_LOS_5plus
# 11 NF_LOS_5plus
# 13 NF_LOS_5plus
# 15 NF_LOS_5plus
# 17 NF_LOS_5plus
# 19 NF_LOS_5plus
# 21 NF_LOS_5plus
# 23 NF_LOS_5plus
# 25 NF_LOS_5plus
# 27 NF_LOS_5plus
# 29 NF_LOS_5plus
# 31 NF_LOS_5plus
# 33 NF_LOS_5plus
# 35 NF_LOS_5plus
# 37 NF_LOS_5plus
# 39 NF_LOS_5plus
# 41 NF_LOS_5plus
# 43 NF_LOS_5plus
# 45 NF_LOS_5plus
# 47 NF_LOS_5plus
# 49 NF_LOS_5plus
# 51 NF_LOS_5plus
# 53 NF_LOS_5plus
# 55 NF_LOS_5plus
# Suggested swivel order
# [22, 2, 6, 1, 3, 0, 8, 4, 15, 14, 16, 7, 5, 12, 17, 9, 18, 20, 13, 10, 21, 19, 11]
# NF_LOS_ltg3mos
# 00 NF_LOS_ltg3mos
# 11 NF_LOS_ltg3mos
# 13 NF_LOS_ltg3mos
# 15 NF_LOS_ltg3mos
# 17 NF_LOS_ltg3mos
# 19 NF_LOS_ltg3mos
# 21 NF_LOS_ltg3mos
# 23 NF_LOS_ltg3mos
# 25 NF_LOS_ltg3mos
# 27 NF_LOS_ltg3mos
# 29 NF_LOS_ltg3mos
# 31 NF_LOS_ltg3mos
# 33 NF_LOS_ltg3mos
# 35 NF_LOS_ltg3mos
# 37 NF_LOS_ltg3mos
# 39 NF_LOS_ltg3mos
# 41 NF_LOS_ltg3mos
# 43 NF_LOS_ltg3mos
# 45 NF_LOS_ltg3mos
# 47 NF_LOS_ltg3mos
# 49 NF_LOS_ltg3mos
# 51 NF_LOS_ltg3mos
# 53 NF_LOS_ltg3mos
# 55 NF_LOS_ltg3mos
# Suggested swivel order
# [22, 2, 6, 1, 3, 0, 4, 7, 8, 5, 9, 16, 15, 14, 11, 19, 13, 20, 12, 10, 18, 21, 17]
# NF_LOS_1to5yr
# 00 NF_LOS_1to5yr
# 11 NF_LOS_1to5yr
# 13 NF_LOS_1to5yr
# 15 NF_LOS_1to5yr
# 17 NF_LOS_1to5yr
# 19 NF_LOS_1to5yr
# 21 NF_LOS_1to5yr
# 23 NF_LOS_1to5yr
# 25 NF_LOS_1to5yr
# 27 NF_LOS_1to5yr
# 29 NF_LOS_1to5yr
# 31 NF_LOS_1to5yr
# 33 NF_LOS_1to5yr
# 35 NF_LOS_1to5yr
# 37 NF_LOS_1to5yr
# 39 NF_LOS_1to5yr
# 41 NF_LOS_1to5yr
# 43 NF_LOS_1to5yr
# 45 NF_LOS_1to5yr
# 47 NF_LOS_1to5yr
# 49 NF_LOS_1to5yr
# 51 NF_LOS_1to5yr
# 53 NF_LOS_1to5yr
# 55 NF_LOS_1to5yr
# Suggested swivel order
# [22, 6, 2, 3, 1, 4, 0, 8, 7, 16, 15, 14, 9, 5, 12, 18, 20, 17, 13, 10, 19, 11, 21]
# NF_LOS_NR
# 00 NF_LOS_NR
# 11 NF_LOS_NR
# 13 NF_LOS_NR
# 15 NF_LOS_NR
# 17 NF_LOS_NR
# 19 NF_LOS_NR
# 21 NF_LOS_NR
# 23 NF_LOS_NR
# 25 NF_LOS_NR
# 27 NF_LOS_NR
# 29 NF_LOS_NR
# 31 NF_LOS_NR
# 33 NF_LOS_NR
# 35 NF_LOS_NR
# 37 NF_LOS_NR
# 39 NF_LOS_NR
# 41 NF_LOS_NR
# 43 NF_LOS_NR
# 45 NF_LOS_NR
# 47 NF_LOS_NR
# 49 NF_LOS_NR
# 51 NF_LOS_NR
# 53 NF_LOS_NR
# 55 NF_LOS_NR
# Suggested swivel order
# [22, 2, 6, 0, 3, 1, 4, 8, 16, 14, 15, 9, 5, 7, 13, 12, 20, 10, 18, 19, 17, 21, 11]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_LOS_3to11mos_all.csv
# NF_LOS_5plus_all.csv
# NF_LOS_ltg3mos_all.csv
# NF_LOS_1to5yr_all.csv
# NF_LOS_NR_all.csv
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# NF_LOS_3to11mos
# 00 NF_LOS_3to11mos
# 11 NF_LOS_3to11mos
# 13 NF_LOS_3to11mos
# 15 NF_LOS_3to11mos
# 17 NF_LOS_3to11mos
# 19 NF_LOS_3to11mos
# 21 NF_LOS_3to11mos
# 23 NF_LOS_3to11mos
# 25 NF_LOS_3to11mos
# 27 NF_LOS_3to11mos
# 29 NF_LOS_3to11mos
# 31 NF_LOS_3to11mos
# 33 NF_LOS_3to11mos
# 35 NF_LOS_3to11mos
# 37 NF_LOS_3to11mos
# 39 NF_LOS_3to11mos
# 41 NF_LOS_3to11mos
# 43 NF_LOS_3to11mos
# 45 NF_LOS_3to11mos
# 47 NF_LOS_3to11mos
# 49 NF_LOS_3to11mos
# 51 NF_LOS_3to11mos
# 53 NF_LOS_3to11mos
# 55 NF_LOS_3to11mos
# Suggested swivel order
# [22, 2, 3, 6, 0, 1, 4, 8, 7, 15, 16, 5, 9, 14, 20, 18, 13, 11, 12, 19, 17, 10, 21]
# NF_LOS_5plus
# 00 NF_LOS_5plus
# 11 NF_LOS_5plus
# 13 NF_LOS_5plus
# 15 NF_LOS_5plus
# 17 NF_LOS_5plus
# 19 NF_LOS_5plus
# 21 NF_LOS_5plus
# 23 NF_LOS_5plus
# 25 NF_LOS_5plus
# 27 NF_LOS_5plus
# 29 NF_LOS_5plus
# 31 NF_LOS_5plus
# 33 NF_LOS_5plus
# 35 NF_LOS_5plus
# 37 NF_LOS_5plus
# 39 NF_LOS_5plus
# 41 NF_LOS_5plus
# 43 NF_LOS_5plus
# 45 NF_LOS_5plus
# 47 NF_LOS_5plus
# 49 NF_LOS_5plus
# 51 NF_LOS_5plus
# 53 NF_LOS_5plus
# 55 NF_LOS_5plus
# Suggested swivel order
# [22, 2, 6, 3, 1, 4, 0, 8, 15, 14, 16, 5, 7, 12, 9, 17, 18, 20, 13, 10, 21, 19, 11]
# NF_LOS_ltg3mos
# 00 NF_LOS_ltg3mos
# 11 NF_LOS_ltg3mos
# 13 NF_LOS_ltg3mos
# 15 NF_LOS_ltg3mos
# 17 NF_LOS_ltg3mos
# 19 NF_LOS_ltg3mos
# 21 NF_LOS_ltg3mos
# 23 NF_LOS_ltg3mos
# 25 NF_LOS_ltg3mos
# 27 NF_LOS_ltg3mos
# 29 NF_LOS_ltg3mos
# 31 NF_LOS_ltg3mos
# 33 NF_LOS_ltg3mos
# 35 NF_LOS_ltg3mos
# 37 NF_LOS_ltg3mos
# 39 NF_LOS_ltg3mos
# 41 NF_LOS_ltg3mos
# 43 NF_LOS_ltg3mos
# 45 NF_LOS_ltg3mos
# 47 NF_LOS_ltg3mos
# 49 NF_LOS_ltg3mos
# 51 NF_LOS_ltg3mos
# 53 NF_LOS_ltg3mos
# 55 NF_LOS_ltg3mos
# Suggested swivel order
# [22, 2, 1, 3, 0, 4, 6, 7, 8, 5, 9, 16, 15, 14, 11, 19, 10, 12, 20, 18, 13, 21, 17]
# NF_LOS_1to5yr
# 00 NF_LOS_1to5yr
# 11 NF_LOS_1to5yr
# 13 NF_LOS_1to5yr
# 15 NF_LOS_1to5yr
# 17 NF_LOS_1to5yr
# 19 NF_LOS_1to5yr
# 21 NF_LOS_1to5yr
# 23 NF_LOS_1to5yr
# 25 NF_LOS_1to5yr
# 27 NF_LOS_1to5yr
# 29 NF_LOS_1to5yr
# 31 NF_LOS_1to5yr
# 33 NF_LOS_1to5yr
# 35 NF_LOS_1to5yr
# 37 NF_LOS_1to5yr
# 39 NF_LOS_1to5yr
# 41 NF_LOS_1to5yr
# 43 NF_LOS_1to5yr
# 45 NF_LOS_1to5yr
# 47 NF_LOS_1to5yr
# 49 NF_LOS_1to5yr
# 51 NF_LOS_1to5yr
# 53 NF_LOS_1to5yr
# 55 NF_LOS_1to5yr
# Suggested swivel order
# [22, 6, 2, 1, 0, 3, 4, 8, 7, 16, 15, 14, 5, 9, 12, 18, 20, 17, 13, 10, 21, 19, 11]
# NF_LOS_NR
# 00 NF_LOS_NR
# 11 NF_LOS_NR
# 13 NF_LOS_NR
# 15 NF_LOS_NR
# 17 NF_LOS_NR
# 19 NF_LOS_NR
# 21 NF_LOS_NR
# 23 NF_LOS_NR
# 25 NF_LOS_NR
# 27 NF_LOS_NR
# 29 NF_LOS_NR
# 31 NF_LOS_NR
# 33 NF_LOS_NR
# 35 NF_LOS_NR
# 37 NF_LOS_NR
# 39 NF_LOS_NR
# 41 NF_LOS_NR
# 43 NF_LOS_NR
# 45 NF_LOS_NR
# 47 NF_LOS_NR
# 49 NF_LOS_NR
# 51 NF_LOS_NR
# 53 NF_LOS_NR
# 55 NF_LOS_NR
# Suggested swivel order
# [6, 22, 2, 8, 1, 3, 0, 15, 4, 7, 14, 16, 9, 5, 20, 12, 10, 18, 13, 19, 17, 21, 11]
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_LOS_3to11mos_all.csv
# NF_LOS_5plus_all.csv
# NF_LOS_ltg3mos_all.csv
# NF_LOS_1to5yr_all.csv
# NF_LOS_NR_all.csv
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# dict_keys(['NF_LOS_3to11mos', 'NF_LOS_5plus', 'NF_LOS_ltg3mos', 'NF_LOS_1to5yr', 'NF_LOS_NR'])
# NF_LOS_3to11mos
# 00 NF_LOS_3to11mos
# 11 NF_LOS_3to11mos
# 13 NF_LOS_3to11mos
# 15 NF_LOS_3to11mos
# 17 NF_LOS_3to11mos
# 19 NF_LOS_3to11mos
# 21 NF_LOS_3to11mos
# 23 NF_LOS_3to11mos
# 25 NF_LOS_3to11mos
# 27 NF_LOS_3to11mos
# 29 NF_LOS_3to11mos
# 31 NF_LOS_3to11mos
# 33 NF_LOS_3to11mos
# 35 NF_LOS_3to11mos
# 37 NF_LOS_3to11mos
# 39 NF_LOS_3to11mos
# 41 NF_LOS_3to11mos
# 43 NF_LOS_3to11mos
# 45 NF_LOS_3to11mos
# 47 NF_LOS_3to11mos
# 49 NF_LOS_3to11mos
# 51 NF_LOS_3to11mos
# 53 NF_LOS_3to11mos
# 55 NF_LOS_3to11mos
# Suggested swivel order
# [22, 2, 6, 4, 1, 0, 3, 8, 7, 16, 15, 5, 9, 14, 11, 18, 20, 13, 12, 19, 17, 10, 21]
# NF_LOS_5plus
# 00 NF_LOS_5plus
# 11 NF_LOS_5plus
# 13 NF_LOS_5plus
# 15 NF_LOS_5plus
# 17 NF_LOS_5plus
# 19 NF_LOS_5plus
# 21 NF_LOS_5plus
# 23 NF_LOS_5plus
# 25 NF_LOS_5plus
# 27 NF_LOS_5plus
# 29 NF_LOS_5plus
# 31 NF_LOS_5plus
# 33 NF_LOS_5plus
# 35 NF_LOS_5plus
# 37 NF_LOS_5plus
# 39 NF_LOS_5plus
# 41 NF_LOS_5plus
# 43 NF_LOS_5plus
# 45 NF_LOS_5plus
# 47 NF_LOS_5plus
# 49 NF_LOS_5plus
# 51 NF_LOS_5plus
# 53 NF_LOS_5plus
# 55 NF_LOS_5plus
# Suggested swivel order
# [22, 2, 6, 3, 1, 4, 8, 0, 14, 15, 16, 5, 7, 12, 9, 18, 17, 20, 13, 10, 21, 19, 11]
# NF_LOS_ltg3mos
# 00 NF_LOS_ltg3mos
# 11 NF_LOS_ltg3mos
# 13 NF_LOS_ltg3mos
# 15 NF_LOS_ltg3mos
# 17 NF_LOS_ltg3mos
# 19 NF_LOS_ltg3mos
# 21 NF_LOS_ltg3mos
# 23 NF_LOS_ltg3mos
# 25 NF_LOS_ltg3mos
# 27 NF_LOS_ltg3mos
# 29 NF_LOS_ltg3mos
# 31 NF_LOS_ltg3mos
# 33 NF_LOS_ltg3mos
# 35 NF_LOS_ltg3mos
# 37 NF_LOS_ltg3mos
# 39 NF_LOS_ltg3mos
# 41 NF_LOS_ltg3mos
# 43 NF_LOS_ltg3mos
# 45 NF_LOS_ltg3mos
# 47 NF_LOS_ltg3mos
# 49 NF_LOS_ltg3mos
# 51 NF_LOS_ltg3mos
# 53 NF_LOS_ltg3mos
# 55 NF_LOS_ltg3mos
# Suggested swivel order
# [6, 22, 2, 1, 3, 0, 4, 5, 7, 8, 9, 16, 15, 14, 11, 19, 13, 10, 18, 12, 20, 21, 17]
# NF_LOS_1to5yr
# 00 NF_LOS_1to5yr
# 11 NF_LOS_1to5yr
# 13 NF_LOS_1to5yr
# 15 NF_LOS_1to5yr
# 17 NF_LOS_1to5yr
# 19 NF_LOS_1to5yr
# 21 NF_LOS_1to5yr
# 23 NF_LOS_1to5yr
# 25 NF_LOS_1to5yr
# 27 NF_LOS_1to5yr
# 29 NF_LOS_1to5yr
# 31 NF_LOS_1to5yr
# 33 NF_LOS_1to5yr
# 35 NF_LOS_1to5yr
# 37 NF_LOS_1to5yr
# 39 NF_LOS_1to5yr
# 41 NF_LOS_1to5yr
# 43 NF_LOS_1to5yr
# 45 NF_LOS_1to5yr
# 47 NF_LOS_1to5yr
# 49 NF_LOS_1to5yr
# 51 NF_LOS_1to5yr
# 53 NF_LOS_1to5yr
# 55 NF_LOS_1to5yr
# Suggested swivel order
# [22, 2, 6, 3, 1, 0, 4, 8, 7, 15, 16, 5, 14, 9, 18, 12, 20, 17, 13, 10, 19, 21, 11]
# NF_LOS_NR
# 00 NF_LOS_NR
# 11 NF_LOS_NR
# 13 NF_LOS_NR
# 15 NF_LOS_NR
# 17 NF_LOS_NR
# 19 NF_LOS_NR
# 21 NF_LOS_NR
# 23 NF_LOS_NR
# 25 NF_LOS_NR
# 27 NF_LOS_NR
# 29 NF_LOS_NR
# 31 NF_LOS_NR
# 33 NF_LOS_NR
# 35 NF_LOS_NR
# 37 NF_LOS_NR
# 39 NF_LOS_NR
# 41 NF_LOS_NR
# 43 NF_LOS_NR
# 45 NF_LOS_NR
# 47 NF_LOS_NR
# 49 NF_LOS_NR
# 51 NF_LOS_NR
# 53 NF_LOS_NR
# 55 NF_LOS_NR
# Suggested swivel order
# [22, 2, 8, 1, 4, 0, 6, 15, 14, 3, 7, 16, 9, 5, 12, 20, 17, 10, 13, 18, 19, 21, 11]

# %% [markdown]
# # Age boxblots

# %%
#print(a16_global_y_soc1)

#print(global_y_soc1)

# %%
"""

data = rsq_array
pd.set_option("display.max_rows", None, "display.max_columns", None)
df = pd.DataFrame(data, columns = ['YEAR', 'RSQ'])

for index in range(0,7):  # 7
    # Creating pandas |dataframe from numpy array
    #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })

    pd_df = pd.DataFrame()
    sel_y = []

    if (index == 0):
        name = "16to19"
        sel_y = a16_global_y_soc1
    elif (index == 1):
        name = "20to24"
        sel_y = a20_global_y_soc1
    elif (index == 2):
        name = "25to34"
        sel_y = a25_global_y_soc1
    elif (index == 3):
        name = "35to44"
        sel_y = a35_global_y_soc1
    elif (index == 4):
        name = "45to54"
        sel_y = a45_global_y_soc1
    elif (index == 5):
        name = "55to64"
        sel_y = a55_global_y_soc1
    elif (index == 6):
        name = "65plus"
        sel_y = a65_global_y_soc1

    #print(sel_y)
        
    for index in range(0,len(sel_y)):
        pd_df[sel_y[index][0]] = sel_y[index][1]

    print(pd_df)
    
    title = desired_file_prefix + " AGE boxplots " + str(name)
    plt.figure(title,figsize=(10, 10))
    plt.title(title)

    #plt.ylim(0.0, 0.15)

    pd_df.boxplot()
    plt.xticks(rotation = 90)
    plt.tight_layout()  

    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    
    plt.show()
    
    #print("HERE")
    #print(df[df['YEAR'].str.contains(name)])
"""
# Out:
# '\n\ndata = rsq_array\npd.set_option("display.max_rows", None, "display.max_columns", None)\ndf = pd.DataFrame(data, columns = [\'YEAR\', \'RSQ\'])\n\nfor index in range(0,7):  # 7\n    # Creating pandas |dataframe from numpy array\n    #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })\n\n    pd_df = pd.DataFrame()\n    sel_y = []\n\n    if (index == 0):\n        name = "16to19"\n        sel_y = a16_global_y_soc1\n    elif (index == 1):\n        name = "20to24"\n        sel_y = a20_global_y_soc1\n    elif (index == 2):\n        name = "25to34"\n        sel_y = a25_global_y_soc1\n    elif (index == 3):\n        name = "35to44"\n        sel_y = a35_global_y_soc1\n    elif (index == 4):\n        name = "45to54"\n        sel_y = a45_global_y_soc1\n    elif (index == 5):\n        name = "55to64"\n        sel_y = a55_global_y_soc1\n    elif (index == 6):\n        name = "65plus"\n        sel_y = a65_global_y_soc1\n\n    #print(sel_y)\n        \n    for index in range(0,len(sel_y)):\n        pd_df[sel_y[index][0]] = sel_y[index][1]\n\n    print(pd_df)\n    \n    title = desired_file_prefix + " AGE boxplots " + str(name)\n    plt.figure(title,figsize=(10, 10))\n    plt.title(title)\n\n    #plt.ylim(0.0, 0.15)\n\n    pd_df.boxplot()\n    plt.xticks(rotation = 90)\n    plt.tight_layout()  \n\n    save_title = "../PLOTS/" + desired_file_output + title + ".png"\n    save_title = save_title.replace(",","")\n    save_title = save_title.replace(" ","_")\n    plt.savefig(save_title, dpi=100, bbox_inches=\'tight\')\n    \n    plt.show()\n    \n    #print("HERE")\n    #print(df[df[\'YEAR\'].str.contains(name)])\n'

# %%
#print(rsq_array)

# %%
"""
import dataframe_image as dfi

data = rsq_array
pd.set_option("display.max_rows", None, "display.max_columns", None)
df = pd.DataFrame(data, columns = ['YEAR', 'RSQ'])

for index in range(0,7):  # 7
    # Creating pandas |dataframe from numpy array
    #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })

    if (index == 0):
        name = "16to19"
    elif (index == 1):
        name = "20to24"
    elif (index == 2):
        name = "25to34"
    elif (index == 3):
        name = "35to44"
    elif (index == 4):
        name = "45to54"
    elif (index == 5):
        name = "55to64"
    elif (index == 6):
        name = "65plus"
        
    print(name)
    print(df[df['YEAR'].str.contains(name)])
    #title = "RSQtable"
    
    #desired_file_output = "./F_PER_AGE/F_AGE_"  
    #save_file = "../PLOTS/" + desired_file_output + title + "_" + name +".png"
    #dfi.export(df[df['YEAR'].str.contains(name)], save_file, max_cols=-1, max_rows=-1)
"""
# Out:
# '\nimport dataframe_image as dfi\n\ndata = rsq_array\npd.set_option("display.max_rows", None, "display.max_columns", None)\ndf = pd.DataFrame(data, columns = [\'YEAR\', \'RSQ\'])\n\nfor index in range(0,7):  # 7\n    # Creating pandas |dataframe from numpy array\n    #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })\n\n    if (index == 0):\n        name = "16to19"\n    elif (index == 1):\n        name = "20to24"\n    elif (index == 2):\n        name = "25to34"\n    elif (index == 3):\n        name = "35to44"\n    elif (index == 4):\n        name = "45to54"\n    elif (index == 5):\n        name = "55to64"\n    elif (index == 6):\n        name = "65plus"\n        \n    print(name)\n    print(df[df[\'YEAR\'].str.contains(name)])\n    #title = "RSQtable"\n    \n    #desired_file_output = "./F_PER_AGE/F_AGE_"  \n    #save_file = "../PLOTS/" + desired_file_output + title + "_" + name +".png"\n    #dfi.export(df[df[\'YEAR\'].str.contains(name)], save_file, max_cols=-1, max_rows=-1)\n'

# %% [markdown]
# # SOC GENDER BOXPLOTS

# %%
print(ltg3m_global_y_soc1[5][1])
# Out:
# [0.00000000e+00 1.75575497e-05 2.11528292e-05 3.82232767e-05
#  5.20992951e-05 5.91359579e-05 7.84826684e-05 2.61748959e-04
#  2.53409213e-04 3.41009743e-04 2.64925373e-04 6.32251555e-04
#  3.08128009e-04 2.67515924e-04 1.52554745e-03 1.57231950e-03
#  1.42558868e-03 3.12221231e-03 1.33754698e-03 1.53761367e-03
#  1.25099761e-03 2.35329704e-03 9.99063378e-04]

# %%
alist = [
    ["1m to 3m",  ltg3m_global_y_soc1],
    ["3m to 11m", l3mto11m_global_y_soc1],
    ["1y to 5y",  l1yto5y_global_y_soc1],
    ["5y plus", l5yplus_global_y_soc1] ]

for arr in alist:
    use_case= arr[0]
    data    = arr[1]
    
    soc_box = []

    for soc_index in range (0,23):
        tmp = []
        avg = np.zeros(23)
        for y_index in range(0,8):
            #avg = ( np.array(male_global_y_soc1[y_index][1][soc_index]) + np.array(female_global_y_soc1[y_index][1][soc_index]) )/2
            #avg = a35_global_y_soc1[y_index][1][soc_index]
            avg = data[y_index][1][soc_index]
            tmp.append(avg)
         
        soc_box.append(tmp)    
    #print(soc_box)

    # BOX PLOT per occupation
    jlist = []
    for jb in range(1,24):
       jlist.append(job_code[jb][1])
    #print(jlist)

    #print(jlist[22])

    # Creating pandas |dataframe from numpy array
    #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
    pd_df = pd.DataFrame(columns=jlist)

    #global_y_soc1 = female_global_y_soc1

    for index in range(0,23):
        pd_df[jlist[index]] = soc_box[index]

    title = use_case + " SOC boxplots"
    plt.figure(title,figsize=(10, 10))
    plt.title(title)
    
    plt.ylim(0.0, 0.02)

    pd_df.boxplot()
    plt.xticks(rotation = 90)
    plt.tight_layout()

    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    
    plt.show()
    plt.close()

    print("STDEV for " + use_case)
    
    title =  use_case + " STDEV(RED) and MEAN(GREEN)"
    
    # Creating plot with dataset_1
    fig, ax1 = plt.subplots(figsize=(10, 10))
    plt.title(title)
    
    ax1.plot(pd_df.std(), 'r-')

    plt.xticks(rotation = 90)
    
    ax2 = ax1.twinx()
    ax2.plot(pd_df.mean(), 'g-')
    
    ax1.tick_params(axis='y', colors='red')
    ax2.tick_params(axis='y', colors='green')
    
    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    plt.show()
    plt.close()
# Out:
# STDEV for 1m to 3m
# STDEV for 3m to 11m
# STDEV for 1y to 5y
# STDEV for 5y plus

# %%
jlist = []
for jb in range(1,23):
   jlist.append(job_code[jb][1])
print(jlist)
# Out:
# ['Military Specific Occupations', 'Computer and Mathematical Occupations', 'Legal Occupations', 'Business and Financial Operations Occupations', 'Architecture and Engineering Occupations', 'Management Occupations', 'Life, Physical, and Social Science Occupations', 'Arts, Design, Entertainment, Sports, and Media Occupations', 'Educational Instruction and Library Occupations', 'Sales and Related Occupations', 'Community and Social Service Occupations', 'Personal Care and Service Occupations', 'Office and Administrative Support Occupations', 'Healthcare Practitioners and Technical Occupations', 'Food Preparation and Serving Related Occupations', 'Construction and Extraction Occupations', 'Production Occupations', 'Farming, Fishing, and Forestry Occupations', 'Building and Grounds Cleaning and Maintenance Occupations', 'Healthcare Support Occupations', 'Installation, Maintenance, and Repair Occupations', 'Transportation and Material Moving Occupations']
