# %%
import os

try:
    os.mkdir("../PLOTS/COMP_BOX_RACE")
except:
    print("COMP_BOX_RACE dir exists.")

#For testing, leave commented
swivel = 1

# F ORDER
#swivel_order = [2, 1, 7, 3, 16, 6, 12, 9, 10, 4, 5, 15, 8, 14, 20, 0, 22, 13, 19, 11, 18, 21, 17]

# NF ORDER
swivel_order = [22, 2, 6, 1, 3, 0, 4, 8, 7, 15, 5, 14, 16, 9, 12, 18, 20, 17, 13, 10, 19, 21, 11]

desired_file_prefix = "NF_R" 

normalize_data=True

lnconvert=False
# Out:
# COMP_BOX_RACE dir exists.

# %%
by_year = 1

"""
year = 8

desired_file_output = "./F_BOX_RACE/F_R_ALL_"

# %run ./analysis-code-race.ipynb
"""

# ##################### FATAL   (NOT USED)

desired_file_prefix = "F_R" 

rw_global_y_soc1 = []
rb_global_y_soc1 = []
ra_global_y_soc1 = []
rh_global_y_soc1 = []
rh2_global_y_soc1 = []

rsq_array = []

for year in range(0,8):       
    desired_file_output = "./COMP_BOX_RACE/F_R_" + str(2011+year) + "_" 

    # %run ./box-analysis-code-race.ipynb
    
f_rw_global_y_soc1 = rw_global_y_soc1;
f_rb_global_y_soc1 = rb_global_y_soc1; 
f_ra_global_y_soc1 = ra_global_y_soc1;
f_rh_global_y_soc1 = rh_global_y_soc1; 
f_rh2_global_y_soc1 = rh2_global_y_soc1; 
   


# ##################### NON-FATAL  

desired_file_prefix = "NF_R" 

rw_global_y_soc1 = []
rb_global_y_soc1 = []
ra_global_y_soc1 = []
rh_global_y_soc1 = []
rh2_global_y_soc1 = []

rsq_array = []

for year in range(0,8):       
    desired_file_output = "./COMP_BOX_RACE/NF_R_" + str(2011+year) + "_"  
    
    # %run ./box-analysis-code-race.ipynb
    
nf_rw_global_y_soc1 = rw_global_y_soc1;
nf_rb_global_y_soc1 = rb_global_y_soc1; 
nf_ra_global_y_soc1 = ra_global_y_soc1;
nf_rh_global_y_soc1 = rh_global_y_soc1; 
nf_rh2_global_y_soc1 = rh2_global_y_soc1;
# Out:
# SOC_all.csv
# global_y_soc1 not found....defining
# global_soc1_empty not found....defining
# F_RWT_White_total_all.csv
# Importing  ../DATA/SOC_all.csv
# F_RBT_Black_total_all.csv
# Importing  ../DATA/F_RWT_White_total_all.csv
# F_RAT_Asian_total_all.csv
# Importing  ../DATA/F_RBT_Black_total_all.csv
# F_RHT_Hispanic_total_all.csv
# Importing  ../DATA/F_RAT_Asian_total_all.csv
# F_RNT_Total_foreign_born_all.csv
# F_RFT_Total_native_born_all.csv
# F_RIT_American_indian_total_all.csv
# F_RMT_Multiple_race_total_all.csv
# F_RPT_Hawaiian_total_all.csv
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# F_RWT_White_total
# 00 F_RWT_White_total
# 11 F_RWT_White_total
# 13 F_RWT_White_total
# 15 F_RWT_White_total
# 17 F_RWT_White_total
# 19 F_RWT_White_total
# 21 F_RWT_White_total
# 23 F_RWT_White_total
# 25 F_RWT_White_total
# 27 F_RWT_White_total
# 29 F_RWT_White_total
# 31 F_RWT_White_total
# 33 F_RWT_White_total
# 35 F_RWT_White_total
# 37 F_RWT_White_total
# 39 F_RWT_White_total
# 41 F_RWT_White_total
# 43 F_RWT_White_total
# 45 F_RWT_White_total
# 47 F_RWT_White_total
# 49 F_RWT_White_total
# 51 F_RWT_White_total
# 53 F_RWT_White_total
# 55 F_RWT_White_total
# Suggested swivel order
# [2, 1, 7, 16, 12, 10, 9, 6, 5, 3, 15, 14, 4, 8, 20, 0, 13, 22, 19, 18, 11, 21, 17]
# F_RBT_Black_total
# 00 F_RBT_Black_total
# 11 F_RBT_Black_total
# 13 F_RBT_Black_total
# 15 F_RBT_Black_total
# 17 F_RBT_Black_total
# 19 F_RBT_Black_total
# 21 F_RBT_Black_total
# 23 F_RBT_Black_total
# 25 F_RBT_Black_total
# 27 F_RBT_Black_total
# 29 F_RBT_Black_total
# 31 F_RBT_Black_total
# 33 F_RBT_Black_total
# 35 F_RBT_Black_total
# 37 F_RBT_Black_total
# 39 F_RBT_Black_total
# 41 F_RBT_Black_total
# 43 F_RBT_Black_total
# 45 F_RBT_Black_total
# 47 F_RBT_Black_total
# 49 F_RBT_Black_total
# 51 F_RBT_Black_total
# 53 F_RBT_Black_total
# 55 F_RBT_Black_total
# Suggested swivel order
# [2, 3, 4, 6, 7, 8, 9, 12, 16, 1, 5, 14, 10, 15, 0, 20, 22, 13, 19, 11, 18, 21, 17]
# F_RAT_Asian_total
# 00 F_RAT_Asian_total
# 11 F_RAT_Asian_total
# 13 F_RAT_Asian_total
# 15 F_RAT_Asian_total
# 17 F_RAT_Asian_total
# 19 F_RAT_Asian_total
# 21 F_RAT_Asian_total
# 23 F_RAT_Asian_total
# 25 F_RAT_Asian_total
# 27 F_RAT_Asian_total
# 29 F_RAT_Asian_total
# 31 F_RAT_Asian_total
# 33 F_RAT_Asian_total
# 35 F_RAT_Asian_total
# 37 F_RAT_Asian_total
# 39 F_RAT_Asian_total
# 41 F_RAT_Asian_total
# 43 F_RAT_Asian_total
# 45 F_RAT_Asian_total
# 47 F_RAT_Asian_total
# 49 F_RAT_Asian_total
# 51 F_RAT_Asian_total
# 53 F_RAT_Asian_total
# 55 F_RAT_Asian_total
# Suggested swivel order
# [1, 2, 3, 5, 6, 7, 8, 10, 11, 12, 16, 9, 14, 20, 0, 4, 19, 13, 15, 18, 22, 21, 17]
# F_RHT_Hispanic_total
# 00 F_RHT_Hispanic_total
# 11 F_RHT_Hispanic_total
# 13 F_RHT_Hispanic_total
# 15 F_RHT_Hispanic_total
# 17 F_RHT_Hispanic_total
# 19 F_RHT_Hispanic_total
# 21 F_RHT_Hispanic_total
# 23 F_RHT_Hispanic_total
# 25 F_RHT_Hispanic_total
# 27 F_RHT_Hispanic_total
# 29 F_RHT_Hispanic_total
# 31 F_RHT_Hispanic_total
# 33 F_RHT_Hispanic_total
# 35 F_RHT_Hispanic_total
# 37 F_RHT_Hispanic_total
# 39 F_RHT_Hispanic_total
# 41 F_RHT_Hispanic_total
# 43 F_RHT_Hispanic_total
# 45 F_RHT_Hispanic_total
# 47 F_RHT_Hispanic_total
# 49 F_RHT_Hispanic_total
# 51 F_RHT_Hispanic_total
# 53 F_RHT_Hispanic_total
# 55 F_RHT_Hispanic_total
# Normalizing Hispanic
# Suggested swivel order
# [1, 2, 3, 6, 9, 4, 7, 14, 16, 0, 12, 10, 5, 8, 15, 20, 22, 19, 21, 13, 11, 18, 17]
# ['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_RWT_White_total_all.csv
# Importing  ../DATA/SOC_all.csv
# F_RBT_Black_total_all.csv
# Importing  ../DATA/F_RWT_White_total_all.csv
# F_RAT_Asian_total_all.csv
# Importing  ../DATA/F_RBT_Black_total_all.csv
# F_RHT_Hispanic_total_all.csv
# Importing  ../DATA/F_RAT_Asian_total_all.csv
# F_RNT_Total_foreign_born_all.csv
# F_RFT_Total_native_born_all.csv
# F_RIT_American_indian_total_all.csv
# F_RMT_Multiple_race_total_all.csv
# F_RPT_Hawaiian_total_all.csv
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# F_RWT_White_total
# 00 F_RWT_White_total
# 11 F_RWT_White_total
# 13 F_RWT_White_total
# 15 F_RWT_White_total
# 17 F_RWT_White_total
# 19 F_RWT_White_total
# 21 F_RWT_White_total
# 23 F_RWT_White_total
# 25 F_RWT_White_total
# 27 F_RWT_White_total
# 29 F_RWT_White_total
# 31 F_RWT_White_total
# 33 F_RWT_White_total
# 35 F_RWT_White_total
# 37 F_RWT_White_total
# 39 F_RWT_White_total
# 41 F_RWT_White_total
# 43 F_RWT_White_total
# 45 F_RWT_White_total
# 47 F_RWT_White_total
# 49 F_RWT_White_total
# 51 F_RWT_White_total
# 53 F_RWT_White_total
# 55 F_RWT_White_total
# Suggested swivel order
# [2, 7, 10, 1, 12, 6, 16, 9, 14, 3, 15, 4, 8, 5, 20, 0, 13, 22, 19, 11, 18, 21, 17]
# F_RBT_Black_total
# 00 F_RBT_Black_total
# 11 F_RBT_Black_total
# 13 F_RBT_Black_total
# 15 F_RBT_Black_total
# 17 F_RBT_Black_total
# 19 F_RBT_Black_total
# 21 F_RBT_Black_total
# 23 F_RBT_Black_total
# 25 F_RBT_Black_total
# 27 F_RBT_Black_total
# 29 F_RBT_Black_total
# 31 F_RBT_Black_total
# 33 F_RBT_Black_total
# 35 F_RBT_Black_total
# 37 F_RBT_Black_total
# 39 F_RBT_Black_total
# 41 F_RBT_Black_total
# 43 F_RBT_Black_total
# 45 F_RBT_Black_total
# 47 F_RBT_Black_total
# 49 F_RBT_Black_total
# 51 F_RBT_Black_total
# 53 F_RBT_Black_total
# 55 F_RBT_Black_total
# Suggested swivel order
# [1, 2, 3, 6, 9, 10, 7, 16, 14, 0, 15, 12, 22, 5, 8, 20, 13, 4, 19, 11, 18, 21, 17]
# F_RAT_Asian_total
# 00 F_RAT_Asian_total
# 11 F_RAT_Asian_total
# 13 F_RAT_Asian_total
# 15 F_RAT_Asian_total
# 17 F_RAT_Asian_total
# 19 F_RAT_Asian_total
# 21 F_RAT_Asian_total
# 23 F_RAT_Asian_total
# 25 F_RAT_Asian_total
# 27 F_RAT_Asian_total
# 29 F_RAT_Asian_total
# 31 F_RAT_Asian_total
# 33 F_RAT_Asian_total
# 35 F_RAT_Asian_total
# 37 F_RAT_Asian_total
# 39 F_RAT_Asian_total
# 41 F_RAT_Asian_total
# 43 F_RAT_Asian_total
# 45 F_RAT_Asian_total
# 47 F_RAT_Asian_total
# 49 F_RAT_Asian_total
# 51 F_RAT_Asian_total
# 53 F_RAT_Asian_total
# 55 F_RAT_Asian_total
# Suggested swivel order
# [1, 2, 3, 4, 5, 6, 7, 8, 10, 17, 22, 9, 16, 12, 14, 0, 20, 13, 15, 11, 19, 18, 21]
# F_RHT_Hispanic_total
# 00 F_RHT_Hispanic_total
# 11 F_RHT_Hispanic_total
# 13 F_RHT_Hispanic_total
# 15 F_RHT_Hispanic_total
# 17 F_RHT_Hispanic_total
# 19 F_RHT_Hispanic_total
# 21 F_RHT_Hispanic_total
# 23 F_RHT_Hispanic_total
# 25 F_RHT_Hispanic_total
# 27 F_RHT_Hispanic_total
# 29 F_RHT_Hispanic_total
# 31 F_RHT_Hispanic_total
# 33 F_RHT_Hispanic_total
# 35 F_RHT_Hispanic_total
# 37 F_RHT_Hispanic_total
# 39 F_RHT_Hispanic_total
# 41 F_RHT_Hispanic_total
# 43 F_RHT_Hispanic_total
# 45 F_RHT_Hispanic_total
# 47 F_RHT_Hispanic_total
# 49 F_RHT_Hispanic_total
# 51 F_RHT_Hispanic_total
# 53 F_RHT_Hispanic_total
# 55 F_RHT_Hispanic_total
# Normalizing Hispanic
# Suggested swivel order
# [1, 2, 4, 6, 7, 9, 10, 22, 3, 0, 5, 16, 14, 8, 12, 15, 20, 19, 11, 13, 21, 18, 17]
# ['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_RWT_White_total_all.csv
# Importing  ../DATA/SOC_all.csv
# F_RBT_Black_total_all.csv
# Importing  ../DATA/F_RWT_White_total_all.csv
# F_RAT_Asian_total_all.csv
# Importing  ../DATA/F_RBT_Black_total_all.csv
# F_RHT_Hispanic_total_all.csv
# Importing  ../DATA/F_RAT_Asian_total_all.csv
# F_RNT_Total_foreign_born_all.csv
# F_RFT_Total_native_born_all.csv
# F_RIT_American_indian_total_all.csv
# F_RMT_Multiple_race_total_all.csv
# F_RPT_Hawaiian_total_all.csv
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# F_RWT_White_total
# 00 F_RWT_White_total
# 11 F_RWT_White_total
# 13 F_RWT_White_total
# 15 F_RWT_White_total
# 17 F_RWT_White_total
# 19 F_RWT_White_total
# 21 F_RWT_White_total
# 23 F_RWT_White_total
# 25 F_RWT_White_total
# 27 F_RWT_White_total
# 29 F_RWT_White_total
# 31 F_RWT_White_total
# 33 F_RWT_White_total
# 35 F_RWT_White_total
# 37 F_RWT_White_total
# 39 F_RWT_White_total
# 41 F_RWT_White_total
# 43 F_RWT_White_total
# 45 F_RWT_White_total
# 47 F_RWT_White_total
# 49 F_RWT_White_total
# 51 F_RWT_White_total
# 53 F_RWT_White_total
# 55 F_RWT_White_total
# Suggested swivel order
# [7, 1, 2, 16, 10, 12, 14, 9, 5, 6, 3, 15, 4, 8, 20, 0, 13, 22, 19, 18, 11, 21, 17]
# F_RBT_Black_total
# 00 F_RBT_Black_total
# 11 F_RBT_Black_total
# 13 F_RBT_Black_total
# 15 F_RBT_Black_total
# 17 F_RBT_Black_total
# 19 F_RBT_Black_total
# 21 F_RBT_Black_total
# 23 F_RBT_Black_total
# 25 F_RBT_Black_total
# 27 F_RBT_Black_total
# 29 F_RBT_Black_total
# 31 F_RBT_Black_total
# 33 F_RBT_Black_total
# 35 F_RBT_Black_total
# 37 F_RBT_Black_total
# 39 F_RBT_Black_total
# 41 F_RBT_Black_total
# 43 F_RBT_Black_total
# 45 F_RBT_Black_total
# 47 F_RBT_Black_total
# 49 F_RBT_Black_total
# 51 F_RBT_Black_total
# 53 F_RBT_Black_total
# 55 F_RBT_Black_total
# Suggested swivel order
# [2, 3, 5, 6, 7, 9, 16, 1, 10, 15, 14, 0, 22, 12, 8, 20, 13, 4, 11, 19, 18, 21, 17]
# F_RAT_Asian_total
# 00 F_RAT_Asian_total
# 11 F_RAT_Asian_total
# 13 F_RAT_Asian_total
# 15 F_RAT_Asian_total
# 17 F_RAT_Asian_total
# 19 F_RAT_Asian_total
# 21 F_RAT_Asian_total
# 23 F_RAT_Asian_total
# 25 F_RAT_Asian_total
# 27 F_RAT_Asian_total
# 29 F_RAT_Asian_total
# 31 F_RAT_Asian_total
# 33 F_RAT_Asian_total
# 35 F_RAT_Asian_total
# 37 F_RAT_Asian_total
# 39 F_RAT_Asian_total
# 41 F_RAT_Asian_total
# 43 F_RAT_Asian_total
# 45 F_RAT_Asian_total
# 47 F_RAT_Asian_total
# 49 F_RAT_Asian_total
# 51 F_RAT_Asian_total
# 53 F_RAT_Asian_total
# 55 F_RAT_Asian_total
# Suggested swivel order
# [2, 4, 5, 6, 7, 8, 9, 10, 11, 12, 14, 16, 22, 1, 3, 20, 0, 19, 13, 15, 21, 18, 17]
# F_RHT_Hispanic_total
# 00 F_RHT_Hispanic_total
# 11 F_RHT_Hispanic_total
# 13 F_RHT_Hispanic_total
# 15 F_RHT_Hispanic_total
# 17 F_RHT_Hispanic_total
# 19 F_RHT_Hispanic_total
# 21 F_RHT_Hispanic_total
# 23 F_RHT_Hispanic_total
# 25 F_RHT_Hispanic_total
# 27 F_RHT_Hispanic_total
# 29 F_RHT_Hispanic_total
# 31 F_RHT_Hispanic_total
# 33 F_RHT_Hispanic_total
# 35 F_RHT_Hispanic_total
# 37 F_RHT_Hispanic_total
# 39 F_RHT_Hispanic_total
# 41 F_RHT_Hispanic_total
# 43 F_RHT_Hispanic_total
# 45 F_RHT_Hispanic_total
# 47 F_RHT_Hispanic_total
# 49 F_RHT_Hispanic_total
# 51 F_RHT_Hispanic_total
# 53 F_RHT_Hispanic_total
# 55 F_RHT_Hispanic_total
# Normalizing Hispanic
# Suggested swivel order
# [1, 2, 3, 5, 6, 7, 10, 9, 16, 14, 0, 4, 15, 12, 8, 20, 22, 19, 21, 11, 13, 18, 17]
# ['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_RWT_White_total_all.csv
# Importing  ../DATA/SOC_all.csv
# F_RBT_Black_total_all.csv
# Importing  ../DATA/F_RWT_White_total_all.csv
# F_RAT_Asian_total_all.csv
# Importing  ../DATA/F_RBT_Black_total_all.csv
# F_RHT_Hispanic_total_all.csv
# Importing  ../DATA/F_RAT_Asian_total_all.csv
# F_RNT_Total_foreign_born_all.csv
# F_RFT_Total_native_born_all.csv
# F_RIT_American_indian_total_all.csv
# F_RMT_Multiple_race_total_all.csv
# F_RPT_Hawaiian_total_all.csv
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# F_RWT_White_total
# 00 F_RWT_White_total
# 11 F_RWT_White_total
# 13 F_RWT_White_total
# 15 F_RWT_White_total
# 17 F_RWT_White_total
# 19 F_RWT_White_total
# 21 F_RWT_White_total
# 23 F_RWT_White_total
# 25 F_RWT_White_total
# 27 F_RWT_White_total
# 29 F_RWT_White_total
# 31 F_RWT_White_total
# 33 F_RWT_White_total
# 35 F_RWT_White_total
# 37 F_RWT_White_total
# 39 F_RWT_White_total
# 41 F_RWT_White_total
# 43 F_RWT_White_total
# 45 F_RWT_White_total
# 47 F_RWT_White_total
# 49 F_RWT_White_total
# 51 F_RWT_White_total
# 53 F_RWT_White_total
# 55 F_RWT_White_total
# Suggested swivel order
# [7, 1, 6, 12, 2, 10, 16, 9, 14, 3, 4, 15, 8, 5, 20, 0, 13, 22, 11, 19, 18, 21, 17]
# F_RBT_Black_total
# 00 F_RBT_Black_total
# 11 F_RBT_Black_total
# 13 F_RBT_Black_total
# 15 F_RBT_Black_total
# 17 F_RBT_Black_total
# 19 F_RBT_Black_total
# 21 F_RBT_Black_total
# 23 F_RBT_Black_total
# 25 F_RBT_Black_total
# 27 F_RBT_Black_total
# 29 F_RBT_Black_total
# 31 F_RBT_Black_total
# 33 F_RBT_Black_total
# 35 F_RBT_Black_total
# 37 F_RBT_Black_total
# 39 F_RBT_Black_total
# 41 F_RBT_Black_total
# 43 F_RBT_Black_total
# 45 F_RBT_Black_total
# 47 F_RBT_Black_total
# 49 F_RBT_Black_total
# 51 F_RBT_Black_total
# 53 F_RBT_Black_total
# 55 F_RBT_Black_total
# Suggested swivel order
# [1, 2, 4, 7, 10, 9, 16, 6, 12, 5, 0, 8, 14, 15, 3, 20, 13, 11, 22, 19, 18, 21, 17]
# F_RAT_Asian_total
# 00 F_RAT_Asian_total
# 11 F_RAT_Asian_total
# 13 F_RAT_Asian_total
# 15 F_RAT_Asian_total
# 17 F_RAT_Asian_total
# 19 F_RAT_Asian_total
# 21 F_RAT_Asian_total
# 23 F_RAT_Asian_total
# 25 F_RAT_Asian_total
# 27 F_RAT_Asian_total
# 29 F_RAT_Asian_total
# 31 F_RAT_Asian_total
# 33 F_RAT_Asian_total
# 35 F_RAT_Asian_total
# 37 F_RAT_Asian_total
# 39 F_RAT_Asian_total
# 41 F_RAT_Asian_total
# 43 F_RAT_Asian_total
# 45 F_RAT_Asian_total
# 47 F_RAT_Asian_total
# 49 F_RAT_Asian_total
# 51 F_RAT_Asian_total
# 53 F_RAT_Asian_total
# 55 F_RAT_Asian_total
# Suggested swivel order
# [1, 2, 4, 5, 6, 7, 8, 9, 10, 22, 14, 0, 3, 16, 20, 12, 13, 19, 11, 15, 21, 18, 17]
# F_RHT_Hispanic_total
# 00 F_RHT_Hispanic_total
# 11 F_RHT_Hispanic_total
# 13 F_RHT_Hispanic_total
# 15 F_RHT_Hispanic_total
# 17 F_RHT_Hispanic_total
# 19 F_RHT_Hispanic_total
# 21 F_RHT_Hispanic_total
# 23 F_RHT_Hispanic_total
# 25 F_RHT_Hispanic_total
# 27 F_RHT_Hispanic_total
# 29 F_RHT_Hispanic_total
# 31 F_RHT_Hispanic_total
# 33 F_RHT_Hispanic_total
# 35 F_RHT_Hispanic_total
# 37 F_RHT_Hispanic_total
# 39 F_RHT_Hispanic_total
# 41 F_RHT_Hispanic_total
# 43 F_RHT_Hispanic_total
# 45 F_RHT_Hispanic_total
# 47 F_RHT_Hispanic_total
# 49 F_RHT_Hispanic_total
# 51 F_RHT_Hispanic_total
# 53 F_RHT_Hispanic_total
# 55 F_RHT_Hispanic_total
# Normalizing Hispanic
# Suggested swivel order
# [1, 2, 3, 5, 6, 7, 10, 22, 9, 16, 14, 0, 4, 15, 8, 12, 20, 11, 19, 21, 13, 18, 17]
# ['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_RWT_White_total_all.csv
# Importing  ../DATA/SOC_all.csv
# F_RBT_Black_total_all.csv
# Importing  ../DATA/F_RWT_White_total_all.csv
# F_RAT_Asian_total_all.csv
# Importing  ../DATA/F_RBT_Black_total_all.csv
# F_RHT_Hispanic_total_all.csv
# Importing  ../DATA/F_RAT_Asian_total_all.csv
# F_RNT_Total_foreign_born_all.csv
# F_RFT_Total_native_born_all.csv
# F_RIT_American_indian_total_all.csv
# F_RMT_Multiple_race_total_all.csv
# F_RPT_Hawaiian_total_all.csv
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# F_RWT_White_total
# 00 F_RWT_White_total
# 11 F_RWT_White_total
# 13 F_RWT_White_total
# 15 F_RWT_White_total
# 17 F_RWT_White_total
# 19 F_RWT_White_total
# 21 F_RWT_White_total
# 23 F_RWT_White_total
# 25 F_RWT_White_total
# 27 F_RWT_White_total
# 29 F_RWT_White_total
# 31 F_RWT_White_total
# 33 F_RWT_White_total
# 35 F_RWT_White_total
# 37 F_RWT_White_total
# 39 F_RWT_White_total
# 41 F_RWT_White_total
# 43 F_RWT_White_total
# 45 F_RWT_White_total
# 47 F_RWT_White_total
# 49 F_RWT_White_total
# 51 F_RWT_White_total
# 53 F_RWT_White_total
# 55 F_RWT_White_total
# Suggested swivel order
# [2, 7, 16, 1, 12, 10, 14, 6, 9, 5, 4, 3, 15, 8, 0, 20, 13, 11, 22, 19, 18, 21, 17]
# F_RBT_Black_total
# 00 F_RBT_Black_total
# 11 F_RBT_Black_total
# 13 F_RBT_Black_total
# 15 F_RBT_Black_total
# 17 F_RBT_Black_total
# 19 F_RBT_Black_total
# 21 F_RBT_Black_total
# 23 F_RBT_Black_total
# 25 F_RBT_Black_total
# 27 F_RBT_Black_total
# 29 F_RBT_Black_total
# 31 F_RBT_Black_total
# 33 F_RBT_Black_total
# 35 F_RBT_Black_total
# 37 F_RBT_Black_total
# 39 F_RBT_Black_total
# 41 F_RBT_Black_total
# 43 F_RBT_Black_total
# 45 F_RBT_Black_total
# 47 F_RBT_Black_total
# 49 F_RBT_Black_total
# 51 F_RBT_Black_total
# 53 F_RBT_Black_total
# 55 F_RBT_Black_total
# Suggested swivel order
# [2, 4, 6, 7, 10, 9, 1, 16, 12, 0, 15, 5, 22, 14, 20, 3, 13, 8, 19, 11, 18, 21, 17]
# F_RAT_Asian_total
# 00 F_RAT_Asian_total
# 11 F_RAT_Asian_total
# 13 F_RAT_Asian_total
# 15 F_RAT_Asian_total
# 17 F_RAT_Asian_total
# 19 F_RAT_Asian_total
# 21 F_RAT_Asian_total
# 23 F_RAT_Asian_total
# 25 F_RAT_Asian_total
# 27 F_RAT_Asian_total
# 29 F_RAT_Asian_total
# 31 F_RAT_Asian_total
# 33 F_RAT_Asian_total
# 35 F_RAT_Asian_total
# 37 F_RAT_Asian_total
# 39 F_RAT_Asian_total
# 41 F_RAT_Asian_total
# 43 F_RAT_Asian_total
# 45 F_RAT_Asian_total
# 47 F_RAT_Asian_total
# 49 F_RAT_Asian_total
# 51 F_RAT_Asian_total
# 53 F_RAT_Asian_total
# 55 F_RAT_Asian_total
# Suggested swivel order
# [1, 2, 3, 4, 5, 6, 7, 8, 10, 13, 14, 22, 0, 16, 9, 20, 12, 19, 15, 11, 18, 21, 17]
# F_RHT_Hispanic_total
# 00 F_RHT_Hispanic_total
# 11 F_RHT_Hispanic_total
# 13 F_RHT_Hispanic_total
# 15 F_RHT_Hispanic_total
# 17 F_RHT_Hispanic_total
# 19 F_RHT_Hispanic_total
# 21 F_RHT_Hispanic_total
# 23 F_RHT_Hispanic_total
# 25 F_RHT_Hispanic_total
# 27 F_RHT_Hispanic_total
# 29 F_RHT_Hispanic_total
# 31 F_RHT_Hispanic_total
# 33 F_RHT_Hispanic_total
# 35 F_RHT_Hispanic_total
# 37 F_RHT_Hispanic_total
# 39 F_RHT_Hispanic_total
# 41 F_RHT_Hispanic_total
# 43 F_RHT_Hispanic_total
# 45 F_RHT_Hispanic_total
# 47 F_RHT_Hispanic_total
# 49 F_RHT_Hispanic_total
# 51 F_RHT_Hispanic_total
# 53 F_RHT_Hispanic_total
# 55 F_RHT_Hispanic_total
# Normalizing Hispanic
# Suggested swivel order
# [1, 2, 4, 5, 6, 7, 9, 3, 16, 14, 10, 0, 12, 15, 8, 20, 22, 11, 19, 21, 13, 18, 17]
# ['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_RWT_White_total_all.csv
# Importing  ../DATA/SOC_all.csv
# F_RBT_Black_total_all.csv
# Importing  ../DATA/F_RWT_White_total_all.csv
# F_RAT_Asian_total_all.csv
# Importing  ../DATA/F_RBT_Black_total_all.csv
# F_RHT_Hispanic_total_all.csv
# Importing  ../DATA/F_RAT_Asian_total_all.csv
# F_RNT_Total_foreign_born_all.csv
# F_RFT_Total_native_born_all.csv
# F_RIT_American_indian_total_all.csv
# F_RMT_Multiple_race_total_all.csv
# F_RPT_Hawaiian_total_all.csv
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# F_RWT_White_total
# 00 F_RWT_White_total
# 11 F_RWT_White_total
# 13 F_RWT_White_total
# 15 F_RWT_White_total
# 17 F_RWT_White_total
# 19 F_RWT_White_total
# 21 F_RWT_White_total
# 23 F_RWT_White_total
# 25 F_RWT_White_total
# 27 F_RWT_White_total
# 29 F_RWT_White_total
# 31 F_RWT_White_total
# 33 F_RWT_White_total
# 35 F_RWT_White_total
# 37 F_RWT_White_total
# 39 F_RWT_White_total
# 41 F_RWT_White_total
# 43 F_RWT_White_total
# 45 F_RWT_White_total
# 47 F_RWT_White_total
# 49 F_RWT_White_total
# 51 F_RWT_White_total
# 53 F_RWT_White_total
# 55 F_RWT_White_total
# Suggested swivel order
# [7, 2, 16, 1, 9, 6, 12, 14, 5, 10, 4, 15, 3, 8, 20, 0, 22, 13, 18, 11, 19, 21, 17]
# F_RBT_Black_total
# 00 F_RBT_Black_total
# 11 F_RBT_Black_total
# 13 F_RBT_Black_total
# 15 F_RBT_Black_total
# 17 F_RBT_Black_total
# 19 F_RBT_Black_total
# 21 F_RBT_Black_total
# 23 F_RBT_Black_total
# 25 F_RBT_Black_total
# 27 F_RBT_Black_total
# 29 F_RBT_Black_total
# 31 F_RBT_Black_total
# 33 F_RBT_Black_total
# 35 F_RBT_Black_total
# 37 F_RBT_Black_total
# 39 F_RBT_Black_total
# 41 F_RBT_Black_total
# 43 F_RBT_Black_total
# 45 F_RBT_Black_total
# 47 F_RBT_Black_total
# 49 F_RBT_Black_total
# 51 F_RBT_Black_total
# 53 F_RBT_Black_total
# 55 F_RBT_Black_total
# Suggested swivel order
# [1, 3, 4, 6, 7, 2, 9, 10, 16, 12, 0, 5, 14, 15, 20, 8, 22, 13, 11, 19, 21, 18, 17]
# F_RAT_Asian_total
# 00 F_RAT_Asian_total
# 11 F_RAT_Asian_total
# 13 F_RAT_Asian_total
# 15 F_RAT_Asian_total
# 17 F_RAT_Asian_total
# 19 F_RAT_Asian_total
# 21 F_RAT_Asian_total
# 23 F_RAT_Asian_total
# 25 F_RAT_Asian_total
# 27 F_RAT_Asian_total
# 29 F_RAT_Asian_total
# 31 F_RAT_Asian_total
# 33 F_RAT_Asian_total
# 35 F_RAT_Asian_total
# 37 F_RAT_Asian_total
# 39 F_RAT_Asian_total
# 41 F_RAT_Asian_total
# 43 F_RAT_Asian_total
# 45 F_RAT_Asian_total
# 47 F_RAT_Asian_total
# 49 F_RAT_Asian_total
# 51 F_RAT_Asian_total
# 53 F_RAT_Asian_total
# 55 F_RAT_Asian_total
# Suggested swivel order
# [1, 3, 5, 6, 8, 9, 10, 16, 17, 2, 14, 4, 0, 7, 20, 13, 12, 15, 19, 11, 22, 18, 21]
# F_RHT_Hispanic_total
# 00 F_RHT_Hispanic_total
# 11 F_RHT_Hispanic_total
# 13 F_RHT_Hispanic_total
# 15 F_RHT_Hispanic_total
# 17 F_RHT_Hispanic_total
# 19 F_RHT_Hispanic_total
# 21 F_RHT_Hispanic_total
# 23 F_RHT_Hispanic_total
# 25 F_RHT_Hispanic_total
# 27 F_RHT_Hispanic_total
# 29 F_RHT_Hispanic_total
# 31 F_RHT_Hispanic_total
# 33 F_RHT_Hispanic_total
# 35 F_RHT_Hispanic_total
# 37 F_RHT_Hispanic_total
# 39 F_RHT_Hispanic_total
# 41 F_RHT_Hispanic_total
# 43 F_RHT_Hispanic_total
# 45 F_RHT_Hispanic_total
# 47 F_RHT_Hispanic_total
# 49 F_RHT_Hispanic_total
# 51 F_RHT_Hispanic_total
# 53 F_RHT_Hispanic_total
# 55 F_RHT_Hispanic_total
# Normalizing Hispanic
# Suggested swivel order
# [1, 3, 4, 6, 7, 9, 10, 22, 2, 14, 16, 0, 12, 8, 5, 15, 20, 19, 11, 21, 13, 18, 17]
# ['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_RWT_White_total_all.csv
# Importing  ../DATA/SOC_all.csv
# F_RBT_Black_total_all.csv
# Importing  ../DATA/F_RWT_White_total_all.csv
# F_RAT_Asian_total_all.csv
# Importing  ../DATA/F_RBT_Black_total_all.csv
# F_RHT_Hispanic_total_all.csv
# Importing  ../DATA/F_RAT_Asian_total_all.csv
# F_RNT_Total_foreign_born_all.csv
# F_RFT_Total_native_born_all.csv
# F_RIT_American_indian_total_all.csv
# F_RMT_Multiple_race_total_all.csv
# F_RPT_Hawaiian_total_all.csv
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# F_RWT_White_total
# 00 F_RWT_White_total
# 11 F_RWT_White_total
# 13 F_RWT_White_total
# 15 F_RWT_White_total
# 17 F_RWT_White_total
# 19 F_RWT_White_total
# 21 F_RWT_White_total
# 23 F_RWT_White_total
# 25 F_RWT_White_total
# 27 F_RWT_White_total
# 29 F_RWT_White_total
# 31 F_RWT_White_total
# 33 F_RWT_White_total
# 35 F_RWT_White_total
# 37 F_RWT_White_total
# 39 F_RWT_White_total
# 41 F_RWT_White_total
# 43 F_RWT_White_total
# 45 F_RWT_White_total
# 47 F_RWT_White_total
# 49 F_RWT_White_total
# 51 F_RWT_White_total
# 53 F_RWT_White_total
# 55 F_RWT_White_total
# Suggested swivel order
# [2, 7, 1, 16, 3, 6, 9, 10, 12, 4, 14, 15, 8, 5, 20, 0, 13, 22, 19, 18, 11, 21, 17]
# F_RBT_Black_total
# 00 F_RBT_Black_total
# 11 F_RBT_Black_total
# 13 F_RBT_Black_total
# 15 F_RBT_Black_total
# 17 F_RBT_Black_total
# 19 F_RBT_Black_total
# 21 F_RBT_Black_total
# 23 F_RBT_Black_total
# 25 F_RBT_Black_total
# 27 F_RBT_Black_total
# 29 F_RBT_Black_total
# 31 F_RBT_Black_total
# 33 F_RBT_Black_total
# 35 F_RBT_Black_total
# 37 F_RBT_Black_total
# 39 F_RBT_Black_total
# 41 F_RBT_Black_total
# 43 F_RBT_Black_total
# 45 F_RBT_Black_total
# 47 F_RBT_Black_total
# 49 F_RBT_Black_total
# 51 F_RBT_Black_total
# 53 F_RBT_Black_total
# 55 F_RBT_Black_total
# Suggested swivel order
# [1, 2, 4, 6, 7, 9, 16, 10, 0, 14, 5, 12, 8, 20, 3, 15, 13, 22, 11, 19, 18, 21, 17]
# F_RAT_Asian_total
# 00 F_RAT_Asian_total
# 11 F_RAT_Asian_total
# 13 F_RAT_Asian_total
# 15 F_RAT_Asian_total
# 17 F_RAT_Asian_total
# 19 F_RAT_Asian_total
# 21 F_RAT_Asian_total
# 23 F_RAT_Asian_total
# 25 F_RAT_Asian_total
# 27 F_RAT_Asian_total
# 29 F_RAT_Asian_total
# 31 F_RAT_Asian_total
# 33 F_RAT_Asian_total
# 35 F_RAT_Asian_total
# 37 F_RAT_Asian_total
# 39 F_RAT_Asian_total
# 41 F_RAT_Asian_total
# 43 F_RAT_Asian_total
# 45 F_RAT_Asian_total
# 47 F_RAT_Asian_total
# 49 F_RAT_Asian_total
# 51 F_RAT_Asian_total
# 53 F_RAT_Asian_total
# 55 F_RAT_Asian_total
# Suggested swivel order
# [1, 2, 3, 4, 5, 6, 7, 10, 11, 13, 14, 22, 9, 8, 16, 0, 20, 12, 15, 19, 21, 17, 18]
# F_RHT_Hispanic_total
# 00 F_RHT_Hispanic_total
# 11 F_RHT_Hispanic_total
# 13 F_RHT_Hispanic_total
# 15 F_RHT_Hispanic_total
# 17 F_RHT_Hispanic_total
# 19 F_RHT_Hispanic_total
# 21 F_RHT_Hispanic_total
# 23 F_RHT_Hispanic_total
# 25 F_RHT_Hispanic_total
# 27 F_RHT_Hispanic_total
# 29 F_RHT_Hispanic_total
# 31 F_RHT_Hispanic_total
# 33 F_RHT_Hispanic_total
# 35 F_RHT_Hispanic_total
# 37 F_RHT_Hispanic_total
# 39 F_RHT_Hispanic_total
# 41 F_RHT_Hispanic_total
# 43 F_RHT_Hispanic_total
# 45 F_RHT_Hispanic_total
# 47 F_RHT_Hispanic_total
# 49 F_RHT_Hispanic_total
# 51 F_RHT_Hispanic_total
# 53 F_RHT_Hispanic_total
# 55 F_RHT_Hispanic_total
# Normalizing Hispanic
# Suggested swivel order
# [1, 2, 3, 4, 5, 6, 7, 9, 10, 14, 0, 16, 8, 15, 12, 22, 20, 19, 11, 21, 13, 18, 17]
# ['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# F_RWT_White_total_all.csv
# Importing  ../DATA/SOC_all.csv
# F_RBT_Black_total_all.csv
# Importing  ../DATA/F_RWT_White_total_all.csv
# F_RAT_Asian_total_all.csv
# Importing  ../DATA/F_RBT_Black_total_all.csv
# F_RHT_Hispanic_total_all.csv
# Importing  ../DATA/F_RAT_Asian_total_all.csv
# F_RNT_Total_foreign_born_all.csv
# F_RFT_Total_native_born_all.csv
# F_RIT_American_indian_total_all.csv
# F_RMT_Multiple_race_total_all.csv
# F_RPT_Hawaiian_total_all.csv
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# dict_keys(['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total'])
# F_RWT_White_total
# 00 F_RWT_White_total
# 11 F_RWT_White_total
# 13 F_RWT_White_total
# 15 F_RWT_White_total
# 17 F_RWT_White_total
# 19 F_RWT_White_total
# 21 F_RWT_White_total
# 23 F_RWT_White_total
# 25 F_RWT_White_total
# 27 F_RWT_White_total
# 29 F_RWT_White_total
# 31 F_RWT_White_total
# 33 F_RWT_White_total
# 35 F_RWT_White_total
# 37 F_RWT_White_total
# 39 F_RWT_White_total
# 41 F_RWT_White_total
# 43 F_RWT_White_total
# 45 F_RWT_White_total
# 47 F_RWT_White_total
# 49 F_RWT_White_total
# 51 F_RWT_White_total
# 53 F_RWT_White_total
# 55 F_RWT_White_total
# Suggested swivel order
# [2, 16, 7, 1, 3, 9, 6, 10, 12, 5, 14, 4, 15, 8, 20, 0, 13, 22, 19, 11, 18, 21, 17]
# F_RBT_Black_total
# 00 F_RBT_Black_total
# 11 F_RBT_Black_total
# 13 F_RBT_Black_total
# 15 F_RBT_Black_total
# 17 F_RBT_Black_total
# 19 F_RBT_Black_total
# 21 F_RBT_Black_total
# 23 F_RBT_Black_total
# 25 F_RBT_Black_total
# 27 F_RBT_Black_total
# 29 F_RBT_Black_total
# 31 F_RBT_Black_total
# 33 F_RBT_Black_total
# 35 F_RBT_Black_total
# 37 F_RBT_Black_total
# 39 F_RBT_Black_total
# 41 F_RBT_Black_total
# 43 F_RBT_Black_total
# 45 F_RBT_Black_total
# 47 F_RBT_Black_total
# 49 F_RBT_Black_total
# 51 F_RBT_Black_total
# 53 F_RBT_Black_total
# 55 F_RBT_Black_total
# Suggested swivel order
# [2, 3, 4, 6, 7, 16, 1, 0, 10, 9, 5, 14, 15, 8, 12, 20, 13, 11, 22, 19, 18, 21, 17]
# F_RAT_Asian_total
# 00 F_RAT_Asian_total
# 11 F_RAT_Asian_total
# 13 F_RAT_Asian_total
# 15 F_RAT_Asian_total
# 17 F_RAT_Asian_total
# 19 F_RAT_Asian_total
# 21 F_RAT_Asian_total
# 23 F_RAT_Asian_total
# 25 F_RAT_Asian_total
# 27 F_RAT_Asian_total
# 29 F_RAT_Asian_total
# 31 F_RAT_Asian_total
# 33 F_RAT_Asian_total
# 35 F_RAT_Asian_total
# 37 F_RAT_Asian_total
# 39 F_RAT_Asian_total
# 41 F_RAT_Asian_total
# 43 F_RAT_Asian_total
# 45 F_RAT_Asian_total
# 47 F_RAT_Asian_total
# 49 F_RAT_Asian_total
# 51 F_RAT_Asian_total
# 53 F_RAT_Asian_total
# 55 F_RAT_Asian_total
# Suggested swivel order
# [1, 2, 5, 6, 7, 8, 9, 10, 17, 22, 16, 14, 3, 12, 0, 20, 4, 13, 15, 19, 18, 11, 21]
# F_RHT_Hispanic_total
# 00 F_RHT_Hispanic_total
# 11 F_RHT_Hispanic_total
# 13 F_RHT_Hispanic_total
# 15 F_RHT_Hispanic_total
# 17 F_RHT_Hispanic_total
# 19 F_RHT_Hispanic_total
# 21 F_RHT_Hispanic_total
# 23 F_RHT_Hispanic_total
# 25 F_RHT_Hispanic_total
# 27 F_RHT_Hispanic_total
# 29 F_RHT_Hispanic_total
# 31 F_RHT_Hispanic_total
# 33 F_RHT_Hispanic_total
# 35 F_RHT_Hispanic_total
# 37 F_RHT_Hispanic_total
# 39 F_RHT_Hispanic_total
# 41 F_RHT_Hispanic_total
# 43 F_RHT_Hispanic_total
# 45 F_RHT_Hispanic_total
# 47 F_RHT_Hispanic_total
# 49 F_RHT_Hispanic_total
# 51 F_RHT_Hispanic_total
# 53 F_RHT_Hispanic_total
# 55 F_RHT_Hispanic_total
# Normalizing Hispanic
# Suggested swivel order
# [1, 4, 5, 6, 7, 9, 2, 0, 14, 16, 3, 10, 15, 12, 8, 20, 22, 11, 19, 21, 13, 18, 17]
# ['F_RWT_White_total', 'F_RBT_Black_total', 'F_RAT_Asian_total', 'F_RHT_Hispanic_total']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_RGX_NR_all.csv
# NF_RAX_AmericanIndian_AlaskaNative_all.csv
# NF_RCX_Black_AfricanAmerican_all.csv
# Importing  ../DATA/SOC_all.csv
# NF_RIX_Hispanic_all.csv
# Importing  ../DATA/NF_RCX_Black_AfricanAmerican_all.csv
# NF_RHX_Multi_all.csv
# NF_REX_Hawaiian_all.csv
# NF_RFX_White_all.csv
# Importing  ../DATA/NF_RIX_Hispanic_all.csv
# NF_RBX_Asian_all.csv
# Importing  ../DATA/NF_RFX_White_all.csv
# NF_RDX_Hispanic_all.csv
# Importing  ../DATA/NF_RBX_Asian_all.csv
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# NF_RCX_Black_AfricanAmerican
# 00 NF_RCX_Black_AfricanAmerican
# 11 NF_RCX_Black_AfricanAmerican
# 13 NF_RCX_Black_AfricanAmerican
# 15 NF_RCX_Black_AfricanAmerican
# 17 NF_RCX_Black_AfricanAmerican
# 19 NF_RCX_Black_AfricanAmerican
# 21 NF_RCX_Black_AfricanAmerican
# 23 NF_RCX_Black_AfricanAmerican
# 25 NF_RCX_Black_AfricanAmerican
# 27 NF_RCX_Black_AfricanAmerican
# 29 NF_RCX_Black_AfricanAmerican
# 31 NF_RCX_Black_AfricanAmerican
# 33 NF_RCX_Black_AfricanAmerican
# 35 NF_RCX_Black_AfricanAmerican
# 37 NF_RCX_Black_AfricanAmerican
# 39 NF_RCX_Black_AfricanAmerican
# 41 NF_RCX_Black_AfricanAmerican
# 43 NF_RCX_Black_AfricanAmerican
# 45 NF_RCX_Black_AfricanAmerican
# 47 NF_RCX_Black_AfricanAmerican
# 49 NF_RCX_Black_AfricanAmerican
# 51 NF_RCX_Black_AfricanAmerican
# 53 NF_RCX_Black_AfricanAmerican
# 55 NF_RCX_Black_AfricanAmerican
# Suggested swivel order
# [22, 3, 6, 2, 1, 8, 0, 15, 4, 7, 16, 5, 14, 9, 18, 12, 17, 20, 19, 21, 13, 11, 10]
# NF_RIX_Hispanic
# 00 NF_RIX_Hispanic
# 11 NF_RIX_Hispanic
# 13 NF_RIX_Hispanic
# 15 NF_RIX_Hispanic
# 17 NF_RIX_Hispanic
# 19 NF_RIX_Hispanic
# 21 NF_RIX_Hispanic
# 23 NF_RIX_Hispanic
# 25 NF_RIX_Hispanic
# 27 NF_RIX_Hispanic
# 29 NF_RIX_Hispanic
# 31 NF_RIX_Hispanic
# 33 NF_RIX_Hispanic
# 35 NF_RIX_Hispanic
# 37 NF_RIX_Hispanic
# 39 NF_RIX_Hispanic
# 41 NF_RIX_Hispanic
# 43 NF_RIX_Hispanic
# 45 NF_RIX_Hispanic
# 47 NF_RIX_Hispanic
# 49 NF_RIX_Hispanic
# 51 NF_RIX_Hispanic
# 53 NF_RIX_Hispanic
# 55 NF_RIX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [1, 2, 3, 4, 5, 6, 8, 11, 14, 17, 18, 22, 15, 9, 16, 0, 12, 20, 7, 10, 21, 19, 13]
# NF_RFX_White
# 00 NF_RFX_White
# 11 NF_RFX_White
# 13 NF_RFX_White
# 15 NF_RFX_White
# 17 NF_RFX_White
# 19 NF_RFX_White
# 21 NF_RFX_White
# 23 NF_RFX_White
# 25 NF_RFX_White
# 27 NF_RFX_White
# 29 NF_RFX_White
# 31 NF_RFX_White
# 33 NF_RFX_White
# 35 NF_RFX_White
# 37 NF_RFX_White
# 39 NF_RFX_White
# 41 NF_RFX_White
# 43 NF_RFX_White
# 45 NF_RFX_White
# 47 NF_RFX_White
# 49 NF_RFX_White
# 51 NF_RFX_White
# 53 NF_RFX_White
# 55 NF_RFX_White
# Suggested swivel order
# [22, 2, 1, 6, 3, 4, 0, 8, 15, 5, 16, 7, 14, 17, 9, 12, 18, 13, 20, 21, 10, 19, 11]
# NF_RBX_Asian
# 00 NF_RBX_Asian
# 11 NF_RBX_Asian
# 13 NF_RBX_Asian
# 15 NF_RBX_Asian
# 17 NF_RBX_Asian
# 19 NF_RBX_Asian
# 21 NF_RBX_Asian
# 23 NF_RBX_Asian
# 25 NF_RBX_Asian
# 27 NF_RBX_Asian
# 29 NF_RBX_Asian
# 31 NF_RBX_Asian
# 33 NF_RBX_Asian
# 35 NF_RBX_Asian
# 37 NF_RBX_Asian
# 39 NF_RBX_Asian
# 41 NF_RBX_Asian
# 43 NF_RBX_Asian
# 45 NF_RBX_Asian
# 47 NF_RBX_Asian
# 49 NF_RBX_Asian
# 51 NF_RBX_Asian
# 53 NF_RBX_Asian
# 55 NF_RBX_Asian
# Suggested swivel order
# [6, 22, 2, 3, 8, 1, 7, 0, 4, 15, 5, 14, 16, 9, 17, 18, 12, 21, 20, 19, 10, 11, 13]
# NF_RDX_Hispanic
# 00 NF_RDX_Hispanic
# 11 NF_RDX_Hispanic
# 13 NF_RDX_Hispanic
# 15 NF_RDX_Hispanic
# 17 NF_RDX_Hispanic
# 19 NF_RDX_Hispanic
# 21 NF_RDX_Hispanic
# 23 NF_RDX_Hispanic
# 25 NF_RDX_Hispanic
# 27 NF_RDX_Hispanic
# 29 NF_RDX_Hispanic
# 31 NF_RDX_Hispanic
# 33 NF_RDX_Hispanic
# 35 NF_RDX_Hispanic
# 37 NF_RDX_Hispanic
# 39 NF_RDX_Hispanic
# 41 NF_RDX_Hispanic
# 43 NF_RDX_Hispanic
# 45 NF_RDX_Hispanic
# 47 NF_RDX_Hispanic
# 49 NF_RDX_Hispanic
# 51 NF_RDX_Hispanic
# 53 NF_RDX_Hispanic
# 55 NF_RDX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [22, 2, 4, 3, 1, 6, 0, 9, 14, 15, 7, 8, 5, 16, 12, 10, 20, 21, 19, 11, 18, 13, 17]
# ['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_RGX_NR_all.csv
# NF_RAX_AmericanIndian_AlaskaNative_all.csv
# NF_RCX_Black_AfricanAmerican_all.csv
# Importing  ../DATA/SOC_all.csv
# NF_RIX_Hispanic_all.csv
# Importing  ../DATA/NF_RCX_Black_AfricanAmerican_all.csv
# NF_RHX_Multi_all.csv
# NF_REX_Hawaiian_all.csv
# NF_RFX_White_all.csv
# Importing  ../DATA/NF_RIX_Hispanic_all.csv
# NF_RBX_Asian_all.csv
# Importing  ../DATA/NF_RFX_White_all.csv
# NF_RDX_Hispanic_all.csv
# Importing  ../DATA/NF_RBX_Asian_all.csv
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# NF_RCX_Black_AfricanAmerican
# 00 NF_RCX_Black_AfricanAmerican
# 11 NF_RCX_Black_AfricanAmerican
# 13 NF_RCX_Black_AfricanAmerican
# 15 NF_RCX_Black_AfricanAmerican
# 17 NF_RCX_Black_AfricanAmerican
# 19 NF_RCX_Black_AfricanAmerican
# 21 NF_RCX_Black_AfricanAmerican
# 23 NF_RCX_Black_AfricanAmerican
# 25 NF_RCX_Black_AfricanAmerican
# 27 NF_RCX_Black_AfricanAmerican
# 29 NF_RCX_Black_AfricanAmerican
# 31 NF_RCX_Black_AfricanAmerican
# 33 NF_RCX_Black_AfricanAmerican
# 35 NF_RCX_Black_AfricanAmerican
# 37 NF_RCX_Black_AfricanAmerican
# 39 NF_RCX_Black_AfricanAmerican
# 41 NF_RCX_Black_AfricanAmerican
# 43 NF_RCX_Black_AfricanAmerican
# 45 NF_RCX_Black_AfricanAmerican
# 47 NF_RCX_Black_AfricanAmerican
# 49 NF_RCX_Black_AfricanAmerican
# 51 NF_RCX_Black_AfricanAmerican
# 53 NF_RCX_Black_AfricanAmerican
# 55 NF_RCX_Black_AfricanAmerican
# Suggested swivel order
# [22, 2, 3, 1, 4, 6, 0, 15, 16, 7, 8, 9, 14, 5, 12, 18, 20, 11, 21, 19, 13, 10, 17]
# NF_RIX_Hispanic
# 00 NF_RIX_Hispanic
# 11 NF_RIX_Hispanic
# 13 NF_RIX_Hispanic
# 15 NF_RIX_Hispanic
# 17 NF_RIX_Hispanic
# 19 NF_RIX_Hispanic
# 21 NF_RIX_Hispanic
# 23 NF_RIX_Hispanic
# 25 NF_RIX_Hispanic
# 27 NF_RIX_Hispanic
# 29 NF_RIX_Hispanic
# 31 NF_RIX_Hispanic
# 33 NF_RIX_Hispanic
# 35 NF_RIX_Hispanic
# 37 NF_RIX_Hispanic
# 39 NF_RIX_Hispanic
# 41 NF_RIX_Hispanic
# 43 NF_RIX_Hispanic
# 45 NF_RIX_Hispanic
# 47 NF_RIX_Hispanic
# 49 NF_RIX_Hispanic
# 51 NF_RIX_Hispanic
# 53 NF_RIX_Hispanic
# 55 NF_RIX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [1, 2, 3, 4, 5, 6, 17, 22, 0, 16, 14, 9, 12, 7, 8, 19, 20, 18, 21, 13, 10, 15, 11]
# NF_RFX_White
# 00 NF_RFX_White
# 11 NF_RFX_White
# 13 NF_RFX_White
# 15 NF_RFX_White
# 17 NF_RFX_White
# 19 NF_RFX_White
# 21 NF_RFX_White
# 23 NF_RFX_White
# 25 NF_RFX_White
# 27 NF_RFX_White
# 29 NF_RFX_White
# 31 NF_RFX_White
# 33 NF_RFX_White
# 35 NF_RFX_White
# 37 NF_RFX_White
# 39 NF_RFX_White
# 41 NF_RFX_White
# 43 NF_RFX_White
# 45 NF_RFX_White
# 47 NF_RFX_White
# 49 NF_RFX_White
# 51 NF_RFX_White
# 53 NF_RFX_White
# 55 NF_RFX_White
# Suggested swivel order
# [22, 2, 6, 1, 3, 8, 4, 0, 15, 16, 7, 5, 14, 17, 9, 12, 13, 18, 20, 21, 10, 19, 11]
# NF_RBX_Asian
# 00 NF_RBX_Asian
# 11 NF_RBX_Asian
# 13 NF_RBX_Asian
# 15 NF_RBX_Asian
# 17 NF_RBX_Asian
# 19 NF_RBX_Asian
# 21 NF_RBX_Asian
# 23 NF_RBX_Asian
# 25 NF_RBX_Asian
# 27 NF_RBX_Asian
# 29 NF_RBX_Asian
# 31 NF_RBX_Asian
# 33 NF_RBX_Asian
# 35 NF_RBX_Asian
# 37 NF_RBX_Asian
# 39 NF_RBX_Asian
# 41 NF_RBX_Asian
# 43 NF_RBX_Asian
# 45 NF_RBX_Asian
# 47 NF_RBX_Asian
# 49 NF_RBX_Asian
# 51 NF_RBX_Asian
# 53 NF_RBX_Asian
# 55 NF_RBX_Asian
# Suggested swivel order
# [6, 22, 2, 1, 0, 3, 4, 8, 7, 14, 15, 16, 5, 9, 18, 21, 12, 20, 10, 19, 13, 17, 11]
# NF_RDX_Hispanic
# 00 NF_RDX_Hispanic
# 11 NF_RDX_Hispanic
# 13 NF_RDX_Hispanic
# 15 NF_RDX_Hispanic
# 17 NF_RDX_Hispanic
# 19 NF_RDX_Hispanic
# 21 NF_RDX_Hispanic
# 23 NF_RDX_Hispanic
# 25 NF_RDX_Hispanic
# 27 NF_RDX_Hispanic
# 29 NF_RDX_Hispanic
# 31 NF_RDX_Hispanic
# 33 NF_RDX_Hispanic
# 35 NF_RDX_Hispanic
# 37 NF_RDX_Hispanic
# 39 NF_RDX_Hispanic
# 41 NF_RDX_Hispanic
# 43 NF_RDX_Hispanic
# 45 NF_RDX_Hispanic
# 47 NF_RDX_Hispanic
# 49 NF_RDX_Hispanic
# 51 NF_RDX_Hispanic
# 53 NF_RDX_Hispanic
# 55 NF_RDX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [22, 2, 3, 4, 1, 6, 0, 8, 9, 7, 15, 14, 5, 16, 10, 12, 20, 21, 11, 19, 18, 13, 17]
# ['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_RGX_NR_all.csv
# NF_RAX_AmericanIndian_AlaskaNative_all.csv
# NF_RCX_Black_AfricanAmerican_all.csv
# Importing  ../DATA/SOC_all.csv
# NF_RIX_Hispanic_all.csv
# Importing  ../DATA/NF_RCX_Black_AfricanAmerican_all.csv
# NF_RHX_Multi_all.csv
# NF_REX_Hawaiian_all.csv
# NF_RFX_White_all.csv
# Importing  ../DATA/NF_RIX_Hispanic_all.csv
# NF_RBX_Asian_all.csv
# Importing  ../DATA/NF_RFX_White_all.csv
# NF_RDX_Hispanic_all.csv
# Importing  ../DATA/NF_RBX_Asian_all.csv
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# NF_RCX_Black_AfricanAmerican
# 00 NF_RCX_Black_AfricanAmerican
# 11 NF_RCX_Black_AfricanAmerican
# 13 NF_RCX_Black_AfricanAmerican
# 15 NF_RCX_Black_AfricanAmerican
# 17 NF_RCX_Black_AfricanAmerican
# 19 NF_RCX_Black_AfricanAmerican
# 21 NF_RCX_Black_AfricanAmerican
# 23 NF_RCX_Black_AfricanAmerican
# 25 NF_RCX_Black_AfricanAmerican
# 27 NF_RCX_Black_AfricanAmerican
# 29 NF_RCX_Black_AfricanAmerican
# 31 NF_RCX_Black_AfricanAmerican
# 33 NF_RCX_Black_AfricanAmerican
# 35 NF_RCX_Black_AfricanAmerican
# 37 NF_RCX_Black_AfricanAmerican
# 39 NF_RCX_Black_AfricanAmerican
# 41 NF_RCX_Black_AfricanAmerican
# 43 NF_RCX_Black_AfricanAmerican
# 45 NF_RCX_Black_AfricanAmerican
# 47 NF_RCX_Black_AfricanAmerican
# 49 NF_RCX_Black_AfricanAmerican
# 51 NF_RCX_Black_AfricanAmerican
# 53 NF_RCX_Black_AfricanAmerican
# 55 NF_RCX_Black_AfricanAmerican
# Suggested swivel order
# [22, 2, 3, 6, 1, 0, 15, 4, 16, 8, 7, 14, 18, 9, 12, 5, 20, 13, 19, 11, 21, 17, 10]
# NF_RIX_Hispanic
# 00 NF_RIX_Hispanic
# 11 NF_RIX_Hispanic
# 13 NF_RIX_Hispanic
# 15 NF_RIX_Hispanic
# 17 NF_RIX_Hispanic
# 19 NF_RIX_Hispanic
# 21 NF_RIX_Hispanic
# 23 NF_RIX_Hispanic
# 25 NF_RIX_Hispanic
# 27 NF_RIX_Hispanic
# 29 NF_RIX_Hispanic
# 31 NF_RIX_Hispanic
# 33 NF_RIX_Hispanic
# 35 NF_RIX_Hispanic
# 37 NF_RIX_Hispanic
# 39 NF_RIX_Hispanic
# 41 NF_RIX_Hispanic
# 43 NF_RIX_Hispanic
# 45 NF_RIX_Hispanic
# 47 NF_RIX_Hispanic
# 49 NF_RIX_Hispanic
# 51 NF_RIX_Hispanic
# 53 NF_RIX_Hispanic
# 55 NF_RIX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [0, 1, 2, 3, 4, 5, 6, 8, 17, 18, 22, 14, 9, 15, 7, 16, 20, 12, 13, 21, 19, 11, 10]
# NF_RFX_White
# 00 NF_RFX_White
# 11 NF_RFX_White
# 13 NF_RFX_White
# 15 NF_RFX_White
# 17 NF_RFX_White
# 19 NF_RFX_White
# 21 NF_RFX_White
# 23 NF_RFX_White
# 25 NF_RFX_White
# 27 NF_RFX_White
# 29 NF_RFX_White
# 31 NF_RFX_White
# 33 NF_RFX_White
# 35 NF_RFX_White
# 37 NF_RFX_White
# 39 NF_RFX_White
# 41 NF_RFX_White
# 43 NF_RFX_White
# 45 NF_RFX_White
# 47 NF_RFX_White
# 49 NF_RFX_White
# 51 NF_RFX_White
# 53 NF_RFX_White
# 55 NF_RFX_White
# Suggested swivel order
# [22, 2, 6, 1, 3, 0, 4, 8, 15, 16, 7, 5, 17, 14, 9, 12, 13, 18, 20, 21, 10, 19, 11]
# NF_RBX_Asian
# 00 NF_RBX_Asian
# 11 NF_RBX_Asian
# 13 NF_RBX_Asian
# 15 NF_RBX_Asian
# 17 NF_RBX_Asian
# 19 NF_RBX_Asian
# 21 NF_RBX_Asian
# 23 NF_RBX_Asian
# 25 NF_RBX_Asian
# 27 NF_RBX_Asian
# 29 NF_RBX_Asian
# 31 NF_RBX_Asian
# 33 NF_RBX_Asian
# 35 NF_RBX_Asian
# 37 NF_RBX_Asian
# 39 NF_RBX_Asian
# 41 NF_RBX_Asian
# 43 NF_RBX_Asian
# 45 NF_RBX_Asian
# 47 NF_RBX_Asian
# 49 NF_RBX_Asian
# 51 NF_RBX_Asian
# 53 NF_RBX_Asian
# 55 NF_RBX_Asian
# Suggested swivel order
# [22, 2, 3, 1, 6, 0, 14, 7, 8, 15, 4, 5, 16, 9, 17, 18, 21, 12, 19, 20, 11, 10, 13]
# NF_RDX_Hispanic
# 00 NF_RDX_Hispanic
# 11 NF_RDX_Hispanic
# 13 NF_RDX_Hispanic
# 15 NF_RDX_Hispanic
# 17 NF_RDX_Hispanic
# 19 NF_RDX_Hispanic
# 21 NF_RDX_Hispanic
# 23 NF_RDX_Hispanic
# 25 NF_RDX_Hispanic
# 27 NF_RDX_Hispanic
# 29 NF_RDX_Hispanic
# 31 NF_RDX_Hispanic
# 33 NF_RDX_Hispanic
# 35 NF_RDX_Hispanic
# 37 NF_RDX_Hispanic
# 39 NF_RDX_Hispanic
# 41 NF_RDX_Hispanic
# 43 NF_RDX_Hispanic
# 45 NF_RDX_Hispanic
# 47 NF_RDX_Hispanic
# 49 NF_RDX_Hispanic
# 51 NF_RDX_Hispanic
# 53 NF_RDX_Hispanic
# 55 NF_RDX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [22, 2, 3, 1, 4, 6, 0, 8, 9, 14, 7, 15, 16, 5, 10, 12, 20, 21, 11, 19, 13, 18, 17]
# ['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_RGX_NR_all.csv
# NF_RAX_AmericanIndian_AlaskaNative_all.csv
# NF_RCX_Black_AfricanAmerican_all.csv
# Importing  ../DATA/SOC_all.csv
# NF_RIX_Hispanic_all.csv
# Importing  ../DATA/NF_RCX_Black_AfricanAmerican_all.csv
# NF_RHX_Multi_all.csv
# NF_REX_Hawaiian_all.csv
# NF_RFX_White_all.csv
# Importing  ../DATA/NF_RIX_Hispanic_all.csv
# NF_RBX_Asian_all.csv
# Importing  ../DATA/NF_RFX_White_all.csv
# NF_RDX_Hispanic_all.csv
# Importing  ../DATA/NF_RBX_Asian_all.csv
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# NF_RCX_Black_AfricanAmerican
# 00 NF_RCX_Black_AfricanAmerican
# 11 NF_RCX_Black_AfricanAmerican
# 13 NF_RCX_Black_AfricanAmerican
# 15 NF_RCX_Black_AfricanAmerican
# 17 NF_RCX_Black_AfricanAmerican
# 19 NF_RCX_Black_AfricanAmerican
# 21 NF_RCX_Black_AfricanAmerican
# 23 NF_RCX_Black_AfricanAmerican
# 25 NF_RCX_Black_AfricanAmerican
# 27 NF_RCX_Black_AfricanAmerican
# 29 NF_RCX_Black_AfricanAmerican
# 31 NF_RCX_Black_AfricanAmerican
# 33 NF_RCX_Black_AfricanAmerican
# 35 NF_RCX_Black_AfricanAmerican
# 37 NF_RCX_Black_AfricanAmerican
# 39 NF_RCX_Black_AfricanAmerican
# 41 NF_RCX_Black_AfricanAmerican
# 43 NF_RCX_Black_AfricanAmerican
# 45 NF_RCX_Black_AfricanAmerican
# 47 NF_RCX_Black_AfricanAmerican
# 49 NF_RCX_Black_AfricanAmerican
# 51 NF_RCX_Black_AfricanAmerican
# 53 NF_RCX_Black_AfricanAmerican
# 55 NF_RCX_Black_AfricanAmerican
# Suggested swivel order
# [22, 2, 3, 6, 4, 1, 15, 0, 16, 7, 8, 5, 14, 9, 12, 17, 18, 20, 13, 19, 11, 21, 10]
# NF_RIX_Hispanic
# 00 NF_RIX_Hispanic
# 11 NF_RIX_Hispanic
# 13 NF_RIX_Hispanic
# 15 NF_RIX_Hispanic
# 17 NF_RIX_Hispanic
# 19 NF_RIX_Hispanic
# 21 NF_RIX_Hispanic
# 23 NF_RIX_Hispanic
# 25 NF_RIX_Hispanic
# 27 NF_RIX_Hispanic
# 29 NF_RIX_Hispanic
# 31 NF_RIX_Hispanic
# 33 NF_RIX_Hispanic
# 35 NF_RIX_Hispanic
# 37 NF_RIX_Hispanic
# 39 NF_RIX_Hispanic
# 41 NF_RIX_Hispanic
# 43 NF_RIX_Hispanic
# 45 NF_RIX_Hispanic
# 47 NF_RIX_Hispanic
# 49 NF_RIX_Hispanic
# 51 NF_RIX_Hispanic
# 53 NF_RIX_Hispanic
# 55 NF_RIX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [0, 1, 2, 3, 4, 5, 6, 7, 8, 14, 17, 22, 9, 15, 16, 12, 20, 19, 10, 21, 18, 11, 13]
# NF_RFX_White
# 00 NF_RFX_White
# 11 NF_RFX_White
# 13 NF_RFX_White
# 15 NF_RFX_White
# 17 NF_RFX_White
# 19 NF_RFX_White
# 21 NF_RFX_White
# 23 NF_RFX_White
# 25 NF_RFX_White
# 27 NF_RFX_White
# 29 NF_RFX_White
# 31 NF_RFX_White
# 33 NF_RFX_White
# 35 NF_RFX_White
# 37 NF_RFX_White
# 39 NF_RFX_White
# 41 NF_RFX_White
# 43 NF_RFX_White
# 45 NF_RFX_White
# 47 NF_RFX_White
# 49 NF_RFX_White
# 51 NF_RFX_White
# 53 NF_RFX_White
# 55 NF_RFX_White
# Suggested swivel order
# [22, 2, 6, 1, 0, 3, 8, 4, 15, 16, 7, 5, 14, 17, 9, 12, 13, 18, 20, 10, 19, 21, 11]
# NF_RBX_Asian
# 00 NF_RBX_Asian
# 11 NF_RBX_Asian
# 13 NF_RBX_Asian
# 15 NF_RBX_Asian
# 17 NF_RBX_Asian
# 19 NF_RBX_Asian
# 21 NF_RBX_Asian
# 23 NF_RBX_Asian
# 25 NF_RBX_Asian
# 27 NF_RBX_Asian
# 29 NF_RBX_Asian
# 31 NF_RBX_Asian
# 33 NF_RBX_Asian
# 35 NF_RBX_Asian
# 37 NF_RBX_Asian
# 39 NF_RBX_Asian
# 41 NF_RBX_Asian
# 43 NF_RBX_Asian
# 45 NF_RBX_Asian
# 47 NF_RBX_Asian
# 49 NF_RBX_Asian
# 51 NF_RBX_Asian
# 53 NF_RBX_Asian
# 55 NF_RBX_Asian
# Suggested swivel order
# [6, 22, 2, 3, 1, 8, 0, 4, 14, 15, 7, 5, 16, 9, 18, 17, 21, 12, 20, 19, 10, 13, 11]
# NF_RDX_Hispanic
# 00 NF_RDX_Hispanic
# 11 NF_RDX_Hispanic
# 13 NF_RDX_Hispanic
# 15 NF_RDX_Hispanic
# 17 NF_RDX_Hispanic
# 19 NF_RDX_Hispanic
# 21 NF_RDX_Hispanic
# 23 NF_RDX_Hispanic
# 25 NF_RDX_Hispanic
# 27 NF_RDX_Hispanic
# 29 NF_RDX_Hispanic
# 31 NF_RDX_Hispanic
# 33 NF_RDX_Hispanic
# 35 NF_RDX_Hispanic
# 37 NF_RDX_Hispanic
# 39 NF_RDX_Hispanic
# 41 NF_RDX_Hispanic
# 43 NF_RDX_Hispanic
# 45 NF_RDX_Hispanic
# 47 NF_RDX_Hispanic
# 49 NF_RDX_Hispanic
# 51 NF_RDX_Hispanic
# 53 NF_RDX_Hispanic
# 55 NF_RDX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [22, 2, 3, 6, 1, 0, 8, 4, 9, 15, 14, 7, 5, 16, 12, 10, 20, 21, 11, 19, 13, 18, 17]
# ['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_RGX_NR_all.csv
# NF_RAX_AmericanIndian_AlaskaNative_all.csv
# NF_RCX_Black_AfricanAmerican_all.csv
# Importing  ../DATA/SOC_all.csv
# NF_RIX_Hispanic_all.csv
# Importing  ../DATA/NF_RCX_Black_AfricanAmerican_all.csv
# NF_RHX_Multi_all.csv
# NF_REX_Hawaiian_all.csv
# NF_RFX_White_all.csv
# Importing  ../DATA/NF_RIX_Hispanic_all.csv
# NF_RBX_Asian_all.csv
# Importing  ../DATA/NF_RFX_White_all.csv
# NF_RDX_Hispanic_all.csv
# Importing  ../DATA/NF_RBX_Asian_all.csv
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# NF_RCX_Black_AfricanAmerican
# 00 NF_RCX_Black_AfricanAmerican
# 11 NF_RCX_Black_AfricanAmerican
# 13 NF_RCX_Black_AfricanAmerican
# 15 NF_RCX_Black_AfricanAmerican
# 17 NF_RCX_Black_AfricanAmerican
# 19 NF_RCX_Black_AfricanAmerican
# 21 NF_RCX_Black_AfricanAmerican
# 23 NF_RCX_Black_AfricanAmerican
# 25 NF_RCX_Black_AfricanAmerican
# 27 NF_RCX_Black_AfricanAmerican
# 29 NF_RCX_Black_AfricanAmerican
# 31 NF_RCX_Black_AfricanAmerican
# 33 NF_RCX_Black_AfricanAmerican
# 35 NF_RCX_Black_AfricanAmerican
# 37 NF_RCX_Black_AfricanAmerican
# 39 NF_RCX_Black_AfricanAmerican
# 41 NF_RCX_Black_AfricanAmerican
# 43 NF_RCX_Black_AfricanAmerican
# 45 NF_RCX_Black_AfricanAmerican
# 47 NF_RCX_Black_AfricanAmerican
# 49 NF_RCX_Black_AfricanAmerican
# 51 NF_RCX_Black_AfricanAmerican
# 53 NF_RCX_Black_AfricanAmerican
# 55 NF_RCX_Black_AfricanAmerican
# Suggested swivel order
# [22, 2, 3, 1, 6, 4, 0, 15, 16, 8, 7, 14, 5, 9, 12, 18, 17, 11, 20, 13, 19, 21, 10]
# NF_RIX_Hispanic
# 00 NF_RIX_Hispanic
# 11 NF_RIX_Hispanic
# 13 NF_RIX_Hispanic
# 15 NF_RIX_Hispanic
# 17 NF_RIX_Hispanic
# 19 NF_RIX_Hispanic
# 21 NF_RIX_Hispanic
# 23 NF_RIX_Hispanic
# 25 NF_RIX_Hispanic
# 27 NF_RIX_Hispanic
# 29 NF_RIX_Hispanic
# 31 NF_RIX_Hispanic
# 33 NF_RIX_Hispanic
# 35 NF_RIX_Hispanic
# 37 NF_RIX_Hispanic
# 39 NF_RIX_Hispanic
# 41 NF_RIX_Hispanic
# 43 NF_RIX_Hispanic
# 45 NF_RIX_Hispanic
# 47 NF_RIX_Hispanic
# 49 NF_RIX_Hispanic
# 51 NF_RIX_Hispanic
# 53 NF_RIX_Hispanic
# 55 NF_RIX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [0, 1, 2, 3, 4, 5, 6, 8, 12, 14, 15, 17, 22, 16, 9, 20, 7, 19, 10, 21, 11, 13, 18]
# NF_RFX_White
# 00 NF_RFX_White
# 11 NF_RFX_White
# 13 NF_RFX_White
# 15 NF_RFX_White
# 17 NF_RFX_White
# 19 NF_RFX_White
# 21 NF_RFX_White
# 23 NF_RFX_White
# 25 NF_RFX_White
# 27 NF_RFX_White
# 29 NF_RFX_White
# 31 NF_RFX_White
# 33 NF_RFX_White
# 35 NF_RFX_White
# 37 NF_RFX_White
# 39 NF_RFX_White
# 41 NF_RFX_White
# 43 NF_RFX_White
# 45 NF_RFX_White
# 47 NF_RFX_White
# 49 NF_RFX_White
# 51 NF_RFX_White
# 53 NF_RFX_White
# 55 NF_RFX_White
# Suggested swivel order
# [22, 2, 6, 1, 4, 0, 8, 3, 15, 16, 7, 5, 17, 14, 9, 12, 13, 18, 20, 10, 21, 19, 11]
# NF_RBX_Asian
# 00 NF_RBX_Asian
# 11 NF_RBX_Asian
# 13 NF_RBX_Asian
# 15 NF_RBX_Asian
# 17 NF_RBX_Asian
# 19 NF_RBX_Asian
# 21 NF_RBX_Asian
# 23 NF_RBX_Asian
# 25 NF_RBX_Asian
# 27 NF_RBX_Asian
# 29 NF_RBX_Asian
# 31 NF_RBX_Asian
# 33 NF_RBX_Asian
# 35 NF_RBX_Asian
# 37 NF_RBX_Asian
# 39 NF_RBX_Asian
# 41 NF_RBX_Asian
# 43 NF_RBX_Asian
# 45 NF_RBX_Asian
# 47 NF_RBX_Asian
# 49 NF_RBX_Asian
# 51 NF_RBX_Asian
# 53 NF_RBX_Asian
# 55 NF_RBX_Asian
# Suggested swivel order
# [6, 22, 2, 1, 4, 8, 3, 5, 7, 14, 0, 16, 15, 9, 17, 11, 19, 12, 21, 20, 10, 18, 13]
# NF_RDX_Hispanic
# 00 NF_RDX_Hispanic
# 11 NF_RDX_Hispanic
# 13 NF_RDX_Hispanic
# 15 NF_RDX_Hispanic
# 17 NF_RDX_Hispanic
# 19 NF_RDX_Hispanic
# 21 NF_RDX_Hispanic
# 23 NF_RDX_Hispanic
# 25 NF_RDX_Hispanic
# 27 NF_RDX_Hispanic
# 29 NF_RDX_Hispanic
# 31 NF_RDX_Hispanic
# 33 NF_RDX_Hispanic
# 35 NF_RDX_Hispanic
# 37 NF_RDX_Hispanic
# 39 NF_RDX_Hispanic
# 41 NF_RDX_Hispanic
# 43 NF_RDX_Hispanic
# 45 NF_RDX_Hispanic
# 47 NF_RDX_Hispanic
# 49 NF_RDX_Hispanic
# 51 NF_RDX_Hispanic
# 53 NF_RDX_Hispanic
# 55 NF_RDX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [22, 2, 3, 4, 1, 6, 8, 0, 9, 14, 15, 7, 16, 5, 10, 12, 20, 11, 21, 19, 13, 18, 17]
# ['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_RGX_NR_all.csv
# NF_RAX_AmericanIndian_AlaskaNative_all.csv
# NF_RCX_Black_AfricanAmerican_all.csv
# Importing  ../DATA/SOC_all.csv
# NF_RIX_Hispanic_all.csv
# Importing  ../DATA/NF_RCX_Black_AfricanAmerican_all.csv
# NF_RHX_Multi_all.csv
# NF_REX_Hawaiian_all.csv
# NF_RFX_White_all.csv
# Importing  ../DATA/NF_RIX_Hispanic_all.csv
# NF_RBX_Asian_all.csv
# Importing  ../DATA/NF_RFX_White_all.csv
# NF_RDX_Hispanic_all.csv
# Importing  ../DATA/NF_RBX_Asian_all.csv
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# NF_RCX_Black_AfricanAmerican
# 00 NF_RCX_Black_AfricanAmerican
# 11 NF_RCX_Black_AfricanAmerican
# 13 NF_RCX_Black_AfricanAmerican
# 15 NF_RCX_Black_AfricanAmerican
# 17 NF_RCX_Black_AfricanAmerican
# 19 NF_RCX_Black_AfricanAmerican
# 21 NF_RCX_Black_AfricanAmerican
# 23 NF_RCX_Black_AfricanAmerican
# 25 NF_RCX_Black_AfricanAmerican
# 27 NF_RCX_Black_AfricanAmerican
# 29 NF_RCX_Black_AfricanAmerican
# 31 NF_RCX_Black_AfricanAmerican
# 33 NF_RCX_Black_AfricanAmerican
# 35 NF_RCX_Black_AfricanAmerican
# 37 NF_RCX_Black_AfricanAmerican
# 39 NF_RCX_Black_AfricanAmerican
# 41 NF_RCX_Black_AfricanAmerican
# 43 NF_RCX_Black_AfricanAmerican
# 45 NF_RCX_Black_AfricanAmerican
# 47 NF_RCX_Black_AfricanAmerican
# 49 NF_RCX_Black_AfricanAmerican
# 51 NF_RCX_Black_AfricanAmerican
# 53 NF_RCX_Black_AfricanAmerican
# 55 NF_RCX_Black_AfricanAmerican
# Suggested swivel order
# [22, 2, 6, 3, 4, 1, 0, 15, 16, 8, 7, 9, 12, 17, 14, 5, 20, 19, 18, 13, 11, 21, 10]
# NF_RIX_Hispanic
# 00 NF_RIX_Hispanic
# 11 NF_RIX_Hispanic
# 13 NF_RIX_Hispanic
# 15 NF_RIX_Hispanic
# 17 NF_RIX_Hispanic
# 19 NF_RIX_Hispanic
# 21 NF_RIX_Hispanic
# 23 NF_RIX_Hispanic
# 25 NF_RIX_Hispanic
# 27 NF_RIX_Hispanic
# 29 NF_RIX_Hispanic
# 31 NF_RIX_Hispanic
# 33 NF_RIX_Hispanic
# 35 NF_RIX_Hispanic
# 37 NF_RIX_Hispanic
# 39 NF_RIX_Hispanic
# 41 NF_RIX_Hispanic
# 43 NF_RIX_Hispanic
# 45 NF_RIX_Hispanic
# 47 NF_RIX_Hispanic
# 49 NF_RIX_Hispanic
# 51 NF_RIX_Hispanic
# 53 NF_RIX_Hispanic
# 55 NF_RIX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [0, 1, 2, 3, 4, 6, 7, 8, 17, 22, 14, 16, 9, 15, 20, 12, 10, 5, 21, 11, 13, 18, 19]
# NF_RFX_White
# 00 NF_RFX_White
# 11 NF_RFX_White
# 13 NF_RFX_White
# 15 NF_RFX_White
# 17 NF_RFX_White
# 19 NF_RFX_White
# 21 NF_RFX_White
# 23 NF_RFX_White
# 25 NF_RFX_White
# 27 NF_RFX_White
# 29 NF_RFX_White
# 31 NF_RFX_White
# 33 NF_RFX_White
# 35 NF_RFX_White
# 37 NF_RFX_White
# 39 NF_RFX_White
# 41 NF_RFX_White
# 43 NF_RFX_White
# 45 NF_RFX_White
# 47 NF_RFX_White
# 49 NF_RFX_White
# 51 NF_RFX_White
# 53 NF_RFX_White
# 55 NF_RFX_White
# Suggested swivel order
# [22, 2, 1, 3, 6, 0, 8, 4, 15, 16, 5, 7, 14, 17, 9, 12, 13, 18, 20, 10, 21, 19, 11]
# NF_RBX_Asian
# 00 NF_RBX_Asian
# 11 NF_RBX_Asian
# 13 NF_RBX_Asian
# 15 NF_RBX_Asian
# 17 NF_RBX_Asian
# 19 NF_RBX_Asian
# 21 NF_RBX_Asian
# 23 NF_RBX_Asian
# 25 NF_RBX_Asian
# 27 NF_RBX_Asian
# 29 NF_RBX_Asian
# 31 NF_RBX_Asian
# 33 NF_RBX_Asian
# 35 NF_RBX_Asian
# 37 NF_RBX_Asian
# 39 NF_RBX_Asian
# 41 NF_RBX_Asian
# 43 NF_RBX_Asian
# 45 NF_RBX_Asian
# 47 NF_RBX_Asian
# 49 NF_RBX_Asian
# 51 NF_RBX_Asian
# 53 NF_RBX_Asian
# 55 NF_RBX_Asian
# Suggested swivel order
# [22, 2, 0, 6, 1, 3, 4, 8, 14, 15, 16, 5, 7, 17, 9, 18, 12, 21, 20, 19, 10, 11, 13]
# NF_RDX_Hispanic
# 00 NF_RDX_Hispanic
# 11 NF_RDX_Hispanic
# 13 NF_RDX_Hispanic
# 15 NF_RDX_Hispanic
# 17 NF_RDX_Hispanic
# 19 NF_RDX_Hispanic
# 21 NF_RDX_Hispanic
# 23 NF_RDX_Hispanic
# 25 NF_RDX_Hispanic
# 27 NF_RDX_Hispanic
# 29 NF_RDX_Hispanic
# 31 NF_RDX_Hispanic
# 33 NF_RDX_Hispanic
# 35 NF_RDX_Hispanic
# 37 NF_RDX_Hispanic
# 39 NF_RDX_Hispanic
# 41 NF_RDX_Hispanic
# 43 NF_RDX_Hispanic
# 45 NF_RDX_Hispanic
# 47 NF_RDX_Hispanic
# 49 NF_RDX_Hispanic
# 51 NF_RDX_Hispanic
# 53 NF_RDX_Hispanic
# 55 NF_RDX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [22, 2, 4, 1, 3, 0, 6, 9, 8, 15, 14, 7, 5, 16, 10, 12, 20, 21, 19, 11, 13, 18, 17]
# ['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_RGX_NR_all.csv
# NF_RAX_AmericanIndian_AlaskaNative_all.csv
# NF_RCX_Black_AfricanAmerican_all.csv
# Importing  ../DATA/SOC_all.csv
# NF_RIX_Hispanic_all.csv
# Importing  ../DATA/NF_RCX_Black_AfricanAmerican_all.csv
# NF_RHX_Multi_all.csv
# NF_REX_Hawaiian_all.csv
# NF_RFX_White_all.csv
# Importing  ../DATA/NF_RIX_Hispanic_all.csv
# NF_RBX_Asian_all.csv
# Importing  ../DATA/NF_RFX_White_all.csv
# NF_RDX_Hispanic_all.csv
# Importing  ../DATA/NF_RBX_Asian_all.csv
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# NF_RCX_Black_AfricanAmerican
# 00 NF_RCX_Black_AfricanAmerican
# 11 NF_RCX_Black_AfricanAmerican
# 13 NF_RCX_Black_AfricanAmerican
# 15 NF_RCX_Black_AfricanAmerican
# 17 NF_RCX_Black_AfricanAmerican
# 19 NF_RCX_Black_AfricanAmerican
# 21 NF_RCX_Black_AfricanAmerican
# 23 NF_RCX_Black_AfricanAmerican
# 25 NF_RCX_Black_AfricanAmerican
# 27 NF_RCX_Black_AfricanAmerican
# 29 NF_RCX_Black_AfricanAmerican
# 31 NF_RCX_Black_AfricanAmerican
# 33 NF_RCX_Black_AfricanAmerican
# 35 NF_RCX_Black_AfricanAmerican
# 37 NF_RCX_Black_AfricanAmerican
# 39 NF_RCX_Black_AfricanAmerican
# 41 NF_RCX_Black_AfricanAmerican
# 43 NF_RCX_Black_AfricanAmerican
# 45 NF_RCX_Black_AfricanAmerican
# 47 NF_RCX_Black_AfricanAmerican
# 49 NF_RCX_Black_AfricanAmerican
# 51 NF_RCX_Black_AfricanAmerican
# 53 NF_RCX_Black_AfricanAmerican
# 55 NF_RCX_Black_AfricanAmerican
# Suggested swivel order
# [22, 2, 3, 6, 4, 1, 8, 15, 0, 7, 16, 9, 5, 12, 14, 18, 17, 20, 13, 21, 11, 19, 10]
# NF_RIX_Hispanic
# 00 NF_RIX_Hispanic
# 11 NF_RIX_Hispanic
# 13 NF_RIX_Hispanic
# 15 NF_RIX_Hispanic
# 17 NF_RIX_Hispanic
# 19 NF_RIX_Hispanic
# 21 NF_RIX_Hispanic
# 23 NF_RIX_Hispanic
# 25 NF_RIX_Hispanic
# 27 NF_RIX_Hispanic
# 29 NF_RIX_Hispanic
# 31 NF_RIX_Hispanic
# 33 NF_RIX_Hispanic
# 35 NF_RIX_Hispanic
# 37 NF_RIX_Hispanic
# 39 NF_RIX_Hispanic
# 41 NF_RIX_Hispanic
# 43 NF_RIX_Hispanic
# 45 NF_RIX_Hispanic
# 47 NF_RIX_Hispanic
# 49 NF_RIX_Hispanic
# 51 NF_RIX_Hispanic
# 53 NF_RIX_Hispanic
# 55 NF_RIX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [0, 1, 2, 3, 4, 5, 6, 8, 9, 11, 22, 16, 15, 7, 10, 20, 14, 12, 13, 18, 21, 19, 17]
# NF_RFX_White
# 00 NF_RFX_White
# 11 NF_RFX_White
# 13 NF_RFX_White
# 15 NF_RFX_White
# 17 NF_RFX_White
# 19 NF_RFX_White
# 21 NF_RFX_White
# 23 NF_RFX_White
# 25 NF_RFX_White
# 27 NF_RFX_White
# 29 NF_RFX_White
# 31 NF_RFX_White
# 33 NF_RFX_White
# 35 NF_RFX_White
# 37 NF_RFX_White
# 39 NF_RFX_White
# 41 NF_RFX_White
# 43 NF_RFX_White
# 45 NF_RFX_White
# 47 NF_RFX_White
# 49 NF_RFX_White
# 51 NF_RFX_White
# 53 NF_RFX_White
# 55 NF_RFX_White
# Suggested swivel order
# [22, 2, 6, 1, 3, 4, 8, 0, 15, 16, 7, 5, 14, 17, 9, 12, 13, 18, 20, 10, 21, 19, 11]
# NF_RBX_Asian
# 00 NF_RBX_Asian
# 11 NF_RBX_Asian
# 13 NF_RBX_Asian
# 15 NF_RBX_Asian
# 17 NF_RBX_Asian
# 19 NF_RBX_Asian
# 21 NF_RBX_Asian
# 23 NF_RBX_Asian
# 25 NF_RBX_Asian
# 27 NF_RBX_Asian
# 29 NF_RBX_Asian
# 31 NF_RBX_Asian
# 33 NF_RBX_Asian
# 35 NF_RBX_Asian
# 37 NF_RBX_Asian
# 39 NF_RBX_Asian
# 41 NF_RBX_Asian
# 43 NF_RBX_Asian
# 45 NF_RBX_Asian
# 47 NF_RBX_Asian
# 49 NF_RBX_Asian
# 51 NF_RBX_Asian
# 53 NF_RBX_Asian
# 55 NF_RBX_Asian
# Suggested swivel order
# [22, 3, 2, 0, 1, 8, 4, 7, 14, 5, 16, 15, 9, 17, 18, 6, 11, 12, 20, 21, 19, 10, 13]
# NF_RDX_Hispanic
# 00 NF_RDX_Hispanic
# 11 NF_RDX_Hispanic
# 13 NF_RDX_Hispanic
# 15 NF_RDX_Hispanic
# 17 NF_RDX_Hispanic
# 19 NF_RDX_Hispanic
# 21 NF_RDX_Hispanic
# 23 NF_RDX_Hispanic
# 25 NF_RDX_Hispanic
# 27 NF_RDX_Hispanic
# 29 NF_RDX_Hispanic
# 31 NF_RDX_Hispanic
# 33 NF_RDX_Hispanic
# 35 NF_RDX_Hispanic
# 37 NF_RDX_Hispanic
# 39 NF_RDX_Hispanic
# 41 NF_RDX_Hispanic
# 43 NF_RDX_Hispanic
# 45 NF_RDX_Hispanic
# 47 NF_RDX_Hispanic
# 49 NF_RDX_Hispanic
# 51 NF_RDX_Hispanic
# 53 NF_RDX_Hispanic
# 55 NF_RDX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [22, 2, 3, 1, 6, 4, 0, 8, 14, 9, 15, 7, 5, 16, 10, 12, 20, 21, 19, 11, 13, 18, 17]
# ['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic']
# SOC_all.csv
# global_y_soc1 found.
# global_soc1_empty found.
# NF_RGX_NR_all.csv
# NF_RAX_AmericanIndian_AlaskaNative_all.csv
# NF_RCX_Black_AfricanAmerican_all.csv
# Importing  ../DATA/SOC_all.csv
# NF_RIX_Hispanic_all.csv
# Importing  ../DATA/NF_RCX_Black_AfricanAmerican_all.csv
# NF_RHX_Multi_all.csv
# NF_REX_Hawaiian_all.csv
# NF_RFX_White_all.csv
# Importing  ../DATA/NF_RIX_Hispanic_all.csv
# NF_RBX_Asian_all.csv
# Importing  ../DATA/NF_RFX_White_all.csv
# NF_RDX_Hispanic_all.csv
# Importing  ../DATA/NF_RBX_Asian_all.csv
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# dict_keys(['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic'])
# NF_RCX_Black_AfricanAmerican
# 00 NF_RCX_Black_AfricanAmerican
# 11 NF_RCX_Black_AfricanAmerican
# 13 NF_RCX_Black_AfricanAmerican
# 15 NF_RCX_Black_AfricanAmerican
# 17 NF_RCX_Black_AfricanAmerican
# 19 NF_RCX_Black_AfricanAmerican
# 21 NF_RCX_Black_AfricanAmerican
# 23 NF_RCX_Black_AfricanAmerican
# 25 NF_RCX_Black_AfricanAmerican
# 27 NF_RCX_Black_AfricanAmerican
# 29 NF_RCX_Black_AfricanAmerican
# 31 NF_RCX_Black_AfricanAmerican
# 33 NF_RCX_Black_AfricanAmerican
# 35 NF_RCX_Black_AfricanAmerican
# 37 NF_RCX_Black_AfricanAmerican
# 39 NF_RCX_Black_AfricanAmerican
# 41 NF_RCX_Black_AfricanAmerican
# 43 NF_RCX_Black_AfricanAmerican
# 45 NF_RCX_Black_AfricanAmerican
# 47 NF_RCX_Black_AfricanAmerican
# 49 NF_RCX_Black_AfricanAmerican
# 51 NF_RCX_Black_AfricanAmerican
# 53 NF_RCX_Black_AfricanAmerican
# 55 NF_RCX_Black_AfricanAmerican
# Suggested swivel order
# [22, 2, 6, 1, 8, 4, 0, 3, 15, 16, 7, 9, 12, 14, 5, 17, 20, 18, 13, 11, 19, 21, 10]
# NF_RIX_Hispanic
# 00 NF_RIX_Hispanic
# 11 NF_RIX_Hispanic
# 13 NF_RIX_Hispanic
# 15 NF_RIX_Hispanic
# 17 NF_RIX_Hispanic
# 19 NF_RIX_Hispanic
# 21 NF_RIX_Hispanic
# 23 NF_RIX_Hispanic
# 25 NF_RIX_Hispanic
# 27 NF_RIX_Hispanic
# 29 NF_RIX_Hispanic
# 31 NF_RIX_Hispanic
# 33 NF_RIX_Hispanic
# 35 NF_RIX_Hispanic
# 37 NF_RIX_Hispanic
# 39 NF_RIX_Hispanic
# 41 NF_RIX_Hispanic
# 43 NF_RIX_Hispanic
# 45 NF_RIX_Hispanic
# 47 NF_RIX_Hispanic
# 49 NF_RIX_Hispanic
# 51 NF_RIX_Hispanic
# 53 NF_RIX_Hispanic
# 55 NF_RIX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [1, 2, 3, 4, 5, 6, 8, 14, 17, 22, 9, 12, 7, 0, 10, 13, 16, 20, 15, 11, 19, 21, 18]
# NF_RFX_White
# 00 NF_RFX_White
# 11 NF_RFX_White
# 13 NF_RFX_White
# 15 NF_RFX_White
# 17 NF_RFX_White
# 19 NF_RFX_White
# 21 NF_RFX_White
# 23 NF_RFX_White
# 25 NF_RFX_White
# 27 NF_RFX_White
# 29 NF_RFX_White
# 31 NF_RFX_White
# 33 NF_RFX_White
# 35 NF_RFX_White
# 37 NF_RFX_White
# 39 NF_RFX_White
# 41 NF_RFX_White
# 43 NF_RFX_White
# 45 NF_RFX_White
# 47 NF_RFX_White
# 49 NF_RFX_White
# 51 NF_RFX_White
# 53 NF_RFX_White
# 55 NF_RFX_White
# Suggested swivel order
# [22, 2, 6, 1, 3, 4, 0, 8, 15, 16, 5, 7, 14, 9, 17, 12, 13, 18, 20, 10, 21, 19, 11]
# NF_RBX_Asian
# 00 NF_RBX_Asian
# 11 NF_RBX_Asian
# 13 NF_RBX_Asian
# 15 NF_RBX_Asian
# 17 NF_RBX_Asian
# 19 NF_RBX_Asian
# 21 NF_RBX_Asian
# 23 NF_RBX_Asian
# 25 NF_RBX_Asian
# 27 NF_RBX_Asian
# 29 NF_RBX_Asian
# 31 NF_RBX_Asian
# 33 NF_RBX_Asian
# 35 NF_RBX_Asian
# 37 NF_RBX_Asian
# 39 NF_RBX_Asian
# 41 NF_RBX_Asian
# 43 NF_RBX_Asian
# 45 NF_RBX_Asian
# 47 NF_RBX_Asian
# 49 NF_RBX_Asian
# 51 NF_RBX_Asian
# 53 NF_RBX_Asian
# 55 NF_RBX_Asian
# Suggested swivel order
# [6, 22, 2, 3, 1, 4, 14, 8, 5, 15, 0, 16, 7, 9, 18, 17, 12, 19, 21, 20, 10, 11, 13]
# NF_RDX_Hispanic
# 00 NF_RDX_Hispanic
# 11 NF_RDX_Hispanic
# 13 NF_RDX_Hispanic
# 15 NF_RDX_Hispanic
# 17 NF_RDX_Hispanic
# 19 NF_RDX_Hispanic
# 21 NF_RDX_Hispanic
# 23 NF_RDX_Hispanic
# 25 NF_RDX_Hispanic
# 27 NF_RDX_Hispanic
# 29 NF_RDX_Hispanic
# 31 NF_RDX_Hispanic
# 33 NF_RDX_Hispanic
# 35 NF_RDX_Hispanic
# 37 NF_RDX_Hispanic
# 39 NF_RDX_Hispanic
# 41 NF_RDX_Hispanic
# 43 NF_RDX_Hispanic
# 45 NF_RDX_Hispanic
# 47 NF_RDX_Hispanic
# 49 NF_RDX_Hispanic
# 51 NF_RDX_Hispanic
# 53 NF_RDX_Hispanic
# 55 NF_RDX_Hispanic
# Normalizing Hispanic
# Suggested swivel order
# [22, 2, 6, 3, 4, 1, 8, 0, 9, 15, 14, 7, 16, 5, 10, 12, 20, 21, 11, 19, 13, 18, 17]
# ['NF_RCX_Black_AfricanAmerican', 'NF_RIX_Hispanic', 'NF_RFX_White', 'NF_RBX_Asian', 'NF_RDX_Hispanic']

# %% [markdown]
# # Age boxblots

# %%
#print(rh_global_y_soc1)

# %%
for index in range(0,4): 
    # Creating pandas |dataframe from numpy array
    #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })

    pd_df = pd.DataFrame()
    sel_y = []

    if (index == 0):
        name = "White"
        sel_y = rw_global_y_soc1
    elif (index == 1):
        name = "Black"
        sel_y = rb_global_y_soc1
    elif (index == 2):
        name = "Asian"
        sel_y = ra_global_y_soc1
    elif (index == 3):
        name = "Hispanic"
        sel_y = rh2_global_y_soc1

    #print(sel_y)
        
    for index in range(0,len(sel_y)):
        pd_df[sel_y[index][0]] = sel_y[index][1]

    #print(pd_df)
    
    title = desired_file_prefix + " AGE boxplots " + str(name)
    plt.figure(title,figsize=(10, 10))
    plt.title(title)

    #plt.ylim(0.0, 0.15)

    pd_df.boxplot()
    plt.xticks(rotation = 90)
    plt.tight_layout()

    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    
    plt.show()

    #plt.close()

# %% [markdown]
# # SOC GENDER BOXPLOTS

# %%
flist = [
    ["NF_RWT White", nf_rw_global_y_soc1],
    ["NF_RBT Black", nf_rb_global_y_soc1],
    ["NF_RAT Asian", nf_ra_global_y_soc1],
    ["NF_RDX Hispanic", nf_rh2_global_y_soc1] ]

nflist = [
    ["NF_RWT White", nf_rw_global_y_soc1],
    ["NF_RWT White", nf_rw_global_y_soc1],
    ["NF_RWT White", nf_rw_global_y_soc1],
    ["NF_RWT White", nf_rw_global_y_soc1] ]

for index in range(0,4):

    #print(index)
    
    use_case1 = flist[index][0]
    data1     = flist[index][1]
    
    use_case2 = nflist[index][0]
    data2     = nflist[index][1]
    
    soc_box1 = []
    soc_box2 = []
    
    #print(data1[0][1])
    #print(data1[0][1][0])
    
    for soc_index in range (0,23):
        tmp1 = []
        tmp2 = []
        for y_index in range(0,8):
            #print(soc_index)
            dat1 = data1[y_index][1][soc_index]
            tmp1.append(dat1)      
            dat2 = data2[y_index][1][soc_index]
            tmp2.append(dat2)
         
        soc_box1.append(tmp1)
        soc_box2.append(tmp2)
                       
    #print(soc_box)

    # BOX PLOT per occupation
    jlist = []
    for jb in range(1,24):
       jlist.append(job_code[jb][1])
    #print(jlist)

    #print(jlist[22])

    # Creating pandas |dataframe from numpy array
    #pd_data_df = pd.DataFrame({ global_y_soc1[0][0] : global_y_soc1[0][1] })
    pd_df1 = pd.DataFrame(columns=jlist)
    pd_df2 = pd.DataFrame(columns=jlist)

    #global_y_soc1 = female_global_y_soc1

    for index in range(0,23):
        pd_df1[jlist[index]] = soc_box1[index]
        pd_df2[jlist[index]] = soc_box2[index]
        #pd_df1[index] = soc_box1[index]
        #pd_df2[index] = soc_box2[index]
                       
    # Creating plot with dataset_1
    fig, ax1 = plt.subplots()

    title = use_case1 + " SOC boxplots " + use_case2
    #plt.figure(title,figsize=(20, 20))
    
    plt.title(title)

    boxprops = dict(color="red",linewidth=1.5)
    medianprops = dict(color="red",linewidth=1.5)
    
    ax1.tick_params(axis='y', colors='red')
    
    ax1.set_ylim([0, 0.02])
    
    pd_df1.boxplot(ax=ax1, rot=90, boxprops=boxprops,medianprops=medianprops)
    #ax1.xticks(rotation = 90)
    #ax1.tight_layout()
    
    ax2 = ax1.twinx()
    
    boxprops = dict(color="green", linewidth=1.5)
    medianprops = dict(color="green",linewidth=1.5)
     
    ax2.tick_params(axis='y', colors='green')
    
    ax2.set_ylim([0, 0.02])

    pd_df2.boxplot(ax=ax2, rot=90, boxprops=boxprops,medianprops=medianprops, grid=False)
    
    save_title = "../PLOTS/" + desired_file_output + title + ".png"
    save_title = save_title.replace(",","")
    save_title = save_title.replace(" ","_")
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
    plt.savefig(save_title, dpi=100, bbox_inches='tight')
